# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import tensorflow as tf
from kaggle_datasets import KaggleDatasets
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import re
import glob
import random
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import auc, roc_curve

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# 2023-01-21 17:15:13.089501: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib
# 2023-01-21 17:15:13.089635: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Device:', tpu.master())
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
except:
    strategy = tf.distribute.get_strategy()
print('Number of replicas:', strategy.num_replicas_in_sync)

print(tf.__version__)
# Out:
# Device: grpc://10.0.0.2:8470
# 2023-01-21 17:15:19.004653: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-01-21 17:15:19.007739: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib
# 2023-01-21 17:15:19.007773: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-01-21 17:15:19.007802: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (e71408eaa647): /proc/driver/nvidia/version does not exist
# 2023-01-21 17:15:19.011206: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-21 17:15:19.012918: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-01-21 17:15:19.019210: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-01-21 17:15:19.047983: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job worker -> {0 -> 10.0.0.2:8470}
# 2023-01-21 17:15:19.048035: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job localhost -> {0 -> localhost:30019}
# 2023-01-21 17:15:19.069162: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job worker -> {0 -> 10.0.0.2:8470}
# 2023-01-21 17:15:19.069215: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job localhost -> {0 -> localhost:30019}
# 2023-01-21 17:15:19.070812: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:411] Started server with target: grpc://localhost:30019
# Number of replicas: 8
# 2.4.1

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
GCS_PATH = KaggleDatasets().get_gcs_path()
BATCH_SIZE = 64*strategy.num_replicas_in_sync
#BATCH_SIZE = 64 # for non-TPU use
IMAGE_SIZE = [180, 180]
EPOCHS = 50

# %%
filenames = tf.io.gfile.glob(str(GCS_PATH + '/chest_xray/train/*/*'))
filenames.extend(tf.io.gfile.glob(str(GCS_PATH + '/chest_xray/val/*/*')))
filenames.extend(tf.io.gfile.glob(str(GCS_PATH + '/chest_xray/test/*/*')))

print(f'The total number of files is {len(filenames)}')
# Out:
# 2023-01-21 17:15:24.524679: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-21 17:15:24.721448: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-21 17:15:24.907033: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-21 17:15:25.010477: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-21 17:15:25.125436: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-21 17:15:25.230536: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-21 17:15:25.321586: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# The total number of files is 5856
# 2023-01-21 17:15:25.387609: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.

# %%
# split the data into 60:40 for train:test+val
train_files, val_test_files = train_test_split(filenames, test_size=0.4,random_state=18)

# %%
# split the val_test_files to 50:50 to have a final split of 60:20:20 of train:val:test
val_files, test_files = train_test_split(val_test_files, test_size=0.5, random_state=18)

# %%
pct_df = pd.DataFrame(columns = ['data_set', 'label', 'pct'], index = range(6))

totals = {'train':len(train_files), 'val':len(val_files), 'test':len(test_files)}

val_pneum_count = 0
val_norm_count = 0

re_pattern = '.*/(NORMAL|PNEUMONIA)/.*'

for file in val_files:
    re_match = re.match(re_pattern, file)
    if re_match[1] == 'NORMAL':
        val_norm_count += 1
    else:
        val_pneum_count += 1

pct_df.iloc[0, :] = ['val', 'NORMAL', round(100* val_norm_count / totals['val'], 1)]
pct_df.iloc[1, :] = ['val', 'PNEUMONIA', round(100* val_pneum_count / totals['val'], 1)]


test_pneum_count = 0
test_norm_count = 0
for file in test_files:
    re_match = re.match(re_pattern, file)
    if re_match[1] == 'NORMAL':
        test_norm_count += 1
    else:
        test_pneum_count += 1

pct_df.iloc[2, :] = ['test', 'NORMAL', round(100* test_norm_count / totals['test'], 1)]
pct_df.iloc[3, :] = ['test', 'PNEUMONIA', round(100* test_pneum_count / totals['test'], 1)]

train_pneum_count = 0
train_norm_count = 0
for file in train_files:
    re_match = re.match(re_pattern, file)
    if re_match[1] == 'NORMAL':
        train_norm_count += 1
    else:
        train_pneum_count += 1

pct_df.iloc[4, :] = ['train', 'NORMAL', round(100* train_norm_count / totals['train'], 1)]
pct_df.iloc[5, :] = ['train', 'PNEUMONIA', round(100* train_pneum_count / totals['train'], 1)]

# %%
PNEUM_COUNT = val_pneum_count + train_pneum_count + test_pneum_count
NORMAL_COUNT = val_norm_count + train_norm_count + test_norm_count
print(f'Normal: {NORMAL_COUNT}\nPneumonia: {PNEUM_COUNT}')

pct_df
# Out:
# Normal: 1583
# Pneumonia: 4273
#   data_set      label   pct
# 0      val     NORMAL  26.9
# 1      val  PNEUMONIA  73.1
# 2     test     NORMAL  27.6
# 3     test  PNEUMONIA  72.4
# 4    train     NORMAL  26.9
# 5    train  PNEUMONIA  73.1

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_files)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_files)
test_list_ds = tf.data.Dataset.from_tensor_slices(test_files)

#view the file paths for training
print('----Training Files----')
for f in train_list_ds.take(5):
    print(f.numpy())
# Out:
# ----Training Files----
# b'gs://kds-f4cd5298952c835b370b10b65341d209198e57d812057e8ad9550752/chest_xray/train/PNEUMONIA/person509_virus_1025.jpeg'
# b'gs://kds-f4cd5298952c835b370b10b65341d209198e57d812057e8ad9550752/chest_xray/train/PNEUMONIA/person671_bacteria_2564.jpeg'
# b'gs://kds-f4cd5298952c835b370b10b65341d209198e57d812057e8ad9550752/chest_xray/train/PNEUMONIA/person957_virus_1629.jpeg'
# b'gs://kds-f4cd5298952c835b370b10b65341d209198e57d812057e8ad9550752/chest_xray/test/PNEUMONIA/person81_bacteria_397.jpeg'
# b'gs://kds-f4cd5298952c835b370b10b65341d209198e57d812057e8ad9550752/chest_xray/train/NORMAL/IM-0500-0001.jpeg'

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
TEST_IMG_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()

print(f'Train Image Count: {TRAIN_IMG_COUNT}\nVal Image Count: {VAL_IMG_COUNT}\nTest Image Count: {TEST_IMG_COUNT}')
# Out:
# Train Image Count: 3513
# Val Image Count: 1171
# Test Image Count: 1172
# 2023-01-21 17:15:25.843458: W ./tensorflow/core/distributed_runtime/eager/destroy_tensor_handle_node.h:57] Ignoring an error encountered when deleting remote tensors handles: Invalid argument: Unable to find the relevant tensor remote_handle: Op ID: 28, Output num: 0
# Additional GRPC error information from remote target /job:worker/replica:0/task:0:
# :{"created":"@1674321325.840177084","description":"Error received from peer ipv4:10.0.0.2:8470","file":"external/com_github_grpc_grpc/src/core/lib/surface/call.cc","file_line":1056,"grpc_message":"Unable to find the relevant tensor remote_handle: Op ID: 28, Output num: 0","grpc_status":3}

# %%
# will label as 1 if pneumonia otherwise 0
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == 'PNEUMONIA'

def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    return tf.image.resize(img, IMAGE_SIZE)

def process_path(file_path):
    label = get_label(file_path)
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
y_train = []
for image, label in train_ds.take(TRAIN_IMG_COUNT):
    y_train.append(label)
    
print('Training Counts')
print(f'Pneumonia count: {np.sum(y_train)}\nNormal count: {TRAIN_IMG_COUNT - np.sum(y_train)}')
# Out:
# 2023-01-21 17:17:30.600592: W ./tensorflow/core/distributed_runtime/eager/destroy_tensor_handle_node.h:57] Ignoring an error encountered when deleting remote tensors handles: Invalid argument: Unable to find the relevant tensor remote_handle: Op ID: 3562, Output num: 0
# Additional GRPC error information from remote target /job:worker/replica:0/task:0:
# :{"created":"@1674321450.600476376","description":"Error received from peer ipv4:10.0.0.2:8470","file":"external/com_github_grpc_grpc/src/core/lib/surface/call.cc","file_line":1056,"grpc_message":"Unable to find the relevant tensor remote_handle: Op ID: 3562, Output num: 0","grpc_status":3}
# Training Counts
# Pneumonia count: 2568
# Normal count: 945

# %%
y_val = []
for image, label in val_ds.take(VAL_IMG_COUNT):
    y_val.append(label)
    
print('Validation Counts')
print(f'Pneumonia count: {np.sum(y_val)}\nNormal count: {VAL_IMG_COUNT - np.sum(y_val)}')
# Out:
# Validation Counts
# 2023-01-21 17:18:33.248803: W ./tensorflow/core/distributed_runtime/eager/destroy_tensor_handle_node.h:57] Ignoring an error encountered when deleting remote tensors handles: Invalid argument: Unable to find the relevant tensor remote_handle: Op ID: 18796, Output num: 0
# Additional GRPC error information from remote target /job:worker/replica:0/task:0:
# :{"created":"@1674321513.248624434","description":"Error received from peer ipv4:10.0.0.2:8470","file":"external/com_github_grpc_grpc/src/core/lib/surface/call.cc","file_line":1056,"grpc_message":"Unable to find the relevant tensor remote_handle: Op ID: 18796, Output num: 0","grpc_status":3}
# Pneumonia count: 856
# Normal count: 315

# %%
y_test = []
for image, label in test_ds.take(TEST_IMG_COUNT):
    y_test.append(label)
    
print('Test Counts')
print(f'Pneumonia count: {np.sum(y_test)}\nNormal count: {TEST_IMG_COUNT - np.sum(y_test)}')
# Out:
# Test Counts
# Pneumonia count: 849
# Normal count: 323

# %%
def prepare_for_training(ds, cache=True, shuffle_buffer_size=1000):
    
    if cache:
        if isinstance(cache, str):
            ds = ds.cache(cache)
        else:
            ds = ds.cache()
            
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    
    ds = ds.repeat()
    
    ds = ds.batch(BATCH_SIZE)
    
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    
    return ds

# %%
train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %%
weight_for_0 = (1 / NORMAL_COUNT)*(TRAIN_IMG_COUNT)/2.0
weight_for_1 = (1 / PNEUM_COUNT)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}
print(f'Weight for class 0: {weight_for_0:.2f}')
print(f'Weight for class 1: {weight_for_1:.2f}')
# Out:
# Weight for class 0: 1.11
# Weight for class 1: 0.41

# %%
# create some metrics for comparing on test results

def precision(y_test, y_pred):
    tp, fp = 0, 0
    
    for i in range(len(y_test)):
        if y_test[i] >= 0.5 and y_pred[i] >= 0.5:
            tp += 1
        elif y_test[i] < 0.5 and y_pred[i] >= 0.5:
            fp += 1
            
    return tp / (tp + fp)

def recall(y_test, y_pred):
    tp, fn = 0, 0
    
    for i in range(len(y_test)):
        if y_test[i] >= 0.5 and y_pred[i] >= 0.5:
            tp += 1
        elif y_test[i] >= 0.5 and y_pred[i] < 0.5:
            fn += 1
            
    return tp / (tp + fn)

def f1_score(y_test, y_pred):
    numerator = precision(y_test, y_pred) * recall(y_test, y_pred)
    denominator = precision(y_test, y_pred) + recall(y_test, y_pred)
    
    return 2 * (numerator / denominator)

# %% [markdown]
# ## Fine Tune the Model
#
# ### Try different learning rate decays by adjusting the s value

# %%
# add exponential decay to try to improve fine tuning
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 ** (epoch / s)
    return exponential_decay_fn

# %%
# use learning rate that gave best results in the learning rate hyperparameter tuning
learning_rate = 0.010395
# use hidden_units that gave best results in the hidden units hyperparameter tuning
hidden_units = 4096
# use mini batch size that gave best results in the mini batch hyperparameter tuning
mini_batch = 32

# try 8 different decay rates
for _ in range(8):
    
    s = random.randint(10, 80)
    
    BATCH_SIZE = mini_batch*strategy.num_replicas_in_sync
    print(f'\n\nBatch Size: {BATCH_SIZE}')    
    print(f'Hidden Units: {hidden_units}')
    print(f'Learning Rate: {learning_rate}')
    print(f'1 Hidden Layer, {hidden_units} units')
    print(f'S value: {s}')
    
    with strategy.scope():
        
        base_model = tf.keras.applications.densenet.DenseNet201(
                        input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3),
                        include_top=False,
                        weights='imagenet'
                        )
        base_model.trainable = False
        
        
        
        x=base_model.output
        inputs = tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))
        x = base_model(inputs, training=False)
        x = tf.keras.layers.GlobalAveragePooling2D()(x)
        x = tf.keras.layers.Dropout(0.3)(x)
        x = tf.keras.layers.Dense(hidden_units, activation='relu')(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.Dropout(0.3)(x)
            
        outputs = tf.keras.layers.Dense(1, activation='sigmoid')(x)
        model = tf.keras.Model(inputs, outputs)
        
        METRICS = [
                'accuracy',
                tf.keras.metrics.Precision(name='precision'),
                tf.keras.metrics.Recall(name='recall')
                ]
        
        model.compile(
                    optimizer='adam',
                    loss='binary_crossentropy',
                    metrics=METRICS
                     )
    
       
        checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(f"densenet_{learning_rate}_{hidden_units}_{BATCH_SIZE}_1layer_{s}_xray_model.h5", save_best_only=True)
        early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=20, restore_best_weights=True)
        exponential_decay_fn = exponential_decay(learning_rate, s)
        lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)
    
        history = model.fit(
                            train_ds,
                            steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
                            epochs=EPOCHS,
                            validation_data=val_ds,
                            validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
                            class_weight=class_weight,
                            callbacks=[checkpoint_cb, early_stopping_cb, lr_scheduler]
                            )
        
        
        
        test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
        test_ds = test_ds.batch(BATCH_SIZE)
                    
        y_preds = model.predict(test_ds, batch_size = BATCH_SIZE, verbose = True)
        y_preds = y_preds.reshape(-1)
        y_actual = [1 if x == True else 0 for x in y_test]
        
        print(f'Learning Rate: {learning_rate}\nHidden Units: {hidden_units}\n1 Hidden Layer\nS value: {s}')
        
        fpr, tpr, thresholds = roc_curve(y_actual, y_preds, pos_label=1)
        print(f'AUC score: {auc(fpr, tpr)}')
               
        print(f'Test Recall: {recall(y_actual, y_preds)}')
        print(f'Test Precision: {precision(y_actual, y_preds)}')
        print(f'Test F1 Scores: {f1_score(y_actual, y_preds)}\n\n')
# Out:
# Batch Size: 256
# Hidden Units: 4096
# Learning Rate: 0.010395
# 1 Hidden Layer, 4096 units
# S value: 33
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74842112/74836368 [==============================] - 1s 0us/step
# Epoch 1/50
# 13/13 [==============================] - 158s 7s/step - loss: 0.7444 - accuracy: 0.7867 - precision: 0.9279 - recall: 0.7637 - val_loss: 22.1425 - val_accuracy: 0.3306 - val_precision: 1.0000 - val_recall: 0.0927
# Epoch 2/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.2387 - accuracy: 0.9250 - precision: 0.9530 - recall: 0.9444 - val_loss: 0.2548 - val_accuracy: 0.9473 - val_precision: 0.9922 - val_recall: 0.9352
# Epoch 3/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.1149 - accuracy: 0.9387 - precision: 0.9732 - recall: 0.9418 - val_loss: 0.3556 - val_accuracy: 0.9219 - val_precision: 0.9919 - val_recall: 0.8999
# Epoch 4/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.1158 - accuracy: 0.9203 - precision: 0.9791 - recall: 0.9119 - val_loss: 0.2660 - val_accuracy: 0.9170 - val_precision: 0.9956 - val_recall: 0.8912
# Epoch 5/50
# 13/13 [==============================] - 3s 229ms/step - loss: 0.0912 - accuracy: 0.9427 - precision: 0.9778 - recall: 0.9429 - val_loss: 0.4194 - val_accuracy: 0.8843 - val_precision: 0.9969 - val_recall: 0.8447
# Epoch 6/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0776 - accuracy: 0.9478 - precision: 0.9830 - recall: 0.9456 - val_loss: 0.0965 - val_accuracy: 0.9629 - val_precision: 0.9758 - val_recall: 0.9732
# Epoch 7/50
# 13/13 [==============================] - 3s 227ms/step - loss: 0.0806 - accuracy: 0.9488 - precision: 0.9773 - recall: 0.9515 - val_loss: 0.1616 - val_accuracy: 0.9370 - val_precision: 0.9921 - val_recall: 0.9211
# Epoch 8/50
# 13/13 [==============================] - 3s 229ms/step - loss: 0.0771 - accuracy: 0.9541 - precision: 0.9839 - recall: 0.9526 - val_loss: 0.1193 - val_accuracy: 0.9590 - val_precision: 0.9870 - val_recall: 0.9570
# Epoch 9/50
# 13/13 [==============================] - 3s 229ms/step - loss: 0.0744 - accuracy: 0.9536 - precision: 0.9825 - recall: 0.9540 - val_loss: 0.1313 - val_accuracy: 0.9512 - val_precision: 0.9902 - val_recall: 0.9427
# Epoch 10/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0635 - accuracy: 0.9567 - precision: 0.9855 - recall: 0.9552 - val_loss: 0.0917 - val_accuracy: 0.9644 - val_precision: 0.9823 - val_recall: 0.9685
# Epoch 11/50
# 13/13 [==============================] - 3s 227ms/step - loss: 0.0651 - accuracy: 0.9583 - precision: 0.9837 - recall: 0.9588 - val_loss: 0.2140 - val_accuracy: 0.9170 - val_precision: 0.9896 - val_recall: 0.8949
# Epoch 12/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0681 - accuracy: 0.9535 - precision: 0.9864 - recall: 0.9497 - val_loss: 0.0861 - val_accuracy: 0.9648 - val_precision: 0.9678 - val_recall: 0.9846
# Epoch 13/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0669 - accuracy: 0.9531 - precision: 0.9863 - recall: 0.9496 - val_loss: 0.0963 - val_accuracy: 0.9634 - val_precision: 0.9830 - val_recall: 0.9666
# Epoch 14/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0592 - accuracy: 0.9590 - precision: 0.9863 - recall: 0.9575 - val_loss: 0.0836 - val_accuracy: 0.9702 - val_precision: 0.9799 - val_recall: 0.9793
# Epoch 15/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0623 - accuracy: 0.9620 - precision: 0.9846 - recall: 0.9630 - val_loss: 0.0820 - val_accuracy: 0.9702 - val_precision: 0.9781 - val_recall: 0.9813
# Epoch 16/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0558 - accuracy: 0.9673 - precision: 0.9871 - recall: 0.9678 - val_loss: 0.0807 - val_accuracy: 0.9702 - val_precision: 0.9762 - val_recall: 0.9833
# Epoch 17/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0588 - accuracy: 0.9609 - precision: 0.9856 - recall: 0.9607 - val_loss: 0.0974 - val_accuracy: 0.9639 - val_precision: 0.9856 - val_recall: 0.9645
# Epoch 18/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0570 - accuracy: 0.9639 - precision: 0.9863 - recall: 0.9636 - val_loss: 0.0948 - val_accuracy: 0.9653 - val_precision: 0.9823 - val_recall: 0.9698
# Epoch 19/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0534 - accuracy: 0.9636 - precision: 0.9890 - recall: 0.9607 - val_loss: 0.0900 - val_accuracy: 0.9658 - val_precision: 0.9820 - val_recall: 0.9716
# Epoch 20/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0589 - accuracy: 0.9631 - precision: 0.9847 - recall: 0.9644 - val_loss: 0.0806 - val_accuracy: 0.9688 - val_precision: 0.9763 - val_recall: 0.9814
# Epoch 21/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0551 - accuracy: 0.9666 - precision: 0.9853 - recall: 0.9685 - val_loss: 0.0793 - val_accuracy: 0.9692 - val_precision: 0.9717 - val_recall: 0.9866
# Epoch 22/50
# 13/13 [==============================] - 3s 230ms/step - loss: 0.0505 - accuracy: 0.9629 - precision: 0.9883 - recall: 0.9609 - val_loss: 0.0730 - val_accuracy: 0.9712 - val_precision: 0.9743 - val_recall: 0.9866
# Epoch 23/50
# 13/13 [==============================] - 3s 230ms/step - loss: 0.0521 - accuracy: 0.9696 - precision: 0.9893 - recall: 0.9691 - val_loss: 0.0845 - val_accuracy: 0.9644 - val_precision: 0.9625 - val_recall: 0.9900
# Epoch 24/50
# 13/13 [==============================] - 3s 227ms/step - loss: 0.0475 - accuracy: 0.9698 - precision: 0.9895 - recall: 0.9689 - val_loss: 0.0964 - val_accuracy: 0.9595 - val_precision: 0.9645 - val_recall: 0.9806
# Epoch 25/50
# 13/13 [==============================] - 3s 228ms/step - loss: 0.0454 - accuracy: 0.9678 - precision: 0.9905 - recall: 0.9651 - val_loss: 0.0817 - val_accuracy: 0.9683 - val_precision: 0.9711 - val_recall: 0.9860
# Epoch 26/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0453 - accuracy: 0.9706 - precision: 0.9886 - recall: 0.9709 - val_loss: 0.0831 - val_accuracy: 0.9653 - val_precision: 0.9672 - val_recall: 0.9859
# Epoch 27/50
# 13/13 [==============================] - 3s 227ms/step - loss: 0.0435 - accuracy: 0.9719 - precision: 0.9905 - recall: 0.9710 - val_loss: 0.0805 - val_accuracy: 0.9688 - val_precision: 0.9735 - val_recall: 0.9839
# Epoch 28/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0452 - accuracy: 0.9692 - precision: 0.9930 - recall: 0.9649 - val_loss: 0.0800 - val_accuracy: 0.9678 - val_precision: 0.9730 - val_recall: 0.9834
# Epoch 29/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0473 - accuracy: 0.9667 - precision: 0.9874 - recall: 0.9666 - val_loss: 0.0764 - val_accuracy: 0.9722 - val_precision: 0.9781 - val_recall: 0.9840
# Epoch 30/50
# 13/13 [==============================] - 3s 215ms/step - loss: 0.0437 - accuracy: 0.9699 - precision: 0.9894 - recall: 0.9694 - val_loss: 0.0813 - val_accuracy: 0.9702 - val_precision: 0.9728 - val_recall: 0.9866
# Epoch 31/50
# 13/13 [==============================] - 3s 215ms/step - loss: 0.0441 - accuracy: 0.9738 - precision: 0.9901 - recall: 0.9739 - val_loss: 0.0886 - val_accuracy: 0.9707 - val_precision: 0.9799 - val_recall: 0.9799
# Epoch 32/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0364 - accuracy: 0.9776 - precision: 0.9930 - recall: 0.9761 - val_loss: 0.0800 - val_accuracy: 0.9683 - val_precision: 0.9729 - val_recall: 0.9839
# Epoch 33/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0391 - accuracy: 0.9720 - precision: 0.9926 - recall: 0.9696 - val_loss: 0.0799 - val_accuracy: 0.9746 - val_precision: 0.9800 - val_recall: 0.9853
# Epoch 34/50
# 13/13 [==============================] - 3s 215ms/step - loss: 0.0396 - accuracy: 0.9744 - precision: 0.9939 - recall: 0.9712 - val_loss: 0.0815 - val_accuracy: 0.9722 - val_precision: 0.9775 - val_recall: 0.9846
# Epoch 35/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0379 - accuracy: 0.9772 - precision: 0.9954 - recall: 0.9735 - val_loss: 0.0792 - val_accuracy: 0.9717 - val_precision: 0.9787 - val_recall: 0.9826
# Epoch 36/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0421 - accuracy: 0.9738 - precision: 0.9912 - recall: 0.9729 - val_loss: 0.0818 - val_accuracy: 0.9688 - val_precision: 0.9730 - val_recall: 0.9847
# Epoch 37/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0364 - accuracy: 0.9770 - precision: 0.9921 - recall: 0.9762 - val_loss: 0.0751 - val_accuracy: 0.9707 - val_precision: 0.9731 - val_recall: 0.9873
# Epoch 38/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0329 - accuracy: 0.9806 - precision: 0.9916 - recall: 0.9816 - val_loss: 0.0797 - val_accuracy: 0.9697 - val_precision: 0.9742 - val_recall: 0.9846
# Epoch 39/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0404 - accuracy: 0.9765 - precision: 0.9922 - recall: 0.9753 - val_loss: 0.0895 - val_accuracy: 0.9702 - val_precision: 0.9806 - val_recall: 0.9786
# Epoch 40/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0412 - accuracy: 0.9707 - precision: 0.9930 - recall: 0.9670 - val_loss: 0.0767 - val_accuracy: 0.9722 - val_precision: 0.9755 - val_recall: 0.9866
# Epoch 41/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0355 - accuracy: 0.9755 - precision: 0.9937 - recall: 0.9728 - val_loss: 0.0825 - val_accuracy: 0.9688 - val_precision: 0.9723 - val_recall: 0.9853
# Epoch 42/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0374 - accuracy: 0.9777 - precision: 0.9903 - recall: 0.9793 - val_loss: 0.0830 - val_accuracy: 0.9692 - val_precision: 0.9767 - val_recall: 0.9813
# 5/5 [==============================] - 48s 11s/step
# Learning Rate: 0.010395
# Hidden Units: 4096
# 1 Hidden Layer
# S value: 33
# AUC score: 0.9893518873050429
# Test Recall: 0.9729093050647821
# Test Precision: 0.9672131147540983
# Test F1 Scores: 0.9700528479154433
#
#
#
#
# Batch Size: 256
# Hidden Units: 4096
# Learning Rate: 0.010395
# 1 Hidden Layer, 4096 units
# S value: 51
# Epoch 1/50
# 13/13 [==============================] - 52s 2s/step - loss: 0.8621 - accuracy: 0.7658 - precision: 0.9159 - recall: 0.7449 - val_loss: 29.3566 - val_accuracy: 0.2866 - val_precision: 1.0000 - val_recall: 0.0286
# Epoch 2/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.2616 - accuracy: 0.9132 - precision: 0.9432 - recall: 0.9386 - val_loss: 0.3308 - val_accuracy: 0.9360 - val_precision: 0.9857 - val_recall: 0.9256
# Epoch 3/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.1380 - accuracy: 0.9311 - precision: 0.9696 - recall: 0.9349 - val_loss: 0.2777 - val_accuracy: 0.9302 - val_precision: 0.9905 - val_recall: 0.9126
# Epoch 4/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.1141 - accuracy: 0.9342 - precision: 0.9801 - recall: 0.9291 - val_loss: 1.0636 - val_accuracy: 0.8042 - val_precision: 1.0000 - val_recall: 0.7328
# Epoch 5/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0971 - accuracy: 0.9376 - precision: 0.9837 - recall: 0.9300 - val_loss: 0.1340 - val_accuracy: 0.9536 - val_precision: 0.9862 - val_recall: 0.9500
# Epoch 6/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0850 - accuracy: 0.9485 - precision: 0.9804 - recall: 0.9489 - val_loss: 0.1239 - val_accuracy: 0.9546 - val_precision: 0.9473 - val_recall: 0.9933
# Epoch 7/50
# 13/13 [==============================] - 4s 285ms/step - loss: 0.0839 - accuracy: 0.9461 - precision: 0.9819 - recall: 0.9434 - val_loss: 0.2537 - val_accuracy: 0.9014 - val_precision: 0.9946 - val_recall: 0.8692
# Epoch 8/50
# 13/13 [==============================] - 3s 232ms/step - loss: 0.0773 - accuracy: 0.9488 - precision: 0.9809 - recall: 0.9482 - val_loss: 0.4542 - val_accuracy: 0.8735 - val_precision: 0.9952 - val_recall: 0.8310
# Epoch 9/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0697 - accuracy: 0.9559 - precision: 0.9868 - recall: 0.9522 - val_loss: 0.0959 - val_accuracy: 0.9688 - val_precision: 0.9830 - val_recall: 0.9738
# Epoch 10/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0687 - accuracy: 0.9601 - precision: 0.9838 - recall: 0.9611 - val_loss: 0.0937 - val_accuracy: 0.9624 - val_precision: 0.9837 - val_recall: 0.9648
# Epoch 11/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0734 - accuracy: 0.9551 - precision: 0.9829 - recall: 0.9552 - val_loss: 0.1067 - val_accuracy: 0.9541 - val_precision: 0.9486 - val_recall: 0.9906
# Epoch 12/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0692 - accuracy: 0.9548 - precision: 0.9799 - recall: 0.9572 - val_loss: 0.2035 - val_accuracy: 0.9365 - val_precision: 0.9837 - val_recall: 0.9284
# Epoch 13/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0874 - accuracy: 0.9484 - precision: 0.9823 - recall: 0.9468 - val_loss: 0.0999 - val_accuracy: 0.9604 - val_precision: 0.9635 - val_recall: 0.9834
# Epoch 14/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0703 - accuracy: 0.9558 - precision: 0.9784 - recall: 0.9609 - val_loss: 0.1528 - val_accuracy: 0.9448 - val_precision: 0.9874 - val_recall: 0.9367
# Epoch 15/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0705 - accuracy: 0.9542 - precision: 0.9891 - recall: 0.9479 - val_loss: 0.0874 - val_accuracy: 0.9663 - val_precision: 0.9811 - val_recall: 0.9726
# Epoch 16/50
# 13/13 [==============================] - 3s 215ms/step - loss: 0.0685 - accuracy: 0.9533 - precision: 0.9829 - recall: 0.9531 - val_loss: 0.1041 - val_accuracy: 0.9624 - val_precision: 0.9863 - val_recall: 0.9620
# Epoch 17/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0610 - accuracy: 0.9640 - precision: 0.9850 - recall: 0.9648 - val_loss: 0.0820 - val_accuracy: 0.9712 - val_precision: 0.9743 - val_recall: 0.9867
# Epoch 18/50
# 13/13 [==============================] - 3s 213ms/step - loss: 0.0602 - accuracy: 0.9642 - precision: 0.9867 - recall: 0.9641 - val_loss: 0.1011 - val_accuracy: 0.9648 - val_precision: 0.9805 - val_recall: 0.9713
# Epoch 19/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0623 - accuracy: 0.9618 - precision: 0.9885 - recall: 0.9590 - val_loss: 0.0924 - val_accuracy: 0.9658 - val_precision: 0.9672 - val_recall: 0.9866
# Epoch 20/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0537 - accuracy: 0.9645 - precision: 0.9874 - recall: 0.9637 - val_loss: 0.0743 - val_accuracy: 0.9741 - val_precision: 0.9775 - val_recall: 0.9873
# Epoch 21/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0527 - accuracy: 0.9610 - precision: 0.9898 - recall: 0.9571 - val_loss: 0.0791 - val_accuracy: 0.9722 - val_precision: 0.9788 - val_recall: 0.9833
# Epoch 22/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0500 - accuracy: 0.9689 - precision: 0.9905 - recall: 0.9668 - val_loss: 0.1024 - val_accuracy: 0.9595 - val_precision: 0.9810 - val_recall: 0.9634
# Epoch 23/50
# 13/13 [==============================] - 3s 215ms/step - loss: 0.0484 - accuracy: 0.9680 - precision: 0.9910 - recall: 0.9652 - val_loss: 0.0806 - val_accuracy: 0.9707 - val_precision: 0.9735 - val_recall: 0.9866
# Epoch 24/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0503 - accuracy: 0.9692 - precision: 0.9883 - recall: 0.9692 - val_loss: 0.0848 - val_accuracy: 0.9673 - val_precision: 0.9666 - val_recall: 0.9893
# Epoch 25/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0455 - accuracy: 0.9686 - precision: 0.9894 - recall: 0.9678 - val_loss: 0.0857 - val_accuracy: 0.9707 - val_precision: 0.9845 - val_recall: 0.9753
# Epoch 26/50
# 13/13 [==============================] - 3s 214ms/step - loss: 0.0445 - accuracy: 0.9672 - precision: 0.9900 - recall: 0.9644 - val_loss: 0.0966 - val_accuracy: 0.9683 - val_precision: 0.9793 - val_recall: 0.9773
# Epoch 27/50
# 13/13 [==============================] - 3s 213ms/step - loss: 0.0496 - accuracy: 0.9693 - precision: 0.9896 - recall: 0.9686 - val_loss: 0.1125 - val_accuracy: 0.9556 - val_precision: 0.9821 - val_recall: 0.9565
# Epoch 28/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0509 - accuracy: 0.9682 - precision: 0.9910 - recall: 0.9653 - val_loss: 0.0840 - val_accuracy: 0.9688 - val_precision: 0.9793 - val_recall: 0.9780
# Epoch 29/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0481 - accuracy: 0.9686 - precision: 0.9904 - recall: 0.9663 - val_loss: 0.0806 - val_accuracy: 0.9697 - val_precision: 0.9818 - val_recall: 0.9766
# Epoch 30/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0487 - accuracy: 0.9698 - precision: 0.9878 - recall: 0.9709 - val_loss: 0.0743 - val_accuracy: 0.9766 - val_precision: 0.9871 - val_recall: 0.9805
# Epoch 31/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0456 - accuracy: 0.9702 - precision: 0.9902 - recall: 0.9687 - val_loss: 0.0850 - val_accuracy: 0.9717 - val_precision: 0.9825 - val_recall: 0.9786
# Epoch 32/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0443 - accuracy: 0.9712 - precision: 0.9907 - recall: 0.9701 - val_loss: 0.0822 - val_accuracy: 0.9727 - val_precision: 0.9858 - val_recall: 0.9766
# Epoch 33/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0467 - accuracy: 0.9696 - precision: 0.9868 - recall: 0.9712 - val_loss: 0.0760 - val_accuracy: 0.9717 - val_precision: 0.9756 - val_recall: 0.9860
# Epoch 34/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0403 - accuracy: 0.9731 - precision: 0.9905 - recall: 0.9727 - val_loss: 0.0816 - val_accuracy: 0.9736 - val_precision: 0.9801 - val_recall: 0.9840
# Epoch 35/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0380 - accuracy: 0.9772 - precision: 0.9932 - recall: 0.9753 - val_loss: 0.0814 - val_accuracy: 0.9717 - val_precision: 0.9717 - val_recall: 0.9900
# Epoch 36/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0389 - accuracy: 0.9768 - precision: 0.9928 - recall: 0.9755 - val_loss: 0.0741 - val_accuracy: 0.9741 - val_precision: 0.9764 - val_recall: 0.9887
# Epoch 37/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0370 - accuracy: 0.9786 - precision: 0.9915 - recall: 0.9788 - val_loss: 0.0777 - val_accuracy: 0.9688 - val_precision: 0.9705 - val_recall: 0.9873
# Epoch 38/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0384 - accuracy: 0.9788 - precision: 0.9911 - recall: 0.9797 - val_loss: 0.0741 - val_accuracy: 0.9707 - val_precision: 0.9774 - val_recall: 0.9826
# Epoch 39/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0421 - accuracy: 0.9758 - precision: 0.9891 - recall: 0.9774 - val_loss: 0.0766 - val_accuracy: 0.9688 - val_precision: 0.9746 - val_recall: 0.9825
# Epoch 40/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0391 - accuracy: 0.9764 - precision: 0.9921 - recall: 0.9755 - val_loss: 0.0698 - val_accuracy: 0.9717 - val_precision: 0.9771 - val_recall: 0.9848
# Epoch 41/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0306 - accuracy: 0.9803 - precision: 0.9926 - recall: 0.9804 - val_loss: 0.0718 - val_accuracy: 0.9741 - val_precision: 0.9788 - val_recall: 0.9860
# Epoch 42/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0366 - accuracy: 0.9794 - precision: 0.9924 - recall: 0.9793 - val_loss: 0.0780 - val_accuracy: 0.9727 - val_precision: 0.9838 - val_recall: 0.9785
# Epoch 43/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0297 - accuracy: 0.9802 - precision: 0.9959 - recall: 0.9773 - val_loss: 0.0727 - val_accuracy: 0.9707 - val_precision: 0.9795 - val_recall: 0.9808
# Epoch 44/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0270 - accuracy: 0.9818 - precision: 0.9957 - recall: 0.9795 - val_loss: 0.0761 - val_accuracy: 0.9722 - val_precision: 0.9824 - val_recall: 0.9791
# Epoch 45/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0304 - accuracy: 0.9791 - precision: 0.9924 - recall: 0.9789 - val_loss: 0.0725 - val_accuracy: 0.9741 - val_precision: 0.9839 - val_recall: 0.9806
# Epoch 46/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0343 - accuracy: 0.9784 - precision: 0.9906 - recall: 0.9795 - val_loss: 0.0760 - val_accuracy: 0.9722 - val_precision: 0.9773 - val_recall: 0.9845
# Epoch 47/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0279 - accuracy: 0.9837 - precision: 0.9931 - recall: 0.9845 - val_loss: 0.0791 - val_accuracy: 0.9673 - val_precision: 0.9825 - val_recall: 0.9726
# Epoch 48/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0298 - accuracy: 0.9844 - precision: 0.9949 - recall: 0.9837 - val_loss: 0.0825 - val_accuracy: 0.9712 - val_precision: 0.9858 - val_recall: 0.9747
# Epoch 49/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0314 - accuracy: 0.9798 - precision: 0.9935 - recall: 0.9786 - val_loss: 0.0952 - val_accuracy: 0.9697 - val_precision: 0.9871 - val_recall: 0.9714
# Epoch 50/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0357 - accuracy: 0.9759 - precision: 0.9918 - recall: 0.9752 - val_loss: 0.0807 - val_accuracy: 0.9697 - val_precision: 0.9819 - val_recall: 0.9767
# 5/5 [==============================] - 48s 11s/step
# Learning Rate: 0.010395
# Hidden Units: 4096
# 1 Hidden Layer
# S value: 51
# AUC score: 0.989282601640247
# Test Recall: 0.967020023557126
# Test Precision: 0.9693034238488784
# Test F1 Scores: 0.9681603773584905
#
#
#
#
# Batch Size: 256
# Hidden Units: 4096
# Learning Rate: 0.010395
# 1 Hidden Layer, 4096 units
# S value: 47
# Epoch 1/50
# 13/13 [==============================] - 52s 2s/step - loss: 0.9793 - accuracy: 0.7435 - precision: 0.8955 - recall: 0.7287 - val_loss: 21.8258 - val_accuracy: 0.3179 - val_precision: 1.0000 - val_recall: 0.0612
# Epoch 2/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.2547 - accuracy: 0.9197 - precision: 0.9493 - recall: 0.9408 - val_loss: 0.4321 - val_accuracy: 0.9233 - val_precision: 0.9890 - val_recall: 0.9049
# Epoch 3/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.1792 - accuracy: 0.9292 - precision: 0.9565 - recall: 0.9453 - val_loss: 0.2404 - val_accuracy: 0.9312 - val_precision: 0.9920 - val_recall: 0.9132
# Epoch 4/50
# 13/13 [==============================] - 3s 241ms/step - loss: 0.1152 - accuracy: 0.9289 - precision: 0.9771 - recall: 0.9238 - val_loss: 0.8328 - val_accuracy: 0.8423 - val_precision: 0.9966 - val_recall: 0.7868
# Epoch 5/50
# 13/13 [==============================] - 3s 247ms/step - loss: 0.0947 - accuracy: 0.9396 - precision: 0.9781 - recall: 0.9390 - val_loss: 0.0964 - val_accuracy: 0.9648 - val_precision: 0.9766 - val_recall: 0.9753
# Epoch 6/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0810 - accuracy: 0.9470 - precision: 0.9790 - recall: 0.9480 - val_loss: 0.1115 - val_accuracy: 0.9624 - val_precision: 0.9623 - val_recall: 0.9873
# Epoch 7/50
# 13/13 [==============================] - 3s 215ms/step - loss: 0.0837 - accuracy: 0.9466 - precision: 0.9813 - recall: 0.9452 - val_loss: 0.3255 - val_accuracy: 0.8872 - val_precision: 0.9969 - val_recall: 0.8492
# Epoch 8/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0768 - accuracy: 0.9518 - precision: 0.9824 - recall: 0.9507 - val_loss: 0.0921 - val_accuracy: 0.9629 - val_precision: 0.9819 - val_recall: 0.9675
# Epoch 9/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0733 - accuracy: 0.9528 - precision: 0.9819 - recall: 0.9524 - val_loss: 0.1008 - val_accuracy: 0.9634 - val_precision: 0.9661 - val_recall: 0.9847
# Epoch 10/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0706 - accuracy: 0.9530 - precision: 0.9843 - recall: 0.9507 - val_loss: 0.1044 - val_accuracy: 0.9619 - val_precision: 0.9817 - val_recall: 0.9659
# Epoch 11/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0682 - accuracy: 0.9576 - precision: 0.9825 - recall: 0.9592 - val_loss: 0.0827 - val_accuracy: 0.9731 - val_precision: 0.9787 - val_recall: 0.9846
# Epoch 12/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0654 - accuracy: 0.9581 - precision: 0.9832 - recall: 0.9589 - val_loss: 0.1533 - val_accuracy: 0.9385 - val_precision: 0.9858 - val_recall: 0.9290
# Epoch 13/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0668 - accuracy: 0.9579 - precision: 0.9891 - recall: 0.9530 - val_loss: 0.1271 - val_accuracy: 0.9497 - val_precision: 0.9387 - val_recall: 0.9960
# Epoch 14/50
# 13/13 [==============================] - 3s 215ms/step - loss: 0.0722 - accuracy: 0.9598 - precision: 0.9829 - recall: 0.9617 - val_loss: 0.2145 - val_accuracy: 0.9297 - val_precision: 0.9857 - val_recall: 0.9174
# Epoch 15/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0770 - accuracy: 0.9466 - precision: 0.9861 - recall: 0.9408 - val_loss: 0.1218 - val_accuracy: 0.9536 - val_precision: 0.9868 - val_recall: 0.9492
# Epoch 16/50
# 13/13 [==============================] - 3s 212ms/step - loss: 0.0638 - accuracy: 0.9562 - precision: 0.9842 - recall: 0.9554 - val_loss: 0.0886 - val_accuracy: 0.9697 - val_precision: 0.9774 - val_recall: 0.9813
# Epoch 17/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0646 - accuracy: 0.9553 - precision: 0.9840 - recall: 0.9544 - val_loss: 0.0850 - val_accuracy: 0.9668 - val_precision: 0.9706 - val_recall: 0.9848
# Epoch 18/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0555 - accuracy: 0.9632 - precision: 0.9883 - recall: 0.9608 - val_loss: 0.0817 - val_accuracy: 0.9692 - val_precision: 0.9755 - val_recall: 0.9826
# Epoch 19/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0609 - accuracy: 0.9615 - precision: 0.9851 - recall: 0.9617 - val_loss: 0.1043 - val_accuracy: 0.9629 - val_precision: 0.9823 - val_recall: 0.9665
# Epoch 20/50
# 13/13 [==============================] - 3s 237ms/step - loss: 0.0639 - accuracy: 0.9604 - precision: 0.9883 - recall: 0.9570 - val_loss: 0.0835 - val_accuracy: 0.9722 - val_precision: 0.9814 - val_recall: 0.9807
# Epoch 21/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0521 - accuracy: 0.9650 - precision: 0.9875 - recall: 0.9643 - val_loss: 0.0801 - val_accuracy: 0.9707 - val_precision: 0.9762 - val_recall: 0.9840
# Epoch 22/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0569 - accuracy: 0.9660 - precision: 0.9855 - recall: 0.9677 - val_loss: 0.0819 - val_accuracy: 0.9663 - val_precision: 0.9671 - val_recall: 0.9872
# Epoch 23/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0580 - accuracy: 0.9605 - precision: 0.9875 - recall: 0.9587 - val_loss: 0.0927 - val_accuracy: 0.9565 - val_precision: 0.9545 - val_recall: 0.9880
# Epoch 24/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0472 - accuracy: 0.9704 - precision: 0.9907 - recall: 0.9687 - val_loss: 0.0821 - val_accuracy: 0.9692 - val_precision: 0.9736 - val_recall: 0.9847
# Epoch 25/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0447 - accuracy: 0.9675 - precision: 0.9926 - recall: 0.9630 - val_loss: 0.0802 - val_accuracy: 0.9683 - val_precision: 0.9730 - val_recall: 0.9840
# Epoch 26/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0536 - accuracy: 0.9654 - precision: 0.9864 - recall: 0.9655 - val_loss: 0.0929 - val_accuracy: 0.9688 - val_precision: 0.9811 - val_recall: 0.9759
# Epoch 27/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0487 - accuracy: 0.9699 - precision: 0.9885 - recall: 0.9697 - val_loss: 0.0867 - val_accuracy: 0.9678 - val_precision: 0.9767 - val_recall: 0.9793
# Epoch 28/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0517 - accuracy: 0.9673 - precision: 0.9872 - recall: 0.9673 - val_loss: 0.0915 - val_accuracy: 0.9658 - val_precision: 0.9720 - val_recall: 0.9812
# Epoch 29/50
# 13/13 [==============================] - 3s 215ms/step - loss: 0.0531 - accuracy: 0.9675 - precision: 0.9887 - recall: 0.9663 - val_loss: 0.0879 - val_accuracy: 0.9702 - val_precision: 0.9768 - val_recall: 0.9827
# Epoch 30/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0518 - accuracy: 0.9697 - precision: 0.9900 - recall: 0.9682 - val_loss: 0.0821 - val_accuracy: 0.9683 - val_precision: 0.9729 - val_recall: 0.9839
# Epoch 31/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0492 - accuracy: 0.9661 - precision: 0.9913 - recall: 0.9628 - val_loss: 0.0969 - val_accuracy: 0.9634 - val_precision: 0.9596 - val_recall: 0.9921
# Epoch 32/50
# 13/13 [==============================] - 3s 227ms/step - loss: 0.0445 - accuracy: 0.9707 - precision: 0.9906 - recall: 0.9694 - val_loss: 0.0867 - val_accuracy: 0.9653 - val_precision: 0.9691 - val_recall: 0.9840
# Epoch 33/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0409 - accuracy: 0.9737 - precision: 0.9910 - recall: 0.9730 - val_loss: 0.0815 - val_accuracy: 0.9658 - val_precision: 0.9639 - val_recall: 0.9899
# Epoch 34/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0397 - accuracy: 0.9755 - precision: 0.9922 - recall: 0.9744 - val_loss: 0.0823 - val_accuracy: 0.9673 - val_precision: 0.9730 - val_recall: 0.9827
# Epoch 35/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0408 - accuracy: 0.9761 - precision: 0.9926 - recall: 0.9749 - val_loss: 0.0806 - val_accuracy: 0.9678 - val_precision: 0.9780 - val_recall: 0.9780
# Epoch 36/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0365 - accuracy: 0.9772 - precision: 0.9935 - recall: 0.9750 - val_loss: 0.0886 - val_accuracy: 0.9653 - val_precision: 0.9717 - val_recall: 0.9814
# Epoch 37/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0429 - accuracy: 0.9738 - precision: 0.9896 - recall: 0.9743 - val_loss: 0.0973 - val_accuracy: 0.9644 - val_precision: 0.9764 - val_recall: 0.9745
# Epoch 38/50
# 13/13 [==============================] - 3s 229ms/step - loss: 0.0498 - accuracy: 0.9683 - precision: 0.9891 - recall: 0.9669 - val_loss: 0.0770 - val_accuracy: 0.9702 - val_precision: 0.9722 - val_recall: 0.9872
# Epoch 39/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0382 - accuracy: 0.9751 - precision: 0.9927 - recall: 0.9730 - val_loss: 0.0817 - val_accuracy: 0.9648 - val_precision: 0.9672 - val_recall: 0.9853
# Epoch 40/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0377 - accuracy: 0.9754 - precision: 0.9931 - recall: 0.9732 - val_loss: 0.0808 - val_accuracy: 0.9658 - val_precision: 0.9685 - val_recall: 0.9853
# Epoch 41/50
# 13/13 [==============================] - 3s 215ms/step - loss: 0.0397 - accuracy: 0.9761 - precision: 0.9894 - recall: 0.9779 - val_loss: 0.0811 - val_accuracy: 0.9683 - val_precision: 0.9752 - val_recall: 0.9811
# Epoch 42/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0425 - accuracy: 0.9736 - precision: 0.9910 - recall: 0.9730 - val_loss: 0.0803 - val_accuracy: 0.9658 - val_precision: 0.9736 - val_recall: 0.9801
# Epoch 43/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0354 - accuracy: 0.9767 - precision: 0.9910 - recall: 0.9773 - val_loss: 0.0834 - val_accuracy: 0.9702 - val_precision: 0.9779 - val_recall: 0.9811
# Epoch 44/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0332 - accuracy: 0.9786 - precision: 0.9943 - recall: 0.9763 - val_loss: 0.0877 - val_accuracy: 0.9692 - val_precision: 0.9811 - val_recall: 0.9765
# Epoch 45/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0389 - accuracy: 0.9740 - precision: 0.9918 - recall: 0.9726 - val_loss: 0.0801 - val_accuracy: 0.9673 - val_precision: 0.9715 - val_recall: 0.9839
# Epoch 46/50
# 13/13 [==============================] - 3s 215ms/step - loss: 0.0361 - accuracy: 0.9803 - precision: 0.9890 - recall: 0.9839 - val_loss: 0.0849 - val_accuracy: 0.9668 - val_precision: 0.9786 - val_recall: 0.9760
# Epoch 47/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0372 - accuracy: 0.9776 - precision: 0.9910 - recall: 0.9782 - val_loss: 0.0873 - val_accuracy: 0.9707 - val_precision: 0.9801 - val_recall: 0.9801
# Epoch 48/50
# 13/13 [==============================] - 3s 215ms/step - loss: 0.0357 - accuracy: 0.9770 - precision: 0.9917 - recall: 0.9766 - val_loss: 0.0797 - val_accuracy: 0.9688 - val_precision: 0.9742 - val_recall: 0.9833
# Epoch 49/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0318 - accuracy: 0.9788 - precision: 0.9931 - recall: 0.9777 - val_loss: 0.0816 - val_accuracy: 0.9692 - val_precision: 0.9761 - val_recall: 0.9820
# Epoch 50/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0340 - accuracy: 0.9779 - precision: 0.9932 - recall: 0.9766 - val_loss: 0.0770 - val_accuracy: 0.9673 - val_precision: 0.9737 - val_recall: 0.9821
# 5/5 [==============================] - 48s 11s/step
# Learning Rate: 0.010395
# Hidden Units: 4096
# 1 Hidden Layer
# S value: 47
# AUC score: 0.9895889172109239
# Test Recall: 0.9705535924617197
# Test Precision: 0.9682726204465335
# Test F1 Scores: 0.9694117647058824
#
#
#
#
# Batch Size: 256
# Hidden Units: 4096
# Learning Rate: 0.010395
# 1 Hidden Layer, 4096 units
# S value: 71
# Epoch 1/50
# 13/13 [==============================] - 53s 2s/step - loss: 0.9287 - accuracy: 0.7631 - precision: 0.9179 - recall: 0.7401 - val_loss: 18.1069 - val_accuracy: 0.4087 - val_precision: 1.0000 - val_recall: 0.1953
# Epoch 2/50
# 13/13 [==============================] - 3s 229ms/step - loss: 0.2727 - accuracy: 0.9279 - precision: 0.9549 - recall: 0.9461 - val_loss: 0.7934 - val_accuracy: 0.8706 - val_precision: 0.9984 - val_recall: 0.8238
# Epoch 3/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.1383 - accuracy: 0.9226 - precision: 0.9667 - recall: 0.9254 - val_loss: 0.2837 - val_accuracy: 0.9141 - val_precision: 0.9910 - val_recall: 0.8901
# Epoch 4/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0909 - accuracy: 0.9380 - precision: 0.9810 - recall: 0.9335 - val_loss: 0.1422 - val_accuracy: 0.9531 - val_precision: 0.9829 - val_recall: 0.9528
# Epoch 5/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0879 - accuracy: 0.9388 - precision: 0.9799 - recall: 0.9356 - val_loss: 0.1192 - val_accuracy: 0.9556 - val_precision: 0.9842 - val_recall: 0.9547
# Epoch 6/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0794 - accuracy: 0.9486 - precision: 0.9822 - recall: 0.9470 - val_loss: 0.1198 - val_accuracy: 0.9512 - val_precision: 0.9487 - val_recall: 0.9866
# Epoch 7/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0861 - accuracy: 0.9459 - precision: 0.9786 - recall: 0.9463 - val_loss: 0.1366 - val_accuracy: 0.9458 - val_precision: 0.9854 - val_recall: 0.9402
# Epoch 8/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0873 - accuracy: 0.9484 - precision: 0.9767 - recall: 0.9516 - val_loss: 0.0887 - val_accuracy: 0.9697 - val_precision: 0.9807 - val_recall: 0.9781
# Epoch 9/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0811 - accuracy: 0.9467 - precision: 0.9802 - recall: 0.9460 - val_loss: 0.0969 - val_accuracy: 0.9658 - val_precision: 0.9805 - val_recall: 0.9726
# Epoch 10/50
# 13/13 [==============================] - 3s 229ms/step - loss: 0.0821 - accuracy: 0.9515 - precision: 0.9781 - recall: 0.9549 - val_loss: 0.1826 - val_accuracy: 0.9263 - val_precision: 0.9898 - val_recall: 0.9084
# Epoch 11/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0771 - accuracy: 0.9544 - precision: 0.9867 - recall: 0.9507 - val_loss: 0.1081 - val_accuracy: 0.9590 - val_precision: 0.9861 - val_recall: 0.9569
# Epoch 12/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0706 - accuracy: 0.9532 - precision: 0.9848 - recall: 0.9507 - val_loss: 0.0846 - val_accuracy: 0.9712 - val_precision: 0.9793 - val_recall: 0.9813
# Epoch 13/50
# 13/13 [==============================] - 3s 227ms/step - loss: 0.0681 - accuracy: 0.9575 - precision: 0.9849 - recall: 0.9560 - val_loss: 0.1527 - val_accuracy: 0.9409 - val_precision: 0.9899 - val_recall: 0.9278
# Epoch 14/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0785 - accuracy: 0.9486 - precision: 0.9865 - recall: 0.9438 - val_loss: 0.0933 - val_accuracy: 0.9668 - val_precision: 0.9635 - val_recall: 0.9919
# Epoch 15/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0648 - accuracy: 0.9623 - precision: 0.9881 - recall: 0.9602 - val_loss: 0.1307 - val_accuracy: 0.9438 - val_precision: 0.9879 - val_recall: 0.9342
# Epoch 16/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0593 - accuracy: 0.9579 - precision: 0.9882 - recall: 0.9542 - val_loss: 0.0829 - val_accuracy: 0.9658 - val_precision: 0.9792 - val_recall: 0.9740
# Epoch 17/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0566 - accuracy: 0.9618 - precision: 0.9887 - recall: 0.9589 - val_loss: 0.1000 - val_accuracy: 0.9663 - val_precision: 0.9761 - val_recall: 0.9781
# Epoch 18/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0667 - accuracy: 0.9600 - precision: 0.9877 - recall: 0.9573 - val_loss: 0.0960 - val_accuracy: 0.9619 - val_precision: 0.9599 - val_recall: 0.9893
# Epoch 19/50
# 13/13 [==============================] - 3s 228ms/step - loss: 0.0689 - accuracy: 0.9611 - precision: 0.9801 - recall: 0.9661 - val_loss: 0.1174 - val_accuracy: 0.9556 - val_precision: 0.9863 - val_recall: 0.9529
# Epoch 20/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0613 - accuracy: 0.9599 - precision: 0.9878 - recall: 0.9565 - val_loss: 0.0799 - val_accuracy: 0.9717 - val_precision: 0.9800 - val_recall: 0.9813
# Epoch 21/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0569 - accuracy: 0.9638 - precision: 0.9856 - recall: 0.9649 - val_loss: 0.0913 - val_accuracy: 0.9634 - val_precision: 0.9773 - val_recall: 0.9728
# Epoch 22/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0622 - accuracy: 0.9560 - precision: 0.9882 - recall: 0.9513 - val_loss: 0.0936 - val_accuracy: 0.9639 - val_precision: 0.9780 - val_recall: 0.9728
# Epoch 23/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0590 - accuracy: 0.9611 - precision: 0.9867 - recall: 0.9597 - val_loss: 0.0943 - val_accuracy: 0.9580 - val_precision: 0.9548 - val_recall: 0.9893
# Epoch 24/50
# 13/13 [==============================] - 3s 227ms/step - loss: 0.0541 - accuracy: 0.9678 - precision: 0.9871 - recall: 0.9687 - val_loss: 0.0884 - val_accuracy: 0.9644 - val_precision: 0.9629 - val_recall: 0.9893
# Epoch 25/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0517 - accuracy: 0.9681 - precision: 0.9861 - recall: 0.9699 - val_loss: 0.0892 - val_accuracy: 0.9688 - val_precision: 0.9793 - val_recall: 0.9780
# Epoch 26/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0539 - accuracy: 0.9658 - precision: 0.9882 - recall: 0.9647 - val_loss: 0.0777 - val_accuracy: 0.9683 - val_precision: 0.9749 - val_recall: 0.9820
# Epoch 27/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0591 - accuracy: 0.9625 - precision: 0.9855 - recall: 0.9627 - val_loss: 0.0840 - val_accuracy: 0.9688 - val_precision: 0.9742 - val_recall: 0.9833
# Epoch 28/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0498 - accuracy: 0.9693 - precision: 0.9857 - recall: 0.9723 - val_loss: 0.0832 - val_accuracy: 0.9707 - val_precision: 0.9858 - val_recall: 0.9739
# Epoch 29/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0583 - accuracy: 0.9653 - precision: 0.9910 - recall: 0.9612 - val_loss: 0.0778 - val_accuracy: 0.9746 - val_precision: 0.9833 - val_recall: 0.9820
# Epoch 30/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0525 - accuracy: 0.9680 - precision: 0.9880 - recall: 0.9680 - val_loss: 0.0884 - val_accuracy: 0.9634 - val_precision: 0.9798 - val_recall: 0.9700
# Epoch 31/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0470 - accuracy: 0.9712 - precision: 0.9892 - recall: 0.9710 - val_loss: 0.0861 - val_accuracy: 0.9702 - val_precision: 0.9865 - val_recall: 0.9728
# Epoch 32/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0455 - accuracy: 0.9727 - precision: 0.9913 - recall: 0.9714 - val_loss: 0.0840 - val_accuracy: 0.9688 - val_precision: 0.9839 - val_recall: 0.9734
# Epoch 33/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0443 - accuracy: 0.9685 - precision: 0.9913 - recall: 0.9657 - val_loss: 0.0939 - val_accuracy: 0.9668 - val_precision: 0.9622 - val_recall: 0.9933
# Epoch 34/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0452 - accuracy: 0.9716 - precision: 0.9913 - recall: 0.9699 - val_loss: 0.0831 - val_accuracy: 0.9692 - val_precision: 0.9845 - val_recall: 0.9734
# Epoch 35/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0413 - accuracy: 0.9725 - precision: 0.9944 - recall: 0.9682 - val_loss: 0.0909 - val_accuracy: 0.9683 - val_precision: 0.9857 - val_recall: 0.9706
# Epoch 36/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0480 - accuracy: 0.9715 - precision: 0.9901 - recall: 0.9707 - val_loss: 0.0788 - val_accuracy: 0.9722 - val_precision: 0.9858 - val_recall: 0.9759
# Epoch 37/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0427 - accuracy: 0.9739 - precision: 0.9918 - recall: 0.9721 - val_loss: 0.0884 - val_accuracy: 0.9619 - val_precision: 0.9805 - val_recall: 0.9675
# Epoch 38/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0433 - accuracy: 0.9701 - precision: 0.9885 - recall: 0.9703 - val_loss: 0.0805 - val_accuracy: 0.9697 - val_precision: 0.9800 - val_recall: 0.9787
# Epoch 39/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0429 - accuracy: 0.9743 - precision: 0.9900 - recall: 0.9745 - val_loss: 0.0833 - val_accuracy: 0.9673 - val_precision: 0.9761 - val_recall: 0.9793
# Epoch 40/50
# 13/13 [==============================] - 3s 215ms/step - loss: 0.0403 - accuracy: 0.9754 - precision: 0.9942 - recall: 0.9721 - val_loss: 0.0812 - val_accuracy: 0.9702 - val_precision: 0.9800 - val_recall: 0.9793
# Epoch 41/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0398 - accuracy: 0.9745 - precision: 0.9911 - recall: 0.9738 - val_loss: 0.0775 - val_accuracy: 0.9741 - val_precision: 0.9845 - val_recall: 0.9799
# Epoch 42/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0402 - accuracy: 0.9759 - precision: 0.9940 - recall: 0.9734 - val_loss: 0.0780 - val_accuracy: 0.9712 - val_precision: 0.9813 - val_recall: 0.9793
# Epoch 43/50
# 13/13 [==============================] - 3s 215ms/step - loss: 0.0340 - accuracy: 0.9801 - precision: 0.9937 - recall: 0.9791 - val_loss: 0.0741 - val_accuracy: 0.9746 - val_precision: 0.9832 - val_recall: 0.9819
# Epoch 44/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0350 - accuracy: 0.9779 - precision: 0.9903 - recall: 0.9792 - val_loss: 0.0745 - val_accuracy: 0.9688 - val_precision: 0.9717 - val_recall: 0.9860
# Epoch 45/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0407 - accuracy: 0.9755 - precision: 0.9899 - recall: 0.9764 - val_loss: 0.0726 - val_accuracy: 0.9736 - val_precision: 0.9755 - val_recall: 0.9886
# Epoch 46/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0338 - accuracy: 0.9797 - precision: 0.9926 - recall: 0.9793 - val_loss: 0.0769 - val_accuracy: 0.9727 - val_precision: 0.9773 - val_recall: 0.9852
# Epoch 47/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0338 - accuracy: 0.9783 - precision: 0.9938 - recall: 0.9764 - val_loss: 0.0822 - val_accuracy: 0.9727 - val_precision: 0.9853 - val_recall: 0.9775
# Epoch 48/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0341 - accuracy: 0.9775 - precision: 0.9907 - recall: 0.9785 - val_loss: 0.1041 - val_accuracy: 0.9619 - val_precision: 0.9897 - val_recall: 0.9580
# Epoch 49/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0373 - accuracy: 0.9762 - precision: 0.9938 - recall: 0.9735 - val_loss: 0.0748 - val_accuracy: 0.9741 - val_precision: 0.9813 - val_recall: 0.9832
# Epoch 50/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0369 - accuracy: 0.9779 - precision: 0.9927 - recall: 0.9768 - val_loss: 0.0762 - val_accuracy: 0.9688 - val_precision: 0.9757 - val_recall: 0.9821
# 5/5 [==============================] - 48s 11s/step
# Learning Rate: 0.010395
# Hidden Units: 4096
# 1 Hidden Layer
# S value: 71
# AUC score: 0.9880354596739197
# Test Recall: 0.967020023557126
# Test Precision: 0.967020023557126
# Test F1 Scores: 0.967020023557126
#
#
#
#
# Batch Size: 256
# Hidden Units: 4096
# Learning Rate: 0.010395
# 1 Hidden Layer, 4096 units
# S value: 31
# Epoch 1/50
# 13/13 [==============================] - 52s 2s/step - loss: 0.8096 - accuracy: 0.7564 - precision: 0.9025 - recall: 0.7427 - val_loss: 20.3020 - val_accuracy: 0.2871 - val_precision: 1.0000 - val_recall: 0.0260
# Epoch 2/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.1920 - accuracy: 0.9185 - precision: 0.9631 - recall: 0.9243 - val_loss: 1.6570 - val_accuracy: 0.8271 - val_precision: 0.9974 - val_recall: 0.7654
# Epoch 3/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.1272 - accuracy: 0.9322 - precision: 0.9737 - recall: 0.9329 - val_loss: 0.1525 - val_accuracy: 0.9585 - val_precision: 0.9875 - val_recall: 0.9551
# Epoch 4/50
# 13/13 [==============================] - 3s 227ms/step - loss: 0.0916 - accuracy: 0.9454 - precision: 0.9801 - recall: 0.9451 - val_loss: 0.8236 - val_accuracy: 0.8188 - val_precision: 1.0000 - val_recall: 0.7498
# Epoch 5/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0801 - accuracy: 0.9436 - precision: 0.9842 - recall: 0.9383 - val_loss: 0.1020 - val_accuracy: 0.9609 - val_precision: 0.9662 - val_recall: 0.9805
# Epoch 6/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0879 - accuracy: 0.9421 - precision: 0.9811 - recall: 0.9390 - val_loss: 0.0900 - val_accuracy: 0.9683 - val_precision: 0.9805 - val_recall: 0.9760
# Epoch 7/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0798 - accuracy: 0.9506 - precision: 0.9782 - recall: 0.9538 - val_loss: 0.0935 - val_accuracy: 0.9668 - val_precision: 0.9792 - val_recall: 0.9753
# Epoch 8/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0815 - accuracy: 0.9509 - precision: 0.9821 - recall: 0.9500 - val_loss: 0.0983 - val_accuracy: 0.9609 - val_precision: 0.9850 - val_recall: 0.9615
# Epoch 9/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0788 - accuracy: 0.9533 - precision: 0.9799 - recall: 0.9554 - val_loss: 0.1018 - val_accuracy: 0.9604 - val_precision: 0.9876 - val_recall: 0.9579
# Epoch 10/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0682 - accuracy: 0.9524 - precision: 0.9840 - recall: 0.9497 - val_loss: 0.0905 - val_accuracy: 0.9663 - val_precision: 0.9716 - val_recall: 0.9826
# Epoch 11/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0644 - accuracy: 0.9584 - precision: 0.9864 - recall: 0.9563 - val_loss: 0.1019 - val_accuracy: 0.9614 - val_precision: 0.9849 - val_recall: 0.9618
# Epoch 12/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0614 - accuracy: 0.9562 - precision: 0.9831 - recall: 0.9569 - val_loss: 0.1000 - val_accuracy: 0.9653 - val_precision: 0.9891 - val_recall: 0.9634
# Epoch 13/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0625 - accuracy: 0.9554 - precision: 0.9859 - recall: 0.9526 - val_loss: 0.1247 - val_accuracy: 0.9507 - val_precision: 0.9855 - val_recall: 0.9468
# Epoch 14/50
# ...
# Epoch 15/50
# 13/13 [==============================] - 3s 230ms/step - loss: 0.0593 - accuracy: 0.9606 - precision: 0.9897 - recall: 0.9563 - val_loss: 0.0882 - val_accuracy: 0.9692 - val_precision: 0.9819 - val_recall: 0.9760
# Epoch 16/50
# 13/13 [==============================] - 3s 229ms/step - loss: 0.0609 - accuracy: 0.9610 - precision: 0.9863 - recall: 0.9599 - val_loss: 0.0810 - val_accuracy: 0.9707 - val_precision: 0.9742 - val_recall: 0.9859
# Epoch 17/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0591 - accuracy: 0.9609 - precision: 0.9836 - recall: 0.9625 - val_loss: 0.0915 - val_accuracy: 0.9688 - val_precision: 0.9773 - val_recall: 0.9800
# Epoch 18/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0537 - accuracy: 0.9675 - precision: 0.9898 - recall: 0.9653 - val_loss: 0.1053 - val_accuracy: 0.9619 - val_precision: 0.9843 - val_recall: 0.9632
# Epoch 19/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0542 - accuracy: 0.9668 - precision: 0.9904 - recall: 0.9637 - val_loss: 0.0888 - val_accuracy: 0.9658 - val_precision: 0.9667 - val_recall: 0.9873
# Epoch 20/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0615 - accuracy: 0.9622 - precision: 0.9816 - recall: 0.9661 - val_loss: 0.1106 - val_accuracy: 0.9575 - val_precision: 0.9856 - val_recall: 0.9562
# Epoch 21/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0537 - accuracy: 0.9665 - precision: 0.9917 - recall: 0.9623 - val_loss: 0.0812 - val_accuracy: 0.9683 - val_precision: 0.9722 - val_recall: 0.9846
# Epoch 22/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0503 - accuracy: 0.9669 - precision: 0.9912 - recall: 0.9635 - val_loss: 0.0949 - val_accuracy: 0.9683 - val_precision: 0.9832 - val_recall: 0.9733
# Epoch 23/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0508 - accuracy: 0.9689 - precision: 0.9896 - recall: 0.9683 - val_loss: 0.0810 - val_accuracy: 0.9653 - val_precision: 0.9697 - val_recall: 0.9833
# Epoch 24/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0518 - accuracy: 0.9649 - precision: 0.9885 - recall: 0.9634 - val_loss: 0.0876 - val_accuracy: 0.9722 - val_precision: 0.9767 - val_recall: 0.9852
# Epoch 25/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0486 - accuracy: 0.9654 - precision: 0.9879 - recall: 0.9645 - val_loss: 0.0806 - val_accuracy: 0.9653 - val_precision: 0.9666 - val_recall: 0.9866
# Epoch 26/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0474 - accuracy: 0.9682 - precision: 0.9852 - recall: 0.9708 - val_loss: 0.0771 - val_accuracy: 0.9697 - val_precision: 0.9769 - val_recall: 0.9820
# Epoch 27/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0484 - accuracy: 0.9679 - precision: 0.9901 - recall: 0.9658 - val_loss: 0.0896 - val_accuracy: 0.9683 - val_precision: 0.9798 - val_recall: 0.9765
# Epoch 28/50
# 13/13 [==============================] - 3s 234ms/step - loss: 0.0459 - accuracy: 0.9715 - precision: 0.9927 - recall: 0.9680 - val_loss: 0.0898 - val_accuracy: 0.9644 - val_precision: 0.9824 - val_recall: 0.9687
# Epoch 29/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0436 - accuracy: 0.9718 - precision: 0.9918 - recall: 0.9696 - val_loss: 0.0842 - val_accuracy: 0.9707 - val_precision: 0.9774 - val_recall: 0.9826
# Epoch 30/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0408 - accuracy: 0.9742 - precision: 0.9914 - recall: 0.9731 - val_loss: 0.0882 - val_accuracy: 0.9688 - val_precision: 0.9812 - val_recall: 0.9760
# Epoch 31/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0450 - accuracy: 0.9698 - precision: 0.9895 - recall: 0.9689 - val_loss: 0.0823 - val_accuracy: 0.9683 - val_precision: 0.9718 - val_recall: 0.9854
# Epoch 32/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0389 - accuracy: 0.9763 - precision: 0.9928 - recall: 0.9750 - val_loss: 0.0811 - val_accuracy: 0.9688 - val_precision: 0.9723 - val_recall: 0.9853
# Epoch 33/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0434 - accuracy: 0.9735 - precision: 0.9922 - recall: 0.9715 - val_loss: 0.0781 - val_accuracy: 0.9722 - val_precision: 0.9774 - val_recall: 0.9846
# Epoch 34/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0428 - accuracy: 0.9722 - precision: 0.9914 - recall: 0.9709 - val_loss: 0.0813 - val_accuracy: 0.9707 - val_precision: 0.9762 - val_recall: 0.9840
# Epoch 35/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0420 - accuracy: 0.9762 - precision: 0.9892 - recall: 0.9781 - val_loss: 0.0826 - val_accuracy: 0.9692 - val_precision: 0.9773 - val_recall: 0.9806
# Epoch 36/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0383 - accuracy: 0.9746 - precision: 0.9919 - recall: 0.9732 - val_loss: 0.0803 - val_accuracy: 0.9668 - val_precision: 0.9697 - val_recall: 0.9853
# Epoch 37/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0359 - accuracy: 0.9781 - precision: 0.9916 - recall: 0.9783 - val_loss: 0.0816 - val_accuracy: 0.9688 - val_precision: 0.9766 - val_recall: 0.9805
# Epoch 38/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0390 - accuracy: 0.9748 - precision: 0.9885 - recall: 0.9767 - val_loss: 0.0825 - val_accuracy: 0.9707 - val_precision: 0.9800 - val_recall: 0.9800
# Epoch 39/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0312 - accuracy: 0.9817 - precision: 0.9959 - recall: 0.9790 - val_loss: 0.0760 - val_accuracy: 0.9712 - val_precision: 0.9808 - val_recall: 0.9801
# Epoch 40/50
# 13/13 [==============================] - 3s 227ms/step - loss: 0.0355 - accuracy: 0.9770 - precision: 0.9900 - recall: 0.9784 - val_loss: 0.0868 - val_accuracy: 0.9692 - val_precision: 0.9819 - val_recall: 0.9760
# Epoch 41/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0334 - accuracy: 0.9789 - precision: 0.9940 - recall: 0.9771 - val_loss: 0.0870 - val_accuracy: 0.9673 - val_precision: 0.9806 - val_recall: 0.9748
# Epoch 42/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0347 - accuracy: 0.9792 - precision: 0.9920 - recall: 0.9793 - val_loss: 0.0843 - val_accuracy: 0.9697 - val_precision: 0.9826 - val_recall: 0.9761
# Epoch 43/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0352 - accuracy: 0.9771 - precision: 0.9940 - recall: 0.9748 - val_loss: 0.0807 - val_accuracy: 0.9712 - val_precision: 0.9775 - val_recall: 0.9834
# Epoch 44/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0378 - accuracy: 0.9750 - precision: 0.9895 - recall: 0.9763 - val_loss: 0.0853 - val_accuracy: 0.9663 - val_precision: 0.9799 - val_recall: 0.9740
# Epoch 45/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0327 - accuracy: 0.9808 - precision: 0.9947 - recall: 0.9789 - val_loss: 0.0840 - val_accuracy: 0.9688 - val_precision: 0.9766 - val_recall: 0.9806
# Epoch 46/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0347 - accuracy: 0.9786 - precision: 0.9924 - recall: 0.9781 - val_loss: 0.0835 - val_accuracy: 0.9702 - val_precision: 0.9807 - val_recall: 0.9787
# Epoch 47/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0316 - accuracy: 0.9804 - precision: 0.9945 - recall: 0.9786 - val_loss: 0.0861 - val_accuracy: 0.9673 - val_precision: 0.9774 - val_recall: 0.9780
# Epoch 48/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0340 - accuracy: 0.9790 - precision: 0.9943 - recall: 0.9771 - val_loss: 0.0773 - val_accuracy: 0.9722 - val_precision: 0.9800 - val_recall: 0.9819
# Epoch 49/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0346 - accuracy: 0.9806 - precision: 0.9938 - recall: 0.9796 - val_loss: 0.0870 - val_accuracy: 0.9707 - val_precision: 0.9793 - val_recall: 0.9806
# Epoch 50/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0317 - accuracy: 0.9785 - precision: 0.9953 - recall: 0.9753 - val_loss: 0.0790 - val_accuracy: 0.9692 - val_precision: 0.9743 - val_recall: 0.9840
# 5/5 [==============================] - 49s 11s/step
# Learning Rate: 0.010395
# Hidden Units: 4096
# 1 Hidden Layer
# S value: 38
# AUC score: 0.9895159849321912
# Test Recall: 0.9729093050647821
# Test Precision: 0.9627039627039627
# Test F1 Scores: 0.9677797305213826
#
#
#
#
# Batch Size: 256
# Hidden Units: 4096
# Learning Rate: 0.010395
# 1 Hidden Layer, 4096 units
# S value: 48
# Epoch 1/50
# 13/13 [==============================] - 53s 2s/step - loss: 0.7881 - accuracy: 0.7884 - precision: 0.9308 - recall: 0.7653 - val_loss: 7.0065 - val_accuracy: 0.5210 - val_precision: 1.0000 - val_recall: 0.3447
# Epoch 2/50
# 13/13 [==============================] - 3s 227ms/step - loss: 0.2266 - accuracy: 0.9220 - precision: 0.9492 - recall: 0.9444 - val_loss: 0.7205 - val_accuracy: 0.8667 - val_precision: 0.9984 - val_recall: 0.8181
# Epoch 3/50
# 13/13 [==============================] - 3s 227ms/step - loss: 0.1168 - accuracy: 0.9364 - precision: 0.9780 - recall: 0.9345 - val_loss: 1.4885 - val_accuracy: 0.7964 - val_precision: 1.0000 - val_recall: 0.7220
# Epoch 4/50
# 13/13 [==============================] - 3s 235ms/step - loss: 0.1104 - accuracy: 0.9344 - precision: 0.9825 - recall: 0.9263 - val_loss: 0.3442 - val_accuracy: 0.9023 - val_precision: 0.9931 - val_recall: 0.8722
# Epoch 5/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0822 - accuracy: 0.9473 - precision: 0.9828 - recall: 0.9450 - val_loss: 0.2479 - val_accuracy: 0.9170 - val_precision: 0.9948 - val_recall: 0.8910
# Epoch 6/50
# 13/13 [==============================] - 3s 231ms/step - loss: 0.0857 - accuracy: 0.9459 - precision: 0.9805 - recall: 0.9446 - val_loss: 0.1549 - val_accuracy: 0.9478 - val_precision: 0.9894 - val_recall: 0.9382
# Epoch 7/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0783 - accuracy: 0.9486 - precision: 0.9820 - recall: 0.9472 - val_loss: 0.1019 - val_accuracy: 0.9604 - val_precision: 0.9587 - val_recall: 0.9887
# Epoch 8/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0844 - accuracy: 0.9485 - precision: 0.9774 - recall: 0.9513 - val_loss: 0.2433 - val_accuracy: 0.9224 - val_precision: 0.9905 - val_recall: 0.9029
# Epoch 9/50
# 13/13 [==============================] - 3s 228ms/step - loss: 0.0710 - accuracy: 0.9529 - precision: 0.9835 - recall: 0.9515 - val_loss: 0.0863 - val_accuracy: 0.9658 - val_precision: 0.9709 - val_recall: 0.9826
# Epoch 10/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0810 - accuracy: 0.9524 - precision: 0.9779 - recall: 0.9562 - val_loss: 0.1368 - val_accuracy: 0.9468 - val_precision: 0.9887 - val_recall: 0.9379
# Epoch 11/50
# 13/13 [==============================] - 4s 300ms/step - loss: 0.0714 - accuracy: 0.9550 - precision: 0.9870 - recall: 0.9503 - val_loss: 0.2330 - val_accuracy: 0.9219 - val_precision: 0.9919 - val_recall: 0.9009
# Epoch 12/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0855 - accuracy: 0.9458 - precision: 0.9827 - recall: 0.9430 - val_loss: 0.0772 - val_accuracy: 0.9673 - val_precision: 0.9706 - val_recall: 0.9854
# Epoch 13/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0640 - accuracy: 0.9591 - precision: 0.9853 - recall: 0.9584 - val_loss: 0.0901 - val_accuracy: 0.9702 - val_precision: 0.9755 - val_recall: 0.9840
# Epoch 14/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0576 - accuracy: 0.9606 - precision: 0.9885 - recall: 0.9578 - val_loss: 0.0816 - val_accuracy: 0.9688 - val_precision: 0.9674 - val_recall: 0.9907
# Epoch 15/50
# 13/13 [==============================] - 3s 234ms/step - loss: 0.0632 - accuracy: 0.9622 - precision: 0.9820 - recall: 0.9656 - val_loss: 0.0863 - val_accuracy: 0.9668 - val_precision: 0.9728 - val_recall: 0.9820
# Epoch 16/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0714 - accuracy: 0.9516 - precision: 0.9817 - recall: 0.9510 - val_loss: 0.1017 - val_accuracy: 0.9634 - val_precision: 0.9823 - val_recall: 0.9671
# Epoch 17/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0588 - accuracy: 0.9610 - precision: 0.9861 - recall: 0.9602 - val_loss: 0.0981 - val_accuracy: 0.9609 - val_precision: 0.9561 - val_recall: 0.9920
# Epoch 18/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0618 - accuracy: 0.9624 - precision: 0.9851 - recall: 0.9626 - val_loss: 0.1093 - val_accuracy: 0.9604 - val_precision: 0.9848 - val_recall: 0.9603
# Epoch 19/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0551 - accuracy: 0.9631 - precision: 0.9867 - recall: 0.9621 - val_loss: 0.0922 - val_accuracy: 0.9673 - val_precision: 0.9759 - val_recall: 0.9792
# Epoch 20/50
# 13/13 [==============================] - 3s 214ms/step - loss: 0.0518 - accuracy: 0.9656 - precision: 0.9860 - recall: 0.9664 - val_loss: 0.0808 - val_accuracy: 0.9722 - val_precision: 0.9767 - val_recall: 0.9852
# Epoch 21/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0523 - accuracy: 0.9665 - precision: 0.9893 - recall: 0.9649 - val_loss: 0.0922 - val_accuracy: 0.9619 - val_precision: 0.9543 - val_recall: 0.9953
# Epoch 22/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0513 - accuracy: 0.9673 - precision: 0.9871 - recall: 0.9678 - val_loss: 0.0782 - val_accuracy: 0.9692 - val_precision: 0.9805 - val_recall: 0.9773
# Epoch 23/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0577 - accuracy: 0.9617 - precision: 0.9849 - recall: 0.9623 - val_loss: 0.0858 - val_accuracy: 0.9697 - val_precision: 0.9825 - val_recall: 0.9759
# Epoch 24/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0476 - accuracy: 0.9670 - precision: 0.9906 - recall: 0.9644 - val_loss: 0.0887 - val_accuracy: 0.9707 - val_precision: 0.9807 - val_recall: 0.9793
# Epoch 25/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0513 - accuracy: 0.9683 - precision: 0.9862 - recall: 0.9699 - val_loss: 0.0856 - val_accuracy: 0.9722 - val_precision: 0.9839 - val_recall: 0.9780
# Epoch 26/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0456 - accuracy: 0.9672 - precision: 0.9903 - recall: 0.9651 - val_loss: 0.0875 - val_accuracy: 0.9658 - val_precision: 0.9798 - val_recall: 0.9733
# Epoch 27/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0553 - accuracy: 0.9652 - precision: 0.9869 - recall: 0.9650 - val_loss: 0.0824 - val_accuracy: 0.9707 - val_precision: 0.9800 - val_recall: 0.9800
# Epoch 28/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0509 - accuracy: 0.9693 - precision: 0.9873 - recall: 0.9703 - val_loss: 0.0804 - val_accuracy: 0.9741 - val_precision: 0.9827 - val_recall: 0.9820
# Epoch 29/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0468 - accuracy: 0.9705 - precision: 0.9872 - recall: 0.9721 - val_loss: 0.0813 - val_accuracy: 0.9644 - val_precision: 0.9671 - val_recall: 0.9846
# Epoch 30/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0448 - accuracy: 0.9726 - precision: 0.9871 - recall: 0.9752 - val_loss: 0.0863 - val_accuracy: 0.9702 - val_precision: 0.9825 - val_recall: 0.9766
# Epoch 31/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0458 - accuracy: 0.9722 - precision: 0.9923 - recall: 0.9695 - val_loss: 0.0802 - val_accuracy: 0.9702 - val_precision: 0.9705 - val_recall: 0.9893
# Epoch 32/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0422 - accuracy: 0.9759 - precision: 0.9882 - recall: 0.9785 - val_loss: 0.0798 - val_accuracy: 0.9673 - val_precision: 0.9686 - val_recall: 0.9874
# 5/5 [==============================] - 48s 11s/step
# Learning Rate: 0.010395
# Hidden Units: 4096
# 1 Hidden Layer
# S value: 48
# AUC score: 0.988564218694731
# Test Recall: 0.9681978798586572
# Test Precision: 0.958041958041958
# Test F1 Scores: 0.9630931458699471

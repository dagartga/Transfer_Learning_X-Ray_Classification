# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import tensorflow as tf
from kaggle_datasets import KaggleDatasets
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import re
import glob
import random
import seaborn as sns
import matplotlib.pyplot as plt

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# 2023-01-07 19:41:37.626382: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib
# 2023-01-07 19:41:37.626564: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Device:', tpu.master())
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
except:
    strategy = tf.distribute.get_strategy()
print('Number of replicas:', strategy.num_replicas_in_sync)

print(tf.__version__)
# Out:
# Device: grpc://10.0.0.2:8470
# 2023-01-07 19:41:43.180194: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-01-07 19:41:43.182530: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib
# 2023-01-07 19:41:43.182561: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-01-07 19:41:43.182588: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (20b5f353cb42): /proc/driver/nvidia/version does not exist
# 2023-01-07 19:41:43.185588: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-07 19:41:43.187192: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-01-07 19:41:43.216071: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job worker -> {0 -> 10.0.0.2:8470}
# 2023-01-07 19:41:43.216131: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job localhost -> {0 -> localhost:30020}
# 2023-01-07 19:41:43.241368: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job worker -> {0 -> 10.0.0.2:8470}
# 2023-01-07 19:41:43.241423: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job localhost -> {0 -> localhost:30020}
# 2023-01-07 19:41:43.242833: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:411] Started server with target: grpc://localhost:30020
# Number of replicas: 8
# 2.4.1

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
GCS_PATH = KaggleDatasets().get_gcs_path()
BATCH_SIZE = 64*strategy.num_replicas_in_sync
#BATCH_SIZE = 64 # for non-TPU use
IMAGE_SIZE = [180, 180]
EPOCHS = 50

# %%
filenames = tf.io.gfile.glob(str(GCS_PATH + '/chest_xray/train/*/*'))
filenames.extend(tf.io.gfile.glob(str(GCS_PATH + '/chest_xray/val/*/*')))
filenames.extend(tf.io.gfile.glob(str(GCS_PATH + '/chest_xray/test/*/*')))

print(f'The total number of files is {len(filenames)}')
# Out:
# 2023-01-07 19:41:48.930051: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-07 19:41:49.050592: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-07 19:41:49.144660: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-07 19:41:49.233961: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-07 19:41:49.339280: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-07 19:41:49.438231: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-07 19:41:49.545258: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-07 19:41:49.611128: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# The total number of files is 5856

# %%
# split the data into 60:40 for train:test+val
train_files, val_test_files = train_test_split(filenames, test_size=0.4,random_state=18)

# %%
# split the val_test_files to 50:50 to have a final split of 60:20:20 of train:val:test
val_files, test_files = train_test_split(val_test_files, test_size=0.5, random_state=18)

# %%
pct_df = pd.DataFrame(columns = ['data_set', 'label', 'pct'], index = range(6))

totals = {'train':len(train_files), 'val':len(val_files), 'test':len(test_files)}

val_pneum_count = 0
val_norm_count = 0

re_pattern = '.*/(NORMAL|PNEUMONIA)/.*'

for file in val_files:
    re_match = re.match(re_pattern, file)
    if re_match[1] == 'NORMAL':
        val_norm_count += 1
    else:
        val_pneum_count += 1

pct_df.iloc[0, :] = ['val', 'NORMAL', round(100* val_norm_count / totals['val'], 1)]
pct_df.iloc[1, :] = ['val', 'PNEUMONIA', round(100* val_pneum_count / totals['val'], 1)]


test_pneum_count = 0
test_norm_count = 0
for file in test_files:
    re_match = re.match(re_pattern, file)
    if re_match[1] == 'NORMAL':
        test_norm_count += 1
    else:
        test_pneum_count += 1

pct_df.iloc[2, :] = ['test', 'NORMAL', round(100* test_norm_count / totals['test'], 1)]
pct_df.iloc[3, :] = ['test', 'PNEUMONIA', round(100* test_pneum_count / totals['test'], 1)]

train_pneum_count = 0
train_norm_count = 0
for file in train_files:
    re_match = re.match(re_pattern, file)
    if re_match[1] == 'NORMAL':
        train_norm_count += 1
    else:
        train_pneum_count += 1

pct_df.iloc[4, :] = ['train', 'NORMAL', round(100* train_norm_count / totals['train'], 1)]
pct_df.iloc[5, :] = ['train', 'PNEUMONIA', round(100* train_pneum_count / totals['train'], 1)]

# %%
PNEUM_COUNT = val_pneum_count + train_pneum_count + test_pneum_count
NORMAL_COUNT = val_norm_count + train_norm_count + test_norm_count
print(f'Normal: {NORMAL_COUNT}\nPneumonia: {PNEUM_COUNT}')

pct_df
# Out:
# Normal: 1583
# Pneumonia: 4273
#   data_set      label   pct
# 0      val     NORMAL  26.9
# 1      val  PNEUMONIA  73.1
# 2     test     NORMAL  27.6
# 3     test  PNEUMONIA  72.4
# 4    train     NORMAL  26.9
# 5    train  PNEUMONIA  73.1

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_files)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_files)
test_list_ds = tf.data.Dataset.from_tensor_slices(test_files)

#view the file paths for training
print('----Training Files----')
for f in train_list_ds.take(5):
    print(f.numpy())
# Out:
# ----Training Files----
# b'gs://kds-c64d0f53ec9c4abe7fa90871ed8ddc3242cec4843db9c83a9f5d571d/chest_xray/train/PNEUMONIA/person509_virus_1025.jpeg'
# b'gs://kds-c64d0f53ec9c4abe7fa90871ed8ddc3242cec4843db9c83a9f5d571d/chest_xray/train/PNEUMONIA/person671_bacteria_2564.jpeg'
# b'gs://kds-c64d0f53ec9c4abe7fa90871ed8ddc3242cec4843db9c83a9f5d571d/chest_xray/train/PNEUMONIA/person957_virus_1629.jpeg'
# b'gs://kds-c64d0f53ec9c4abe7fa90871ed8ddc3242cec4843db9c83a9f5d571d/chest_xray/test/PNEUMONIA/person81_bacteria_397.jpeg'
# b'gs://kds-c64d0f53ec9c4abe7fa90871ed8ddc3242cec4843db9c83a9f5d571d/chest_xray/train/NORMAL/IM-0500-0001.jpeg'
# 2023-01-07 19:41:50.043702: W ./tensorflow/core/distributed_runtime/eager/destroy_tensor_handle_node.h:57] Ignoring an error encountered when deleting remote tensors handles: Invalid argument: Unable to find the relevant tensor remote_handle: Op ID: 28, Output num: 0
# Additional GRPC error information from remote target /job:worker/replica:0/task:0:
# :{"created":"@1673120510.040421621","description":"Error received from peer ipv4:10.0.0.2:8470","file":"external/com_github_grpc_grpc/src/core/lib/surface/call.cc","file_line":1056,"grpc_message":"Unable to find the relevant tensor remote_handle: Op ID: 28, Output num: 0","grpc_status":3}

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
TEST_IMG_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()

print(f'Train Image Count: {TRAIN_IMG_COUNT}\nVal Image Count: {VAL_IMG_COUNT}\nTest Image Count: {TEST_IMG_COUNT}')
# Out:
# Train Image Count: 3513
# Val Image Count: 1171
# Test Image Count: 1172

# %%
# will label as 1 if pneumonia otherwise 0
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == 'PNEUMONIA'

def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    return tf.image.resize(img, IMAGE_SIZE)

def process_path(file_path):
    label = get_label(file_path)
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
y_train = []
for image, label in train_ds.take(TRAIN_IMG_COUNT):
    y_train.append(label)
    
print('Training Counts')
print(f'Pneumonia count: {np.sum(y_train)}\nNormal count: {TRAIN_IMG_COUNT - np.sum(y_train)}')
# Out:
# 2023-01-07 19:43:43.659332: W ./tensorflow/core/distributed_runtime/eager/destroy_tensor_handle_node.h:57] Ignoring an error encountered when deleting remote tensors handles: Invalid argument: Unable to find the relevant tensor remote_handle: Op ID: 3562, Output num: 1
# Additional GRPC error information from remote target /job:worker/replica:0/task:0:
# :{"created":"@1673120623.659233011","description":"Error received from peer ipv4:10.0.0.2:8470","file":"external/com_github_grpc_grpc/src/core/lib/surface/call.cc","file_line":1056,"grpc_message":"Unable to find the relevant tensor remote_handle: Op ID: 3562, Output num: 1","grpc_status":3}
# Training Counts
# Pneumonia count: 2568
# Normal count: 945

# %%
y_val = []
for image, label in val_ds.take(VAL_IMG_COUNT):
    y_val.append(label)
    
print('Validation Counts')
print(f'Pneumonia count: {np.sum(y_val)}\nNormal count: {VAL_IMG_COUNT - np.sum(y_val)}')
# Out:
# Validation Counts
# Pneumonia count: 856
# Normal count: 315

# %%
y_test = []
for image, label in test_ds.take(TEST_IMG_COUNT):
    y_test.append(label)
    
print('Test Counts')
print(f'Pneumonia count: {np.sum(y_test)}\nNormal count: {TEST_IMG_COUNT - np.sum(y_test)}')
# Out:
# Test Counts
# 2023-01-07 19:45:21.905716: W ./tensorflow/core/distributed_runtime/eager/destroy_tensor_handle_node.h:57] Ignoring an error encountered when deleting remote tensors handles: Invalid argument: Unable to find the relevant tensor remote_handle: Op ID: 24663, Output num: 1
# Additional GRPC error information from remote target /job:worker/replica:0/task:0:
# :{"created":"@1673120721.905584672","description":"Error received from peer ipv4:10.0.0.2:8470","file":"external/com_github_grpc_grpc/src/core/lib/surface/call.cc","file_line":1056,"grpc_message":"Unable to find the relevant tensor remote_handle: Op ID: 24663, Output num: 1","grpc_status":3}
# Pneumonia count: 849
# Normal count: 323

# %%
def prepare_for_training(ds, cache=True, shuffle_buffer_size=1000):
    
    if cache:
        if isinstance(cache, str):
            ds = ds.cache(cache)
        else:
            ds = ds.cache()
            
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    
    ds = ds.repeat()
    
    ds = ds.batch(BATCH_SIZE)
    
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    
    return ds

# %%
train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %%
weight_for_0 = (1 / NORMAL_COUNT)*(TRAIN_IMG_COUNT)/2.0
weight_for_1 = (1 / PNEUM_COUNT)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}
print(f'Weight for class 0: {weight_for_0:.2f}')
print(f'Weight for class 1: {weight_for_1:.2f}')
# Out:
# Weight for class 0: 1.11
# Weight for class 1: 0.41

# %%
# create some metrics for comparing on test results

def precision(y_test, y_pred):
    tp, fp = 0, 0
    
    for i in range(len(y_test)):
        if y_test[i] >= 0.5 and y_pred[i] >= 0.5:
            tp += 1
        elif y_test[i] < 0.5 and y_pred[i] >= 0.5:
            fp += 1
            
    return tp / (tp + fp)

def recall(y_test, y_pred):
    tp, fn = 0, 0
    
    for i in range(len(y_test)):
        if y_test[i] >= 0.5 and y_pred[i] >= 0.5:
            tp += 1
        elif y_test[i] >= 0.5 and y_pred[i] < 0.5:
            fn += 1
            
    return tp / (tp + fn)

def f1_score(y_test, y_pred):
    numerator = precision(y_test, y_pred) * recall(y_test, y_pred)
    denominator = precision(y_test, y_pred) + recall(y_test, y_pred)
    
    return 2 * (numerator / denominator)

# %% [markdown]
# ## Fine Tune the Model
#
# ### Try different learning rate decays by adjusting the s value

# %%
# add exponential decay to try to improve fine tuning
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 ** (epoch / s)
    return exponential_decay_fn

# %%
# use learning rate that gave best results in the learning rate hyperparameter tuning
learning_rate = 0.06103
# use hidden_units that gave best results in the hidden units hyperparameter tuning
hidden_units = 4096
# use mini batch size that gave best results in the mini batch hyperparameter tuning
mini_batch = 32

# try 8 different decay rates
for _ in range(8):
    
    s = random.randint(10, 80)
    
    BATCH_SIZE = mini_batch*strategy.num_replicas_in_sync
    print(f'\n\nBatch Size: {BATCH_SIZE}')    
    print(f'Hidden Units: {hidden_units}')
    print(f'Learning Rate: {learning_rate}')
    print(f'1 Hidden Layer, {hidden_units} units')
    print(f'S value: {s}')
    
    with strategy.scope():
        
        base_model = tf.keras.applications.densenet.DenseNet201(
                        input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3),
                        include_top=False,
                        weights='imagenet'
                        )
        base_model.trainable = False
        
        
        
        x=base_model.output
        inputs = tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))
        x = base_model(inputs, training=False)
        x = tf.keras.layers.GlobalAveragePooling2D()(x)
        x = tf.keras.layers.Dropout(0.3)(x)
        x = tf.keras.layers.Dense(hidden_units, activation='relu')(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.Dropout(0.3)(x)
            
        outputs = tf.keras.layers.Dense(1, activation='sigmoid')(x)
        model = tf.keras.Model(inputs, outputs)
        
        METRICS = [
                'accuracy',
                tf.keras.metrics.Precision(name='precision'),
                tf.keras.metrics.Recall(name='recall')
                ]
        
        model.compile(
                    optimizer='adam',
                    loss='binary_crossentropy',
                    metrics=METRICS
                     )
    
       
        checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(f"densenet_{learning_rate}_{hidden_units}_{BATCH_SIZE}_1layer_{s}_xray_model.h5", save_best_only=True)
        early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=20, restore_best_weights=True)
        exponential_decay_fn = exponential_decay(learning_rate, s)
        lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)
    
        history = model.fit(
                            train_ds,
                            steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
                            epochs=EPOCHS,
                            validation_data=val_ds,
                            validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
                            class_weight=class_weight,
                            callbacks=[checkpoint_cb, early_stopping_cb, lr_scheduler]
                            )
# Out:
# Batch Size: 256
# Hidden Units: 4096
# Learning Rate: 0.06103
# 1 Hidden Layer, 4096 units
# S value: 66
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74842112/74836368 [==============================] - 0s 0us/step
# Epoch 1/50
# 13/13 [==============================] - 139s 6s/step - loss: 5.6139 - accuracy: 0.7266 - precision: 0.8830 - recall: 0.7193 - val_loss: 125.1199 - val_accuracy: 0.6885 - val_precision: 0.9988 - val_recall: 0.5742
# Epoch 2/50
# 13/13 [==============================] - 3s 222ms/step - loss: 3.0673 - accuracy: 0.9306 - precision: 0.9588 - recall: 0.9462 - val_loss: 3.3895 - val_accuracy: 0.9058 - val_precision: 0.9615 - val_recall: 0.9066
# Epoch 3/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.7739 - accuracy: 0.9155 - precision: 0.9646 - recall: 0.9187 - val_loss: 4.8453 - val_accuracy: 0.7964 - val_precision: 1.0000 - val_recall: 0.7207
# Epoch 4/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.4596 - accuracy: 0.9086 - precision: 0.9719 - recall: 0.9022 - val_loss: 0.8159 - val_accuracy: 0.8979 - val_precision: 0.9931 - val_recall: 0.8659
# Epoch 5/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.2012 - accuracy: 0.9243 - precision: 0.9754 - recall: 0.9197 - val_loss: 0.1437 - val_accuracy: 0.9688 - val_precision: 0.9774 - val_recall: 0.9800
# Epoch 6/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.1744 - accuracy: 0.9224 - precision: 0.9767 - recall: 0.9158 - val_loss: 0.1652 - val_accuracy: 0.9653 - val_precision: 0.9674 - val_recall: 0.9860
# Epoch 7/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.1247 - accuracy: 0.9459 - precision: 0.9787 - recall: 0.9461 - val_loss: 0.2447 - val_accuracy: 0.9507 - val_precision: 0.9468 - val_recall: 0.9880
# Epoch 8/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.1342 - accuracy: 0.9335 - precision: 0.9785 - recall: 0.9293 - val_loss: 0.1285 - val_accuracy: 0.9678 - val_precision: 0.9857 - val_recall: 0.9699
# Epoch 9/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.1133 - accuracy: 0.9447 - precision: 0.9771 - recall: 0.9459 - val_loss: 0.1243 - val_accuracy: 0.9604 - val_precision: 0.9567 - val_recall: 0.9906
# Epoch 10/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.1078 - accuracy: 0.9316 - precision: 0.9794 - recall: 0.9263 - val_loss: 0.3152 - val_accuracy: 0.9219 - val_precision: 0.9034 - val_recall: 0.9993
# Epoch 11/50
# 13/13 [==============================] - 3s 213ms/step - loss: 0.1168 - accuracy: 0.9466 - precision: 0.9730 - recall: 0.9531 - val_loss: 0.2319 - val_accuracy: 0.9341 - val_precision: 0.9170 - val_recall: 1.0000
# Epoch 12/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0966 - accuracy: 0.9494 - precision: 0.9782 - recall: 0.9524 - val_loss: 0.1878 - val_accuracy: 0.9453 - val_precision: 0.9320 - val_recall: 0.9987
# Epoch 13/50
# 13/13 [==============================] - 3s 215ms/step - loss: 0.1026 - accuracy: 0.9485 - precision: 0.9751 - recall: 0.9538 - val_loss: 0.1323 - val_accuracy: 0.9575 - val_precision: 0.9496 - val_recall: 0.9947
# Epoch 14/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0852 - accuracy: 0.9451 - precision: 0.9839 - recall: 0.9405 - val_loss: 0.1342 - val_accuracy: 0.9526 - val_precision: 0.9453 - val_recall: 0.9926
# Epoch 15/50
# 13/13 [==============================] - 3s 214ms/step - loss: 0.0754 - accuracy: 0.9529 - precision: 0.9817 - recall: 0.9532 - val_loss: 0.1389 - val_accuracy: 0.9531 - val_precision: 0.9500 - val_recall: 0.9880
# Epoch 16/50
# 13/13 [==============================] - 3s 215ms/step - loss: 0.0754 - accuracy: 0.9512 - precision: 0.9818 - recall: 0.9503 - val_loss: 0.1102 - val_accuracy: 0.9658 - val_precision: 0.9787 - val_recall: 0.9748
# Epoch 17/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0783 - accuracy: 0.9504 - precision: 0.9843 - recall: 0.9475 - val_loss: 0.1522 - val_accuracy: 0.9434 - val_precision: 0.9323 - val_recall: 0.9947
# Epoch 18/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0906 - accuracy: 0.9473 - precision: 0.9814 - recall: 0.9455 - val_loss: 0.1436 - val_accuracy: 0.9487 - val_precision: 0.9373 - val_recall: 0.9960
# Epoch 19/50
# 13/13 [==============================] - 3s 212ms/step - loss: 0.1071 - accuracy: 0.9456 - precision: 0.9724 - recall: 0.9522 - val_loss: 0.0984 - val_accuracy: 0.9688 - val_precision: 0.9730 - val_recall: 0.9847
# Epoch 20/50
# 13/13 [==============================] - 4s 291ms/step - loss: 0.0850 - accuracy: 0.9559 - precision: 0.9759 - recall: 0.9634 - val_loss: 0.1489 - val_accuracy: 0.9502 - val_precision: 0.9780 - val_recall: 0.9531
# Epoch 21/50
# 13/13 [==============================] - 3s 247ms/step - loss: 0.0732 - accuracy: 0.9533 - precision: 0.9889 - recall: 0.9468 - val_loss: 0.0858 - val_accuracy: 0.9688 - val_precision: 0.9734 - val_recall: 0.9838
# Epoch 22/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0675 - accuracy: 0.9558 - precision: 0.9872 - recall: 0.9522 - val_loss: 0.1016 - val_accuracy: 0.9639 - val_precision: 0.9770 - val_recall: 0.9731
# Epoch 23/50
# 13/13 [==============================] - 3s 215ms/step - loss: 0.0699 - accuracy: 0.9558 - precision: 0.9861 - recall: 0.9536 - val_loss: 0.1335 - val_accuracy: 0.9575 - val_precision: 0.9662 - val_recall: 0.9759
# Epoch 24/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0795 - accuracy: 0.9509 - precision: 0.9889 - recall: 0.9432 - val_loss: 0.1207 - val_accuracy: 0.9531 - val_precision: 0.9467 - val_recall: 0.9920
# Epoch 25/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0685 - accuracy: 0.9617 - precision: 0.9816 - recall: 0.9657 - val_loss: 0.0915 - val_accuracy: 0.9653 - val_precision: 0.9735 - val_recall: 0.9793
# Epoch 26/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0644 - accuracy: 0.9552 - precision: 0.9865 - recall: 0.9514 - val_loss: 0.1759 - val_accuracy: 0.9355 - val_precision: 0.9206 - val_recall: 0.9966
# Epoch 27/50
# 13/13 [==============================] - 3s 214ms/step - loss: 0.0665 - accuracy: 0.9596 - precision: 0.9849 - recall: 0.9593 - val_loss: 0.1302 - val_accuracy: 0.9517 - val_precision: 0.9441 - val_recall: 0.9927
# Epoch 28/50
# 13/13 [==============================] - 3s 212ms/step - loss: 0.0656 - accuracy: 0.9584 - precision: 0.9828 - recall: 0.9601 - val_loss: 0.0890 - val_accuracy: 0.9707 - val_precision: 0.9782 - val_recall: 0.9821
# Epoch 29/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0631 - accuracy: 0.9583 - precision: 0.9876 - recall: 0.9555 - val_loss: 0.1012 - val_accuracy: 0.9619 - val_precision: 0.9619 - val_recall: 0.9874
# Epoch 30/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0611 - accuracy: 0.9594 - precision: 0.9839 - recall: 0.9599 - val_loss: 0.0916 - val_accuracy: 0.9639 - val_precision: 0.9654 - val_recall: 0.9860
# Epoch 31/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0544 - accuracy: 0.9702 - precision: 0.9873 - recall: 0.9719 - val_loss: 0.0910 - val_accuracy: 0.9678 - val_precision: 0.9684 - val_recall: 0.9879
# Epoch 32/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0542 - accuracy: 0.9658 - precision: 0.9862 - recall: 0.9666 - val_loss: 0.0853 - val_accuracy: 0.9702 - val_precision: 0.9774 - val_recall: 0.9820
# Epoch 33/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0548 - accuracy: 0.9651 - precision: 0.9893 - recall: 0.9627 - val_loss: 0.1006 - val_accuracy: 0.9619 - val_precision: 0.9830 - val_recall: 0.9646
# Epoch 34/50
# 13/13 [==============================] - 3s 227ms/step - loss: 0.0623 - accuracy: 0.9593 - precision: 0.9893 - recall: 0.9546 - val_loss: 0.0829 - val_accuracy: 0.9688 - val_precision: 0.9741 - val_recall: 0.9832
# Epoch 35/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0489 - accuracy: 0.9663 - precision: 0.9888 - recall: 0.9647 - val_loss: 0.0891 - val_accuracy: 0.9717 - val_precision: 0.9736 - val_recall: 0.9879
# Epoch 36/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0481 - accuracy: 0.9708 - precision: 0.9894 - recall: 0.9702 - val_loss: 0.0929 - val_accuracy: 0.9639 - val_precision: 0.9671 - val_recall: 0.9840
# Epoch 37/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0510 - accuracy: 0.9679 - precision: 0.9875 - recall: 0.9686 - val_loss: 0.0882 - val_accuracy: 0.9668 - val_precision: 0.9748 - val_recall: 0.9800
# Epoch 38/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0447 - accuracy: 0.9690 - precision: 0.9917 - recall: 0.9658 - val_loss: 0.0837 - val_accuracy: 0.9692 - val_precision: 0.9741 - val_recall: 0.9839
# Epoch 39/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0490 - accuracy: 0.9726 - precision: 0.9897 - recall: 0.9726 - val_loss: 0.0962 - val_accuracy: 0.9639 - val_precision: 0.9616 - val_recall: 0.9900
# Epoch 40/50
# 13/13 [==============================] - 3s 227ms/step - loss: 0.0486 - accuracy: 0.9713 - precision: 0.9900 - recall: 0.9705 - val_loss: 0.0923 - val_accuracy: 0.9683 - val_precision: 0.9844 - val_recall: 0.9719
# Epoch 41/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0467 - accuracy: 0.9601 - precision: 0.9920 - recall: 0.9528 - val_loss: 0.1149 - val_accuracy: 0.9561 - val_precision: 0.9827 - val_recall: 0.9563
# Epoch 42/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0533 - accuracy: 0.9609 - precision: 0.9917 - recall: 0.9550 - val_loss: 0.0950 - val_accuracy: 0.9658 - val_precision: 0.9710 - val_recall: 0.9826
# Epoch 43/50
# 13/13 [==============================] - 3s 214ms/step - loss: 0.0431 - accuracy: 0.9738 - precision: 0.9911 - recall: 0.9728 - val_loss: 0.1015 - val_accuracy: 0.9629 - val_precision: 0.9772 - val_recall: 0.9719
# Epoch 44/50
# 13/13 [==============================] - 3s 215ms/step - loss: 0.0396 - accuracy: 0.9748 - precision: 0.9936 - recall: 0.9717 - val_loss: 0.0887 - val_accuracy: 0.9658 - val_precision: 0.9845 - val_recall: 0.9688
# Epoch 45/50
# 13/13 [==============================] - 3s 215ms/step - loss: 0.0418 - accuracy: 0.9712 - precision: 0.9925 - recall: 0.9681 - val_loss: 0.0925 - val_accuracy: 0.9688 - val_precision: 0.9817 - val_recall: 0.9751
# Epoch 46/50
# 13/13 [==============================] - 3s 215ms/step - loss: 0.0560 - accuracy: 0.9636 - precision: 0.9858 - recall: 0.9640 - val_loss: 0.1012 - val_accuracy: 0.9658 - val_precision: 0.9754 - val_recall: 0.9780
# Epoch 47/50
# 13/13 [==============================] - 3s 211ms/step - loss: 0.0491 - accuracy: 0.9721 - precision: 0.9878 - recall: 0.9734 - val_loss: 0.0854 - val_accuracy: 0.9673 - val_precision: 0.9710 - val_recall: 0.9846
# Epoch 48/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0467 - accuracy: 0.9692 - precision: 0.9860 - recall: 0.9714 - val_loss: 0.1035 - val_accuracy: 0.9663 - val_precision: 0.9844 - val_recall: 0.9693
# Epoch 49/50
# 13/13 [==============================] - 3s 211ms/step - loss: 0.0446 - accuracy: 0.9688 - precision: 0.9922 - recall: 0.9649 - val_loss: 0.0747 - val_accuracy: 0.9727 - val_precision: 0.9806 - val_recall: 0.9819
# Epoch 50/50
# 13/13 [==============================] - 3s 212ms/step - loss: 0.0387 - accuracy: 0.9709 - precision: 0.9949 - recall: 0.9652 - val_loss: 0.0861 - val_accuracy: 0.9717 - val_precision: 0.9799 - val_recall: 0.9812
#
#
# Batch Size: 256
# Hidden Units: 4096
# Learning Rate: 0.06103
# 1 Hidden Layer, 4096 units
# S value: 64
# Epoch 1/50
# 13/13 [==============================] - 51s 2s/step - loss: 5.4642 - accuracy: 0.7371 - precision: 0.8890 - recall: 0.7275 - val_loss: 115.2272 - val_accuracy: 0.6543 - val_precision: 1.0000 - val_recall: 0.5289
# Epoch 2/50
# 13/13 [==============================] - 3s 222ms/step - loss: 3.1147 - accuracy: 0.9190 - precision: 0.9529 - recall: 0.9361 - val_loss: 22.7294 - val_accuracy: 0.5640 - val_precision: 0.9917 - val_recall: 0.4020
# Epoch 3/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.9202 - accuracy: 0.9071 - precision: 0.9583 - recall: 0.9135 - val_loss: 0.9234 - val_accuracy: 0.9531 - val_precision: 0.9680 - val_recall: 0.9680
# Epoch 4/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.4677 - accuracy: 0.9187 - precision: 0.9758 - recall: 0.9104 - val_loss: 6.9662 - val_accuracy: 0.5942 - val_precision: 1.0000 - val_recall: 0.4438
# Epoch 5/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.2049 - accuracy: 0.9377 - precision: 0.9726 - recall: 0.9417 - val_loss: 0.7222 - val_accuracy: 0.8799 - val_precision: 0.9921 - val_recall: 0.8416
# Epoch 6/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.1464 - accuracy: 0.9368 - precision: 0.9786 - recall: 0.9338 - val_loss: 0.1754 - val_accuracy: 0.9634 - val_precision: 0.9856 - val_recall: 0.9638
# Epoch 7/50
# 13/13 [==============================] - 3s 229ms/step - loss: 0.1357 - accuracy: 0.9343 - precision: 0.9800 - recall: 0.9296 - val_loss: 0.2925 - val_accuracy: 0.9302 - val_precision: 0.9892 - val_recall: 0.9146
# Epoch 8/50
# 13/13 [==============================] - 3s 233ms/step - loss: 0.1375 - accuracy: 0.9329 - precision: 0.9783 - recall: 0.9296 - val_loss: 0.1131 - val_accuracy: 0.9624 - val_precision: 0.9670 - val_recall: 0.9819
# Epoch 9/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.1038 - accuracy: 0.9447 - precision: 0.9764 - recall: 0.9467 - val_loss: 0.2630 - val_accuracy: 0.9160 - val_precision: 0.8982 - val_recall: 0.9993
# Epoch 10/50
# 13/13 [==============================] - 3s 228ms/step - loss: 0.1167 - accuracy: 0.9397 - precision: 0.9766 - recall: 0.9400 - val_loss: 0.1492 - val_accuracy: 0.9551 - val_precision: 0.9536 - val_recall: 0.9867
# Epoch 11/50
# 13/13 [==============================] - 3s 235ms/step - loss: 0.1401 - accuracy: 0.9367 - precision: 0.9732 - recall: 0.9389 - val_loss: 0.3510 - val_accuracy: 0.9146 - val_precision: 0.8958 - val_recall: 0.9987
# Epoch 12/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.1656 - accuracy: 0.9341 - precision: 0.9603 - recall: 0.9494 - val_loss: 0.3194 - val_accuracy: 0.9248 - val_precision: 0.9821 - val_recall: 0.9139
# Epoch 13/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.1328 - accuracy: 0.9347 - precision: 0.9839 - recall: 0.9253 - val_loss: 0.2254 - val_accuracy: 0.9238 - val_precision: 0.9071 - val_recall: 0.9980
# Epoch 14/50
# 13/13 [==============================] - 3s 229ms/step - loss: 0.0793 - accuracy: 0.9488 - precision: 0.9817 - recall: 0.9478 - val_loss: 0.1092 - val_accuracy: 0.9619 - val_precision: 0.9596 - val_recall: 0.9893
# Epoch 15/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0773 - accuracy: 0.9511 - precision: 0.9871 - recall: 0.9460 - val_loss: 0.1872 - val_accuracy: 0.9395 - val_precision: 0.9241 - val_recall: 0.9993
# Epoch 16/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0761 - accuracy: 0.9514 - precision: 0.9833 - recall: 0.9498 - val_loss: 0.1462 - val_accuracy: 0.9521 - val_precision: 0.9437 - val_recall: 0.9940
# Epoch 17/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0797 - accuracy: 0.9515 - precision: 0.9778 - recall: 0.9552 - val_loss: 0.1084 - val_accuracy: 0.9556 - val_precision: 0.9513 - val_recall: 0.9900
# Epoch 18/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0813 - accuracy: 0.9513 - precision: 0.9775 - recall: 0.9549 - val_loss: 0.0925 - val_accuracy: 0.9639 - val_precision: 0.9681 - val_recall: 0.9835
# Epoch 19/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0705 - accuracy: 0.9559 - precision: 0.9855 - recall: 0.9535 - val_loss: 0.1041 - val_accuracy: 0.9644 - val_precision: 0.9630 - val_recall: 0.9893
# Epoch 20/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0777 - accuracy: 0.9527 - precision: 0.9787 - recall: 0.9561 - val_loss: 0.1263 - val_accuracy: 0.9570 - val_precision: 0.9753 - val_recall: 0.9662
# Epoch 21/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0900 - accuracy: 0.9481 - precision: 0.9854 - recall: 0.9427 - val_loss: 0.0979 - val_accuracy: 0.9634 - val_precision: 0.9647 - val_recall: 0.9860
# Epoch 22/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0871 - accuracy: 0.9509 - precision: 0.9768 - recall: 0.9557 - val_loss: 0.1039 - val_accuracy: 0.9619 - val_precision: 0.9584 - val_recall: 0.9906
# Epoch 23/50
# 13/13 [==============================] - 3s 228ms/step - loss: 0.0678 - accuracy: 0.9588 - precision: 0.9865 - recall: 0.9568 - val_loss: 0.0971 - val_accuracy: 0.9600 - val_precision: 0.9603 - val_recall: 0.9860
# Epoch 24/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0666 - accuracy: 0.9540 - precision: 0.9817 - recall: 0.9548 - val_loss: 0.0937 - val_accuracy: 0.9678 - val_precision: 0.9716 - val_recall: 0.9846
# Epoch 25/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0596 - accuracy: 0.9618 - precision: 0.9854 - recall: 0.9618 - val_loss: 0.0933 - val_accuracy: 0.9678 - val_precision: 0.9710 - val_recall: 0.9853
# Epoch 26/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0608 - accuracy: 0.9630 - precision: 0.9852 - recall: 0.9635 - val_loss: 0.1694 - val_accuracy: 0.9419 - val_precision: 0.9783 - val_recall: 0.9407
# Epoch 27/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0867 - accuracy: 0.9481 - precision: 0.9856 - recall: 0.9421 - val_loss: 0.0877 - val_accuracy: 0.9668 - val_precision: 0.9741 - val_recall: 0.9806
# Epoch 28/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0612 - accuracy: 0.9633 - precision: 0.9843 - recall: 0.9646 - val_loss: 0.0826 - val_accuracy: 0.9683 - val_precision: 0.9724 - val_recall: 0.9847
# Epoch 29/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0534 - accuracy: 0.9653 - precision: 0.9907 - recall: 0.9614 - val_loss: 0.0835 - val_accuracy: 0.9702 - val_precision: 0.9782 - val_recall: 0.9814
# Epoch 30/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0570 - accuracy: 0.9647 - precision: 0.9886 - recall: 0.9628 - val_loss: 0.0936 - val_accuracy: 0.9639 - val_precision: 0.9617 - val_recall: 0.9900
# Epoch 31/50
# 13/13 [==============================] - 3s 229ms/step - loss: 0.0572 - accuracy: 0.9645 - precision: 0.9849 - recall: 0.9662 - val_loss: 0.0980 - val_accuracy: 0.9692 - val_precision: 0.9780 - val_recall: 0.9799
# Epoch 32/50
# 13/13 [==============================] - 3s 235ms/step - loss: 0.0568 - accuracy: 0.9643 - precision: 0.9907 - recall: 0.9600 - val_loss: 0.0957 - val_accuracy: 0.9644 - val_precision: 0.9817 - val_recall: 0.9692
# Epoch 33/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0598 - accuracy: 0.9577 - precision: 0.9879 - recall: 0.9540 - val_loss: 0.0901 - val_accuracy: 0.9634 - val_precision: 0.9601 - val_recall: 0.9914
# Epoch 34/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0599 - accuracy: 0.9600 - precision: 0.9840 - recall: 0.9608 - val_loss: 0.0987 - val_accuracy: 0.9692 - val_precision: 0.9793 - val_recall: 0.9786
# Epoch 35/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0570 - accuracy: 0.9598 - precision: 0.9900 - recall: 0.9551 - val_loss: 0.0910 - val_accuracy: 0.9648 - val_precision: 0.9838 - val_recall: 0.9680
# Epoch 36/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0580 - accuracy: 0.9595 - precision: 0.9896 - recall: 0.9549 - val_loss: 0.0811 - val_accuracy: 0.9683 - val_precision: 0.9756 - val_recall: 0.9814
# Epoch 37/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0554 - accuracy: 0.9663 - precision: 0.9846 - recall: 0.9688 - val_loss: 0.0797 - val_accuracy: 0.9712 - val_precision: 0.9831 - val_recall: 0.9772
# Epoch 38/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0546 - accuracy: 0.9687 - precision: 0.9881 - recall: 0.9692 - val_loss: 0.0904 - val_accuracy: 0.9644 - val_precision: 0.9609 - val_recall: 0.9913
# Epoch 39/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0558 - accuracy: 0.9657 - precision: 0.9874 - recall: 0.9654 - val_loss: 0.0869 - val_accuracy: 0.9653 - val_precision: 0.9760 - val_recall: 0.9767
# Epoch 40/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0516 - accuracy: 0.9650 - precision: 0.9861 - recall: 0.9657 - val_loss: 0.0953 - val_accuracy: 0.9678 - val_precision: 0.9825 - val_recall: 0.9733
# Epoch 41/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0481 - accuracy: 0.9669 - precision: 0.9936 - recall: 0.9606 - val_loss: 0.0967 - val_accuracy: 0.9692 - val_precision: 0.9843 - val_recall: 0.9730
# Epoch 42/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0500 - accuracy: 0.9656 - precision: 0.9909 - recall: 0.9620 - val_loss: 0.0804 - val_accuracy: 0.9692 - val_precision: 0.9767 - val_recall: 0.9813
# Epoch 43/50
# 13/13 [==============================] - 3s 215ms/step - loss: 0.0456 - accuracy: 0.9685 - precision: 0.9909 - recall: 0.9663 - val_loss: 0.0959 - val_accuracy: 0.9692 - val_precision: 0.9786 - val_recall: 0.9793
# Epoch 44/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0502 - accuracy: 0.9641 - precision: 0.9891 - recall: 0.9621 - val_loss: 0.0972 - val_accuracy: 0.9673 - val_precision: 0.9805 - val_recall: 0.9745
# Epoch 45/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0423 - accuracy: 0.9737 - precision: 0.9912 - recall: 0.9726 - val_loss: 0.0772 - val_accuracy: 0.9717 - val_precision: 0.9807 - val_recall: 0.9807
# Epoch 46/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0480 - accuracy: 0.9718 - precision: 0.9900 - recall: 0.9711 - val_loss: 0.0868 - val_accuracy: 0.9702 - val_precision: 0.9799 - val_recall: 0.9793
# Epoch 47/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0479 - accuracy: 0.9701 - precision: 0.9911 - recall: 0.9677 - val_loss: 0.0794 - val_accuracy: 0.9707 - val_precision: 0.9850 - val_recall: 0.9744
# Epoch 48/50
# 13/13 [==============================] - 3s 215ms/step - loss: 0.0495 - accuracy: 0.9692 - precision: 0.9895 - recall: 0.9681 - val_loss: 0.0794 - val_accuracy: 0.9731 - val_precision: 0.9819 - val_recall: 0.9812
# Epoch 49/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0498 - accuracy: 0.9662 - precision: 0.9872 - recall: 0.9661 - val_loss: 0.0773 - val_accuracy: 0.9697 - val_precision: 0.9794 - val_recall: 0.9794
# Epoch 50/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0456 - accuracy: 0.9698 - precision: 0.9897 - recall: 0.9688 - val_loss: 0.0787 - val_accuracy: 0.9712 - val_precision: 0.9806 - val_recall: 0.9799
#
#
# Batch Size: 256
# Hidden Units: 4096
# Learning Rate: 0.06103
# 1 Hidden Layer, 4096 units
# S value: 17
# Epoch 1/50
# 13/13 [==============================] - 52s 2s/step - loss: 5.7967 - accuracy: 0.7451 - precision: 0.8903 - recall: 0.7392 - val_loss: 71.1211 - val_accuracy: 0.8125 - val_precision: 0.9946 - val_recall: 0.7465
# Epoch 2/50
# 13/13 [==============================] - 3s 223ms/step - loss: 3.2649 - accuracy: 0.9244 - precision: 0.9613 - recall: 0.9353 - val_loss: 72.1238 - val_accuracy: 0.3926 - val_precision: 1.0000 - val_recall: 0.1668
# Epoch 3/50
# 13/13 [==============================] - 3s 226ms/step - loss: 1.1443 - accuracy: 0.9118 - precision: 0.9630 - recall: 0.9152 - val_loss: 11.7628 - val_accuracy: 0.7305 - val_precision: 1.0000 - val_recall: 0.6310
# Epoch 4/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.6027 - accuracy: 0.9222 - precision: 0.9739 - recall: 0.9187 - val_loss: 1.6091 - val_accuracy: 0.8760 - val_precision: 0.9936 - val_recall: 0.8353
# Epoch 5/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.3445 - accuracy: 0.9346 - precision: 0.9732 - recall: 0.9374 - val_loss: 5.2940 - val_accuracy: 0.7329 - val_precision: 1.0000 - val_recall: 0.6336
# Epoch 6/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.3680 - accuracy: 0.9154 - precision: 0.9703 - recall: 0.9124 - val_loss: 3.2273 - val_accuracy: 0.8203 - val_precision: 0.8029 - val_recall: 1.0000
# Epoch 7/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.3395 - accuracy: 0.9331 - precision: 0.9643 - recall: 0.9433 - val_loss: 0.2935 - val_accuracy: 0.9526 - val_precision: 0.9868 - val_recall: 0.9480
# Epoch 8/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.2292 - accuracy: 0.9336 - precision: 0.9812 - recall: 0.9272 - val_loss: 0.5187 - val_accuracy: 0.9277 - val_precision: 0.9913 - val_recall: 0.9092
# Epoch 9/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.2327 - accuracy: 0.9273 - precision: 0.9793 - recall: 0.9199 - val_loss: 0.3121 - val_accuracy: 0.9478 - val_precision: 0.9846 - val_recall: 0.9430
# Epoch 10/50
# 13/13 [==============================] - 3s 215ms/step - loss: 0.2032 - accuracy: 0.9383 - precision: 0.9744 - recall: 0.9401 - val_loss: 0.1606 - val_accuracy: 0.9614 - val_precision: 0.9715 - val_recall: 0.9760
# Epoch 11/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.1370 - accuracy: 0.9464 - precision: 0.9732 - recall: 0.9523 - val_loss: 0.1798 - val_accuracy: 0.9536 - val_precision: 0.9543 - val_recall: 0.9832
# Epoch 12/50
# 13/13 [==============================] - 3s 227ms/step - loss: 0.1337 - accuracy: 0.9428 - precision: 0.9741 - recall: 0.9468 - val_loss: 0.2288 - val_accuracy: 0.9517 - val_precision: 0.9421 - val_recall: 0.9953
# Epoch 13/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.1199 - accuracy: 0.9542 - precision: 0.9797 - recall: 0.9576 - val_loss: 0.2056 - val_accuracy: 0.9487 - val_precision: 0.9373 - val_recall: 0.9967
# Epoch 14/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.1328 - accuracy: 0.9495 - precision: 0.9741 - recall: 0.9566 - val_loss: 0.1833 - val_accuracy: 0.9517 - val_precision: 0.9422 - val_recall: 0.9946
# Epoch 15/50
# 13/13 [==============================] - 3s 214ms/step - loss: 0.1081 - accuracy: 0.9490 - precision: 0.9789 - recall: 0.9515 - val_loss: 0.1810 - val_accuracy: 0.9575 - val_precision: 0.9478 - val_recall: 0.9967
# Epoch 16/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0963 - accuracy: 0.9531 - precision: 0.9809 - recall: 0.9544 - val_loss: 0.2239 - val_accuracy: 0.9443 - val_precision: 0.9309 - val_recall: 0.9980
# Epoch 17/50
# 13/13 [==============================] - 3s 215ms/step - loss: 0.0937 - accuracy: 0.9560 - precision: 0.9807 - recall: 0.9586 - val_loss: 0.1235 - val_accuracy: 0.9575 - val_precision: 0.9590 - val_recall: 0.9840
# Epoch 18/50
# 13/13 [==============================] - 3s 229ms/step - loss: 0.1043 - accuracy: 0.9486 - precision: 0.9816 - recall: 0.9476 - val_loss: 0.1125 - val_accuracy: 0.9644 - val_precision: 0.9666 - val_recall: 0.9853
# Epoch 19/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0960 - accuracy: 0.9471 - precision: 0.9773 - recall: 0.9494 - val_loss: 0.1580 - val_accuracy: 0.9526 - val_precision: 0.9453 - val_recall: 0.9926
# Epoch 20/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0982 - accuracy: 0.9504 - precision: 0.9800 - recall: 0.9511 - val_loss: 0.1354 - val_accuracy: 0.9546 - val_precision: 0.9526 - val_recall: 0.9866
# Epoch 21/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0852 - accuracy: 0.9512 - precision: 0.9807 - recall: 0.9523 - val_loss: 0.1150 - val_accuracy: 0.9595 - val_precision: 0.9575 - val_recall: 0.9887
# Epoch 22/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0959 - accuracy: 0.9528 - precision: 0.9816 - recall: 0.9535 - val_loss: 0.1138 - val_accuracy: 0.9604 - val_precision: 0.9623 - val_recall: 0.9847
# Epoch 23/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0858 - accuracy: 0.9536 - precision: 0.9803 - recall: 0.9558 - val_loss: 0.1113 - val_accuracy: 0.9639 - val_precision: 0.9640 - val_recall: 0.9873
# Epoch 24/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0958 - accuracy: 0.9454 - precision: 0.9825 - recall: 0.9424 - val_loss: 0.1167 - val_accuracy: 0.9600 - val_precision: 0.9589 - val_recall: 0.9872
# Epoch 25/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0850 - accuracy: 0.9502 - precision: 0.9803 - recall: 0.9506 - val_loss: 0.1072 - val_accuracy: 0.9639 - val_precision: 0.9667 - val_recall: 0.9847
# Epoch 26/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0916 - accuracy: 0.9506 - precision: 0.9820 - recall: 0.9499 - val_loss: 0.1049 - val_accuracy: 0.9653 - val_precision: 0.9696 - val_recall: 0.9833
# Epoch 27/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0847 - accuracy: 0.9546 - precision: 0.9833 - recall: 0.9541 - val_loss: 0.0983 - val_accuracy: 0.9678 - val_precision: 0.9722 - val_recall: 0.9839
# Epoch 28/50
# 13/13 [==============================] - 4s 310ms/step - loss: 0.0819 - accuracy: 0.9506 - precision: 0.9823 - recall: 0.9491 - val_loss: 0.1043 - val_accuracy: 0.9663 - val_precision: 0.9690 - val_recall: 0.9853
# Epoch 29/50
# 13/13 [==============================] - 3s 227ms/step - loss: 0.0793 - accuracy: 0.9563 - precision: 0.9792 - recall: 0.9605 - val_loss: 0.1033 - val_accuracy: 0.9639 - val_precision: 0.9704 - val_recall: 0.9807
# Epoch 30/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0841 - accuracy: 0.9519 - precision: 0.9801 - recall: 0.9530 - val_loss: 0.0966 - val_accuracy: 0.9658 - val_precision: 0.9711 - val_recall: 0.9827
# Epoch 31/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0849 - accuracy: 0.9535 - precision: 0.9829 - recall: 0.9529 - val_loss: 0.0948 - val_accuracy: 0.9678 - val_precision: 0.9704 - val_recall: 0.9860
# Epoch 32/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0901 - accuracy: 0.9548 - precision: 0.9816 - recall: 0.9559 - val_loss: 0.0972 - val_accuracy: 0.9673 - val_precision: 0.9730 - val_recall: 0.9827
# Epoch 33/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0799 - accuracy: 0.9476 - precision: 0.9855 - recall: 0.9423 - val_loss: 0.0914 - val_accuracy: 0.9683 - val_precision: 0.9742 - val_recall: 0.9826
# Epoch 34/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0805 - accuracy: 0.9553 - precision: 0.9828 - recall: 0.9558 - val_loss: 0.0965 - val_accuracy: 0.9673 - val_precision: 0.9748 - val_recall: 0.9807
# Epoch 35/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0775 - accuracy: 0.9553 - precision: 0.9834 - recall: 0.9547 - val_loss: 0.0924 - val_accuracy: 0.9673 - val_precision: 0.9735 - val_recall: 0.9820
# Epoch 36/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0749 - accuracy: 0.9537 - precision: 0.9848 - recall: 0.9517 - val_loss: 0.0944 - val_accuracy: 0.9678 - val_precision: 0.9753 - val_recall: 0.9805
# Epoch 37/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0811 - accuracy: 0.9528 - precision: 0.9817 - recall: 0.9531 - val_loss: 0.0991 - val_accuracy: 0.9697 - val_precision: 0.9807 - val_recall: 0.9781
# Epoch 38/50
# 13/13 [==============================] - 3s 215ms/step - loss: 0.0804 - accuracy: 0.9534 - precision: 0.9833 - recall: 0.9527 - val_loss: 0.0896 - val_accuracy: 0.9712 - val_precision: 0.9793 - val_recall: 0.9813
# Epoch 39/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0849 - accuracy: 0.9549 - precision: 0.9802 - recall: 0.9573 - val_loss: 0.0955 - val_accuracy: 0.9683 - val_precision: 0.9799 - val_recall: 0.9766
# Epoch 40/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0780 - accuracy: 0.9525 - precision: 0.9872 - recall: 0.9474 - val_loss: 0.0931 - val_accuracy: 0.9692 - val_precision: 0.9785 - val_recall: 0.9792
# Epoch 41/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0778 - accuracy: 0.9584 - precision: 0.9821 - recall: 0.9605 - val_loss: 0.0887 - val_accuracy: 0.9722 - val_precision: 0.9820 - val_recall: 0.9800
# Epoch 42/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0800 - accuracy: 0.9541 - precision: 0.9852 - recall: 0.9517 - val_loss: 0.0947 - val_accuracy: 0.9683 - val_precision: 0.9792 - val_recall: 0.9772
# Epoch 43/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0829 - accuracy: 0.9484 - precision: 0.9837 - recall: 0.9458 - val_loss: 0.0925 - val_accuracy: 0.9668 - val_precision: 0.9793 - val_recall: 0.9753
# Epoch 44/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0697 - accuracy: 0.9617 - precision: 0.9860 - recall: 0.9604 - val_loss: 0.0952 - val_accuracy: 0.9697 - val_precision: 0.9799 - val_recall: 0.9786
# Epoch 45/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0723 - accuracy: 0.9561 - precision: 0.9854 - recall: 0.9539 - val_loss: 0.0995 - val_accuracy: 0.9688 - val_precision: 0.9793 - val_recall: 0.9779
# Epoch 46/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0781 - accuracy: 0.9565 - precision: 0.9823 - recall: 0.9577 - val_loss: 0.1022 - val_accuracy: 0.9658 - val_precision: 0.9791 - val_recall: 0.9738
# Epoch 47/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0795 - accuracy: 0.9557 - precision: 0.9836 - recall: 0.9552 - val_loss: 0.0961 - val_accuracy: 0.9663 - val_precision: 0.9798 - val_recall: 0.9739
# Epoch 48/50
# 13/13 [==============================] - 3s 213ms/step - loss: 0.0782 - accuracy: 0.9542 - precision: 0.9843 - recall: 0.9528 - val_loss: 0.0924 - val_accuracy: 0.9688 - val_precision: 0.9813 - val_recall: 0.9760
# Epoch 49/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0773 - accuracy: 0.9569 - precision: 0.9846 - recall: 0.9558 - val_loss: 0.0995 - val_accuracy: 0.9683 - val_precision: 0.9812 - val_recall: 0.9754
# Epoch 50/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0714 - accuracy: 0.9532 - precision: 0.9836 - recall: 0.9520 - val_loss: 0.0922 - val_accuracy: 0.9688 - val_precision: 0.9778 - val_recall: 0.9791
#
#
# Batch Size: 256
# Hidden Units: 4096
# Learning Rate: 0.06103
# 1 Hidden Layer, 4096 units
# S value: 42
# Epoch 1/50
# 13/13 [==============================] - 52s 2s/step - loss: 4.5693 - accuracy: 0.7443 - precision: 0.8964 - recall: 0.7306 - val_loss: 104.7003 - val_accuracy: 0.7100 - val_precision: 0.9989 - val_recall: 0.6039
# Epoch 2/50
# 13/13 [==============================] - 3s 229ms/step - loss: 2.8464 - accuracy: 0.9173 - precision: 0.9570 - recall: 0.9289 - val_loss: 3.9247 - val_accuracy: 0.8872 - val_precision: 0.9946 - val_recall: 0.8510
# Epoch 3/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.7404 - accuracy: 0.9209 - precision: 0.9724 - recall: 0.9168 - val_loss: 1.8695 - val_accuracy: 0.8877 - val_precision: 0.9992 - val_recall: 0.8469
# Epoch 4/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.4952 - accuracy: 0.9013 - precision: 0.9770 - recall: 0.8877 - val_loss: 0.6241 - val_accuracy: 0.9033 - val_precision: 0.9888 - val_recall: 0.8787
# Epoch 5/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.2396 - accuracy: 0.9242 - precision: 0.9669 - recall: 0.9285 - val_loss: 0.1734 - val_accuracy: 0.9609 - val_precision: 0.9869 - val_recall: 0.9592
# Epoch 6/50
# 13/13 [==============================] - 3s 229ms/step - loss: 0.1855 - accuracy: 0.9262 - precision: 0.9775 - recall: 0.9207 - val_loss: 0.1274 - val_accuracy: 0.9644 - val_precision: 0.9652 - val_recall: 0.9866
# Epoch 7/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.1610 - accuracy: 0.9311 - precision: 0.9760 - recall: 0.9286 - val_loss: 0.4356 - val_accuracy: 0.9141 - val_precision: 0.8953 - val_recall: 0.9993
# Epoch 8/50
# 13/13 [==============================] - 3s 235ms/step - loss: 0.1535 - accuracy: 0.9331 - precision: 0.9631 - recall: 0.9448 - val_loss: 0.3620 - val_accuracy: 0.9067 - val_precision: 0.8882 - val_recall: 0.9987
# Epoch 9/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0977 - accuracy: 0.9474 - precision: 0.9741 - recall: 0.9535 - val_loss: 0.1610 - val_accuracy: 0.9507 - val_precision: 0.9392 - val_recall: 0.9973
# Epoch 10/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.1310 - accuracy: 0.9353 - precision: 0.9711 - recall: 0.9394 - val_loss: 0.1031 - val_accuracy: 0.9604 - val_precision: 0.9596 - val_recall: 0.9873
# Epoch 11/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0879 - accuracy: 0.9516 - precision: 0.9793 - recall: 0.9539 - val_loss: 0.0939 - val_accuracy: 0.9702 - val_precision: 0.9791 - val_recall: 0.9798
# Epoch 12/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0847 - accuracy: 0.9465 - precision: 0.9825 - recall: 0.9436 - val_loss: 0.1303 - val_accuracy: 0.9541 - val_precision: 0.9788 - val_recall: 0.9579
# Epoch 13/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0946 - accuracy: 0.9371 - precision: 0.9816 - recall: 0.9323 - val_loss: 0.1444 - val_accuracy: 0.9399 - val_precision: 0.9825 - val_recall: 0.9348
# Epoch 14/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0831 - accuracy: 0.9415 - precision: 0.9837 - recall: 0.9368 - val_loss: 0.0844 - val_accuracy: 0.9707 - val_precision: 0.9762 - val_recall: 0.9840
# Epoch 15/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0704 - accuracy: 0.9538 - precision: 0.9843 - recall: 0.9526 - val_loss: 0.1055 - val_accuracy: 0.9580 - val_precision: 0.9557 - val_recall: 0.9887
# Epoch 16/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0796 - accuracy: 0.9482 - precision: 0.9799 - recall: 0.9486 - val_loss: 0.0869 - val_accuracy: 0.9697 - val_precision: 0.9750 - val_recall: 0.9841
# Epoch 17/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0703 - accuracy: 0.9513 - precision: 0.9846 - recall: 0.9482 - val_loss: 0.1133 - val_accuracy: 0.9556 - val_precision: 0.9505 - val_recall: 0.9906
# Epoch 18/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0685 - accuracy: 0.9568 - precision: 0.9849 - recall: 0.9558 - val_loss: 0.0913 - val_accuracy: 0.9644 - val_precision: 0.9677 - val_recall: 0.9839
# Epoch 19/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0766 - accuracy: 0.9520 - precision: 0.9786 - recall: 0.9554 - val_loss: 0.1095 - val_accuracy: 0.9604 - val_precision: 0.9688 - val_recall: 0.9772
# Epoch 20/50
# 13/13 [==============================] - 3s 215ms/step - loss: 0.0741 - accuracy: 0.9560 - precision: 0.9868 - recall: 0.9526 - val_loss: 0.0783 - val_accuracy: 0.9692 - val_precision: 0.9738 - val_recall: 0.9847
# Epoch 21/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0686 - accuracy: 0.9563 - precision: 0.9888 - recall: 0.9510 - val_loss: 0.0829 - val_accuracy: 0.9692 - val_precision: 0.9741 - val_recall: 0.9839
# Epoch 22/50
# 13/13 [==============================] - 3s 214ms/step - loss: 0.0662 - accuracy: 0.9579 - precision: 0.9878 - recall: 0.9542 - val_loss: 0.0841 - val_accuracy: 0.9688 - val_precision: 0.9812 - val_recall: 0.9760
# Epoch 23/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0653 - accuracy: 0.9566 - precision: 0.9853 - recall: 0.9550 - val_loss: 0.0838 - val_accuracy: 0.9727 - val_precision: 0.9839 - val_recall: 0.9787
# Epoch 24/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0616 - accuracy: 0.9534 - precision: 0.9897 - recall: 0.9462 - val_loss: 0.0819 - val_accuracy: 0.9712 - val_precision: 0.9793 - val_recall: 0.9813
# Epoch 25/50
# 13/13 [==============================] - 3s 215ms/step - loss: 0.0650 - accuracy: 0.9562 - precision: 0.9873 - recall: 0.9528 - val_loss: 0.0773 - val_accuracy: 0.9722 - val_precision: 0.9768 - val_recall: 0.9853
# Epoch 26/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0543 - accuracy: 0.9631 - precision: 0.9869 - recall: 0.9625 - val_loss: 0.0793 - val_accuracy: 0.9683 - val_precision: 0.9696 - val_recall: 0.9872
# Epoch 27/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0567 - accuracy: 0.9675 - precision: 0.9876 - recall: 0.9674 - val_loss: 0.0899 - val_accuracy: 0.9712 - val_precision: 0.9826 - val_recall: 0.9780
# Epoch 28/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0563 - accuracy: 0.9628 - precision: 0.9884 - recall: 0.9602 - val_loss: 0.0806 - val_accuracy: 0.9683 - val_precision: 0.9742 - val_recall: 0.9826
# Epoch 29/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0582 - accuracy: 0.9607 - precision: 0.9863 - recall: 0.9595 - val_loss: 0.0860 - val_accuracy: 0.9639 - val_precision: 0.9741 - val_recall: 0.9767
# Epoch 30/50
# 13/13 [==============================] - 3s 212ms/step - loss: 0.0552 - accuracy: 0.9626 - precision: 0.9885 - recall: 0.9602 - val_loss: 0.0840 - val_accuracy: 0.9673 - val_precision: 0.9817 - val_recall: 0.9732
# Epoch 31/50
# 13/13 [==============================] - 3s 214ms/step - loss: 0.0608 - accuracy: 0.9567 - precision: 0.9872 - recall: 0.9526 - val_loss: 0.0898 - val_accuracy: 0.9653 - val_precision: 0.9857 - val_recall: 0.9666
# Epoch 32/50
# 13/13 [==============================] - 3s 212ms/step - loss: 0.0606 - accuracy: 0.9593 - precision: 0.9881 - recall: 0.9565 - val_loss: 0.0925 - val_accuracy: 0.9639 - val_precision: 0.9824 - val_recall: 0.9680
# Epoch 33/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0514 - accuracy: 0.9645 - precision: 0.9903 - recall: 0.9614 - val_loss: 0.0885 - val_accuracy: 0.9653 - val_precision: 0.9838 - val_recall: 0.9687
# Epoch 34/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0558 - accuracy: 0.9640 - precision: 0.9907 - recall: 0.9602 - val_loss: 0.0866 - val_accuracy: 0.9712 - val_precision: 0.9766 - val_recall: 0.9838
# Epoch 35/50
# 13/13 [==============================] - 3s 227ms/step - loss: 0.0552 - accuracy: 0.9641 - precision: 0.9889 - recall: 0.9616 - val_loss: 0.0819 - val_accuracy: 0.9697 - val_precision: 0.9830 - val_recall: 0.9750
# Epoch 36/50
# 13/13 [==============================] - 3s 213ms/step - loss: 0.0499 - accuracy: 0.9714 - precision: 0.9915 - recall: 0.9692 - val_loss: 0.0776 - val_accuracy: 0.9722 - val_precision: 0.9812 - val_recall: 0.9805
# Epoch 37/50
# 13/13 [==============================] - 3s 215ms/step - loss: 0.0538 - accuracy: 0.9657 - precision: 0.9858 - recall: 0.9667 - val_loss: 0.0786 - val_accuracy: 0.9692 - val_precision: 0.9737 - val_recall: 0.9847
# Epoch 38/50
# 13/13 [==============================] - 3s 213ms/step - loss: 0.0570 - accuracy: 0.9649 - precision: 0.9859 - recall: 0.9659 - val_loss: 0.0765 - val_accuracy: 0.9712 - val_precision: 0.9839 - val_recall: 0.9767
# Epoch 39/50
# 13/13 [==============================] - 3s 212ms/step - loss: 0.0505 - accuracy: 0.9704 - precision: 0.9907 - recall: 0.9685 - val_loss: 0.0794 - val_accuracy: 0.9712 - val_precision: 0.9814 - val_recall: 0.9794
# Epoch 40/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0480 - accuracy: 0.9656 - precision: 0.9894 - recall: 0.9633 - val_loss: 0.0835 - val_accuracy: 0.9692 - val_precision: 0.9806 - val_recall: 0.9774
# Epoch 41/50
# 13/13 [==============================] - 3s 214ms/step - loss: 0.0531 - accuracy: 0.9633 - precision: 0.9901 - recall: 0.9598 - val_loss: 0.0849 - val_accuracy: 0.9678 - val_precision: 0.9819 - val_recall: 0.9741
# Epoch 42/50
# 13/13 [==============================] - 3s 212ms/step - loss: 0.0482 - accuracy: 0.9670 - precision: 0.9903 - recall: 0.9644 - val_loss: 0.0779 - val_accuracy: 0.9692 - val_precision: 0.9781 - val_recall: 0.9801
# Epoch 43/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0513 - accuracy: 0.9655 - precision: 0.9872 - recall: 0.9653 - val_loss: 0.0814 - val_accuracy: 0.9712 - val_precision: 0.9807 - val_recall: 0.9800
# Epoch 44/50
# 13/13 [==============================] - 3s 210ms/step - loss: 0.0505 - accuracy: 0.9665 - precision: 0.9874 - recall: 0.9663 - val_loss: 0.0791 - val_accuracy: 0.9702 - val_precision: 0.9801 - val_recall: 0.9795
# Epoch 45/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0410 - accuracy: 0.9756 - precision: 0.9887 - recall: 0.9775 - val_loss: 0.0787 - val_accuracy: 0.9688 - val_precision: 0.9786 - val_recall: 0.9786
# Epoch 46/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0483 - accuracy: 0.9690 - precision: 0.9917 - recall: 0.9658 - val_loss: 0.0817 - val_accuracy: 0.9688 - val_precision: 0.9794 - val_recall: 0.9781
# Epoch 47/50
# 13/13 [==============================] - 3s 213ms/step - loss: 0.0485 - accuracy: 0.9680 - precision: 0.9895 - recall: 0.9664 - val_loss: 0.0900 - val_accuracy: 0.9629 - val_precision: 0.9796 - val_recall: 0.9691
# Epoch 48/50
# 13/13 [==============================] - 3s 213ms/step - loss: 0.0449 - accuracy: 0.9711 - precision: 0.9946 - recall: 0.9656 - val_loss: 0.0827 - val_accuracy: 0.9707 - val_precision: 0.9814 - val_recall: 0.9788
# Epoch 49/50
# 13/13 [==============================] - 3s 215ms/step - loss: 0.0427 - accuracy: 0.9710 - precision: 0.9881 - recall: 0.9720 - val_loss: 0.0825 - val_accuracy: 0.9692 - val_precision: 0.9873 - val_recall: 0.9710
# Epoch 50/50
# 13/13 [==============================] - 3s 213ms/step - loss: 0.0459 - accuracy: 0.9694 - precision: 0.9920 - recall: 0.9663 - val_loss: 0.0762 - val_accuracy: 0.9722 - val_precision: 0.9837 - val_recall: 0.9778
#
#
# Batch Size: 256
# Hidden Units: 4096
# Learning Rate: 0.06103
# 1 Hidden Layer, 4096 units
# S value: 59
# Epoch 1/50
# 13/13 [==============================] - 52s 2s/step - loss: 4.6444 - accuracy: 0.7182 - precision: 0.8735 - recall: 0.7144 - val_loss: 24.8399 - val_accuracy: 0.8076 - val_precision: 0.9973 - val_recall: 0.7379
# Epoch 2/50
# 13/13 [==============================] - 3s 224ms/step - loss: 1.2645 - accuracy: 0.9122 - precision: 0.9642 - recall: 0.9141 - val_loss: 68.0106 - val_accuracy: 0.4082 - val_precision: 1.0000 - val_recall: 0.1877
# Epoch 3/50
# 13/13 [==============================] - 3s 213ms/step - loss: 0.7258 - accuracy: 0.9082 - precision: 0.9622 - recall: 0.9106 - val_loss: 9.3436 - val_accuracy: 0.7705 - val_precision: 0.7611 - val_recall: 1.0000
# Epoch 4/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.3812 - accuracy: 0.9302 - precision: 0.9628 - recall: 0.9413 - val_loss: 1.1138 - val_accuracy: 0.8994 - val_precision: 0.9916 - val_recall: 0.8697
# Epoch 5/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.3330 - accuracy: 0.9142 - precision: 0.9689 - recall: 0.9124 - val_loss: 1.0019 - val_accuracy: 0.8950 - val_precision: 0.9946 - val_recall: 0.8613
# Epoch 6/50
# 13/13 [==============================] - 3s 214ms/step - loss: 0.2171 - accuracy: 0.9216 - precision: 0.9814 - recall: 0.9105 - val_loss: 0.3068 - val_accuracy: 0.9312 - val_precision: 0.9899 - val_recall: 0.9156
# Epoch 7/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.1669 - accuracy: 0.9271 - precision: 0.9798 - recall: 0.9192 - val_loss: 0.1790 - val_accuracy: 0.9487 - val_precision: 0.9408 - val_recall: 0.9927
# Epoch 8/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.1290 - accuracy: 0.9316 - precision: 0.9649 - recall: 0.9405 - val_loss: 0.1156 - val_accuracy: 0.9653 - val_precision: 0.9837 - val_recall: 0.9685
# Epoch 9/50
# 13/13 [==============================] - 3s 215ms/step - loss: 0.1119 - accuracy: 0.9332 - precision: 0.9787 - recall: 0.9288 - val_loss: 0.1621 - val_accuracy: 0.9404 - val_precision: 0.9290 - val_recall: 0.9954
# Epoch 10/50
# 13/13 [==============================] - 3s 228ms/step - loss: 0.1103 - accuracy: 0.9486 - precision: 0.9750 - recall: 0.9541 - val_loss: 0.0984 - val_accuracy: 0.9644 - val_precision: 0.9691 - val_recall: 0.9826
# Epoch 11/50
# ...
# Epoch 31/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0532 - accuracy: 0.9670 - precision: 0.9894 - recall: 0.9655 - val_loss: 0.0831 - val_accuracy: 0.9678 - val_precision: 0.9721 - val_recall: 0.9839
# Epoch 32/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0501 - accuracy: 0.9697 - precision: 0.9879 - recall: 0.9707 - val_loss: 0.0887 - val_accuracy: 0.9658 - val_precision: 0.9655 - val_recall: 0.9887
# Epoch 33/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0515 - accuracy: 0.9673 - precision: 0.9881 - recall: 0.9673 - val_loss: 0.0849 - val_accuracy: 0.9702 - val_precision: 0.9754 - val_recall: 0.9839
# Epoch 34/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0528 - accuracy: 0.9680 - precision: 0.9898 - recall: 0.9664 - val_loss: 0.0905 - val_accuracy: 0.9678 - val_precision: 0.9680 - val_recall: 0.9887
# Epoch 35/50
# 13/13 [==============================] - 3s 213ms/step - loss: 0.0527 - accuracy: 0.9695 - precision: 0.9893 - recall: 0.9689 - val_loss: 0.0910 - val_accuracy: 0.9634 - val_precision: 0.9665 - val_recall: 0.9839
# Epoch 36/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0523 - accuracy: 0.9680 - precision: 0.9862 - recall: 0.9696 - val_loss: 0.0909 - val_accuracy: 0.9658 - val_precision: 0.9679 - val_recall: 0.9860
# Epoch 37/50
# 13/13 [==============================] - 3s 212ms/step - loss: 0.0522 - accuracy: 0.9668 - precision: 0.9851 - recall: 0.9688 - val_loss: 0.0797 - val_accuracy: 0.9727 - val_precision: 0.9808 - val_recall: 0.9821
# Epoch 38/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0524 - accuracy: 0.9686 - precision: 0.9901 - recall: 0.9668 - val_loss: 0.0828 - val_accuracy: 0.9673 - val_precision: 0.9771 - val_recall: 0.9777
# Epoch 39/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0490 - accuracy: 0.9666 - precision: 0.9878 - recall: 0.9661 - val_loss: 0.0838 - val_accuracy: 0.9697 - val_precision: 0.9845 - val_recall: 0.9741
# Epoch 40/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0548 - accuracy: 0.9629 - precision: 0.9913 - recall: 0.9576 - val_loss: 0.0978 - val_accuracy: 0.9624 - val_precision: 0.9778 - val_recall: 0.9706
# Epoch 41/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0466 - accuracy: 0.9672 - precision: 0.9929 - recall: 0.9619 - val_loss: 0.0932 - val_accuracy: 0.9624 - val_precision: 0.9622 - val_recall: 0.9873
# Epoch 42/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0518 - accuracy: 0.9678 - precision: 0.9884 - recall: 0.9671 - val_loss: 0.0885 - val_accuracy: 0.9697 - val_precision: 0.9767 - val_recall: 0.9819
# Epoch 43/50
# 13/13 [==============================] - 3s 228ms/step - loss: 0.0419 - accuracy: 0.9711 - precision: 0.9933 - recall: 0.9672 - val_loss: 0.0866 - val_accuracy: 0.9668 - val_precision: 0.9817 - val_recall: 0.9725
# Epoch 44/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0511 - accuracy: 0.9698 - precision: 0.9912 - recall: 0.9673 - val_loss: 0.0865 - val_accuracy: 0.9663 - val_precision: 0.9798 - val_recall: 0.9739
# Epoch 45/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0389 - accuracy: 0.9764 - precision: 0.9901 - recall: 0.9773 - val_loss: 0.0838 - val_accuracy: 0.9722 - val_precision: 0.9763 - val_recall: 0.9860
# Epoch 46/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0435 - accuracy: 0.9749 - precision: 0.9936 - recall: 0.9720 - val_loss: 0.0883 - val_accuracy: 0.9658 - val_precision: 0.9728 - val_recall: 0.9806
# Epoch 47/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0464 - accuracy: 0.9687 - precision: 0.9902 - recall: 0.9665 - val_loss: 0.0903 - val_accuracy: 0.9668 - val_precision: 0.9766 - val_recall: 0.9779
# Epoch 48/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0429 - accuracy: 0.9697 - precision: 0.9908 - recall: 0.9678 - val_loss: 0.0744 - val_accuracy: 0.9707 - val_precision: 0.9818 - val_recall: 0.9778
# Epoch 49/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0443 - accuracy: 0.9698 - precision: 0.9920 - recall: 0.9666 - val_loss: 0.0804 - val_accuracy: 0.9678 - val_precision: 0.9793 - val_recall: 0.9767
# Epoch 50/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0458 - accuracy: 0.9756 - precision: 0.9920 - recall: 0.9743 - val_loss: 0.0781 - val_accuracy: 0.9722 - val_precision: 0.9801 - val_recall: 0.9820
#
#
# Batch Size: 256
# Hidden Units: 4096
# Learning Rate: 0.06103
# 1 Hidden Layer, 4096 units
# S value: 47
# Epoch 1/50
# 13/13 [==============================] - 53s 2s/step - loss: 4.6801 - accuracy: 0.7384 - precision: 0.8921 - recall: 0.7261 - val_loss: 26.2051 - val_accuracy: 0.8711 - val_precision: 0.9928 - val_recall: 0.8302
# Epoch 2/50
# 13/13 [==============================] - 3s 225ms/step - loss: 2.7452 - accuracy: 0.9178 - precision: 0.9509 - recall: 0.9358 - val_loss: 5.2615 - val_accuracy: 0.8594 - val_precision: 0.8431 - val_recall: 0.9927
# Epoch 3/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.7354 - accuracy: 0.9177 - precision: 0.9542 - recall: 0.9318 - val_loss: 0.6306 - val_accuracy: 0.9463 - val_precision: 0.9880 - val_recall: 0.9378
# Epoch 4/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.2815 - accuracy: 0.9176 - precision: 0.9826 - recall: 0.9043 - val_loss: 0.1971 - val_accuracy: 0.9556 - val_precision: 0.9757 - val_recall: 0.9633
# Epoch 5/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.2018 - accuracy: 0.9168 - precision: 0.9681 - recall: 0.9177 - val_loss: 1.7547 - val_accuracy: 0.8013 - val_precision: 0.9991 - val_recall: 0.7297
# Epoch 6/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.1763 - accuracy: 0.9267 - precision: 0.9765 - recall: 0.9234 - val_loss: 0.6228 - val_accuracy: 0.8726 - val_precision: 0.9984 - val_recall: 0.8271
# Epoch 7/50
# 13/13 [==============================] - 3s 230ms/step - loss: 0.1324 - accuracy: 0.9284 - precision: 0.9812 - recall: 0.9197 - val_loss: 0.1959 - val_accuracy: 0.9429 - val_precision: 0.9914 - val_recall: 0.9297
# Epoch 8/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0985 - accuracy: 0.9443 - precision: 0.9789 - recall: 0.9442 - val_loss: 0.3378 - val_accuracy: 0.9077 - val_precision: 0.9925 - val_recall: 0.8808
# Epoch 9/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0972 - accuracy: 0.9472 - precision: 0.9799 - recall: 0.9466 - val_loss: 0.1354 - val_accuracy: 0.9546 - val_precision: 0.9840 - val_recall: 0.9528
# Epoch 10/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0992 - accuracy: 0.9407 - precision: 0.9764 - recall: 0.9417 - val_loss: 0.1858 - val_accuracy: 0.9253 - val_precision: 0.9095 - val_recall: 0.9966
# Epoch 11/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.1032 - accuracy: 0.9404 - precision: 0.9758 - recall: 0.9413 - val_loss: 0.2705 - val_accuracy: 0.9072 - val_precision: 0.8885 - val_recall: 0.9987
# Epoch 12/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0937 - accuracy: 0.9455 - precision: 0.9762 - recall: 0.9494 - val_loss: 0.1415 - val_accuracy: 0.9502 - val_precision: 0.9408 - val_recall: 0.9947
# Epoch 13/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0774 - accuracy: 0.9482 - precision: 0.9836 - recall: 0.9451 - val_loss: 0.1790 - val_accuracy: 0.9419 - val_precision: 0.9778 - val_recall: 0.9419
# Epoch 14/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0930 - accuracy: 0.9477 - precision: 0.9807 - recall: 0.9468 - val_loss: 0.1601 - val_accuracy: 0.9385 - val_precision: 0.9859 - val_recall: 0.9295
# Epoch 15/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0802 - accuracy: 0.9439 - precision: 0.9836 - recall: 0.9389 - val_loss: 0.0859 - val_accuracy: 0.9722 - val_precision: 0.9885 - val_recall: 0.9734
# Epoch 16/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0770 - accuracy: 0.9491 - precision: 0.9871 - recall: 0.9430 - val_loss: 0.0952 - val_accuracy: 0.9663 - val_precision: 0.9843 - val_recall: 0.9691
# Epoch 17/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0901 - accuracy: 0.9467 - precision: 0.9802 - recall: 0.9461 - val_loss: 0.1012 - val_accuracy: 0.9653 - val_precision: 0.9760 - val_recall: 0.9766
# Epoch 18/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0706 - accuracy: 0.9554 - precision: 0.9801 - recall: 0.9580 - val_loss: 0.1486 - val_accuracy: 0.9453 - val_precision: 0.9840 - val_recall: 0.9409
# Epoch 19/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0869 - accuracy: 0.9520 - precision: 0.9847 - recall: 0.9489 - val_loss: 0.0839 - val_accuracy: 0.9658 - val_precision: 0.9703 - val_recall: 0.9833
# Epoch 20/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0733 - accuracy: 0.9589 - precision: 0.9804 - recall: 0.9631 - val_loss: 0.1099 - val_accuracy: 0.9624 - val_precision: 0.9785 - val_recall: 0.9701
# Epoch 21/50
# 13/13 [==============================] - 3s 233ms/step - loss: 0.0681 - accuracy: 0.9530 - precision: 0.9856 - recall: 0.9501 - val_loss: 0.1229 - val_accuracy: 0.9512 - val_precision: 0.9420 - val_recall: 0.9940
# Epoch 22/50
# 13/13 [==============================] - 3s 229ms/step - loss: 0.0820 - accuracy: 0.9486 - precision: 0.9785 - recall: 0.9507 - val_loss: 0.0851 - val_accuracy: 0.9629 - val_precision: 0.9640 - val_recall: 0.9859
# Epoch 23/50
# 13/13 [==============================] - 3s 233ms/step - loss: 0.0634 - accuracy: 0.9619 - precision: 0.9848 - recall: 0.9626 - val_loss: 0.0853 - val_accuracy: 0.9692 - val_precision: 0.9851 - val_recall: 0.9726
# Epoch 24/50
# 13/13 [==============================] - 3s 228ms/step - loss: 0.0615 - accuracy: 0.9611 - precision: 0.9874 - recall: 0.9593 - val_loss: 0.0888 - val_accuracy: 0.9697 - val_precision: 0.9773 - val_recall: 0.9812
# Epoch 25/50
# 13/13 [==============================] - 3s 227ms/step - loss: 0.0623 - accuracy: 0.9568 - precision: 0.9874 - recall: 0.9531 - val_loss: 0.0914 - val_accuracy: 0.9663 - val_precision: 0.9836 - val_recall: 0.9698
# Epoch 26/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0631 - accuracy: 0.9593 - precision: 0.9858 - recall: 0.9582 - val_loss: 0.0811 - val_accuracy: 0.9688 - val_precision: 0.9762 - val_recall: 0.9814
# Epoch 27/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0619 - accuracy: 0.9647 - precision: 0.9838 - recall: 0.9677 - val_loss: 0.0927 - val_accuracy: 0.9624 - val_precision: 0.9810 - val_recall: 0.9672
# Epoch 28/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0577 - accuracy: 0.9647 - precision: 0.9914 - recall: 0.9602 - val_loss: 0.0801 - val_accuracy: 0.9712 - val_precision: 0.9719 - val_recall: 0.9894
# Epoch 29/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0580 - accuracy: 0.9629 - precision: 0.9872 - recall: 0.9615 - val_loss: 0.0855 - val_accuracy: 0.9697 - val_precision: 0.9787 - val_recall: 0.9800
# Epoch 30/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0603 - accuracy: 0.9608 - precision: 0.9840 - recall: 0.9618 - val_loss: 0.0922 - val_accuracy: 0.9668 - val_precision: 0.9793 - val_recall: 0.9753
# Epoch 31/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0546 - accuracy: 0.9637 - precision: 0.9899 - recall: 0.9599 - val_loss: 0.0944 - val_accuracy: 0.9644 - val_precision: 0.9797 - val_recall: 0.9712
# Epoch 32/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0599 - accuracy: 0.9643 - precision: 0.9899 - recall: 0.9614 - val_loss: 0.0986 - val_accuracy: 0.9629 - val_precision: 0.9830 - val_recall: 0.9660
# Epoch 33/50
# 13/13 [==============================] - 3s 233ms/step - loss: 0.0550 - accuracy: 0.9626 - precision: 0.9908 - recall: 0.9578 - val_loss: 0.1197 - val_accuracy: 0.9526 - val_precision: 0.9821 - val_recall: 0.9525
# Epoch 34/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0556 - accuracy: 0.9641 - precision: 0.9907 - recall: 0.9603 - val_loss: 0.0906 - val_accuracy: 0.9634 - val_precision: 0.9765 - val_recall: 0.9732
# Epoch 35/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0545 - accuracy: 0.9676 - precision: 0.9890 - recall: 0.9667 - val_loss: 0.0867 - val_accuracy: 0.9673 - val_precision: 0.9774 - val_recall: 0.9781
# Epoch 36/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0514 - accuracy: 0.9682 - precision: 0.9888 - recall: 0.9675 - val_loss: 0.0935 - val_accuracy: 0.9692 - val_precision: 0.9844 - val_recall: 0.9732
# Epoch 37/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0490 - accuracy: 0.9697 - precision: 0.9896 - recall: 0.9682 - val_loss: 0.0904 - val_accuracy: 0.9683 - val_precision: 0.9805 - val_recall: 0.9760
# Epoch 38/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0535 - accuracy: 0.9654 - precision: 0.9873 - recall: 0.9648 - val_loss: 0.0930 - val_accuracy: 0.9663 - val_precision: 0.9792 - val_recall: 0.9746
# Epoch 39/50
# 13/13 [==============================] - 3s 214ms/step - loss: 0.0566 - accuracy: 0.9659 - precision: 0.9849 - recall: 0.9681 - val_loss: 0.1569 - val_accuracy: 0.9624 - val_precision: 0.9771 - val_recall: 0.9712
# Epoch 40/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0502 - accuracy: 0.9681 - precision: 0.9866 - recall: 0.9693 - val_loss: 0.0848 - val_accuracy: 0.9692 - val_precision: 0.9819 - val_recall: 0.9760
# Epoch 41/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0488 - accuracy: 0.9703 - precision: 0.9899 - recall: 0.9692 - val_loss: 0.0833 - val_accuracy: 0.9727 - val_precision: 0.9838 - val_recall: 0.9786
# Epoch 42/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0456 - accuracy: 0.9662 - precision: 0.9911 - recall: 0.9626 - val_loss: 0.0937 - val_accuracy: 0.9639 - val_precision: 0.9714 - val_recall: 0.9792
# Epoch 43/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0521 - accuracy: 0.9655 - precision: 0.9886 - recall: 0.9641 - val_loss: 0.0856 - val_accuracy: 0.9702 - val_precision: 0.9786 - val_recall: 0.9806
# Epoch 44/50
# 13/13 [==============================] - 3s 215ms/step - loss: 0.0472 - accuracy: 0.9695 - precision: 0.9883 - recall: 0.9696 - val_loss: 0.0862 - val_accuracy: 0.9673 - val_precision: 0.9773 - val_recall: 0.9780
# Epoch 45/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0449 - accuracy: 0.9709 - precision: 0.9904 - recall: 0.9697 - val_loss: 0.0863 - val_accuracy: 0.9678 - val_precision: 0.9805 - val_recall: 0.9753
# Epoch 46/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0405 - accuracy: 0.9745 - precision: 0.9937 - recall: 0.9715 - val_loss: 0.0794 - val_accuracy: 0.9688 - val_precision: 0.9838 - val_recall: 0.9732
# Epoch 47/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0506 - accuracy: 0.9669 - precision: 0.9884 - recall: 0.9656 - val_loss: 0.0753 - val_accuracy: 0.9731 - val_precision: 0.9782 - val_recall: 0.9853
# Epoch 48/50
# 13/13 [==============================] - 3s 227ms/step - loss: 0.0435 - accuracy: 0.9722 - precision: 0.9894 - recall: 0.9723 - val_loss: 0.0769 - val_accuracy: 0.9673 - val_precision: 0.9747 - val_recall: 0.9806
# Epoch 49/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0452 - accuracy: 0.9691 - precision: 0.9881 - recall: 0.9691 - val_loss: 0.0806 - val_accuracy: 0.9712 - val_precision: 0.9775 - val_recall: 0.9833
# Epoch 50/50
# 13/13 [==============================] - 3s 214ms/step - loss: 0.0385 - accuracy: 0.9753 - precision: 0.9945 - recall: 0.9715 - val_loss: 0.0776 - val_accuracy: 0.9692 - val_precision: 0.9785 - val_recall: 0.9791

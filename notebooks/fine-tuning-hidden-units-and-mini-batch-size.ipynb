# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import tensorflow as tf
from kaggle_datasets import KaggleDatasets
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import re
import glob
import random
import seaborn as sns
import matplotlib.pyplot as plt

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# 2023-01-02 06:24:18.868868: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib
# 2023-01-02 06:24:18.869110: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Device:', tpu.master())
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
except:
    strategy = tf.distribute.get_strategy()
print('Number of replicas:', strategy.num_replicas_in_sync)

print(tf.__version__)
# Out:
# Device: grpc://10.0.0.2:8470
# 2023-01-02 06:24:25.503469: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-01-02 06:24:25.506522: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib
# 2023-01-02 06:24:25.506566: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-01-02 06:24:25.506595: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (0f23bd511f60): /proc/driver/nvidia/version does not exist
# 2023-01-02 06:24:25.509939: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-02 06:24:25.511724: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-01-02 06:24:25.518859: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-01-02 06:24:25.548545: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job worker -> {0 -> 10.0.0.2:8470}
# 2023-01-02 06:24:25.548607: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job localhost -> {0 -> localhost:30019}
# 2023-01-02 06:24:25.573597: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job worker -> {0 -> 10.0.0.2:8470}
# 2023-01-02 06:24:25.573659: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job localhost -> {0 -> localhost:30019}
# 2023-01-02 06:24:25.575817: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:411] Started server with target: grpc://localhost:30019
# Number of replicas: 8
# 2.4.1

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
GCS_PATH = KaggleDatasets().get_gcs_path()
BATCH_SIZE = 64*strategy.num_replicas_in_sync
#BATCH_SIZE = 64 # for non-TPU use
IMAGE_SIZE = [180, 180]
EPOCHS = 50

# %%
filenames = tf.io.gfile.glob(str(GCS_PATH + '/chest_xray/train/*/*'))
filenames.extend(tf.io.gfile.glob(str(GCS_PATH + '/chest_xray/val/*/*')))
filenames.extend(tf.io.gfile.glob(str(GCS_PATH + '/chest_xray/test/*/*')))

print(f'The total number of files is {len(filenames)}')
# Out:
# 2023-01-02 06:24:31.445843: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-02 06:24:31.553190: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-02 06:24:31.671141: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-02 06:24:31.766858: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-02 06:24:31.859502: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-02 06:24:31.968257: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-02 06:24:32.057240: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-02 06:24:32.123434: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# The total number of files is 5856

# %%
# split the data into 60:40 for train:test+val
train_files, val_test_files = train_test_split(filenames, test_size=0.4,random_state=18)

# %%
# split the val_test_files to 50:50 to have a final split of 60:20:20 of train:val:test
val_files, test_files = train_test_split(val_test_files, test_size=0.5, random_state=18)

# %%
pct_df = pd.DataFrame(columns = ['data_set', 'label', 'pct'], index = range(6))

totals = {'train':len(train_files), 'val':len(val_files), 'test':len(test_files)}

val_pneum_count = 0
val_norm_count = 0

re_pattern = '.*/(NORMAL|PNEUMONIA)/.*'

for file in val_files:
    re_match = re.match(re_pattern, file)
    if re_match[1] == 'NORMAL':
        val_norm_count += 1
    else:
        val_pneum_count += 1

pct_df.iloc[0, :] = ['val', 'NORMAL', round(100* val_norm_count / totals['val'], 1)]
pct_df.iloc[1, :] = ['val', 'PNEUMONIA', round(100* val_pneum_count / totals['val'], 1)]


test_pneum_count = 0
test_norm_count = 0
for file in test_files:
    re_match = re.match(re_pattern, file)
    if re_match[1] == 'NORMAL':
        test_norm_count += 1
    else:
        test_pneum_count += 1

pct_df.iloc[2, :] = ['test', 'NORMAL', round(100* test_norm_count / totals['test'], 1)]
pct_df.iloc[3, :] = ['test', 'PNEUMONIA', round(100* test_pneum_count / totals['test'], 1)]

train_pneum_count = 0
train_norm_count = 0
for file in train_files:
    re_match = re.match(re_pattern, file)
    if re_match[1] == 'NORMAL':
        train_norm_count += 1
    else:
        train_pneum_count += 1

pct_df.iloc[4, :] = ['train', 'NORMAL', round(100* train_norm_count / totals['train'], 1)]
pct_df.iloc[5, :] = ['train', 'PNEUMONIA', round(100* train_pneum_count / totals['train'], 1)]

# %%
PNEUM_COUNT = val_pneum_count + train_pneum_count + test_pneum_count
NORMAL_COUNT = val_norm_count + train_norm_count + test_norm_count
print(f'Normal: {NORMAL_COUNT}\nPneumonia: {PNEUM_COUNT}')

pct_df
# Out:
# Normal: 1583
# Pneumonia: 4273
#   data_set      label   pct
# 0      val     NORMAL  26.9
# 1      val  PNEUMONIA  73.1
# 2     test     NORMAL  27.6
# 3     test  PNEUMONIA  72.4
# 4    train     NORMAL  26.9
# 5    train  PNEUMONIA  73.1

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_files)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_files)
test_list_ds = tf.data.Dataset.from_tensor_slices(test_files)

#view the file paths for training
print('----Training Files----')
for f in train_list_ds.take(5):
    print(f.numpy())
# Out:
# ----Training Files----
# b'gs://kds-2620457a4e9f9b50269b131bc7e626ac570c179e3a006cd1452d73ba/chest_xray/train/PNEUMONIA/person509_virus_1025.jpeg'
# b'gs://kds-2620457a4e9f9b50269b131bc7e626ac570c179e3a006cd1452d73ba/chest_xray/train/PNEUMONIA/person671_bacteria_2564.jpeg'
# b'gs://kds-2620457a4e9f9b50269b131bc7e626ac570c179e3a006cd1452d73ba/chest_xray/train/PNEUMONIA/person957_virus_1629.jpeg'
# b'gs://kds-2620457a4e9f9b50269b131bc7e626ac570c179e3a006cd1452d73ba/chest_xray/test/PNEUMONIA/person81_bacteria_397.jpeg'
# b'gs://kds-2620457a4e9f9b50269b131bc7e626ac570c179e3a006cd1452d73ba/chest_xray/train/NORMAL/IM-0500-0001.jpeg'

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
TEST_IMG_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()

print(f'Train Image Count: {TRAIN_IMG_COUNT}\nVal Image Count: {VAL_IMG_COUNT}\nTest Image Count: {TEST_IMG_COUNT}')
# Out:
# Train Image Count: 3513
# Val Image Count: 1171
# Test Image Count: 1172
# 2023-01-02 06:24:32.594091: W ./tensorflow/core/distributed_runtime/eager/destroy_tensor_handle_node.h:57] Ignoring an error encountered when deleting remote tensors handles: Invalid argument: Unable to find the relevant tensor remote_handle: Op ID: 28, Output num: 0
# Additional GRPC error information from remote target /job:worker/replica:0/task:0:
# :{"created":"@1672640672.590769788","description":"Error received from peer ipv4:10.0.0.2:8470","file":"external/com_github_grpc_grpc/src/core/lib/surface/call.cc","file_line":1056,"grpc_message":"Unable to find the relevant tensor remote_handle: Op ID: 28, Output num: 0","grpc_status":3}

# %%
# will label as 1 if pneumonia otherwise 0
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == 'PNEUMONIA'

# %%
def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    return tf.image.resize(img, IMAGE_SIZE)

# %%
def process_path(file_path):
    label = get_label(file_path)
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
y_train = []
for image, label in train_ds.take(TRAIN_IMG_COUNT):
    y_train.append(label)
    
print('Training Counts')
print(f'Pneumonia count: {np.sum(y_train)}\nNormal count: {TRAIN_IMG_COUNT - np.sum(y_train)}')
# Out:
# Training Counts
# 2023-01-02 06:26:44.678614: W ./tensorflow/core/distributed_runtime/eager/destroy_tensor_handle_node.h:57] Ignoring an error encountered when deleting remote tensors handles: Invalid argument: Unable to find the relevant tensor remote_handle: Op ID: 3562, Output num: 0
# Additional GRPC error information from remote target /job:worker/replica:0/task:0:
# :{"created":"@1672640804.678518551","description":"Error received from peer ipv4:10.0.0.2:8470","file":"external/com_github_grpc_grpc/src/core/lib/surface/call.cc","file_line":1056,"grpc_message":"Unable to find the relevant tensor remote_handle: Op ID: 3562, Output num: 0","grpc_status":3}
# Pneumonia count: 2568
# Normal count: 945

# %%
y_val = []
for image, label in val_ds.take(VAL_IMG_COUNT):
    y_val.append(label)
    
print('Validation Counts')
print(f'Pneumonia count: {np.sum(y_val)}\nNormal count: {VAL_IMG_COUNT - np.sum(y_val)}')
# Out:
# 2023-01-02 06:27:50.380351: W ./tensorflow/core/distributed_runtime/eager/destroy_tensor_handle_node.h:57] Ignoring an error encountered when deleting remote tensors handles: Invalid argument: Unable to find the relevant tensor remote_handle: Op ID: 18796, Output num: 1
# Additional GRPC error information from remote target /job:worker/replica:0/task:0:
# :{"created":"@1672640870.380113172","description":"Error received from peer ipv4:10.0.0.2:8470","file":"external/com_github_grpc_grpc/src/core/lib/surface/call.cc","file_line":1056,"grpc_message":"Unable to find the relevant tensor remote_handle: Op ID: 18796, Output num: 1","grpc_status":3}
# Validation Counts
# Pneumonia count: 856
# Normal count: 315

# %%
y_test = []
for image, label in test_ds.take(TEST_IMG_COUNT):
    y_test.append(label)
    
print('Test Counts')
print(f'Pneumonia count: {np.sum(y_test)}\nNormal count: {TEST_IMG_COUNT - np.sum(y_test)}')
# Out:
# Test Counts
# Pneumonia count: 849
# Normal count: 323

# %%
def prepare_for_training(ds, cache=True, shuffle_buffer_size=1000):
    
    if cache:
        if isinstance(cache, str):
            ds = ds.cache(cache)
        else:
            ds = ds.cache()
            
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    
    ds = ds.repeat()
    
    ds = ds.batch(BATCH_SIZE)
    
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    
    return ds

# %%
train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %%
weight_for_0 = (1 / NORMAL_COUNT)*(TRAIN_IMG_COUNT)/2.0
weight_for_1 = (1 / PNEUM_COUNT)*(TRAIN_IMG_COUNT)/2.0

# %%
class_weight = {0: weight_for_0, 1: weight_for_1}
print(f'Weight for class 0: {weight_for_0:.2f}')
print(f'Weight for class 1: {weight_for_1:.2f}')
# Out:
# Weight for class 0: 1.11
# Weight for class 1: 0.41

# %%
# create some metrics for comparing on test results

def precision(y_test, y_pred):
    tp, fp = 0, 0
    
    for i in range(len(y_test)):
        if y_test[i] >= 0.5 and y_pred[i] >= 0.5:
            tp += 1
        elif y_test[i] < 0.5 and y_pred[i] >= 0.5:
            fp += 1
            
    return tp / (tp + fp)

def recall(y_test, y_pred):
    tp, fn = 0, 0
    
    for i in range(len(y_test)):
        if y_test[i] >= 0.5 and y_pred[i] >= 0.5:
            tp += 1
        elif y_test[i] >= 0.5 and y_pred[i] < 0.5:
            fn += 1
            
    return tp / (tp + fn)

def f1_score(y_test, y_pred):
    numerator = precision(y_test, y_pred) * recall(y_test, y_pred)
    denominator = precision(y_test, y_pred) + recall(y_test, y_pred)
    
    return 2 * (numerator / denominator)

# %% [markdown]
# ## Fine Tune the Model
#
# ## Expore different Hidden Units and Mini Batch Sizes

# %%
# add exponential decay to try to improve fine tuning
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 ** (epoch / s)
    return exponential_decay_fn

# %%
# use learning rate that gave best results in the learning rate hyperparameter tuning
learning_rate = 0.06103

# try four different hidden_units
for hidden_units in [4096, 2048, 1024, 512, 256]:
    # try three different batch sizes
    for mini_batch in [32, 64, 128]:
    
        BATCH_SIZE = mini_batch*strategy.num_replicas_in_sync
        print(f'\n\nBatch Size: {BATCH_SIZE}')    
        print(f'Hidden Units: {hidden_units}')
        print(f'Learning Rate: {learning_rate}')
    
    
        with strategy.scope():
        
            base_model = tf.keras.applications.densenet.DenseNet201(
                        input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3),
                        include_top=False,
                        weights='imagenet'
                        )
            base_model.trainable = False
        
            x=base_model.output
            inputs = tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))
            x = base_model(inputs, training=False)
            x = tf.keras.layers.GlobalAveragePooling2D()(x)
            x = tf.keras.layers.Dropout(0.3)(x)
            x = tf.keras.layers.Dense(hidden_units, activation='relu')(x)
            x = tf.keras.layers.BatchNormalization()(x)
            x = tf.keras.layers.Dropout(0.3)(x)
            outputs = tf.keras.layers.Dense(1, activation='sigmoid')(x)
            model = tf.keras.Model(inputs, outputs)
    
        
        
            METRICS = [
                'accuracy',
                tf.keras.metrics.Precision(name='precision'),
                tf.keras.metrics.Recall(name='recall')
                ]
        
            model.compile(
                    optimizer='adam',
                    loss='binary_crossentropy',
                    metrics=METRICS
                     )
            
            checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(f"densenet_{learning_rate}_{hidden_units}_{BATCH_SIZE}_xray_model.h5", save_best_only=True)
            early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
            exponential_decay_fn = exponential_decay(learning_rate, 20)
            lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)
    
            history = model.fit(
                                train_ds,
                                steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
                                epochs=EPOCHS,
                                validation_data=val_ds,
                                validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
                                class_weight=class_weight,
                                callbacks=[checkpoint_cb, early_stopping_cb, lr_scheduler]
                                )
# Out:
# Batch Size: 256
# Hidden Units: 4096
# Learning Rate: 0.06103
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74842112/74836368 [==============================] - 0s 0us/step
# Epoch 1/50
# 13/13 [==============================] - 155s 7s/step - loss: 4.7457 - accuracy: 0.7274 - precision: 0.8860 - recall: 0.7158 - val_loss: 65.0956 - val_accuracy: 0.7920 - val_precision: 0.9963 - val_recall: 0.7181
# Epoch 2/50
# 13/13 [==============================] - 3s 224ms/step - loss: 2.3947 - accuracy: 0.9274 - precision: 0.9585 - recall: 0.9414 - val_loss: 5.1007 - val_accuracy: 0.8706 - val_precision: 0.8524 - val_recall: 0.9946
# Epoch 3/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.6395 - accuracy: 0.9143 - precision: 0.9641 - recall: 0.9168 - val_loss: 1.5628 - val_accuracy: 0.8721 - val_precision: 0.9968 - val_recall: 0.8271
# Epoch 4/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.3313 - accuracy: 0.9268 - precision: 0.9699 - recall: 0.9298 - val_loss: 0.3763 - val_accuracy: 0.9492 - val_precision: 0.9407 - val_recall: 0.9933
# Epoch 5/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.1921 - accuracy: 0.9258 - precision: 0.9744 - recall: 0.9225 - val_loss: 0.2828 - val_accuracy: 0.9492 - val_precision: 0.9829 - val_recall: 0.9479
# Epoch 6/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.1921 - accuracy: 0.9250 - precision: 0.9798 - recall: 0.9168 - val_loss: 0.2056 - val_accuracy: 0.9551 - val_precision: 0.9861 - val_recall: 0.9518
# Epoch 7/50
# 13/13 [==============================] - 3s 231ms/step - loss: 0.1826 - accuracy: 0.9165 - precision: 0.9796 - recall: 0.9052 - val_loss: 0.2786 - val_accuracy: 0.9448 - val_precision: 0.9336 - val_recall: 0.9953
# Epoch 8/50
# 13/13 [==============================] - 3s 227ms/step - loss: 0.2230 - accuracy: 0.9287 - precision: 0.9588 - recall: 0.9430 - val_loss: 0.1375 - val_accuracy: 0.9653 - val_precision: 0.9691 - val_recall: 0.9840
# Epoch 9/50
# 13/13 [==============================] - 3s 227ms/step - loss: 0.1261 - accuracy: 0.9410 - precision: 0.9718 - recall: 0.9464 - val_loss: 0.2196 - val_accuracy: 0.9395 - val_precision: 0.9249 - val_recall: 0.9980
# Epoch 10/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.1057 - accuracy: 0.9472 - precision: 0.9762 - recall: 0.9511 - val_loss: 0.1175 - val_accuracy: 0.9629 - val_precision: 0.9850 - val_recall: 0.9640
# Epoch 11/50
# 13/13 [==============================] - 3s 229ms/step - loss: 0.0918 - accuracy: 0.9422 - precision: 0.9820 - recall: 0.9381 - val_loss: 0.1542 - val_accuracy: 0.9570 - val_precision: 0.9787 - val_recall: 0.9616
# Epoch 12/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.1068 - accuracy: 0.9418 - precision: 0.9833 - recall: 0.9365 - val_loss: 0.0948 - val_accuracy: 0.9644 - val_precision: 0.9678 - val_recall: 0.9840
# Epoch 13/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0928 - accuracy: 0.9480 - precision: 0.9763 - recall: 0.9516 - val_loss: 0.0915 - val_accuracy: 0.9653 - val_precision: 0.9671 - val_recall: 0.9859
# Epoch 14/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0841 - accuracy: 0.9458 - precision: 0.9824 - recall: 0.9429 - val_loss: 0.0896 - val_accuracy: 0.9678 - val_precision: 0.9729 - val_recall: 0.9833
# Epoch 15/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0812 - accuracy: 0.9473 - precision: 0.9825 - recall: 0.9445 - val_loss: 0.1218 - val_accuracy: 0.9570 - val_precision: 0.9868 - val_recall: 0.9536
# Epoch 16/50
# 13/13 [==============================] - 3s 229ms/step - loss: 0.0857 - accuracy: 0.9450 - precision: 0.9860 - recall: 0.9387 - val_loss: 0.0966 - val_accuracy: 0.9624 - val_precision: 0.9665 - val_recall: 0.9827
# Epoch 17/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0828 - accuracy: 0.9505 - precision: 0.9774 - recall: 0.9540 - val_loss: 0.0889 - val_accuracy: 0.9673 - val_precision: 0.9729 - val_recall: 0.9826
# Epoch 18/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0694 - accuracy: 0.9582 - precision: 0.9880 - recall: 0.9546 - val_loss: 0.0931 - val_accuracy: 0.9702 - val_precision: 0.9779 - val_recall: 0.9812
# Epoch 19/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0786 - accuracy: 0.9530 - precision: 0.9807 - recall: 0.9543 - val_loss: 0.0908 - val_accuracy: 0.9673 - val_precision: 0.9716 - val_recall: 0.9840
# Epoch 20/50
# 13/13 [==============================] - 3s 215ms/step - loss: 0.0753 - accuracy: 0.9551 - precision: 0.9802 - recall: 0.9574 - val_loss: 0.0849 - val_accuracy: 0.9712 - val_precision: 0.9806 - val_recall: 0.9800
# Epoch 21/50
# 13/13 [==============================] - 3s 231ms/step - loss: 0.0808 - accuracy: 0.9427 - precision: 0.9824 - recall: 0.9392 - val_loss: 0.0858 - val_accuracy: 0.9717 - val_precision: 0.9781 - val_recall: 0.9834
# Epoch 22/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0725 - accuracy: 0.9521 - precision: 0.9834 - recall: 0.9509 - val_loss: 0.0873 - val_accuracy: 0.9692 - val_precision: 0.9760 - val_recall: 0.9819
# Epoch 23/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0692 - accuracy: 0.9563 - precision: 0.9840 - recall: 0.9564 - val_loss: 0.0933 - val_accuracy: 0.9707 - val_precision: 0.9845 - val_recall: 0.9754
# Epoch 24/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0652 - accuracy: 0.9570 - precision: 0.9878 - recall: 0.9530 - val_loss: 0.1022 - val_accuracy: 0.9673 - val_precision: 0.9826 - val_recall: 0.9728
# Epoch 25/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0697 - accuracy: 0.9563 - precision: 0.9859 - recall: 0.9541 - val_loss: 0.0929 - val_accuracy: 0.9692 - val_precision: 0.9824 - val_recall: 0.9752
# Epoch 26/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0816 - accuracy: 0.9486 - precision: 0.9858 - recall: 0.9432 - val_loss: 0.0967 - val_accuracy: 0.9683 - val_precision: 0.9760 - val_recall: 0.9806
# Epoch 27/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0762 - accuracy: 0.9517 - precision: 0.9832 - recall: 0.9499 - val_loss: 0.0906 - val_accuracy: 0.9727 - val_precision: 0.9832 - val_recall: 0.9793
# Epoch 28/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0777 - accuracy: 0.9482 - precision: 0.9839 - recall: 0.9447 - val_loss: 0.0971 - val_accuracy: 0.9697 - val_precision: 0.9840 - val_recall: 0.9748
# Epoch 29/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0693 - accuracy: 0.9576 - precision: 0.9838 - recall: 0.9579 - val_loss: 0.0830 - val_accuracy: 0.9736 - val_precision: 0.9833 - val_recall: 0.9807
# Epoch 30/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0657 - accuracy: 0.9593 - precision: 0.9843 - recall: 0.9594 - val_loss: 0.0907 - val_accuracy: 0.9722 - val_precision: 0.9825 - val_recall: 0.9792
# Epoch 31/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0686 - accuracy: 0.9561 - precision: 0.9848 - recall: 0.9550 - val_loss: 0.0918 - val_accuracy: 0.9722 - val_precision: 0.9832 - val_recall: 0.9786
# Epoch 32/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0659 - accuracy: 0.9592 - precision: 0.9876 - recall: 0.9566 - val_loss: 0.0860 - val_accuracy: 0.9712 - val_precision: 0.9807 - val_recall: 0.9801
# Epoch 33/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0626 - accuracy: 0.9595 - precision: 0.9862 - recall: 0.9577 - val_loss: 0.0906 - val_accuracy: 0.9722 - val_precision: 0.9827 - val_recall: 0.9794
# Epoch 34/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0658 - accuracy: 0.9566 - precision: 0.9857 - recall: 0.9548 - val_loss: 0.0886 - val_accuracy: 0.9722 - val_precision: 0.9826 - val_recall: 0.9793
# Epoch 35/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0653 - accuracy: 0.9619 - precision: 0.9875 - recall: 0.9598 - val_loss: 0.0895 - val_accuracy: 0.9717 - val_precision: 0.9825 - val_recall: 0.9786
# Epoch 36/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0629 - accuracy: 0.9574 - precision: 0.9866 - recall: 0.9546 - val_loss: 0.0882 - val_accuracy: 0.9717 - val_precision: 0.9819 - val_recall: 0.9793
# Epoch 37/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0565 - accuracy: 0.9636 - precision: 0.9906 - recall: 0.9592 - val_loss: 0.0800 - val_accuracy: 0.9736 - val_precision: 0.9834 - val_recall: 0.9808
# Epoch 38/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0625 - accuracy: 0.9606 - precision: 0.9827 - recall: 0.9627 - val_loss: 0.0878 - val_accuracy: 0.9741 - val_precision: 0.9853 - val_recall: 0.9793
# Epoch 39/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0649 - accuracy: 0.9592 - precision: 0.9855 - recall: 0.9581 - val_loss: 0.0930 - val_accuracy: 0.9736 - val_precision: 0.9845 - val_recall: 0.9792
# Epoch 40/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0645 - accuracy: 0.9553 - precision: 0.9875 - recall: 0.9508 - val_loss: 0.0842 - val_accuracy: 0.9761 - val_precision: 0.9860 - val_recall: 0.9814
# Epoch 41/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0624 - accuracy: 0.9596 - precision: 0.9858 - recall: 0.9589 - val_loss: 0.0901 - val_accuracy: 0.9741 - val_precision: 0.9839 - val_recall: 0.9806
# Epoch 42/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0655 - accuracy: 0.9608 - precision: 0.9814 - recall: 0.9646 - val_loss: 0.0953 - val_accuracy: 0.9727 - val_precision: 0.9870 - val_recall: 0.9751
# Epoch 43/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0621 - accuracy: 0.9551 - precision: 0.9891 - recall: 0.9498 - val_loss: 0.0906 - val_accuracy: 0.9731 - val_precision: 0.9858 - val_recall: 0.9772
# Epoch 44/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0603 - accuracy: 0.9602 - precision: 0.9885 - recall: 0.9574 - val_loss: 0.0903 - val_accuracy: 0.9736 - val_precision: 0.9853 - val_recall: 0.9788
# Epoch 45/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0642 - accuracy: 0.9570 - precision: 0.9879 - recall: 0.9534 - val_loss: 0.0938 - val_accuracy: 0.9731 - val_precision: 0.9845 - val_recall: 0.9786
# Epoch 46/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0736 - accuracy: 0.9553 - precision: 0.9837 - recall: 0.9547 - val_loss: 0.0952 - val_accuracy: 0.9712 - val_precision: 0.9831 - val_recall: 0.9772
# Epoch 47/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0596 - accuracy: 0.9607 - precision: 0.9856 - recall: 0.9600 - val_loss: 0.0902 - val_accuracy: 0.9746 - val_precision: 0.9831 - val_recall: 0.9818
#
#
# Batch Size: 512
# Hidden Units: 4096
# Learning Rate: 0.06103
# Epoch 1/50
# 6/6 [==============================] - 53s 4s/step - loss: 5.2959 - accuracy: 0.6266 - precision: 0.8133 - recall: 0.6295 - val_loss: 405.1542 - val_accuracy: 0.5820 - val_precision: 1.0000 - val_recall: 0.4316
# Epoch 2/50
# 6/6 [==============================] - 2s 315ms/step - loss: 6.3910 - accuracy: 0.8630 - precision: 0.9774 - recall: 0.8294 - val_loss: 109.9133 - val_accuracy: 0.6855 - val_precision: 1.0000 - val_recall: 0.5689
# Epoch 3/50
# 6/6 [==============================] - 2s 313ms/step - loss: 2.9022 - accuracy: 0.9303 - precision: 0.9464 - recall: 0.9584 - val_loss: 30.2954 - val_accuracy: 0.8008 - val_precision: 0.9982 - val_recall: 0.7286
# Epoch 4/50
# 6/6 [==============================] - 2s 329ms/step - loss: 1.8961 - accuracy: 0.9261 - precision: 0.9589 - recall: 0.9391 - val_loss: 14.7562 - val_accuracy: 0.8096 - val_precision: 0.9982 - val_recall: 0.7434
# Epoch 5/50
# 6/6 [==============================] - 2s 371ms/step - loss: 0.8958 - accuracy: 0.9067 - precision: 0.9814 - recall: 0.8910 - val_loss: 3.0909 - val_accuracy: 0.8770 - val_precision: 0.9873 - val_recall: 0.8410
# Epoch 6/50
# 6/6 [==============================] - 2s 334ms/step - loss: 0.5168 - accuracy: 0.9272 - precision: 0.9674 - recall: 0.9315 - val_loss: 12.4713 - val_accuracy: 0.6738 - val_precision: 1.0000 - val_recall: 0.5493
# Epoch 7/50
# 6/6 [==============================] - 2s 323ms/step - loss: 0.5584 - accuracy: 0.9312 - precision: 0.9669 - recall: 0.9381 - val_loss: 2.4037 - val_accuracy: 0.8496 - val_precision: 0.9983 - val_recall: 0.7949
# Epoch 8/50
# 6/6 [==============================] - 2s 313ms/step - loss: 0.3250 - accuracy: 0.9338 - precision: 0.9727 - recall: 0.9365 - val_loss: 0.4189 - val_accuracy: 0.9570 - val_precision: 0.9695 - val_recall: 0.9721
# Epoch 9/50
# 6/6 [==============================] - 2s 319ms/step - loss: 0.2730 - accuracy: 0.9220 - precision: 0.9819 - recall: 0.9080 - val_loss: 0.4840 - val_accuracy: 0.9414 - val_precision: 0.9887 - val_recall: 0.9311
# Epoch 10/50
# 6/6 [==============================] - 2s 323ms/step - loss: 0.2596 - accuracy: 0.9360 - precision: 0.9658 - recall: 0.9458 - val_loss: 2.0919 - val_accuracy: 0.8281 - val_precision: 1.0000 - val_recall: 0.7634
# Epoch 11/50
# 6/6 [==============================] - 2s 315ms/step - loss: 0.2647 - accuracy: 0.9081 - precision: 0.9755 - recall: 0.8993 - val_loss: 0.1814 - val_accuracy: 0.9648 - val_precision: 0.9786 - val_recall: 0.9734
# Epoch 12/50
# 6/6 [==============================] - 2s 312ms/step - loss: 0.1969 - accuracy: 0.9229 - precision: 0.9874 - recall: 0.9079 - val_loss: 0.3409 - val_accuracy: 0.9482 - val_precision: 0.9357 - val_recall: 0.9973
# Epoch 13/50
# 6/6 [==============================] - 2s 299ms/step - loss: 0.1579 - accuracy: 0.9479 - precision: 0.9738 - recall: 0.9548 - val_loss: 0.2239 - val_accuracy: 0.9570 - val_precision: 0.9847 - val_recall: 0.9555
# Epoch 14/50
# 6/6 [==============================] - 2s 294ms/step - loss: 0.1697 - accuracy: 0.9279 - precision: 0.9793 - recall: 0.9196 - val_loss: 0.1564 - val_accuracy: 0.9580 - val_precision: 0.9683 - val_recall: 0.9747
# Epoch 15/50
# 6/6 [==============================] - 2s 320ms/step - loss: 0.1490 - accuracy: 0.9321 - precision: 0.9632 - recall: 0.9436 - val_loss: 0.2139 - val_accuracy: 0.9512 - val_precision: 0.9847 - val_recall: 0.9477
# Epoch 16/50
# 6/6 [==============================] - 2s 316ms/step - loss: 0.1645 - accuracy: 0.9355 - precision: 0.9837 - recall: 0.9266 - val_loss: 0.3368 - val_accuracy: 0.9287 - val_precision: 0.9126 - val_recall: 0.9973
# Epoch 17/50
# 6/6 [==============================] - 2s 311ms/step - loss: 0.1343 - accuracy: 0.9427 - precision: 0.9681 - recall: 0.9524 - val_loss: 0.1757 - val_accuracy: 0.9600 - val_precision: 0.9612 - val_recall: 0.9854
# Epoch 18/50
# 6/6 [==============================] - 2s 308ms/step - loss: 0.1444 - accuracy: 0.9364 - precision: 0.9770 - recall: 0.9352 - val_loss: 0.1837 - val_accuracy: 0.9502 - val_precision: 0.9451 - val_recall: 0.9893
# Epoch 19/50
# 6/6 [==============================] - 2s 299ms/step - loss: 0.1340 - accuracy: 0.9394 - precision: 0.9777 - recall: 0.9396 - val_loss: 0.1354 - val_accuracy: 0.9648 - val_precision: 0.9707 - val_recall: 0.9812
# Epoch 20/50
# 6/6 [==============================] - 2s 306ms/step - loss: 0.1287 - accuracy: 0.9423 - precision: 0.9814 - recall: 0.9384 - val_loss: 0.1363 - val_accuracy: 0.9639 - val_precision: 0.9694 - val_recall: 0.9812
# Epoch 21/50
# 6/6 [==============================] - 2s 307ms/step - loss: 0.1169 - accuracy: 0.9394 - precision: 0.9799 - recall: 0.9372 - val_loss: 0.1484 - val_accuracy: 0.9541 - val_precision: 0.9487 - val_recall: 0.9906
# Epoch 22/50
# 6/6 [==============================] - 2s 295ms/step - loss: 0.1029 - accuracy: 0.9473 - precision: 0.9786 - recall: 0.9491 - val_loss: 0.1298 - val_accuracy: 0.9629 - val_precision: 0.9695 - val_recall: 0.9799
# Epoch 23/50
# 6/6 [==============================] - 2s 330ms/step - loss: 0.1298 - accuracy: 0.9416 - precision: 0.9748 - recall: 0.9438 - val_loss: 0.1301 - val_accuracy: 0.9600 - val_precision: 0.9642 - val_recall: 0.9811
# Epoch 24/50
# 6/6 [==============================] - 2s 311ms/step - loss: 0.1047 - accuracy: 0.9472 - precision: 0.9791 - recall: 0.9475 - val_loss: 0.1283 - val_accuracy: 0.9619 - val_precision: 0.9658 - val_recall: 0.9826
# Epoch 25/50
# 6/6 [==============================] - 2s 327ms/step - loss: 0.1103 - accuracy: 0.9451 - precision: 0.9831 - recall: 0.9407 - val_loss: 0.1363 - val_accuracy: 0.9590 - val_precision: 0.9605 - val_recall: 0.9838
# Epoch 26/50
# 6/6 [==============================] - 2s 313ms/step - loss: 0.1267 - accuracy: 0.9335 - precision: 0.9745 - recall: 0.9334 - val_loss: 0.1337 - val_accuracy: 0.9590 - val_precision: 0.9609 - val_recall: 0.9840
# Epoch 27/50
# 6/6 [==============================] - 2s 314ms/step - loss: 0.1216 - accuracy: 0.9399 - precision: 0.9773 - recall: 0.9391 - val_loss: 0.1177 - val_accuracy: 0.9580 - val_precision: 0.9597 - val_recall: 0.9840
# Epoch 28/50
# 6/6 [==============================] - 2s 312ms/step - loss: 0.1157 - accuracy: 0.9508 - precision: 0.9762 - recall: 0.9548 - val_loss: 0.1203 - val_accuracy: 0.9619 - val_precision: 0.9658 - val_recall: 0.9826
# Epoch 29/50
# 6/6 [==============================] - 2s 330ms/step - loss: 0.1057 - accuracy: 0.9433 - precision: 0.9776 - recall: 0.9438 - val_loss: 0.1134 - val_accuracy: 0.9648 - val_precision: 0.9675 - val_recall: 0.9854
# Epoch 30/50
# 6/6 [==============================] - 2s 325ms/step - loss: 0.1167 - accuracy: 0.9375 - precision: 0.9757 - recall: 0.9382 - val_loss: 0.1147 - val_accuracy: 0.9639 - val_precision: 0.9634 - val_recall: 0.9879
# Epoch 31/50
# 6/6 [==============================] - 2s 309ms/step - loss: 0.1099 - accuracy: 0.9504 - precision: 0.9718 - recall: 0.9587 - val_loss: 0.1053 - val_accuracy: 0.9668 - val_precision: 0.9737 - val_recall: 0.9815
# Epoch 32/50
# 6/6 [==============================] - 2s 332ms/step - loss: 0.1085 - accuracy: 0.9398 - precision: 0.9800 - recall: 0.9365 - val_loss: 0.1015 - val_accuracy: 0.9678 - val_precision: 0.9709 - val_recall: 0.9852
# Epoch 33/50
# 6/6 [==============================] - 2s 307ms/step - loss: 0.0983 - accuracy: 0.9501 - precision: 0.9840 - recall: 0.9472 - val_loss: 0.1077 - val_accuracy: 0.9629 - val_precision: 0.9637 - val_recall: 0.9867
# Epoch 34/50
# 6/6 [==============================] - 2s 306ms/step - loss: 0.1029 - accuracy: 0.9374 - precision: 0.9727 - recall: 0.9404 - val_loss: 0.0827 - val_accuracy: 0.9707 - val_precision: 0.9725 - val_recall: 0.9880
# Epoch 35/50
# 6/6 [==============================] - 2s 313ms/step - loss: 0.0991 - accuracy: 0.9444 - precision: 0.9843 - recall: 0.9403 - val_loss: 0.0960 - val_accuracy: 0.9697 - val_precision: 0.9735 - val_recall: 0.9853
# Epoch 36/50
# 6/6 [==============================] - 2s 303ms/step - loss: 0.0936 - accuracy: 0.9493 - precision: 0.9826 - recall: 0.9475 - val_loss: 0.1123 - val_accuracy: 0.9609 - val_precision: 0.9661 - val_recall: 0.9814
# Epoch 37/50
# 6/6 [==============================] - 2s 298ms/step - loss: 0.1127 - accuracy: 0.9363 - precision: 0.9810 - recall: 0.9325 - val_loss: 0.0930 - val_accuracy: 0.9658 - val_precision: 0.9688 - val_recall: 0.9854
# Epoch 38/50
# 6/6 [==============================] - 2s 295ms/step - loss: 0.1057 - accuracy: 0.9436 - precision: 0.9784 - recall: 0.9441 - val_loss: 0.1109 - val_accuracy: 0.9619 - val_precision: 0.9686 - val_recall: 0.9801
# Epoch 39/50
# 6/6 [==============================] - 2s 305ms/step - loss: 0.0975 - accuracy: 0.9502 - precision: 0.9773 - recall: 0.9540 - val_loss: 0.1091 - val_accuracy: 0.9648 - val_precision: 0.9730 - val_recall: 0.9783
# Epoch 40/50
# 6/6 [==============================] - 2s 311ms/step - loss: 0.1095 - accuracy: 0.9410 - precision: 0.9748 - recall: 0.9428 - val_loss: 0.1068 - val_accuracy: 0.9629 - val_precision: 0.9733 - val_recall: 0.9759
# Epoch 41/50
# 6/6 [==============================] - 2s 323ms/step - loss: 0.1147 - accuracy: 0.9386 - precision: 0.9823 - recall: 0.9334 - val_loss: 0.1039 - val_accuracy: 0.9639 - val_precision: 0.9759 - val_recall: 0.9746
# Epoch 42/50
# 6/6 [==============================] - 2s 301ms/step - loss: 0.1067 - accuracy: 0.9441 - precision: 0.9768 - recall: 0.9454 - val_loss: 0.0943 - val_accuracy: 0.9658 - val_precision: 0.9761 - val_recall: 0.9774
# Epoch 43/50
# 6/6 [==============================] - 2s 298ms/step - loss: 0.1087 - accuracy: 0.9415 - precision: 0.9778 - recall: 0.9416 - val_loss: 0.1030 - val_accuracy: 0.9639 - val_precision: 0.9734 - val_recall: 0.9773
# Epoch 44/50
# 6/6 [==============================] - 2s 293ms/step - loss: 0.0986 - accuracy: 0.9416 - precision: 0.9796 - recall: 0.9400 - val_loss: 0.1026 - val_accuracy: 0.9648 - val_precision: 0.9733 - val_recall: 0.9786
#
#
# Batch Size: 1024
# Hidden Units: 4096
# Learning Rate: 0.06103
# Epoch 1/50
# 3/3 [==============================] - 51s 9s/step - loss: 4.3418 - accuracy: 0.5945 - precision: 0.7908 - recall: 0.6032 - val_loss: 268.9403 - val_accuracy: 0.6133 - val_precision: 1.0000 - val_recall: 0.4776
# Epoch 2/50
# 3/3 [==============================] - 1s 538ms/step - loss: 4.9178 - accuracy: 0.8383 - precision: 0.9865 - recall: 0.7890 - val_loss: 363.6893 - val_accuracy: 0.6074 - val_precision: 1.0000 - val_recall: 0.4611
# Epoch 3/50
# 3/3 [==============================] - 1s 552ms/step - loss: 6.6940 - accuracy: 0.8568 - precision: 0.9775 - recall: 0.8228 - val_loss: 168.2942 - val_accuracy: 0.7188 - val_precision: 1.0000 - val_recall: 0.6044
# Epoch 4/50
# 3/3 [==============================] - 1s 544ms/step - loss: 5.6984 - accuracy: 0.8982 - precision: 0.9670 - recall: 0.8925 - val_loss: 96.3632 - val_accuracy: 0.7793 - val_precision: 1.0000 - val_recall: 0.6896
# Epoch 5/50
# 3/3 [==============================] - 1s 494ms/step - loss: 3.5581 - accuracy: 0.9146 - precision: 0.9477 - recall: 0.9345 - val_loss: 46.9553 - val_accuracy: 0.8184 - val_precision: 1.0000 - val_recall: 0.7540
# Epoch 6/50
# 3/3 [==============================] - 1s 574ms/step - loss: 3.4557 - accuracy: 0.9264 - precision: 0.9524 - recall: 0.9485 - val_loss: 36.1670 - val_accuracy: 0.8047 - val_precision: 1.0000 - val_recall: 0.7423
# Epoch 7/50
# 3/3 [==============================] - 1s 527ms/step - loss: 2.2574 - accuracy: 0.9403 - precision: 0.9670 - recall: 0.9518 - val_loss: 23.7604 - val_accuracy: 0.8242 - val_precision: 0.9964 - val_recall: 0.7568
# Epoch 8/50
# 3/3 [==============================] - 1s 522ms/step - loss: 1.8008 - accuracy: 0.9329 - precision: 0.9689 - recall: 0.9383 - val_loss: 18.4971 - val_accuracy: 0.8145 - val_precision: 1.0000 - val_recall: 0.7507
# Epoch 9/50
# 3/3 [==============================] - 1s 503ms/step - loss: 1.5739 - accuracy: 0.9259 - precision: 0.9787 - recall: 0.9199 - val_loss: 11.0322 - val_accuracy: 0.8379 - val_precision: 0.9935 - val_recall: 0.7918
# Epoch 10/50
# 3/3 [==============================] - 1s 545ms/step - loss: 1.1626 - accuracy: 0.9235 - precision: 0.9776 - recall: 0.9161 - val_loss: 8.9281 - val_accuracy: 0.8320 - val_precision: 0.9965 - val_recall: 0.7721
# Epoch 11/50
# 3/3 [==============================] - 2s 988ms/step - loss: 0.9208 - accuracy: 0.9320 - precision: 0.9798 - recall: 0.9249 - val_loss: 7.5082 - val_accuracy: 0.8359 - val_precision: 1.0000 - val_recall: 0.7760
# Epoch 12/50
# 3/3 [==============================] - 1s 506ms/step - loss: 0.7155 - accuracy: 0.9310 - precision: 0.9860 - recall: 0.9197 - val_loss: 6.9227 - val_accuracy: 0.7832 - val_precision: 0.9961 - val_recall: 0.7011
# Epoch 13/50
# 3/3 [==============================] - 1s 514ms/step - loss: 0.6873 - accuracy: 0.9419 - precision: 0.9627 - recall: 0.9562 - val_loss: 8.5912 - val_accuracy: 0.7266 - val_precision: 0.9959 - val_recall: 0.6332
# Epoch 14/50
# 3/3 [==============================] - 1s 503ms/step - loss: 0.6807 - accuracy: 0.9264 - precision: 0.9600 - recall: 0.9384 - val_loss: 7.1619 - val_accuracy: 0.7559 - val_precision: 1.0000 - val_recall: 0.6684
# Epoch 15/50
# 3/3 [==============================] - 1s 499ms/step - loss: 0.7785 - accuracy: 0.9223 - precision: 0.9585 - recall: 0.9318 - val_loss: 5.1100 - val_accuracy: 0.8027 - val_precision: 0.9964 - val_recall: 0.7333
# Epoch 16/50
# 3/3 [==============================] - 1s 490ms/step - loss: 0.5050 - accuracy: 0.9223 - precision: 0.9796 - recall: 0.9136 - val_loss: 2.3525 - val_accuracy: 0.8926 - val_precision: 0.9969 - val_recall: 0.8571
# Epoch 17/50
# 3/3 [==============================] - 1s 508ms/step - loss: 0.4398 - accuracy: 0.9367 - precision: 0.9813 - recall: 0.9305 - val_loss: 1.3282 - val_accuracy: 0.9277 - val_precision: 0.9941 - val_recall: 0.9062
# Epoch 18/50
# 3/3 [==============================] - 1s 484ms/step - loss: 0.6579 - accuracy: 0.9275 - precision: 0.9685 - recall: 0.9296 - val_loss: 0.8167 - val_accuracy: 0.9453 - val_precision: 0.9972 - val_recall: 0.9291
# Epoch 19/50
# 3/3 [==============================] - 1s 488ms/step - loss: 0.4061 - accuracy: 0.9359 - precision: 0.9744 - recall: 0.9387 - val_loss: 0.6291 - val_accuracy: 0.9570 - val_precision: 0.9945 - val_recall: 0.9478
# Epoch 20/50
# 3/3 [==============================] - 1s 484ms/step - loss: 0.3950 - accuracy: 0.9411 - precision: 0.9687 - recall: 0.9496 - val_loss: 0.5038 - val_accuracy: 0.9590 - val_precision: 0.9837 - val_recall: 0.9601
# Epoch 21/50
# 3/3 [==============================] - 1s 504ms/step - loss: 0.3852 - accuracy: 0.9359 - precision: 0.9728 - recall: 0.9386 - val_loss: 0.6762 - val_accuracy: 0.9395 - val_precision: 0.9863 - val_recall: 0.9326
# Epoch 22/50
# 3/3 [==============================] - 1s 491ms/step - loss: 0.4606 - accuracy: 0.9355 - precision: 0.9691 - recall: 0.9416 - val_loss: 1.0445 - val_accuracy: 0.9375 - val_precision: 0.9859 - val_recall: 0.9284
# Epoch 23/50
# 3/3 [==============================] - 1s 484ms/step - loss: 0.2591 - accuracy: 0.9494 - precision: 0.9783 - recall: 0.9513 - val_loss: 0.6561 - val_accuracy: 0.9473 - val_precision: 0.9942 - val_recall: 0.9324
# Epoch 24/50
# 3/3 [==============================] - 1s 486ms/step - loss: 0.2727 - accuracy: 0.9528 - precision: 0.9782 - recall: 0.9551 - val_loss: 0.7247 - val_accuracy: 0.9395 - val_precision: 0.9890 - val_recall: 0.9301
# Epoch 25/50
# 3/3 [==============================] - 1s 484ms/step - loss: 0.3252 - accuracy: 0.9302 - precision: 0.9796 - recall: 0.9257 - val_loss: 0.5535 - val_accuracy: 0.9512 - val_precision: 0.9942 - val_recall: 0.9370
# Epoch 26/50
# 3/3 [==============================] - 1s 494ms/step - loss: 0.3006 - accuracy: 0.9443 - precision: 0.9687 - recall: 0.9521 - val_loss: 0.8398 - val_accuracy: 0.9297 - val_precision: 0.9913 - val_recall: 0.9118
# Epoch 27/50
# 3/3 [==============================] - 1s 490ms/step - loss: 0.2854 - accuracy: 0.9333 - precision: 0.9820 - recall: 0.9271 - val_loss: 0.6157 - val_accuracy: 0.9395 - val_precision: 0.9862 - val_recall: 0.9323
# Epoch 28/50
# 3/3 [==============================] - 1s 503ms/step - loss: 0.2299 - accuracy: 0.9433 - precision: 0.9870 - recall: 0.9352 - val_loss: 0.4329 - val_accuracy: 0.9531 - val_precision: 0.9944 - val_recall: 0.9413
# Epoch 29/50
# 3/3 [==============================] - 1s 564ms/step - loss: 0.4161 - accuracy: 0.9346 - precision: 0.9653 - recall: 0.9424 - val_loss: 0.4556 - val_accuracy: 0.9492 - val_precision: 0.9862 - val_recall: 0.9444
# Epoch 30/50
# 3/3 [==============================] - 1s 492ms/step - loss: 0.3024 - accuracy: 0.9325 - precision: 0.9752 - recall: 0.9330 - val_loss: 0.2748 - val_accuracy: 0.9668 - val_precision: 0.9918 - val_recall: 0.9627
# Epoch 31/50
# 3/3 [==============================] - 1s 495ms/step - loss: 0.2766 - accuracy: 0.9377 - precision: 0.9758 - recall: 0.9381 - val_loss: 0.3927 - val_accuracy: 0.9473 - val_precision: 0.9837 - val_recall: 0.9450
# Epoch 32/50
# 3/3 [==============================] - 1s 529ms/step - loss: 0.3010 - accuracy: 0.9368 - precision: 0.9717 - recall: 0.9398 - val_loss: 0.5604 - val_accuracy: 0.9316 - val_precision: 0.9828 - val_recall: 0.9220
# Epoch 33/50
# 3/3 [==============================] - 1s 498ms/step - loss: 0.4013 - accuracy: 0.9338 - precision: 0.9675 - recall: 0.9402 - val_loss: 0.3051 - val_accuracy: 0.9609 - val_precision: 0.9916 - val_recall: 0.9542
# Epoch 34/50
# 3/3 [==============================] - 1s 487ms/step - loss: 0.2614 - accuracy: 0.9421 - precision: 0.9780 - recall: 0.9429 - val_loss: 0.2959 - val_accuracy: 0.9648 - val_precision: 0.9918 - val_recall: 0.9602
# Epoch 35/50
# 3/3 [==============================] - 1s 506ms/step - loss: 0.3465 - accuracy: 0.9191 - precision: 0.9786 - recall: 0.9116 - val_loss: 0.5091 - val_accuracy: 0.9453 - val_precision: 0.9865 - val_recall: 0.9407
# Epoch 36/50
# 3/3 [==============================] - 1s 483ms/step - loss: 0.3176 - accuracy: 0.9377 - precision: 0.9719 - recall: 0.9396 - val_loss: 0.2776 - val_accuracy: 0.9590 - val_precision: 0.9892 - val_recall: 0.9558
# Epoch 37/50
# 3/3 [==============================] - 1s 506ms/step - loss: 0.2935 - accuracy: 0.9414 - precision: 0.9833 - recall: 0.9368 - val_loss: 0.3553 - val_accuracy: 0.9551 - val_precision: 0.9890 - val_recall: 0.9497
# Epoch 38/50
# 3/3 [==============================] - 1s 526ms/step - loss: 0.3533 - accuracy: 0.9329 - precision: 0.9627 - recall: 0.9419 - val_loss: 0.3255 - val_accuracy: 0.9570 - val_precision: 0.9915 - val_recall: 0.9488
# Epoch 39/50
# 3/3 [==============================] - 1s 480ms/step - loss: 0.2927 - accuracy: 0.9296 - precision: 0.9813 - recall: 0.9235 - val_loss: 0.4310 - val_accuracy: 0.9453 - val_precision: 0.9914 - val_recall: 0.9328
# Epoch 40/50
# 3/3 [==============================] - 1s 474ms/step - loss: 0.3086 - accuracy: 0.9349 - precision: 0.9706 - recall: 0.9392 - val_loss: 0.2656 - val_accuracy: 0.9590 - val_precision: 0.9917 - val_recall: 0.9523
# Epoch 41/50
# 3/3 [==============================] - 1s 505ms/step - loss: 0.2925 - accuracy: 0.9352 - precision: 0.9756 - recall: 0.9367 - val_loss: 0.3962 - val_accuracy: 0.9473 - val_precision: 0.9863 - val_recall: 0.9426
# Epoch 42/50
# 3/3 [==============================] - 1s 478ms/step - loss: 0.3098 - accuracy: 0.9357 - precision: 0.9647 - recall: 0.9451 - val_loss: 0.3695 - val_accuracy: 0.9473 - val_precision: 0.9886 - val_recall: 0.9380
# Epoch 43/50
# 3/3 [==============================] - 1s 507ms/step - loss: 0.2313 - accuracy: 0.9351 - precision: 0.9806 - recall: 0.9306 - val_loss: 0.3148 - val_accuracy: 0.9551 - val_precision: 0.9830 - val_recall: 0.9532
# Epoch 44/50
# 3/3 [==============================] - 1s 529ms/step - loss: 0.2989 - accuracy: 0.9384 - precision: 0.9736 - recall: 0.9409 - val_loss: 0.3578 - val_accuracy: 0.9453 - val_precision: 0.9893 - val_recall: 0.9389
# Epoch 45/50
# 3/3 [==============================] - 1s 531ms/step - loss: 0.3061 - accuracy: 0.9299 - precision: 0.9675 - recall: 0.9336 - val_loss: 0.2910 - val_accuracy: 0.9609 - val_precision: 0.9946 - val_recall: 0.9534
# Epoch 46/50
# 3/3 [==============================] - 1s 472ms/step - loss: 0.2674 - accuracy: 0.9434 - precision: 0.9751 - recall: 0.9468 - val_loss: 0.3114 - val_accuracy: 0.9551 - val_precision: 0.9812 - val_recall: 0.9580
# Epoch 47/50
# 3/3 [==============================] - 1s 499ms/step - loss: 0.2924 - accuracy: 0.9422 - precision: 0.9750 - recall: 0.9435 - val_loss: 0.2619 - val_accuracy: 0.9531 - val_precision: 0.9891 - val_recall: 0.9479
# Epoch 48/50
# 3/3 [==============================] - 1s 483ms/step - loss: 0.3406 - accuracy: 0.9354 - precision: 0.9836 - recall: 0.9293 - val_loss: 0.3478 - val_accuracy: 0.9473 - val_precision: 0.9855 - val_recall: 0.9394
# Epoch 49/50
# 3/3 [==============================] - 1s 524ms/step - loss: 0.2206 - accuracy: 0.9474 - precision: 0.9845 - recall: 0.9434 - val_loss: 0.2911 - val_accuracy: 0.9629 - val_precision: 0.9944 - val_recall: 0.9544
# Epoch 50/50
# 3/3 [==============================] - 1s 526ms/step - loss: 0.2633 - accuracy: 0.9325 - precision: 0.9806 - recall: 0.9258 - val_loss: 0.3547 - val_accuracy: 0.9512 - val_precision: 0.9886 - val_recall: 0.9431
#
#
# Batch Size: 256
# Hidden Units: 2048
# Learning Rate: 0.06103
# Epoch 1/50
# 13/13 [==============================] - 52s 2s/step - loss: 2.1425 - accuracy: 0.7508 - precision: 0.8941 - recall: 0.7452 - val_loss: 25.8769 - val_accuracy: 0.7622 - val_precision: 0.9990 - val_recall: 0.6745
# Epoch 2/50
# 13/13 [==============================] - 3s 228ms/step - loss: 1.1357 - accuracy: 0.9083 - precision: 0.9516 - recall: 0.9217 - val_loss: 12.8593 - val_accuracy: 0.6431 - val_precision: 1.0000 - val_recall: 0.5136
# Epoch 3/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.3343 - accuracy: 0.9277 - precision: 0.9702 - recall: 0.9301 - val_loss: 0.3724 - val_accuracy: 0.9316 - val_precision: 0.9871 - val_recall: 0.9184
# Epoch 4/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.1758 - accuracy: 0.9146 - precision: 0.9782 - recall: 0.9039 - val_loss: 0.3561 - val_accuracy: 0.9053 - val_precision: 0.9939 - val_recall: 0.8756
# Epoch 5/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.1183 - accuracy: 0.9347 - precision: 0.9792 - recall: 0.9310 - val_loss: 0.6889 - val_accuracy: 0.8652 - val_precision: 0.9967 - val_recall: 0.8178
# Epoch 6/50
# 13/13 [==============================] - 3s 232ms/step - loss: 0.1090 - accuracy: 0.9323 - precision: 0.9790 - recall: 0.9280 - val_loss: 0.0987 - val_accuracy: 0.9678 - val_precision: 0.9852 - val_recall: 0.9707
# Epoch 7/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.1020 - accuracy: 0.9413 - precision: 0.9766 - recall: 0.9418 - val_loss: 0.1155 - val_accuracy: 0.9570 - val_precision: 0.9869 - val_recall: 0.9540
# Epoch 8/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0926 - accuracy: 0.9419 - precision: 0.9799 - recall: 0.9403 - val_loss: 0.0960 - val_accuracy: 0.9634 - val_precision: 0.9753 - val_recall: 0.9746
# Epoch 9/50
# 13/13 [==============================] - 3s 227ms/step - loss: 0.0898 - accuracy: 0.9457 - precision: 0.9755 - recall: 0.9498 - val_loss: 0.1315 - val_accuracy: 0.9492 - val_precision: 0.9881 - val_recall: 0.9419
# Epoch 10/50
# 13/13 [==============================] - 3s 227ms/step - loss: 0.0866 - accuracy: 0.9451 - precision: 0.9829 - recall: 0.9413 - val_loss: 0.0898 - val_accuracy: 0.9697 - val_precision: 0.9800 - val_recall: 0.9787
# Epoch 11/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0844 - accuracy: 0.9506 - precision: 0.9781 - recall: 0.9535 - val_loss: 0.1684 - val_accuracy: 0.9282 - val_precision: 0.9905 - val_recall: 0.9104
# Epoch 12/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0828 - accuracy: 0.9412 - precision: 0.9824 - recall: 0.9364 - val_loss: 0.1081 - val_accuracy: 0.9644 - val_precision: 0.9826 - val_recall: 0.9689
# Epoch 13/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0732 - accuracy: 0.9553 - precision: 0.9811 - recall: 0.9568 - val_loss: 0.0844 - val_accuracy: 0.9688 - val_precision: 0.9749 - val_recall: 0.9827
# Epoch 14/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0765 - accuracy: 0.9507 - precision: 0.9828 - recall: 0.9496 - val_loss: 0.1130 - val_accuracy: 0.9551 - val_precision: 0.9876 - val_recall: 0.9509
# Epoch 15/50
# 13/13 [==============================] - 3s 215ms/step - loss: 0.0712 - accuracy: 0.9481 - precision: 0.9861 - recall: 0.9427 - val_loss: 0.0902 - val_accuracy: 0.9697 - val_precision: 0.9818 - val_recall: 0.9766
# Epoch 16/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0791 - accuracy: 0.9473 - precision: 0.9836 - recall: 0.9430 - val_loss: 0.1207 - val_accuracy: 0.9565 - val_precision: 0.9855 - val_recall: 0.9546
# Epoch 17/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0719 - accuracy: 0.9547 - precision: 0.9841 - recall: 0.9534 - val_loss: 0.1174 - val_accuracy: 0.9536 - val_precision: 0.9868 - val_recall: 0.9493
# Epoch 18/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0731 - accuracy: 0.9496 - precision: 0.9824 - recall: 0.9472 - val_loss: 0.0999 - val_accuracy: 0.9639 - val_precision: 0.9863 - val_recall: 0.9640
# Epoch 19/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0703 - accuracy: 0.9526 - precision: 0.9875 - recall: 0.9472 - val_loss: 0.1031 - val_accuracy: 0.9619 - val_precision: 0.9876 - val_recall: 0.9599
# Epoch 20/50
# 13/13 [==============================] - 3s 215ms/step - loss: 0.0790 - accuracy: 0.9472 - precision: 0.9811 - recall: 0.9459 - val_loss: 0.0941 - val_accuracy: 0.9688 - val_precision: 0.9844 - val_recall: 0.9724
# Epoch 21/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0680 - accuracy: 0.9550 - precision: 0.9855 - recall: 0.9526 - val_loss: 0.1018 - val_accuracy: 0.9604 - val_precision: 0.9843 - val_recall: 0.9612
# Epoch 22/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0682 - accuracy: 0.9559 - precision: 0.9881 - recall: 0.9512 - val_loss: 0.1061 - val_accuracy: 0.9624 - val_precision: 0.9831 - val_recall: 0.9654
# Epoch 23/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0687 - accuracy: 0.9545 - precision: 0.9865 - recall: 0.9511 - val_loss: 0.1034 - val_accuracy: 0.9600 - val_precision: 0.9835 - val_recall: 0.9609
#
#
# Batch Size: 512
# Hidden Units: 2048
# Learning Rate: 0.06103
# Epoch 1/50
# 6/6 [==============================] - 51s 4s/step - loss: 2.1712 - accuracy: 0.6980 - precision: 0.8905 - recall: 0.6725 - val_loss: 333.8461 - val_accuracy: 0.4072 - val_precision: 1.0000 - val_recall: 0.1917
# Epoch 2/50
# 6/6 [==============================] - 2s 308ms/step - loss: 2.9825 - accuracy: 0.8867 - precision: 0.9714 - recall: 0.8718 - val_loss: 89.3270 - val_accuracy: 0.6045 - val_precision: 1.0000 - val_recall: 0.4593
# Epoch 3/50
# 6/6 [==============================] - 2s 303ms/step - loss: 1.6172 - accuracy: 0.9262 - precision: 0.9548 - recall: 0.9444 - val_loss: 20.7193 - val_accuracy: 0.7939 - val_precision: 0.9981 - val_recall: 0.7177
# Epoch 4/50
# 6/6 [==============================] - 2s 302ms/step - loss: 0.9335 - accuracy: 0.9229 - precision: 0.9793 - recall: 0.9160 - val_loss: 4.9456 - val_accuracy: 0.8389 - val_precision: 0.9966 - val_recall: 0.7824
# Epoch 5/50
# 6/6 [==============================] - 2s 308ms/step - loss: 0.5245 - accuracy: 0.9145 - precision: 0.9700 - recall: 0.9135 - val_loss: 4.1879 - val_accuracy: 0.8086 - val_precision: 0.9982 - val_recall: 0.7427
# Epoch 6/50
# 6/6 [==============================] - 2s 306ms/step - loss: 0.3858 - accuracy: 0.9217 - precision: 0.9724 - recall: 0.9172 - val_loss: 2.8102 - val_accuracy: 0.8418 - val_precision: 0.9984 - val_recall: 0.7904
# Epoch 7/50
# 6/6 [==============================] - 2s 299ms/step - loss: 0.2655 - accuracy: 0.9429 - precision: 0.9705 - recall: 0.9500 - val_loss: 1.7275 - val_accuracy: 0.8438 - val_precision: 1.0000 - val_recall: 0.7881
# Epoch 8/50
# 6/6 [==============================] - 2s 303ms/step - loss: 0.2254 - accuracy: 0.9250 - precision: 0.9765 - recall: 0.9190 - val_loss: 0.5658 - val_accuracy: 0.9150 - val_precision: 0.9925 - val_recall: 0.8895
# Epoch 9/50
# 6/6 [==============================] - 2s 306ms/step - loss: 0.1946 - accuracy: 0.9258 - precision: 0.9692 - recall: 0.9281 - val_loss: 0.4788 - val_accuracy: 0.9111 - val_precision: 0.9924 - val_recall: 0.8843
# Epoch 10/50
# 6/6 [==============================] - 2s 306ms/step - loss: 0.1638 - accuracy: 0.9315 - precision: 0.9722 - recall: 0.9314 - val_loss: 0.1826 - val_accuracy: 0.9600 - val_precision: 0.9694 - val_recall: 0.9759
# Epoch 11/50
# 6/6 [==============================] - 2s 303ms/step - loss: 0.1461 - accuracy: 0.9358 - precision: 0.9748 - recall: 0.9367 - val_loss: 0.2119 - val_accuracy: 0.9541 - val_precision: 0.9874 - val_recall: 0.9487
# Epoch 12/50
# 6/6 [==============================] - 2s 296ms/step - loss: 0.1650 - accuracy: 0.9190 - precision: 0.9820 - recall: 0.9070 - val_loss: 0.1230 - val_accuracy: 0.9678 - val_precision: 0.9814 - val_recall: 0.9749
# Epoch 13/50
# 6/6 [==============================] - 2s 308ms/step - loss: 0.1187 - accuracy: 0.9403 - precision: 0.9696 - recall: 0.9487 - val_loss: 0.1364 - val_accuracy: 0.9629 - val_precision: 0.9864 - val_recall: 0.9629
# Epoch 14/50
# 6/6 [==============================] - 2s 299ms/step - loss: 0.1303 - accuracy: 0.9333 - precision: 0.9764 - recall: 0.9323 - val_loss: 0.1581 - val_accuracy: 0.9482 - val_precision: 0.9887 - val_recall: 0.9394
# Epoch 15/50
# 6/6 [==============================] - 2s 299ms/step - loss: 0.1312 - accuracy: 0.9371 - precision: 0.9761 - recall: 0.9362 - val_loss: 0.1010 - val_accuracy: 0.9678 - val_precision: 0.9722 - val_recall: 0.9839
# Epoch 16/50
# 6/6 [==============================] - 2s 304ms/step - loss: 0.1459 - accuracy: 0.9345 - precision: 0.9651 - recall: 0.9436 - val_loss: 0.1417 - val_accuracy: 0.9561 - val_precision: 0.9890 - val_recall: 0.9512
# Epoch 17/50
# 6/6 [==============================] - 2s 294ms/step - loss: 0.1098 - accuracy: 0.9423 - precision: 0.9813 - recall: 0.9390 - val_loss: 0.1081 - val_accuracy: 0.9658 - val_precision: 0.9709 - val_recall: 0.9826
# Epoch 18/50
# 6/6 [==============================] - 2s 281ms/step - loss: 0.1099 - accuracy: 0.9422 - precision: 0.9790 - recall: 0.9419 - val_loss: 0.1100 - val_accuracy: 0.9668 - val_precision: 0.9825 - val_recall: 0.9720
# Epoch 19/50
# 6/6 [==============================] - 2s 289ms/step - loss: 0.1116 - accuracy: 0.9352 - precision: 0.9785 - recall: 0.9314 - val_loss: 0.1119 - val_accuracy: 0.9639 - val_precision: 0.9838 - val_recall: 0.9669
# Epoch 20/50
# 6/6 [==============================] - 2s 286ms/step - loss: 0.0938 - accuracy: 0.9434 - precision: 0.9813 - recall: 0.9402 - val_loss: 0.1064 - val_accuracy: 0.9678 - val_precision: 0.9825 - val_recall: 0.9733
# Epoch 21/50
# 6/6 [==============================] - 2s 286ms/step - loss: 0.0936 - accuracy: 0.9427 - precision: 0.9817 - recall: 0.9399 - val_loss: 0.1156 - val_accuracy: 0.9619 - val_precision: 0.9809 - val_recall: 0.9664
# Epoch 22/50
# 6/6 [==============================] - 2s 307ms/step - loss: 0.1047 - accuracy: 0.9442 - precision: 0.9812 - recall: 0.9420 - val_loss: 0.0955 - val_accuracy: 0.9707 - val_precision: 0.9840 - val_recall: 0.9761
# Epoch 23/50
# 6/6 [==============================] - 2s 312ms/step - loss: 0.0992 - accuracy: 0.9421 - precision: 0.9756 - recall: 0.9441 - val_loss: 0.1130 - val_accuracy: 0.9629 - val_precision: 0.9809 - val_recall: 0.9677
# Epoch 24/50
# 6/6 [==============================] - 2s 292ms/step - loss: 0.0963 - accuracy: 0.9407 - precision: 0.9847 - recall: 0.9331 - val_loss: 0.1051 - val_accuracy: 0.9658 - val_precision: 0.9772 - val_recall: 0.9759
# Epoch 25/50
# 6/6 [==============================] - 2s 293ms/step - loss: 0.0967 - accuracy: 0.9448 - precision: 0.9789 - recall: 0.9457 - val_loss: 0.1006 - val_accuracy: 0.9707 - val_precision: 0.9812 - val_recall: 0.9786
# Epoch 26/50
# 6/6 [==============================] - 2s 304ms/step - loss: 0.0940 - accuracy: 0.9456 - precision: 0.9813 - recall: 0.9433 - val_loss: 0.1018 - val_accuracy: 0.9697 - val_precision: 0.9828 - val_recall: 0.9763
# Epoch 27/50
# 6/6 [==============================] - 2s 285ms/step - loss: 0.0900 - accuracy: 0.9436 - precision: 0.9845 - recall: 0.9385 - val_loss: 0.0993 - val_accuracy: 0.9707 - val_precision: 0.9776 - val_recall: 0.9828
# Epoch 28/50
# 6/6 [==============================] - 2s 297ms/step - loss: 0.0788 - accuracy: 0.9605 - precision: 0.9822 - recall: 0.9628 - val_loss: 0.0998 - val_accuracy: 0.9707 - val_precision: 0.9799 - val_recall: 0.9799
# Epoch 29/50
# 6/6 [==============================] - 2s 293ms/step - loss: 0.0953 - accuracy: 0.9475 - precision: 0.9824 - recall: 0.9449 - val_loss: 0.1156 - val_accuracy: 0.9609 - val_precision: 0.9834 - val_recall: 0.9621
# Epoch 30/50
# 6/6 [==============================] - 2s 293ms/step - loss: 0.1016 - accuracy: 0.9357 - precision: 0.9788 - recall: 0.9331 - val_loss: 0.1194 - val_accuracy: 0.9531 - val_precision: 0.9835 - val_recall: 0.9520
# Epoch 31/50
# 6/6 [==============================] - 2s 292ms/step - loss: 0.1048 - accuracy: 0.9366 - precision: 0.9820 - recall: 0.9307 - val_loss: 0.0989 - val_accuracy: 0.9697 - val_precision: 0.9877 - val_recall: 0.9705
# Epoch 32/50
# 6/6 [==============================] - 2s 290ms/step - loss: 0.0878 - accuracy: 0.9467 - precision: 0.9873 - recall: 0.9399 - val_loss: 0.1013 - val_accuracy: 0.9668 - val_precision: 0.9812 - val_recall: 0.9734
#
#
# Batch Size: 1024
# Hidden Units: 2048
# Learning Rate: 0.06103
# Epoch 1/50
# 3/3 [==============================] - 51s 9s/step - loss: 1.7157 - accuracy: 0.6143 - precision: 0.8055 - recall: 0.6184 - val_loss: 134.0004 - val_accuracy: 0.6074 - val_precision: 1.0000 - val_recall: 0.4752
# Epoch 2/50
# 3/3 [==============================] - 1s 521ms/step - loss: 2.3254 - accuracy: 0.8324 - precision: 0.9900 - recall: 0.7834 - val_loss: 168.1089 - val_accuracy: 0.6270 - val_precision: 1.0000 - val_recall: 0.4947
# Epoch 3/50
# 3/3 [==============================] - 1s 516ms/step - loss: 3.1945 - accuracy: 0.8660 - precision: 0.9725 - recall: 0.8401 - val_loss: 99.7149 - val_accuracy: 0.6484 - val_precision: 1.0000 - val_recall: 0.5263
# Epoch 4/50
# 3/3 [==============================] - 1s 502ms/step - loss: 2.3240 - accuracy: 0.9031 - precision: 0.9687 - recall: 0.8974 - val_loss: 39.8993 - val_accuracy: 0.7402 - val_precision: 0.9919 - val_recall: 0.6525
# Epoch 5/50
# 3/3 [==============================] - 1s 482ms/step - loss: 1.3093 - accuracy: 0.9345 - precision: 0.9571 - recall: 0.9533 - val_loss: 14.7128 - val_accuracy: 0.8281 - val_precision: 0.9966 - val_recall: 0.7686
# Epoch 6/50
# 3/3 [==============================] - 1s 549ms/step - loss: 1.6909 - accuracy: 0.9194 - precision: 0.9295 - recall: 0.9606 - val_loss: 7.6669 - val_accuracy: 0.8438 - val_precision: 0.9834 - val_recall: 0.7984
# Epoch 7/50
# 3/3 [==============================] - 1s 480ms/step - loss: 0.6590 - accuracy: 0.9410 - precision: 0.9639 - recall: 0.9554 - val_loss: 3.1373 - val_accuracy: 0.9004 - val_precision: 0.9879 - val_recall: 0.8740
# Epoch 8/50
# 3/3 [==============================] - 1s 497ms/step - loss: 0.4923 - accuracy: 0.9348 - precision: 0.9770 - recall: 0.9318 - val_loss: 1.6231 - val_accuracy: 0.9277 - val_precision: 0.9761 - val_recall: 0.9185
# Epoch 9/50
# 3/3 [==============================] - 1s 521ms/step - loss: 0.5097 - accuracy: 0.9076 - precision: 0.9821 - recall: 0.8892 - val_loss: 0.5665 - val_accuracy: 0.9492 - val_precision: 0.9780 - val_recall: 0.9519
# Epoch 10/50
# 3/3 [==============================] - 1s 542ms/step - loss: 0.3690 - accuracy: 0.9066 - precision: 0.9761 - recall: 0.8961 - val_loss: 1.0182 - val_accuracy: 0.8984 - val_precision: 0.9491 - val_recall: 0.9147
# Epoch 11/50
# 3/3 [==============================] - 1s 491ms/step - loss: 0.3692 - accuracy: 0.9093 - precision: 0.9490 - recall: 0.9248 - val_loss: 2.9669 - val_accuracy: 0.8027 - val_precision: 0.9964 - val_recall: 0.7361
# Epoch 12/50
# 3/3 [==============================] - 1s 529ms/step - loss: 0.3077 - accuracy: 0.9103 - precision: 0.9789 - recall: 0.9011 - val_loss: 4.9515 - val_accuracy: 0.7227 - val_precision: 1.0000 - val_recall: 0.6302
# Epoch 13/50
# 3/3 [==============================] - 1s 480ms/step - loss: 0.3181 - accuracy: 0.9209 - precision: 0.9718 - recall: 0.9150 - val_loss: 4.0570 - val_accuracy: 0.7480 - val_precision: 1.0000 - val_recall: 0.6701
# Epoch 14/50
# 3/3 [==============================] - 1s 473ms/step - loss: 0.2532 - accuracy: 0.9230 - precision: 0.9785 - recall: 0.9160 - val_loss: 2.1267 - val_accuracy: 0.8223 - val_precision: 0.9965 - val_recall: 0.7587
# Epoch 15/50
# 3/3 [==============================] - 1s 520ms/step - loss: 0.2660 - accuracy: 0.9344 - precision: 0.9645 - recall: 0.9422 - val_loss: 0.4009 - val_accuracy: 0.9414 - val_precision: 0.9971 - val_recall: 0.9227
# Epoch 16/50
# 3/3 [==============================] - 1s 518ms/step - loss: 0.1759 - accuracy: 0.9405 - precision: 0.9783 - recall: 0.9417 - val_loss: 0.2984 - val_accuracy: 0.9609 - val_precision: 0.9749 - val_recall: 0.9694
# Epoch 17/50
# ...
# Epoch 17/50
# 6/6 [==============================] - 2s 293ms/step - loss: 0.0816 - accuracy: 0.9540 - precision: 0.9847 - recall: 0.9511 - val_loss: 0.1433 - val_accuracy: 0.9326 - val_precision: 0.9872 - val_recall: 0.9202
# Epoch 18/50
# 6/6 [==============================] - 2s 300ms/step - loss: 0.0800 - accuracy: 0.9500 - precision: 0.9846 - recall: 0.9464 - val_loss: 0.1166 - val_accuracy: 0.9502 - val_precision: 0.9861 - val_recall: 0.9452
# Epoch 19/50
# 6/6 [==============================] - 2s 298ms/step - loss: 0.0744 - accuracy: 0.9503 - precision: 0.9833 - recall: 0.9484 - val_loss: 0.1193 - val_accuracy: 0.9482 - val_precision: 0.9848 - val_recall: 0.9442
# Epoch 20/50
# 6/6 [==============================] - 2s 293ms/step - loss: 0.0845 - accuracy: 0.9447 - precision: 0.9750 - recall: 0.9485 - val_loss: 0.1377 - val_accuracy: 0.9375 - val_precision: 0.9858 - val_recall: 0.9280
# Epoch 21/50
# 6/6 [==============================] - 2s 293ms/step - loss: 0.0813 - accuracy: 0.9463 - precision: 0.9894 - recall: 0.9378 - val_loss: 0.1247 - val_accuracy: 0.9434 - val_precision: 0.9872 - val_recall: 0.9339
# Epoch 22/50
# 6/6 [==============================] - 2s 289ms/step - loss: 0.0783 - accuracy: 0.9506 - precision: 0.9838 - recall: 0.9485 - val_loss: 0.1059 - val_accuracy: 0.9580 - val_precision: 0.9876 - val_recall: 0.9547
# Epoch 23/50
# 6/6 [==============================] - 2s 297ms/step - loss: 0.0854 - accuracy: 0.9514 - precision: 0.9748 - recall: 0.9572 - val_loss: 0.1097 - val_accuracy: 0.9551 - val_precision: 0.9863 - val_recall: 0.9524
# Epoch 24/50
# 6/6 [==============================] - 2s 290ms/step - loss: 0.0883 - accuracy: 0.9491 - precision: 0.9746 - recall: 0.9543 - val_loss: 0.1064 - val_accuracy: 0.9570 - val_precision: 0.9902 - val_recall: 0.9504
# Epoch 25/50
# 6/6 [==============================] - 2s 281ms/step - loss: 0.0779 - accuracy: 0.9525 - precision: 0.9870 - recall: 0.9481 - val_loss: 0.1280 - val_accuracy: 0.9424 - val_precision: 0.9846 - val_recall: 0.9361
# Epoch 26/50
# 6/6 [==============================] - 2s 286ms/step - loss: 0.0826 - accuracy: 0.9483 - precision: 0.9819 - recall: 0.9460 - val_loss: 0.1206 - val_accuracy: 0.9492 - val_precision: 0.9873 - val_recall: 0.9420
# Epoch 27/50
# 6/6 [==============================] - 2s 291ms/step - loss: 0.0728 - accuracy: 0.9504 - precision: 0.9827 - recall: 0.9481 - val_loss: 0.1112 - val_accuracy: 0.9561 - val_precision: 0.9875 - val_recall: 0.9518
# Epoch 28/50
# 6/6 [==============================] - 2s 300ms/step - loss: 0.0791 - accuracy: 0.9461 - precision: 0.9866 - recall: 0.9406 - val_loss: 0.1103 - val_accuracy: 0.9570 - val_precision: 0.9862 - val_recall: 0.9547
# Epoch 29/50
# 6/6 [==============================] - 2s 283ms/step - loss: 0.0811 - accuracy: 0.9466 - precision: 0.9808 - recall: 0.9453 - val_loss: 0.1050 - val_accuracy: 0.9619 - val_precision: 0.9836 - val_recall: 0.9639
# Epoch 30/50
# 6/6 [==============================] - 2s 300ms/step - loss: 0.0786 - accuracy: 0.9502 - precision: 0.9731 - recall: 0.9566 - val_loss: 0.1013 - val_accuracy: 0.9619 - val_precision: 0.9838 - val_recall: 0.9642
# Epoch 31/50
# 6/6 [==============================] - 2s 301ms/step - loss: 0.0791 - accuracy: 0.9509 - precision: 0.9805 - recall: 0.9516 - val_loss: 0.1018 - val_accuracy: 0.9639 - val_precision: 0.9849 - val_recall: 0.9650
# Epoch 32/50
# 6/6 [==============================] - 2s 301ms/step - loss: 0.0762 - accuracy: 0.9523 - precision: 0.9813 - recall: 0.9522 - val_loss: 0.1018 - val_accuracy: 0.9619 - val_precision: 0.9835 - val_recall: 0.9636
# Epoch 33/50
# 6/6 [==============================] - 2s 285ms/step - loss: 0.0799 - accuracy: 0.9514 - precision: 0.9814 - recall: 0.9523 - val_loss: 0.1029 - val_accuracy: 0.9619 - val_precision: 0.9838 - val_recall: 0.9642
# Epoch 34/50
# 6/6 [==============================] - 2s 283ms/step - loss: 0.0709 - accuracy: 0.9530 - precision: 0.9865 - recall: 0.9493 - val_loss: 0.0986 - val_accuracy: 0.9668 - val_precision: 0.9876 - val_recall: 0.9664
# Epoch 35/50
# 6/6 [==============================] - 2s 291ms/step - loss: 0.0726 - accuracy: 0.9556 - precision: 0.9822 - recall: 0.9556 - val_loss: 0.0942 - val_accuracy: 0.9658 - val_precision: 0.9851 - val_recall: 0.9680
# Epoch 36/50
# 6/6 [==============================] - 2s 300ms/step - loss: 0.0786 - accuracy: 0.9488 - precision: 0.9827 - recall: 0.9474 - val_loss: 0.0910 - val_accuracy: 0.9668 - val_precision: 0.9865 - val_recall: 0.9683
# Epoch 37/50
# 6/6 [==============================] - 2s 300ms/step - loss: 0.0753 - accuracy: 0.9572 - precision: 0.9820 - recall: 0.9583 - val_loss: 0.1002 - val_accuracy: 0.9619 - val_precision: 0.9835 - val_recall: 0.9637
# Epoch 38/50
# 6/6 [==============================] - 2s 297ms/step - loss: 0.0839 - accuracy: 0.9485 - precision: 0.9773 - recall: 0.9513 - val_loss: 0.1003 - val_accuracy: 0.9629 - val_precision: 0.9837 - val_recall: 0.9654
# Epoch 39/50
# 6/6 [==============================] - 2s 298ms/step - loss: 0.0841 - accuracy: 0.9463 - precision: 0.9810 - recall: 0.9446 - val_loss: 0.0973 - val_accuracy: 0.9639 - val_precision: 0.9863 - val_recall: 0.9638
# Epoch 40/50
# 6/6 [==============================] - 2s 289ms/step - loss: 0.0722 - accuracy: 0.9544 - precision: 0.9858 - recall: 0.9507 - val_loss: 0.1008 - val_accuracy: 0.9619 - val_precision: 0.9836 - val_recall: 0.9639
# Epoch 41/50
# 6/6 [==============================] - 2s 284ms/step - loss: 0.0869 - accuracy: 0.9461 - precision: 0.9768 - recall: 0.9481 - val_loss: 0.0990 - val_accuracy: 0.9629 - val_precision: 0.9851 - val_recall: 0.9641
# Epoch 42/50
# 6/6 [==============================] - 2s 284ms/step - loss: 0.0729 - accuracy: 0.9551 - precision: 0.9867 - recall: 0.9524 - val_loss: 0.0950 - val_accuracy: 0.9629 - val_precision: 0.9863 - val_recall: 0.9625
# Epoch 43/50
# 6/6 [==============================] - 2s 285ms/step - loss: 0.0743 - accuracy: 0.9504 - precision: 0.9830 - recall: 0.9490 - val_loss: 0.1089 - val_accuracy: 0.9580 - val_precision: 0.9822 - val_recall: 0.9598
# Epoch 44/50
# 6/6 [==============================] - 2s 294ms/step - loss: 0.0737 - accuracy: 0.9486 - precision: 0.9828 - recall: 0.9462 - val_loss: 0.1023 - val_accuracy: 0.9609 - val_precision: 0.9850 - val_recall: 0.9614
# Epoch 45/50
# 6/6 [==============================] - 2s 286ms/step - loss: 0.0761 - accuracy: 0.9491 - precision: 0.9854 - recall: 0.9449 - val_loss: 0.1022 - val_accuracy: 0.9619 - val_precision: 0.9851 - val_recall: 0.9629
# Epoch 46/50
# 6/6 [==============================] - 2s 292ms/step - loss: 0.0913 - accuracy: 0.9453 - precision: 0.9780 - recall: 0.9464 - val_loss: 0.0985 - val_accuracy: 0.9619 - val_precision: 0.9836 - val_recall: 0.9639
#
#
# Batch Size: 1024
# Hidden Units: 256
# Learning Rate: 0.06103
# Epoch 1/50
# 3/3 [==============================] - 50s 9s/step - loss: 0.4918 - accuracy: 0.6591 - precision: 0.8495 - recall: 0.6415 - val_loss: 2.0379 - val_accuracy: 0.6895 - val_precision: 0.9459 - val_recall: 0.6282
# Epoch 2/50
# 3/3 [==============================] - 1s 515ms/step - loss: 0.3284 - accuracy: 0.8025 - precision: 0.8800 - recall: 0.8495 - val_loss: 11.7562 - val_accuracy: 0.6523 - val_precision: 1.0000 - val_recall: 0.5096
# Epoch 3/50
# 3/3 [==============================] - 1s 505ms/step - loss: 0.2368 - accuracy: 0.8770 - precision: 0.9831 - recall: 0.8470 - val_loss: 4.7691 - val_accuracy: 0.7754 - val_precision: 0.9960 - val_recall: 0.6877
# Epoch 4/50
# 3/3 [==============================] - 1s 486ms/step - loss: 0.1852 - accuracy: 0.9102 - precision: 0.9668 - recall: 0.9090 - val_loss: 1.5250 - val_accuracy: 0.8789 - val_precision: 0.9903 - val_recall: 0.8379
# Epoch 5/50
# 3/3 [==============================] - 1s 536ms/step - loss: 0.1567 - accuracy: 0.9316 - precision: 0.9546 - recall: 0.9532 - val_loss: 0.5773 - val_accuracy: 0.9062 - val_precision: 0.9910 - val_recall: 0.8797
# Epoch 6/50
# 3/3 [==============================] - 1s 494ms/step - loss: 0.1313 - accuracy: 0.9393 - precision: 0.9662 - recall: 0.9499 - val_loss: 0.7182 - val_accuracy: 0.8652 - val_precision: 0.9873 - val_recall: 0.8271
# Epoch 7/50
# 3/3 [==============================] - 1s 470ms/step - loss: 0.1300 - accuracy: 0.8935 - precision: 0.9881 - recall: 0.8668 - val_loss: 0.3649 - val_accuracy: 0.8848 - val_precision: 0.9939 - val_recall: 0.8512
# Epoch 8/50
# 3/3 [==============================] - 1s 516ms/step - loss: 0.1437 - accuracy: 0.8958 - precision: 0.9753 - recall: 0.8800 - val_loss: 0.2373 - val_accuracy: 0.9141 - val_precision: 0.9818 - val_recall: 0.8950
# Epoch 9/50
# 3/3 [==============================] - 1s 476ms/step - loss: 0.1051 - accuracy: 0.9257 - precision: 0.9838 - recall: 0.9159 - val_loss: 0.2646 - val_accuracy: 0.9219 - val_precision: 0.9881 - val_recall: 0.9022
# Epoch 10/50
# 3/3 [==============================] - 1s 523ms/step - loss: 0.1027 - accuracy: 0.9364 - precision: 0.9762 - recall: 0.9359 - val_loss: 0.5281 - val_accuracy: 0.8848 - val_precision: 0.9969 - val_recall: 0.8470
# Epoch 11/50
# 3/3 [==============================] - 1s 473ms/step - loss: 0.1122 - accuracy: 0.9390 - precision: 0.9615 - recall: 0.9519 - val_loss: 0.6068 - val_accuracy: 0.8809 - val_precision: 1.0000 - val_recall: 0.8395
# Epoch 12/50
# 3/3 [==============================] - 1s 482ms/step - loss: 0.1031 - accuracy: 0.9203 - precision: 0.9841 - recall: 0.9082 - val_loss: 0.5512 - val_accuracy: 0.8711 - val_precision: 0.9934 - val_recall: 0.8247
# Epoch 13/50
# 3/3 [==============================] - 1s 492ms/step - loss: 0.1226 - accuracy: 0.9287 - precision: 0.9682 - recall: 0.9305 - val_loss: 0.4355 - val_accuracy: 0.8730 - val_precision: 0.9871 - val_recall: 0.8333
# Epoch 14/50
# 3/3 [==============================] - 1s 487ms/step - loss: 0.0978 - accuracy: 0.9319 - precision: 0.9878 - recall: 0.9208 - val_loss: 0.3054 - val_accuracy: 0.9062 - val_precision: 0.9938 - val_recall: 0.8753
# Epoch 15/50
# 3/3 [==============================] - 1s 510ms/step - loss: 0.1249 - accuracy: 0.9258 - precision: 0.9673 - recall: 0.9275 - val_loss: 0.2176 - val_accuracy: 0.9160 - val_precision: 0.9971 - val_recall: 0.8901
# Epoch 16/50
# 3/3 [==============================] - 1s 503ms/step - loss: 0.0858 - accuracy: 0.9434 - precision: 0.9813 - recall: 0.9404 - val_loss: 0.1671 - val_accuracy: 0.9375 - val_precision: 0.9882 - val_recall: 0.9231
# Epoch 17/50
# 3/3 [==============================] - 1s 502ms/step - loss: 0.1049 - accuracy: 0.9316 - precision: 0.9719 - recall: 0.9333 - val_loss: 0.2879 - val_accuracy: 0.8945 - val_precision: 0.9969 - val_recall: 0.8568
# Epoch 18/50
# 3/3 [==============================] - 1s 501ms/step - loss: 0.1115 - accuracy: 0.9283 - precision: 0.9762 - recall: 0.9252 - val_loss: 0.2964 - val_accuracy: 0.9004 - val_precision: 0.9882 - val_recall: 0.8773
# Epoch 19/50
# 3/3 [==============================] - 1s 490ms/step - loss: 0.0927 - accuracy: 0.9362 - precision: 0.9810 - recall: 0.9313 - val_loss: 0.2928 - val_accuracy: 0.8945 - val_precision: 0.9939 - val_recall: 0.8621
# Epoch 20/50
# 3/3 [==============================] - 1s 489ms/step - loss: 0.1088 - accuracy: 0.9388 - precision: 0.9673 - recall: 0.9449 - val_loss: 0.3802 - val_accuracy: 0.8809 - val_precision: 1.0000 - val_recall: 0.8369
# Epoch 21/50
# 3/3 [==============================] - 1s 484ms/step - loss: 0.0798 - accuracy: 0.9398 - precision: 0.9895 - recall: 0.9302 - val_loss: 0.3198 - val_accuracy: 0.8906 - val_precision: 1.0000 - val_recall: 0.8491
# Epoch 22/50
# 3/3 [==============================] - 1s 497ms/step - loss: 0.1104 - accuracy: 0.9268 - precision: 0.9737 - recall: 0.9252 - val_loss: 0.3096 - val_accuracy: 0.8867 - val_precision: 0.9878 - val_recall: 0.8568
# Epoch 23/50
# 3/3 [==============================] - 1s 480ms/step - loss: 0.0972 - accuracy: 0.9346 - precision: 0.9830 - recall: 0.9258 - val_loss: 0.2416 - val_accuracy: 0.9160 - val_precision: 0.9938 - val_recall: 0.8874
# Epoch 24/50
# 3/3 [==============================] - 1s 487ms/step - loss: 0.0915 - accuracy: 0.9469 - precision: 0.9780 - recall: 0.9472 - val_loss: 0.2151 - val_accuracy: 0.9160 - val_precision: 0.9940 - val_recall: 0.8895
# Epoch 25/50
# 3/3 [==============================] - 1s 480ms/step - loss: 0.0963 - accuracy: 0.9473 - precision: 0.9797 - recall: 0.9474 - val_loss: 0.2234 - val_accuracy: 0.9043 - val_precision: 0.9881 - val_recall: 0.8803
# Epoch 26/50
# 3/3 [==============================] - 1s 483ms/step - loss: 0.1002 - accuracy: 0.9350 - precision: 0.9783 - recall: 0.9323 - val_loss: 0.1431 - val_accuracy: 0.9375 - val_precision: 0.9913 - val_recall: 0.9214
# Epoch 27/50
# 3/3 [==============================] - 1s 486ms/step - loss: 0.1042 - accuracy: 0.9376 - precision: 0.9703 - recall: 0.9414 - val_loss: 0.1409 - val_accuracy: 0.9336 - val_precision: 0.9881 - val_recall: 0.9174
# Epoch 28/50
# 3/3 [==============================] - 1s 502ms/step - loss: 0.0963 - accuracy: 0.9355 - precision: 0.9849 - recall: 0.9285 - val_loss: 0.1289 - val_accuracy: 0.9453 - val_precision: 0.9943 - val_recall: 0.9310
# Epoch 29/50
# 3/3 [==============================] - 1s 493ms/step - loss: 0.1199 - accuracy: 0.9311 - precision: 0.9604 - recall: 0.9413 - val_loss: 0.1706 - val_accuracy: 0.9258 - val_precision: 0.9886 - val_recall: 0.9105
# Epoch 30/50
# 3/3 [==============================] - 1s 507ms/step - loss: 0.0927 - accuracy: 0.9305 - precision: 0.9892 - recall: 0.9193 - val_loss: 0.1754 - val_accuracy: 0.9219 - val_precision: 0.9853 - val_recall: 0.9051
# Epoch 31/50
# 3/3 [==============================] - 1s 501ms/step - loss: 0.1105 - accuracy: 0.9359 - precision: 0.9726 - recall: 0.9381 - val_loss: 0.1277 - val_accuracy: 0.9375 - val_precision: 0.9913 - val_recall: 0.9220
# Epoch 32/50
# 3/3 [==============================] - 1s 562ms/step - loss: 0.0802 - accuracy: 0.9462 - precision: 0.9829 - recall: 0.9427 - val_loss: 0.1568 - val_accuracy: 0.9277 - val_precision: 0.9912 - val_recall: 0.9088
# Epoch 33/50
# 3/3 [==============================] - 1s 492ms/step - loss: 0.0992 - accuracy: 0.9334 - precision: 0.9799 - recall: 0.9283 - val_loss: 0.1633 - val_accuracy: 0.9297 - val_precision: 0.9943 - val_recall: 0.9112
# Epoch 34/50
# 3/3 [==============================] - 1s 478ms/step - loss: 0.0876 - accuracy: 0.9434 - precision: 0.9760 - recall: 0.9439 - val_loss: 0.1572 - val_accuracy: 0.9277 - val_precision: 0.9915 - val_recall: 0.9110
# Epoch 35/50
# 3/3 [==============================] - 1s 491ms/step - loss: 0.1073 - accuracy: 0.9243 - precision: 0.9790 - recall: 0.9197 - val_loss: 0.1317 - val_accuracy: 0.9473 - val_precision: 0.9837 - val_recall: 0.9453
# Epoch 36/50
# 3/3 [==============================] - 1s 473ms/step - loss: 0.0833 - accuracy: 0.9521 - precision: 0.9817 - recall: 0.9517 - val_loss: 0.1444 - val_accuracy: 0.9316 - val_precision: 0.9915 - val_recall: 0.9158
# Epoch 37/50
# 3/3 [==============================] - 1s 481ms/step - loss: 0.0779 - accuracy: 0.9497 - precision: 0.9847 - recall: 0.9459 - val_loss: 0.1467 - val_accuracy: 0.9395 - val_precision: 0.9915 - val_recall: 0.9259
# Epoch 38/50
# 3/3 [==============================] - 1s 474ms/step - loss: 0.1043 - accuracy: 0.9373 - precision: 0.9674 - recall: 0.9447 - val_loss: 0.1748 - val_accuracy: 0.9277 - val_precision: 0.9827 - val_recall: 0.9164
# Epoch 39/50
# 3/3 [==============================] - 1s 482ms/step - loss: 0.0994 - accuracy: 0.9373 - precision: 0.9736 - recall: 0.9400 - val_loss: 0.1482 - val_accuracy: 0.9297 - val_precision: 0.9887 - val_recall: 0.9160
# Epoch 40/50
# 3/3 [==============================] - 1s 486ms/step - loss: 0.1059 - accuracy: 0.9408 - precision: 0.9780 - recall: 0.9397 - val_loss: 0.1737 - val_accuracy: 0.9199 - val_precision: 0.9853 - val_recall: 0.9032
# Epoch 41/50
# 3/3 [==============================] - 1s 473ms/step - loss: 0.0891 - accuracy: 0.9348 - precision: 0.9785 - recall: 0.9315 - val_loss: 0.1538 - val_accuracy: 0.9199 - val_precision: 0.9881 - val_recall: 0.9000

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import tensorflow as tf
from kaggle_datasets import KaggleDatasets
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import re
import glob
import random
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import auc, roc_curve

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# 2023-01-21 05:06:20.070006: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib
# 2023-01-21 05:06:20.070226: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Device:', tpu.master())
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
except:
    strategy = tf.distribute.get_strategy()
print('Number of replicas:', strategy.num_replicas_in_sync)

print(tf.__version__)
# Out:
# Device: grpc://10.0.0.2:8470
# 2023-01-21 05:06:26.831678: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-01-21 05:06:26.834991: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib
# 2023-01-21 05:06:26.835032: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-01-21 05:06:26.835061: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (8d9335631cfb): /proc/driver/nvidia/version does not exist
# 2023-01-21 05:06:26.839342: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-21 05:06:26.841618: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-01-21 05:06:26.876047: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job worker -> {0 -> 10.0.0.2:8470}
# 2023-01-21 05:06:26.876118: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job localhost -> {0 -> localhost:30019}
# 2023-01-21 05:06:26.902229: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job worker -> {0 -> 10.0.0.2:8470}
# 2023-01-21 05:06:26.902289: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job localhost -> {0 -> localhost:30019}
# 2023-01-21 05:06:26.904070: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:411] Started server with target: grpc://localhost:30019
# Number of replicas: 8
# 2.4.1

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
GCS_PATH = KaggleDatasets().get_gcs_path()
BATCH_SIZE = 64*strategy.num_replicas_in_sync
#BATCH_SIZE = 64 # for non-TPU use
IMAGE_SIZE = [180, 180]
EPOCHS = 50

# %%
filenames = tf.io.gfile.glob(str(GCS_PATH + '/chest_xray/train/*/*'))
filenames.extend(tf.io.gfile.glob(str(GCS_PATH + '/chest_xray/val/*/*')))
filenames.extend(tf.io.gfile.glob(str(GCS_PATH + '/chest_xray/test/*/*')))

print(f'The total number of files is {len(filenames)}')
# Out:
# 2023-01-21 05:06:33.427982: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-21 05:06:33.541141: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-21 05:06:33.646288: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-21 05:06:33.745601: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-21 05:06:33.854041: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-21 05:06:33.959810: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-21 05:06:34.051228: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# The total number of files is 5856
# 2023-01-21 05:06:34.122136: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.

# %%
# split the data into 60:40 for train:test+val
train_files, val_test_files = train_test_split(filenames, test_size=0.4,random_state=18)

# %%
# split the val_test_files to 50:50 to have a final split of 60:20:20 of train:val:test
val_files, test_files = train_test_split(val_test_files, test_size=0.5, random_state=18)

# %%
pct_df = pd.DataFrame(columns = ['data_set', 'label', 'pct'], index = range(6))

totals = {'train':len(train_files), 'val':len(val_files), 'test':len(test_files)}

val_pneum_count = 0
val_norm_count = 0

re_pattern = '.*/(NORMAL|PNEUMONIA)/.*'

for file in val_files:
    re_match = re.match(re_pattern, file)
    if re_match[1] == 'NORMAL':
        val_norm_count += 1
    else:
        val_pneum_count += 1

pct_df.iloc[0, :] = ['val', 'NORMAL', round(100* val_norm_count / totals['val'], 1)]
pct_df.iloc[1, :] = ['val', 'PNEUMONIA', round(100* val_pneum_count / totals['val'], 1)]


test_pneum_count = 0
test_norm_count = 0
for file in test_files:
    re_match = re.match(re_pattern, file)
    if re_match[1] == 'NORMAL':
        test_norm_count += 1
    else:
        test_pneum_count += 1

pct_df.iloc[2, :] = ['test', 'NORMAL', round(100* test_norm_count / totals['test'], 1)]
pct_df.iloc[3, :] = ['test', 'PNEUMONIA', round(100* test_pneum_count / totals['test'], 1)]

train_pneum_count = 0
train_norm_count = 0
for file in train_files:
    re_match = re.match(re_pattern, file)
    if re_match[1] == 'NORMAL':
        train_norm_count += 1
    else:
        train_pneum_count += 1

pct_df.iloc[4, :] = ['train', 'NORMAL', round(100* train_norm_count / totals['train'], 1)]
pct_df.iloc[5, :] = ['train', 'PNEUMONIA', round(100* train_pneum_count / totals['train'], 1)]

# %%
PNEUM_COUNT = val_pneum_count + train_pneum_count + test_pneum_count
NORMAL_COUNT = val_norm_count + train_norm_count + test_norm_count
print(f'Normal: {NORMAL_COUNT}\nPneumonia: {PNEUM_COUNT}')

pct_df
# Out:
# Normal: 1583
# Pneumonia: 4273
#   data_set      label   pct
# 0      val     NORMAL  26.9
# 1      val  PNEUMONIA  73.1
# 2     test     NORMAL  27.6
# 3     test  PNEUMONIA  72.4
# 4    train     NORMAL  26.9
# 5    train  PNEUMONIA  73.1

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_files)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_files)
test_list_ds = tf.data.Dataset.from_tensor_slices(test_files)

#view the file paths for training
print('----Training Files----')
for f in train_list_ds.take(5):
    print(f.numpy())
# Out:
# ----Training Files----
# b'gs://kds-f4cd5298952c835b370b10b65341d209198e57d812057e8ad9550752/chest_xray/train/PNEUMONIA/person509_virus_1025.jpeg'
# b'gs://kds-f4cd5298952c835b370b10b65341d209198e57d812057e8ad9550752/chest_xray/train/PNEUMONIA/person671_bacteria_2564.jpeg'
# b'gs://kds-f4cd5298952c835b370b10b65341d209198e57d812057e8ad9550752/chest_xray/train/PNEUMONIA/person957_virus_1629.jpeg'
# b'gs://kds-f4cd5298952c835b370b10b65341d209198e57d812057e8ad9550752/chest_xray/test/PNEUMONIA/person81_bacteria_397.jpeg'
# b'gs://kds-f4cd5298952c835b370b10b65341d209198e57d812057e8ad9550752/chest_xray/train/NORMAL/IM-0500-0001.jpeg'

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
TEST_IMG_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()

print(f'Train Image Count: {TRAIN_IMG_COUNT}\nVal Image Count: {VAL_IMG_COUNT}\nTest Image Count: {TEST_IMG_COUNT}')
# Out:
# Train Image Count: 3513
# Val Image Count: 1171
# Test Image Count: 1172
# 2023-01-21 05:06:34.603298: W ./tensorflow/core/distributed_runtime/eager/destroy_tensor_handle_node.h:57] Ignoring an error encountered when deleting remote tensors handles: Invalid argument: Unable to find the relevant tensor remote_handle: Op ID: 28, Output num: 0
# Additional GRPC error information from remote target /job:worker/replica:0/task:0:
# :{"created":"@1674277594.599956746","description":"Error received from peer ipv4:10.0.0.2:8470","file":"external/com_github_grpc_grpc/src/core/lib/surface/call.cc","file_line":1056,"grpc_message":"Unable to find the relevant tensor remote_handle: Op ID: 28, Output num: 0","grpc_status":3}

# %%
# will label as 1 if pneumonia otherwise 0
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == 'PNEUMONIA'

# %%
def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    return tf.image.resize(img, IMAGE_SIZE)

# %%
def process_path(file_path):
    label = get_label(file_path)
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
y_train = []
for image, label in train_ds.take(TRAIN_IMG_COUNT):
    y_train.append(label)
    
print('Training Counts')
print(f'Pneumonia count: {np.sum(y_train)}\nNormal count: {TRAIN_IMG_COUNT - np.sum(y_train)}')
# Out:
# Training Counts
# 2023-01-21 05:08:57.857409: W ./tensorflow/core/distributed_runtime/eager/destroy_tensor_handle_node.h:57] Ignoring an error encountered when deleting remote tensors handles: Invalid argument: Unable to find the relevant tensor remote_handle: Op ID: 3562, Output num: 0
# Additional GRPC error information from remote target /job:worker/replica:0/task:0:
# :{"created":"@1674277737.857335086","description":"Error received from peer ipv4:10.0.0.2:8470","file":"external/com_github_grpc_grpc/src/core/lib/surface/call.cc","file_line":1056,"grpc_message":"Unable to find the relevant tensor remote_handle: Op ID: 3562, Output num: 0","grpc_status":3}
# Pneumonia count: 2568
# Normal count: 945

# %%
y_val = []
for image, label in val_ds.take(VAL_IMG_COUNT):
    y_val.append(label)
    
print('Validation Counts')
print(f'Pneumonia count: {np.sum(y_val)}\nNormal count: {VAL_IMG_COUNT - np.sum(y_val)}')
# Out:
# Validation Counts
# 2023-01-21 05:10:07.599733: W ./tensorflow/core/distributed_runtime/eager/destroy_tensor_handle_node.h:57] Ignoring an error encountered when deleting remote tensors handles: Invalid argument: Unable to find the relevant tensor remote_handle: Op ID: 18796, Output num: 1
# Additional GRPC error information from remote target /job:worker/replica:0/task:0:
# :{"created":"@1674277807.599668676","description":"Error received from peer ipv4:10.0.0.2:8470","file":"external/com_github_grpc_grpc/src/core/lib/surface/call.cc","file_line":1056,"grpc_message":"Unable to find the relevant tensor remote_handle: Op ID: 18796, Output num: 1","grpc_status":3}
# Pneumonia count: 856
# Normal count: 315

# %%
y_test = []
for image, label in test_ds.take(TEST_IMG_COUNT):
    y_test.append(label)
    
print('Test Counts')
print(f'Pneumonia count: {np.sum(y_test)}\nNormal count: {TEST_IMG_COUNT - np.sum(y_test)}')
# Out:
# Test Counts
# Pneumonia count: 849
# Normal count: 323

# %%
def prepare_for_training(ds, cache=True, shuffle_buffer_size=1000):
    
    if cache:
        if isinstance(cache, str):
            ds = ds.cache(cache)
        else:
            ds = ds.cache()
            
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    
    ds = ds.repeat()
    
    ds = ds.batch(BATCH_SIZE)
    
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    
    return ds

# %%
train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %%
weight_for_0 = (1 / NORMAL_COUNT)*(TRAIN_IMG_COUNT)/2.0
weight_for_1 = (1 / PNEUM_COUNT)*(TRAIN_IMG_COUNT)/2.0

# %%
class_weight = {0: weight_for_0, 1: weight_for_1}
print(f'Weight for class 0: {weight_for_0:.2f}')
print(f'Weight for class 1: {weight_for_1:.2f}')
# Out:
# Weight for class 0: 1.11
# Weight for class 1: 0.41

# %%
# create some metrics for comparing on test results

def precision(y_test, y_pred):
    tp, fp = 0, 0
    
    for i in range(len(y_test)):
        if y_test[i] >= 0.5 and y_pred[i] >= 0.5:
            tp += 1
        elif y_test[i] < 0.5 and y_pred[i] >= 0.5:
            fp += 1
            
    return tp / (tp + fp)

def recall(y_test, y_pred):
    tp, fn = 0, 0
    
    for i in range(len(y_test)):
        if y_test[i] >= 0.5 and y_pred[i] >= 0.5:
            tp += 1
        elif y_test[i] >= 0.5 and y_pred[i] < 0.5:
            fn += 1
            
    return tp / (tp + fn)

def f1_score(y_test, y_pred):
    numerator = precision(y_test, y_pred) * recall(y_test, y_pred)
    denominator = precision(y_test, y_pred) + recall(y_test, y_pred)
    
    return 2 * (numerator / denominator)

# %% [markdown]
# ## Fine Tune the Model
#
# ## Expore different Hidden Units and Mini Batch Sizes

# %%
# add exponential decay to try to improve fine tuning
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 ** (epoch / s)
    return exponential_decay_fn

# %%
# use learning rate that gave best results in the learning rate hyperparameter tuning
learning_rate = 0.010395

# try four different hidden_units
for hidden_units in [4096, 2048, 1024, 512, 256]:
    # try three different batch sizes
    for mini_batch in [32, 64, 128]:
    
        BATCH_SIZE = mini_batch*strategy.num_replicas_in_sync
        print(f'\n\nBatch Size: {BATCH_SIZE}')    
        print(f'Hidden Units: {hidden_units}')
        print(f'Learning Rate: {learning_rate}')
    
    
        with strategy.scope():
        
            base_model = tf.keras.applications.densenet.DenseNet201(
                        input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3),
                        include_top=False,
                        weights='imagenet'
                        )
            base_model.trainable = False
        
            x=base_model.output
            inputs = tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))
            x = base_model(inputs, training=False)
            x = tf.keras.layers.GlobalAveragePooling2D()(x)
            x = tf.keras.layers.Dropout(0.3)(x)
            x = tf.keras.layers.Dense(hidden_units, activation='relu')(x)
            x = tf.keras.layers.BatchNormalization()(x)
            x = tf.keras.layers.Dropout(0.3)(x)
            outputs = tf.keras.layers.Dense(1, activation='sigmoid')(x)
            model = tf.keras.Model(inputs, outputs)
    
        
        
            METRICS = [
                'accuracy',
                tf.keras.metrics.Precision(name='precision'),
                tf.keras.metrics.Recall(name='recall')
                ]
        
            model.compile(
                    optimizer='adam',
                    loss='binary_crossentropy',
                    metrics=METRICS
                     )
            
            checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(f"densenet_{learning_rate}_{hidden_units}_{BATCH_SIZE}_xray_model.h5", save_best_only=True)
            early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
            exponential_decay_fn = exponential_decay(learning_rate, 20)
            lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)
    
            history = model.fit(
                                train_ds,
                                steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
                                epochs=EPOCHS,
                                validation_data=val_ds,
                                validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
                                class_weight=class_weight,
                                callbacks=[checkpoint_cb, early_stopping_cb, lr_scheduler]
                                )
        
        test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
        test_ds = test_ds.batch(BATCH_SIZE)
            
        y_preds = model.predict(test_ds, batch_size = BATCH_SIZE, verbose = True)
        y_preds = y_preds.reshape(-1)
        y_actual = [1 if x == True else 0 for x in y_test]
        
        fpr, tpr, thresholds = roc_curve(y_actual, y_preds, pos_label=1)
        
        print(f'Learning Rate: {learning_rate}\nHidden Units: {hidden_units}\nMini Batch:{mini_batch}')
        print(f'AUC score: {auc(fpr, tpr)}')
               
        print(f'Test Recall: {recall(y_actual, y_preds)}')
        print(f'Test Precision: {precision(y_actual, y_preds)}')
        print(f'Test F1 Scores: {f1_score(y_actual, y_preds)}\n\n')
# Out:
# Batch Size: 256
# Hidden Units: 4096
# Learning Rate: 0.010395
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74842112/74836368 [==============================] - 0s 0us/step
# Epoch 1/50
# 13/13 [==============================] - 170s 8s/step - loss: 0.9031 - accuracy: 0.7440 - precision: 0.8991 - recall: 0.7256 - val_loss: 33.1037 - val_accuracy: 0.2759 - val_precision: 1.0000 - val_recall: 0.0040
# Epoch 2/50
# 13/13 [==============================] - 3s 227ms/step - loss: 0.2176 - accuracy: 0.9176 - precision: 0.9562 - recall: 0.9311 - val_loss: 0.2087 - val_accuracy: 0.9561 - val_precision: 0.9615 - val_recall: 0.9794
# Epoch 3/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.1152 - accuracy: 0.9377 - precision: 0.9684 - recall: 0.9460 - val_loss: 1.8258 - val_accuracy: 0.7378 - val_precision: 1.0000 - val_recall: 0.6386
# Epoch 4/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0995 - accuracy: 0.9388 - precision: 0.9816 - recall: 0.9343 - val_loss: 0.1781 - val_accuracy: 0.9399 - val_precision: 0.9886 - val_recall: 0.9286
# Epoch 5/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0842 - accuracy: 0.9460 - precision: 0.9798 - recall: 0.9456 - val_loss: 0.3268 - val_accuracy: 0.9082 - val_precision: 0.9940 - val_recall: 0.8796
# Epoch 6/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0815 - accuracy: 0.9425 - precision: 0.9851 - recall: 0.9361 - val_loss: 0.2558 - val_accuracy: 0.9141 - val_precision: 0.9947 - val_recall: 0.8867
# Epoch 7/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0787 - accuracy: 0.9520 - precision: 0.9802 - recall: 0.9533 - val_loss: 0.0978 - val_accuracy: 0.9629 - val_precision: 0.9877 - val_recall: 0.9614
# Epoch 8/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0749 - accuracy: 0.9517 - precision: 0.9805 - recall: 0.9524 - val_loss: 0.0961 - val_accuracy: 0.9673 - val_precision: 0.9885 - val_recall: 0.9669
# Epoch 9/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0808 - accuracy: 0.9503 - precision: 0.9799 - recall: 0.9509 - val_loss: 0.1284 - val_accuracy: 0.9521 - val_precision: 0.9895 - val_recall: 0.9447
# Epoch 10/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0774 - accuracy: 0.9533 - precision: 0.9825 - recall: 0.9532 - val_loss: 0.1330 - val_accuracy: 0.9468 - val_precision: 0.9875 - val_recall: 0.9398
# Epoch 11/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0632 - accuracy: 0.9564 - precision: 0.9861 - recall: 0.9538 - val_loss: 0.1137 - val_accuracy: 0.9570 - val_precision: 0.9862 - val_recall: 0.9546
# Epoch 12/50
# 13/13 [==============================] - 3s 227ms/step - loss: 0.0645 - accuracy: 0.9570 - precision: 0.9852 - recall: 0.9561 - val_loss: 0.1339 - val_accuracy: 0.9468 - val_precision: 0.9921 - val_recall: 0.9339
# Epoch 13/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0685 - accuracy: 0.9527 - precision: 0.9839 - recall: 0.9506 - val_loss: 0.0995 - val_accuracy: 0.9629 - val_precision: 0.9752 - val_recall: 0.9739
# Epoch 14/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0608 - accuracy: 0.9649 - precision: 0.9859 - recall: 0.9657 - val_loss: 0.0965 - val_accuracy: 0.9644 - val_precision: 0.9890 - val_recall: 0.9619
# Epoch 15/50
# 13/13 [==============================] - 3s 213ms/step - loss: 0.0627 - accuracy: 0.9586 - precision: 0.9905 - recall: 0.9534 - val_loss: 0.0923 - val_accuracy: 0.9668 - val_precision: 0.9830 - val_recall: 0.9711
# Epoch 16/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0561 - accuracy: 0.9631 - precision: 0.9878 - recall: 0.9611 - val_loss: 0.0992 - val_accuracy: 0.9644 - val_precision: 0.9829 - val_recall: 0.9678
# Epoch 17/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0553 - accuracy: 0.9626 - precision: 0.9857 - recall: 0.9629 - val_loss: 0.0925 - val_accuracy: 0.9702 - val_precision: 0.9845 - val_recall: 0.9747
# Epoch 18/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0577 - accuracy: 0.9622 - precision: 0.9853 - recall: 0.9626 - val_loss: 0.0869 - val_accuracy: 0.9702 - val_precision: 0.9825 - val_recall: 0.9766
# Epoch 19/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0560 - accuracy: 0.9657 - precision: 0.9859 - recall: 0.9668 - val_loss: 0.0940 - val_accuracy: 0.9688 - val_precision: 0.9811 - val_recall: 0.9759
# Epoch 20/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0585 - accuracy: 0.9632 - precision: 0.9867 - recall: 0.9627 - val_loss: 0.0927 - val_accuracy: 0.9692 - val_precision: 0.9800 - val_recall: 0.9780
# Epoch 21/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0508 - accuracy: 0.9691 - precision: 0.9905 - recall: 0.9673 - val_loss: 0.0931 - val_accuracy: 0.9688 - val_precision: 0.9837 - val_recall: 0.9731
# Epoch 22/50
# 13/13 [==============================] - 3s 227ms/step - loss: 0.0516 - accuracy: 0.9666 - precision: 0.9888 - recall: 0.9651 - val_loss: 0.0941 - val_accuracy: 0.9648 - val_precision: 0.9830 - val_recall: 0.9685
# Epoch 23/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0541 - accuracy: 0.9626 - precision: 0.9890 - recall: 0.9599 - val_loss: 0.0894 - val_accuracy: 0.9697 - val_precision: 0.9819 - val_recall: 0.9767
# Epoch 24/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0527 - accuracy: 0.9641 - precision: 0.9887 - recall: 0.9625 - val_loss: 0.0932 - val_accuracy: 0.9663 - val_precision: 0.9812 - val_recall: 0.9728
# Epoch 25/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0473 - accuracy: 0.9690 - precision: 0.9909 - recall: 0.9669 - val_loss: 0.0922 - val_accuracy: 0.9668 - val_precision: 0.9812 - val_recall: 0.9733
# Epoch 26/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0554 - accuracy: 0.9644 - precision: 0.9878 - recall: 0.9627 - val_loss: 0.0870 - val_accuracy: 0.9692 - val_precision: 0.9797 - val_recall: 0.9777
# Epoch 27/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0519 - accuracy: 0.9673 - precision: 0.9856 - recall: 0.9697 - val_loss: 0.0929 - val_accuracy: 0.9644 - val_precision: 0.9766 - val_recall: 0.9746
# Epoch 28/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0532 - accuracy: 0.9642 - precision: 0.9872 - recall: 0.9633 - val_loss: 0.0961 - val_accuracy: 0.9648 - val_precision: 0.9804 - val_recall: 0.9713
# 5/5 [==============================] - 52s 11s/step
# Learning Rate: 0.010395
# Hidden Units: 4096
# Mini Batch:32
# AUC score: 0.9899645184463965
# Test Recall: 0.9681978798586572
# Test Precision: 0.9716312056737588
# Test F1 Scores: 0.9699115044247787
#
#
#
#
# Batch Size: 512
# Hidden Units: 4096
# Learning Rate: 0.010395
# Epoch 1/50
# 6/6 [==============================] - 52s 4s/step - loss: 1.0575 - accuracy: 0.6916 - precision: 0.8671 - recall: 0.6776 - val_loss: 34.4183 - val_accuracy: 0.3291 - val_precision: 1.0000 - val_recall: 0.0840
# Epoch 2/50
# 6/6 [==============================] - 2s 315ms/step - loss: 0.5022 - accuracy: 0.8575 - precision: 0.9799 - recall: 0.8244 - val_loss: 18.6722 - val_accuracy: 0.3486 - val_precision: 1.0000 - val_recall: 0.0999
# Epoch 3/50
# 6/6 [==============================] - 2s 308ms/step - loss: 0.1955 - accuracy: 0.9272 - precision: 0.9539 - recall: 0.9479 - val_loss: 2.3135 - val_accuracy: 0.8252 - val_precision: 0.9982 - val_recall: 0.7620
# Epoch 4/50
# 6/6 [==============================] - 2s 336ms/step - loss: 0.1955 - accuracy: 0.9181 - precision: 0.9846 - recall: 0.9012 - val_loss: 1.6407 - val_accuracy: 0.8027 - val_precision: 1.0000 - val_recall: 0.7267
# Epoch 5/50
# 6/6 [==============================] - 2s 301ms/step - loss: 0.1386 - accuracy: 0.9263 - precision: 0.9705 - recall: 0.9274 - val_loss: 2.5884 - val_accuracy: 0.7188 - val_precision: 1.0000 - val_recall: 0.6139
# Epoch 6/50
# 6/6 [==============================] - 2s 313ms/step - loss: 0.1431 - accuracy: 0.9321 - precision: 0.9782 - recall: 0.9276 - val_loss: 1.4585 - val_accuracy: 0.7822 - val_precision: 1.0000 - val_recall: 0.7011
# Epoch 7/50
# 6/6 [==============================] - 2s 308ms/step - loss: 0.1069 - accuracy: 0.9471 - precision: 0.9684 - recall: 0.9569 - val_loss: 0.6021 - val_accuracy: 0.8477 - val_precision: 1.0000 - val_recall: 0.7923
# Epoch 8/50
# 6/6 [==============================] - 2s 306ms/step - loss: 0.1048 - accuracy: 0.9345 - precision: 0.9796 - recall: 0.9300 - val_loss: 0.9114 - val_accuracy: 0.7988 - val_precision: 1.0000 - val_recall: 0.7257
# Epoch 9/50
# 6/6 [==============================] - 2s 310ms/step - loss: 0.0856 - accuracy: 0.9445 - precision: 0.9822 - recall: 0.9407 - val_loss: 0.2112 - val_accuracy: 0.9199 - val_precision: 0.9955 - val_recall: 0.8938
# Epoch 10/50
# 6/6 [==============================] - 2s 310ms/step - loss: 0.0944 - accuracy: 0.9426 - precision: 0.9739 - recall: 0.9460 - val_loss: 0.2575 - val_accuracy: 0.9170 - val_precision: 0.9911 - val_recall: 0.8945
# Epoch 11/50
# 6/6 [==============================] - 2s 299ms/step - loss: 0.0928 - accuracy: 0.9402 - precision: 0.9805 - recall: 0.9378 - val_loss: 0.1076 - val_accuracy: 0.9619 - val_precision: 0.9903 - val_recall: 0.9573
# Epoch 12/50
# 6/6 [==============================] - 2s 328ms/step - loss: 0.0851 - accuracy: 0.9491 - precision: 0.9766 - recall: 0.9531 - val_loss: 0.1823 - val_accuracy: 0.9365 - val_precision: 0.9943 - val_recall: 0.9190
# Epoch 13/50
# 6/6 [==============================] - 2s 309ms/step - loss: 0.0822 - accuracy: 0.9390 - precision: 0.9861 - recall: 0.9299 - val_loss: 0.0926 - val_accuracy: 0.9648 - val_precision: 0.9826 - val_recall: 0.9695
# Epoch 14/50
# 6/6 [==============================] - 2s 323ms/step - loss: 0.0798 - accuracy: 0.9548 - precision: 0.9778 - recall: 0.9601 - val_loss: 0.1194 - val_accuracy: 0.9541 - val_precision: 0.9849 - val_recall: 0.9522
# Epoch 15/50
# 6/6 [==============================] - 2s 471ms/step - loss: 0.0810 - accuracy: 0.9448 - precision: 0.9828 - recall: 0.9413 - val_loss: 0.1246 - val_accuracy: 0.9482 - val_precision: 0.9874 - val_recall: 0.9414
# Epoch 16/50
# 6/6 [==============================] - 2s 302ms/step - loss: 0.0840 - accuracy: 0.9453 - precision: 0.9747 - recall: 0.9492 - val_loss: 0.1201 - val_accuracy: 0.9521 - val_precision: 0.9862 - val_recall: 0.9483
# Epoch 17/50
# 6/6 [==============================] - 2s 293ms/step - loss: 0.0695 - accuracy: 0.9587 - precision: 0.9881 - recall: 0.9552 - val_loss: 0.1102 - val_accuracy: 0.9580 - val_precision: 0.9861 - val_recall: 0.9557
# Epoch 18/50
# 6/6 [==============================] - 2s 288ms/step - loss: 0.0830 - accuracy: 0.9523 - precision: 0.9769 - recall: 0.9567 - val_loss: 0.1259 - val_accuracy: 0.9463 - val_precision: 0.9874 - val_recall: 0.9387
# Epoch 19/50
# 6/6 [==============================] - 2s 313ms/step - loss: 0.0747 - accuracy: 0.9480 - precision: 0.9817 - recall: 0.9467 - val_loss: 0.1107 - val_accuracy: 0.9541 - val_precision: 0.9861 - val_recall: 0.9505
# Epoch 20/50
# 6/6 [==============================] - 2s 306ms/step - loss: 0.0663 - accuracy: 0.9617 - precision: 0.9882 - recall: 0.9593 - val_loss: 0.0972 - val_accuracy: 0.9658 - val_precision: 0.9891 - val_recall: 0.9641
# Epoch 21/50
# 6/6 [==============================] - 2s 311ms/step - loss: 0.0663 - accuracy: 0.9556 - precision: 0.9850 - recall: 0.9542 - val_loss: 0.0972 - val_accuracy: 0.9648 - val_precision: 0.9850 - val_recall: 0.9666
# Epoch 22/50
# 6/6 [==============================] - 2s 303ms/step - loss: 0.0648 - accuracy: 0.9539 - precision: 0.9893 - recall: 0.9474 - val_loss: 0.0883 - val_accuracy: 0.9639 - val_precision: 0.9851 - val_recall: 0.9654
# Epoch 23/50
# 6/6 [==============================] - 2s 307ms/step - loss: 0.0797 - accuracy: 0.9481 - precision: 0.9770 - recall: 0.9510 - val_loss: 0.1004 - val_accuracy: 0.9600 - val_precision: 0.9877 - val_recall: 0.9576
# Epoch 24/50
# 6/6 [==============================] - 2s 306ms/step - loss: 0.0722 - accuracy: 0.9524 - precision: 0.9840 - recall: 0.9508 - val_loss: 0.0943 - val_accuracy: 0.9648 - val_precision: 0.9850 - val_recall: 0.9665
# Epoch 25/50
# 6/6 [==============================] - 2s 297ms/step - loss: 0.0755 - accuracy: 0.9581 - precision: 0.9776 - recall: 0.9640 - val_loss: 0.1051 - val_accuracy: 0.9570 - val_precision: 0.9876 - val_recall: 0.9535
# Epoch 26/50
# 6/6 [==============================] - 2s 304ms/step - loss: 0.0666 - accuracy: 0.9534 - precision: 0.9833 - recall: 0.9525 - val_loss: 0.1165 - val_accuracy: 0.9512 - val_precision: 0.9861 - val_recall: 0.9467
# Epoch 27/50
# 6/6 [==============================] - 2s 296ms/step - loss: 0.0706 - accuracy: 0.9495 - precision: 0.9823 - recall: 0.9477 - val_loss: 0.1062 - val_accuracy: 0.9580 - val_precision: 0.9861 - val_recall: 0.9555
# Epoch 28/50
# 6/6 [==============================] - 2s 299ms/step - loss: 0.0714 - accuracy: 0.9477 - precision: 0.9850 - recall: 0.9438 - val_loss: 0.0949 - val_accuracy: 0.9639 - val_precision: 0.9850 - val_recall: 0.9653
# Epoch 29/50
# 6/6 [==============================] - 2s 307ms/step - loss: 0.0688 - accuracy: 0.9607 - precision: 0.9830 - recall: 0.9628 - val_loss: 0.0936 - val_accuracy: 0.9639 - val_precision: 0.9852 - val_recall: 0.9657
# Epoch 30/50
# 6/6 [==============================] - 2s 291ms/step - loss: 0.0645 - accuracy: 0.9567 - precision: 0.9891 - recall: 0.9514 - val_loss: 0.0948 - val_accuracy: 0.9648 - val_precision: 0.9825 - val_recall: 0.9694
# Epoch 31/50
# 6/6 [==============================] - 2s 295ms/step - loss: 0.0842 - accuracy: 0.9486 - precision: 0.9760 - recall: 0.9524 - val_loss: 0.0921 - val_accuracy: 0.9648 - val_precision: 0.9851 - val_recall: 0.9668
# Epoch 32/50
# 6/6 [==============================] - 2s 306ms/step - loss: 0.0738 - accuracy: 0.9560 - precision: 0.9820 - recall: 0.9571 - val_loss: 0.1043 - val_accuracy: 0.9580 - val_precision: 0.9835 - val_recall: 0.9584
# 3/3 [==============================] - 53s 24s/step
# Learning Rate: 0.010395
# Hidden Units: 4096
# Mini Batch:64
# AUC score: 0.9892826016402468
# Test Recall: 0.9540636042402827
# Test Precision: 0.9747292418772563
# Test F1 Scores: 0.9642857142857143
#
#
#
#
# Batch Size: 1024
# Hidden Units: 4096
# Learning Rate: 0.010395
# Epoch 1/50
# 3/3 [==============================] - 51s 9s/step - loss: 1.0032 - accuracy: 0.6423 - precision: 0.8607 - recall: 0.6075 - val_loss: 2.1421 - val_accuracy: 0.8652 - val_precision: 0.9931 - val_recall: 0.8107
# Epoch 2/50
# 3/3 [==============================] - 1s 501ms/step - loss: 0.5268 - accuracy: 0.8590 - precision: 0.9385 - recall: 0.8644 - val_loss: 26.9732 - val_accuracy: 0.3301 - val_precision: 1.0000 - val_recall: 0.0730
# Epoch 3/50
# 3/3 [==============================] - 1s 518ms/step - loss: 0.3325 - accuracy: 0.8917 - precision: 0.9869 - recall: 0.8634 - val_loss: 33.9591 - val_accuracy: 0.2637 - val_precision: 1.0000 - val_recall: 0.0383
# Epoch 4/50
# 3/3 [==============================] - 1s 501ms/step - loss: 0.3158 - accuracy: 0.8960 - precision: 0.9677 - recall: 0.8895 - val_loss: 18.1604 - val_accuracy: 0.3125 - val_precision: 1.0000 - val_recall: 0.0383
# Epoch 5/50
# 3/3 [==============================] - 1s 535ms/step - loss: 0.1865 - accuracy: 0.9184 - precision: 0.9433 - recall: 0.9451 - val_loss: 9.6645 - val_accuracy: 0.4883 - val_precision: 1.0000 - val_recall: 0.3013
# Epoch 6/50
# 3/3 [==============================] - 1s 505ms/step - loss: 0.1648 - accuracy: 0.9310 - precision: 0.9679 - recall: 0.9342 - val_loss: 5.6365 - val_accuracy: 0.6816 - val_precision: 1.0000 - val_recall: 0.5711
# Epoch 7/50
# 3/3 [==============================] - 1s 497ms/step - loss: 0.2168 - accuracy: 0.8875 - precision: 0.9867 - recall: 0.8601 - val_loss: 1.9564 - val_accuracy: 0.8066 - val_precision: 1.0000 - val_recall: 0.7468
# Epoch 8/50
# 3/3 [==============================] - 1s 515ms/step - loss: 0.1602 - accuracy: 0.9261 - precision: 0.9752 - recall: 0.9212 - val_loss: 0.5789 - val_accuracy: 0.8984 - val_precision: 0.9969 - val_recall: 0.8633
# Epoch 9/50
# 3/3 [==============================] - 1s 494ms/step - loss: 0.1320 - accuracy: 0.9297 - precision: 0.9697 - recall: 0.9340 - val_loss: 1.1096 - val_accuracy: 0.8105 - val_precision: 1.0000 - val_recall: 0.7481
# Epoch 10/50
# 3/3 [==============================] - 1s 506ms/step - loss: 0.1185 - accuracy: 0.9447 - precision: 0.9657 - recall: 0.9590 - val_loss: 2.5779 - val_accuracy: 0.7109 - val_precision: 1.0000 - val_recall: 0.6011
# Epoch 11/50
# 3/3 [==============================] - 1s 497ms/step - loss: 0.0958 - accuracy: 0.9393 - precision: 0.9781 - recall: 0.9377 - val_loss: 3.2280 - val_accuracy: 0.6367 - val_precision: 1.0000 - val_recall: 0.4918
# Epoch 12/50
# 3/3 [==============================] - 1s 516ms/step - loss: 0.1113 - accuracy: 0.9300 - precision: 0.9777 - recall: 0.9263 - val_loss: 2.8642 - val_accuracy: 0.6133 - val_precision: 1.0000 - val_recall: 0.4634
# Epoch 13/50
# 3/3 [==============================] - 1s 514ms/step - loss: 0.1059 - accuracy: 0.9417 - precision: 0.9678 - recall: 0.9502 - val_loss: 2.0346 - val_accuracy: 0.6738 - val_precision: 1.0000 - val_recall: 0.5617
# Epoch 14/50
# 3/3 [==============================] - 1s 506ms/step - loss: 0.0967 - accuracy: 0.9329 - precision: 0.9810 - recall: 0.9279 - val_loss: 0.8408 - val_accuracy: 0.8086 - val_precision: 1.0000 - val_recall: 0.7387
# Epoch 15/50
# 3/3 [==============================] - 1s 499ms/step - loss: 0.1040 - accuracy: 0.9350 - precision: 0.9733 - recall: 0.9358 - val_loss: 0.3832 - val_accuracy: 0.8984 - val_precision: 1.0000 - val_recall: 0.8602
# Epoch 16/50
# 3/3 [==============================] - 1s 509ms/step - loss: 0.0893 - accuracy: 0.9373 - precision: 0.9830 - recall: 0.9305 - val_loss: 0.2302 - val_accuracy: 0.9297 - val_precision: 0.9944 - val_recall: 0.9128
# Epoch 17/50
# 3/3 [==============================] - 1s 550ms/step - loss: 0.0819 - accuracy: 0.9483 - precision: 0.9840 - recall: 0.9437 - val_loss: 0.1360 - val_accuracy: 0.9512 - val_precision: 0.9888 - val_recall: 0.9439
# Epoch 18/50
# 3/3 [==============================] - 1s 572ms/step - loss: 0.0837 - accuracy: 0.9522 - precision: 0.9855 - recall: 0.9490 - val_loss: 0.0840 - val_accuracy: 0.9609 - val_precision: 0.9812 - val_recall: 0.9656
# Epoch 19/50
# 3/3 [==============================] - 1s 506ms/step - loss: 0.1118 - accuracy: 0.9438 - precision: 0.9682 - recall: 0.9533 - val_loss: 0.1754 - val_accuracy: 0.9395 - val_precision: 0.9858 - val_recall: 0.9305
# Epoch 20/50
# 3/3 [==============================] - 1s 513ms/step - loss: 0.1054 - accuracy: 0.9395 - precision: 0.9689 - recall: 0.9467 - val_loss: 0.2793 - val_accuracy: 0.9082 - val_precision: 0.9971 - val_recall: 0.8805
# Epoch 21/50
# 3/3 [==============================] - 1s 505ms/step - loss: 0.0840 - accuracy: 0.9282 - precision: 0.9941 - recall: 0.9115 - val_loss: 0.2258 - val_accuracy: 0.9160 - val_precision: 0.9971 - val_recall: 0.8912
# Epoch 22/50
# 3/3 [==============================] - 1s 503ms/step - loss: 0.0833 - accuracy: 0.9513 - precision: 0.9772 - recall: 0.9543 - val_loss: 0.2452 - val_accuracy: 0.9062 - val_precision: 0.9970 - val_recall: 0.8763
# Epoch 23/50
# 3/3 [==============================] - 1s 491ms/step - loss: 0.0865 - accuracy: 0.9370 - precision: 0.9816 - recall: 0.9329 - val_loss: 0.2686 - val_accuracy: 0.9141 - val_precision: 0.9970 - val_recall: 0.8850
# Epoch 24/50
# 3/3 [==============================] - 1s 507ms/step - loss: 0.0813 - accuracy: 0.9473 - precision: 0.9842 - recall: 0.9440 - val_loss: 0.2004 - val_accuracy: 0.9180 - val_precision: 0.9883 - val_recall: 0.8987
# Epoch 25/50
# 3/3 [==============================] - 1s 545ms/step - loss: 0.0832 - accuracy: 0.9527 - precision: 0.9825 - recall: 0.9517 - val_loss: 0.2182 - val_accuracy: 0.9219 - val_precision: 0.9913 - val_recall: 0.9024
# Epoch 26/50
# 3/3 [==============================] - 1s 547ms/step - loss: 0.0821 - accuracy: 0.9482 - precision: 0.9727 - recall: 0.9556 - val_loss: 0.2035 - val_accuracy: 0.9277 - val_precision: 0.9939 - val_recall: 0.9036
# Epoch 27/50
# 3/3 [==============================] - 1s 513ms/step - loss: 0.0755 - accuracy: 0.9451 - precision: 0.9831 - recall: 0.9427 - val_loss: 0.1722 - val_accuracy: 0.9336 - val_precision: 0.9940 - val_recall: 0.9126
# Epoch 28/50
# 3/3 [==============================] - 1s 503ms/step - loss: 0.0866 - accuracy: 0.9486 - precision: 0.9828 - recall: 0.9473 - val_loss: 0.2017 - val_accuracy: 0.9258 - val_precision: 0.9940 - val_recall: 0.9019
# 2/2 [==============================] - 64s 58s/step
# Learning Rate: 0.010395
# Hidden Units: 4096
# Mini Batch:128
# AUC score: 0.9882797828076739
# Test Recall: 0.9481743227326266
# Test Precision: 0.9757575757575757
# Test F1 Scores: 0.961768219832736
#
#
#
#
# Batch Size: 256
# Hidden Units: 2048
# Learning Rate: 0.010395
# Epoch 1/50
# 13/13 [==============================] - 53s 2s/step - loss: 0.6012 - accuracy: 0.7746 - precision: 0.9123 - recall: 0.7575 - val_loss: 3.9976 - val_accuracy: 0.5015 - val_precision: 1.0000 - val_recall: 0.3166
# Epoch 2/50
# 13/13 [==============================] - 3s 228ms/step - loss: 0.1224 - accuracy: 0.9312 - precision: 0.9694 - recall: 0.9365 - val_loss: 0.7746 - val_accuracy: 0.8462 - val_precision: 0.9975 - val_recall: 0.7930
# Epoch 3/50
# 13/13 [==============================] - 3s 228ms/step - loss: 0.0973 - accuracy: 0.9383 - precision: 0.9740 - recall: 0.9410 - val_loss: 0.4830 - val_accuracy: 0.8672 - val_precision: 0.9959 - val_recall: 0.8208
# Epoch 4/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0805 - accuracy: 0.9494 - precision: 0.9834 - recall: 0.9470 - val_loss: 0.4969 - val_accuracy: 0.8677 - val_precision: 0.9968 - val_recall: 0.8239
# Epoch 5/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0801 - accuracy: 0.9482 - precision: 0.9807 - recall: 0.9480 - val_loss: 0.1389 - val_accuracy: 0.9502 - val_precision: 0.9902 - val_recall: 0.9413
# Epoch 6/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0894 - accuracy: 0.9442 - precision: 0.9771 - recall: 0.9459 - val_loss: 0.2492 - val_accuracy: 0.9180 - val_precision: 0.9912 - val_recall: 0.8960
# Epoch 7/50
# 13/13 [==============================] - 3s 215ms/step - loss: 0.0837 - accuracy: 0.9460 - precision: 0.9791 - recall: 0.9463 - val_loss: 0.0881 - val_accuracy: 0.9688 - val_precision: 0.9826 - val_recall: 0.9748
# Epoch 8/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0680 - accuracy: 0.9586 - precision: 0.9824 - recall: 0.9605 - val_loss: 0.1549 - val_accuracy: 0.9370 - val_precision: 0.9921 - val_recall: 0.9212
# Epoch 9/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0725 - accuracy: 0.9535 - precision: 0.9855 - recall: 0.9505 - val_loss: 0.1006 - val_accuracy: 0.9629 - val_precision: 0.9849 - val_recall: 0.9638
# Epoch 10/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0642 - accuracy: 0.9586 - precision: 0.9841 - recall: 0.9589 - val_loss: 0.1216 - val_accuracy: 0.9497 - val_precision: 0.9894 - val_recall: 0.9409
# Epoch 11/50
# 13/13 [==============================] - 3s 213ms/step - loss: 0.0666 - accuracy: 0.9576 - precision: 0.9861 - recall: 0.9553 - val_loss: 0.0954 - val_accuracy: 0.9644 - val_precision: 0.9838 - val_recall: 0.9674
# Epoch 12/50
# 13/13 [==============================] - 3s 227ms/step - loss: 0.0659 - accuracy: 0.9544 - precision: 0.9860 - recall: 0.9514 - val_loss: 0.0919 - val_accuracy: 0.9673 - val_precision: 0.9831 - val_recall: 0.9720
# Epoch 13/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0603 - accuracy: 0.9608 - precision: 0.9864 - recall: 0.9593 - val_loss: 0.0783 - val_accuracy: 0.9678 - val_precision: 0.9737 - val_recall: 0.9827
# Epoch 14/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0581 - accuracy: 0.9614 - precision: 0.9866 - recall: 0.9603 - val_loss: 0.0930 - val_accuracy: 0.9658 - val_precision: 0.9844 - val_recall: 0.9687
# Epoch 15/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0630 - accuracy: 0.9604 - precision: 0.9860 - recall: 0.9602 - val_loss: 0.1098 - val_accuracy: 0.9580 - val_precision: 0.9863 - val_recall: 0.9561
# Epoch 16/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0529 - accuracy: 0.9620 - precision: 0.9913 - recall: 0.9567 - val_loss: 0.0912 - val_accuracy: 0.9683 - val_precision: 0.9800 - val_recall: 0.9767
# Epoch 17/50
# 13/13 [==============================] - 3s 215ms/step - loss: 0.0539 - accuracy: 0.9633 - precision: 0.9860 - recall: 0.9633 - val_loss: 0.0855 - val_accuracy: 0.9722 - val_precision: 0.9852 - val_recall: 0.9766
# Epoch 18/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0602 - accuracy: 0.9587 - precision: 0.9843 - recall: 0.9585 - val_loss: 0.0937 - val_accuracy: 0.9658 - val_precision: 0.9838 - val_recall: 0.9694
# Epoch 19/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0542 - accuracy: 0.9648 - precision: 0.9859 - recall: 0.9654 - val_loss: 0.0976 - val_accuracy: 0.9644 - val_precision: 0.9851 - val_recall: 0.9661
# Epoch 20/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0520 - accuracy: 0.9631 - precision: 0.9868 - recall: 0.9622 - val_loss: 0.0847 - val_accuracy: 0.9692 - val_precision: 0.9806 - val_recall: 0.9773
# Epoch 21/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0579 - accuracy: 0.9607 - precision: 0.9837 - recall: 0.9623 - val_loss: 0.0796 - val_accuracy: 0.9712 - val_precision: 0.9820 - val_recall: 0.9787
# Epoch 22/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0513 - accuracy: 0.9667 - precision: 0.9881 - recall: 0.9658 - val_loss: 0.0826 - val_accuracy: 0.9707 - val_precision: 0.9845 - val_recall: 0.9753
# Epoch 23/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0481 - accuracy: 0.9671 - precision: 0.9912 - recall: 0.9640 - val_loss: 0.0810 - val_accuracy: 0.9707 - val_precision: 0.9800 - val_recall: 0.9800
# 5/5 [==============================] - 51s 12s/step
# Learning Rate: 0.010395
# Hidden Units: 2048
# Mini Batch:32
# AUC score: 0.9891914362918313
# Test Recall: 0.9705535924617197
# Test Precision: 0.9671361502347418
# Test F1 Scores: 0.9688418577307466
#
#
#
#
# Batch Size: 512
# Hidden Units: 2048
# Learning Rate: 0.010395
# Epoch 1/50
# 6/6 [==============================] - 52s 4s/step - loss: 0.7175 - accuracy: 0.7061 - precision: 0.8742 - recall: 0.6913 - val_loss: 2.4222 - val_accuracy: 0.7666 - val_precision: 0.9980 - val_recall: 0.6818
# Epoch 2/50
# 6/6 [==============================] - 2s 311ms/step - loss: 0.2256 - accuracy: 0.8950 - precision: 0.9701 - recall: 0.8819 - val_loss: 20.1174 - val_accuracy: 0.2676 - val_precision: 1.0000 - val_recall: 0.0066
# Epoch 3/50
# 6/6 [==============================] - 2s 307ms/step - loss: 0.1498 - accuracy: 0.9189 - precision: 0.9579 - recall: 0.9295 - val_loss: 0.2810 - val_accuracy: 0.9375 - val_precision: 0.9900 - val_recall: 0.9242
# Epoch 4/50
# 6/6 [==============================] - 2s 308ms/step - loss: 0.1056 - accuracy: 0.9379 - precision: 0.9774 - recall: 0.9383 - val_loss: 0.1820 - val_accuracy: 0.9570 - val_precision: 0.9658 - val_recall: 0.9761
# Epoch 5/50
# 6/6 [==============================] - 2s 306ms/step - loss: 0.1059 - accuracy: 0.9290 - precision: 0.9789 - recall: 0.9224 - val_loss: 0.5774 - val_accuracy: 0.8643 - val_precision: 0.9984 - val_recall: 0.8155
# Epoch 6/50
# 6/6 [==============================] - 2s 306ms/step - loss: 0.0964 - accuracy: 0.9416 - precision: 0.9805 - recall: 0.9383 - val_loss: 1.6967 - val_accuracy: 0.6973 - val_precision: 1.0000 - val_recall: 0.5916
# Epoch 7/50
# 6/6 [==============================] - 2s 311ms/step - loss: 0.0914 - accuracy: 0.9423 - precision: 0.9766 - recall: 0.9436 - val_loss: 0.7283 - val_accuracy: 0.8262 - val_precision: 1.0000 - val_recall: 0.7636
# Epoch 8/50
# 6/6 [==============================] - 2s 314ms/step - loss: 0.1022 - accuracy: 0.9424 - precision: 0.9695 - recall: 0.9497 - val_loss: 0.3835 - val_accuracy: 0.8838 - val_precision: 0.9953 - val_recall: 0.8455
# Epoch 9/50
# 6/6 [==============================] - 3s 480ms/step - loss: 0.0811 - accuracy: 0.9439 - precision: 0.9812 - recall: 0.9403 - val_loss: 0.2497 - val_accuracy: 0.9111 - val_precision: 0.9910 - val_recall: 0.8862
# Epoch 10/50
# 6/6 [==============================] - 2s 312ms/step - loss: 0.0914 - accuracy: 0.9362 - precision: 0.9818 - recall: 0.9313 - val_loss: 0.2711 - val_accuracy: 0.9023 - val_precision: 0.9939 - val_recall: 0.8715
# Epoch 11/50
# 6/6 [==============================] - 2s 304ms/step - loss: 0.0756 - accuracy: 0.9565 - precision: 0.9841 - recall: 0.9555 - val_loss: 0.3843 - val_accuracy: 0.8818 - val_precision: 0.9968 - val_recall: 0.8415
# Epoch 12/50
# 6/6 [==============================] - 2s 300ms/step - loss: 0.0947 - accuracy: 0.9345 - precision: 0.9800 - recall: 0.9309 - val_loss: 0.3212 - val_accuracy: 0.8867 - val_precision: 0.9937 - val_recall: 0.8497
# Epoch 13/50
# 6/6 [==============================] - 2s 288ms/step - loss: 0.0819 - accuracy: 0.9512 - precision: 0.9861 - recall: 0.9471 - val_loss: 0.1922 - val_accuracy: 0.9229 - val_precision: 0.9926 - val_recall: 0.9005
# Epoch 14/50
# 6/6 [==============================] - 2s 287ms/step - loss: 0.0812 - accuracy: 0.9470 - precision: 0.9796 - recall: 0.9470 - val_loss: 0.1702 - val_accuracy: 0.9277 - val_precision: 0.9900 - val_recall: 0.9116
# Epoch 15/50
# 6/6 [==============================] - 2s 312ms/step - loss: 0.0731 - accuracy: 0.9532 - precision: 0.9877 - recall: 0.9477 - val_loss: 0.1201 - val_accuracy: 0.9492 - val_precision: 0.9859 - val_recall: 0.9435
# Epoch 16/50
# 6/6 [==============================] - 2s 311ms/step - loss: 0.0885 - accuracy: 0.9419 - precision: 0.9762 - recall: 0.9431 - val_loss: 0.1251 - val_accuracy: 0.9482 - val_precision: 0.9860 - val_recall: 0.9425
# Epoch 17/50
# 6/6 [==============================] - 2s 314ms/step - loss: 0.0792 - accuracy: 0.9537 - precision: 0.9808 - recall: 0.9549 - val_loss: 0.1501 - val_accuracy: 0.9365 - val_precision: 0.9928 - val_recall: 0.9203
# Epoch 18/50
# 6/6 [==============================] - 2s 307ms/step - loss: 0.0720 - accuracy: 0.9491 - precision: 0.9879 - recall: 0.9426 - val_loss: 0.1377 - val_accuracy: 0.9346 - val_precision: 0.9900 - val_recall: 0.9202
# Epoch 19/50
# 6/6 [==============================] - 2s 305ms/step - loss: 0.0767 - accuracy: 0.9496 - precision: 0.9853 - recall: 0.9461 - val_loss: 0.1411 - val_accuracy: 0.9365 - val_precision: 0.9885 - val_recall: 0.9235
# Epoch 20/50
# 6/6 [==============================] - 2s 305ms/step - loss: 0.0711 - accuracy: 0.9533 - precision: 0.9835 - recall: 0.9524 - val_loss: 0.1303 - val_accuracy: 0.9395 - val_precision: 0.9888 - val_recall: 0.9289
# Epoch 21/50
# 6/6 [==============================] - 2s 291ms/step - loss: 0.0763 - accuracy: 0.9528 - precision: 0.9824 - recall: 0.9529 - val_loss: 0.1373 - val_accuracy: 0.9395 - val_precision: 0.9929 - val_recall: 0.9248
# Epoch 22/50
# 6/6 [==============================] - 2s 307ms/step - loss: 0.0747 - accuracy: 0.9475 - precision: 0.9870 - recall: 0.9411 - val_loss: 0.1261 - val_accuracy: 0.9434 - val_precision: 0.9900 - val_recall: 0.9315
# Epoch 23/50
# 6/6 [==============================] - 2s 307ms/step - loss: 0.0783 - accuracy: 0.9535 - precision: 0.9813 - recall: 0.9533 - val_loss: 0.1307 - val_accuracy: 0.9375 - val_precision: 0.9871 - val_recall: 0.9258
# Epoch 24/50
# 6/6 [==============================] - 2s 304ms/step - loss: 0.0777 - accuracy: 0.9479 - precision: 0.9838 - recall: 0.9446 - val_loss: 0.1189 - val_accuracy: 0.9473 - val_precision: 0.9915 - val_recall: 0.9356
# Epoch 25/50
# 6/6 [==============================] - 2s 314ms/step - loss: 0.0780 - accuracy: 0.9565 - precision: 0.9818 - recall: 0.9573 - val_loss: 0.1291 - val_accuracy: 0.9404 - val_precision: 0.9845 - val_recall: 0.9332
# Epoch 26/50
# 6/6 [==============================] - 2s 316ms/step - loss: 0.0722 - accuracy: 0.9564 - precision: 0.9801 - recall: 0.9594 - val_loss: 0.1119 - val_accuracy: 0.9512 - val_precision: 0.9889 - val_recall: 0.9442
# Epoch 27/50
# 6/6 [==============================] - 2s 328ms/step - loss: 0.0738 - accuracy: 0.9528 - precision: 0.9845 - recall: 0.9511 - val_loss: 0.1126 - val_accuracy: 0.9541 - val_precision: 0.9902 - val_recall: 0.9467
# Epoch 28/50
# 6/6 [==============================] - 2s 318ms/step - loss: 0.0722 - accuracy: 0.9551 - precision: 0.9860 - recall: 0.9523 - val_loss: 0.1088 - val_accuracy: 0.9531 - val_precision: 0.9861 - val_recall: 0.9493
# Epoch 29/50
# 6/6 [==============================] - 2s 318ms/step - loss: 0.0701 - accuracy: 0.9570 - precision: 0.9824 - recall: 0.9581 - val_loss: 0.1092 - val_accuracy: 0.9570 - val_precision: 0.9860 - val_recall: 0.9538
# Epoch 30/50
# 6/6 [==============================] - 2s 306ms/step - loss: 0.0718 - accuracy: 0.9589 - precision: 0.9824 - recall: 0.9604 - val_loss: 0.1111 - val_accuracy: 0.9512 - val_precision: 0.9861 - val_recall: 0.9465
# Epoch 31/50
# 6/6 [==============================] - 2s 320ms/step - loss: 0.0826 - accuracy: 0.9478 - precision: 0.9783 - recall: 0.9492 - val_loss: 0.1054 - val_accuracy: 0.9561 - val_precision: 0.9889 - val_recall: 0.9505
# Epoch 32/50
# 6/6 [==============================] - 2s 315ms/step - loss: 0.0768 - accuracy: 0.9524 - precision: 0.9880 - recall: 0.9466 - val_loss: 0.1084 - val_accuracy: 0.9580 - val_precision: 0.9862 - val_recall: 0.9558
# Epoch 33/50
# 6/6 [==============================] - 2s 303ms/step - loss: 0.0739 - accuracy: 0.9552 - precision: 0.9838 - recall: 0.9542 - val_loss: 0.1020 - val_accuracy: 0.9639 - val_precision: 0.9890 - val_recall: 0.9613
# Epoch 34/50
# 6/6 [==============================] - 2s 317ms/step - loss: 0.0671 - accuracy: 0.9562 - precision: 0.9839 - recall: 0.9558 - val_loss: 0.1049 - val_accuracy: 0.9590 - val_precision: 0.9862 - val_recall: 0.9573
# Epoch 35/50
# 6/6 [==============================] - 2s 316ms/step - loss: 0.0702 - accuracy: 0.9540 - precision: 0.9874 - recall: 0.9496 - val_loss: 0.1061 - val_accuracy: 0.9570 - val_precision: 0.9863 - val_recall: 0.9549
# Epoch 36/50
# 6/6 [==============================] - 2s 304ms/step - loss: 0.0677 - accuracy: 0.9589 - precision: 0.9844 - recall: 0.9597 - val_loss: 0.1065 - val_accuracy: 0.9580 - val_precision: 0.9848 - val_recall: 0.9571
# Epoch 37/50
# 6/6 [==============================] - 2s 310ms/step - loss: 0.0769 - accuracy: 0.9438 - precision: 0.9862 - recall: 0.9382 - val_loss: 0.1017 - val_accuracy: 0.9619 - val_precision: 0.9890 - val_recall: 0.9587
# Epoch 38/50
# 6/6 [==============================] - 2s 312ms/step - loss: 0.0640 - accuracy: 0.9579 - precision: 0.9893 - recall: 0.9526 - val_loss: 0.1076 - val_accuracy: 0.9580 - val_precision: 0.9863 - val_recall: 0.9562
# Epoch 39/50
# 6/6 [==============================] - 2s 308ms/step - loss: 0.0801 - accuracy: 0.9469 - precision: 0.9850 - recall: 0.9413 - val_loss: 0.1081 - val_accuracy: 0.9600 - val_precision: 0.9863 - val_recall: 0.9587
# Epoch 40/50
# 6/6 [==============================] - 2s 297ms/step - loss: 0.0724 - accuracy: 0.9547 - precision: 0.9857 - recall: 0.9521 - val_loss: 0.0975 - val_accuracy: 0.9648 - val_precision: 0.9850 - val_recall: 0.9666
# Epoch 41/50
# 6/6 [==============================] - 2s 312ms/step - loss: 0.0792 - accuracy: 0.9447 - precision: 0.9840 - recall: 0.9401 - val_loss: 0.0972 - val_accuracy: 0.9678 - val_precision: 0.9890 - val_recall: 0.9663
# Epoch 42/50
# 6/6 [==============================] - 2s 319ms/step - loss: 0.0758 - accuracy: 0.9528 - precision: 0.9802 - recall: 0.9540 - val_loss: 0.0944 - val_accuracy: 0.9697 - val_precision: 0.9879 - val_recall: 0.9709
# Epoch 43/50
# 6/6 [==============================] - 2s 309ms/step - loss: 0.0727 - accuracy: 0.9524 - precision: 0.9846 - recall: 0.9504 - val_loss: 0.0938 - val_accuracy: 0.9668 - val_precision: 0.9850 - val_recall: 0.9691
# Epoch 44/50
# 6/6 [==============================] - 2s 321ms/step - loss: 0.0635 - accuracy: 0.9538 - precision: 0.9851 - recall: 0.9518 - val_loss: 0.0996 - val_accuracy: 0.9658 - val_precision: 0.9851 - val_recall: 0.9680
# Epoch 45/50
# 6/6 [==============================] - 2s 322ms/step - loss: 0.0666 - accuracy: 0.9601 - precision: 0.9854 - recall: 0.9594 - val_loss: 0.0985 - val_accuracy: 0.9648 - val_precision: 0.9834 - val_recall: 0.9674
# Epoch 46/50
# 6/6 [==============================] - 2s 319ms/step - loss: 0.0676 - accuracy: 0.9526 - precision: 0.9853 - recall: 0.9499 - val_loss: 0.0986 - val_accuracy: 0.9648 - val_precision: 0.9826 - val_recall: 0.9696
# Epoch 47/50
# 6/6 [==============================] - 2s 310ms/step - loss: 0.0690 - accuracy: 0.9595 - precision: 0.9811 - recall: 0.9625 - val_loss: 0.0907 - val_accuracy: 0.9678 - val_precision: 0.9837 - val_recall: 0.9718
# Epoch 48/50
# 6/6 [==============================] - 2s 306ms/step - loss: 0.0802 - accuracy: 0.9467 - precision: 0.9813 - recall: 0.9456 - val_loss: 0.0946 - val_accuracy: 0.9688 - val_precision: 0.9863 - val_recall: 0.9704
# Epoch 49/50
# 6/6 [==============================] - 2s 317ms/step - loss: 0.0657 - accuracy: 0.9589 - precision: 0.9893 - recall: 0.9545 - val_loss: 0.1011 - val_accuracy: 0.9658 - val_precision: 0.9823 - val_recall: 0.9704
# Epoch 50/50
# 6/6 [==============================] - 2s 313ms/step - loss: 0.0651 - accuracy: 0.9547 - precision: 0.9878 - recall: 0.9502 - val_loss: 0.1004 - val_accuracy: 0.9648 - val_precision: 0.9837 - val_recall: 0.9679
# 3/3 [==============================] - 52s 24s/step
# Learning Rate: 0.010395
# Hidden Units: 2048
# Mini Batch:64
# AUC score: 0.9896764359454029
# Test Recall: 0.9587750294464076
# Test Precision: 0.972520908004779
# Test F1 Scores: 0.9655990510083037
#
#
#
#
# Batch Size: 1024
# Hidden Units: 2048
# Learning Rate: 0.010395
# Epoch 1/50
# 3/3 [==============================] - 55s 9s/step - loss: 0.8340 - accuracy: 0.6516 - precision: 0.8582 - recall: 0.6178 - val_loss: 2.3840 - val_accuracy: 0.8184 - val_precision: 0.9860 - val_recall: 0.7601
# Epoch 2/50
# 3/3 [==============================] - 1s 535ms/step - loss: 0.2772 - accuracy: 0.8882 - precision: 0.9532 - recall: 0.8919 - val_loss: 11.0883 - val_accuracy: 0.2832 - val_precision: 1.0000 - val_recall: 0.0161
# Epoch 3/50
# 3/3 [==============================] - 1s 553ms/step - loss: 0.1585 - accuracy: 0.9181 - precision: 0.9771 - recall: 0.9103 - val_loss: 30.1204 - val_accuracy: 0.2441 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/50
# 3/3 [==============================] - 1s 505ms/step - loss: 0.2222 - accuracy: 0.8767 - precision: 0.9752 - recall: 0.8527 - val_loss: 15.3414 - val_accuracy: 0.2734 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/50
# 3/3 [==============================] - 1s 504ms/step - loss: 0.1186 - accuracy: 0.9135 - precision: 0.9670 - recall: 0.9145 - val_loss: 1.2176 - val_accuracy: 0.7285 - val_precision: 1.0000 - val_recall: 0.6171
# Epoch 6/50
# 3/3 [==============================] - 1s 568ms/step - loss: 0.1393 - accuracy: 0.9211 - precision: 0.9430 - recall: 0.9463 - val_loss: 0.5779 - val_accuracy: 0.9004 - val_precision: 0.9884 - val_recall: 0.8786
# Epoch 7/50
# 3/3 [==============================] - 1s 501ms/step - loss: 0.1073 - accuracy: 0.9209 - precision: 0.9828 - recall: 0.9091 - val_loss: 0.3916 - val_accuracy: 0.9258 - val_precision: 0.9855 - val_recall: 0.9118
# Epoch 8/50
# 3/3 [==============================] - 1s 512ms/step - loss: 0.1285 - accuracy: 0.9242 - precision: 0.9794 - recall: 0.9156 - val_loss: 0.2322 - val_accuracy: 0.9375 - val_precision: 0.9721 - val_recall: 0.9407
# Epoch 9/50
# 3/3 [==============================] - 1s 516ms/step - loss: 0.0876 - accuracy: 0.9480 - precision: 0.9881 - recall: 0.9425 - val_loss: 0.2011 - val_accuracy: 0.9355 - val_precision: 0.9916 - val_recall: 0.9221
# Epoch 10/50
# 3/3 [==============================] - 1s 511ms/step - loss: 0.0814 - accuracy: 0.9568 - precision: 0.9786 - recall: 0.9619 - val_loss: 0.8924 - val_accuracy: 0.8125 - val_precision: 1.0000 - val_recall: 0.7377
# Epoch 11/50
# 3/3 [==============================] - 1s 493ms/step - loss: 0.1047 - accuracy: 0.9340 - precision: 0.9720 - recall: 0.9381 - val_loss: 1.6716 - val_accuracy: 0.7012 - val_precision: 1.0000 - val_recall: 0.5931
# Epoch 12/50
# 3/3 [==============================] - 1s 539ms/step - loss: 0.0767 - accuracy: 0.9524 - precision: 0.9821 - recall: 0.9515 - val_loss: 1.8197 - val_accuracy: 0.6797 - val_precision: 1.0000 - val_recall: 0.5795
# Epoch 13/50
# 3/3 [==============================] - 1s 482ms/step - loss: 0.0991 - accuracy: 0.9379 - precision: 0.9816 - recall: 0.9300 - val_loss: 1.7598 - val_accuracy: 0.6934 - val_precision: 1.0000 - val_recall: 0.5868
# Epoch 14/50
# 3/3 [==============================] - 1s 488ms/step - loss: 0.0941 - accuracy: 0.9380 - precision: 0.9862 - recall: 0.9309 - val_loss: 1.1101 - val_accuracy: 0.7520 - val_precision: 1.0000 - val_recall: 0.6549
# Epoch 15/50
# 3/3 [==============================] - 1s 526ms/step - loss: 0.0852 - accuracy: 0.9513 - precision: 0.9790 - recall: 0.9527 - val_loss: 0.8790 - val_accuracy: 0.7695 - val_precision: 1.0000 - val_recall: 0.6959
# Epoch 16/50
# 3/3 [==============================] - 1s 527ms/step - loss: 0.0776 - accuracy: 0.9443 - precision: 0.9811 - recall: 0.9420 - val_loss: 0.5238 - val_accuracy: 0.8418 - val_precision: 1.0000 - val_recall: 0.7840
# Epoch 17/50
# 3/3 [==============================] - 1s 480ms/step - loss: 0.0828 - accuracy: 0.9506 - precision: 0.9811 - recall: 0.9505 - val_loss: 0.5809 - val_accuracy: 0.8457 - val_precision: 0.9966 - val_recall: 0.7875
# Epoch 18/50
# 3/3 [==============================] - 1s 487ms/step - loss: 0.0898 - accuracy: 0.9384 - precision: 0.9769 - recall: 0.9367 - val_loss: 0.3954 - val_accuracy: 0.8691 - val_precision: 0.9967 - val_recall: 0.8192
# Epoch 19/50
# 3/3 [==============================] - 1s 521ms/step - loss: 0.0891 - accuracy: 0.9383 - precision: 0.9774 - recall: 0.9377 - val_loss: 0.3444 - val_accuracy: 0.8750 - val_precision: 1.0000 - val_recall: 0.8307
# 2/2 [==============================] - 63s 58s/step
# Learning Rate: 0.010395
# Hidden Units: 2048
# Mini Batch:128
# AUC score: 0.9865257615041554
# Test Recall: 0.9199057714958775
# Test Precision: 0.9848675914249685
# Test F1 Scores: 0.9512789281364191
#
#
#
#
# Batch Size: 256
# Hidden Units: 1024
# Learning Rate: 0.010395
# Epoch 1/50
# 13/13 [==============================] - 53s 2s/step - loss: 0.5243 - accuracy: 0.7450 - precision: 0.8998 - recall: 0.7270 - val_loss: 10.1073 - val_accuracy: 0.2817 - val_precision: 1.0000 - val_recall: 0.0180
# Epoch 2/50
# 13/13 [==============================] - 3s 227ms/step - loss: 0.1229 - accuracy: 0.9225 - precision: 0.9728 - recall: 0.9206 - val_loss: 0.5628 - val_accuracy: 0.8921 - val_precision: 0.9923 - val_recall: 0.8591
# Epoch 3/50
# 13/13 [==============================] - 3s 231ms/step - loss: 0.1008 - accuracy: 0.9349 - precision: 0.9820 - recall: 0.9288 - val_loss: 0.7678 - val_accuracy: 0.8262 - val_precision: 0.9983 - val_recall: 0.7637
# Epoch 4/50
# 13/13 [==============================] - 3s 237ms/step - loss: 0.0916 - accuracy: 0.9403 - precision: 0.9801 - recall: 0.9379 - val_loss: 0.5083 - val_accuracy: 0.8599 - val_precision: 0.9983 - val_recall: 0.8091
# Epoch 5/50
# 13/13 [==============================] - 3s 228ms/step - loss: 0.0828 - accuracy: 0.9450 - precision: 0.9860 - recall: 0.9384 - val_loss: 0.2456 - val_accuracy: 0.9131 - val_precision: 0.9933 - val_recall: 0.8873
# Epoch 6/50
# 13/13 [==============================] - 3s 229ms/step - loss: 0.0727 - accuracy: 0.9507 - precision: 0.9843 - recall: 0.9480 - val_loss: 0.3014 - val_accuracy: 0.8906 - val_precision: 0.9976 - val_recall: 0.8518
# Epoch 7/50
# 13/13 [==============================] - 3s 228ms/step - loss: 0.0793 - accuracy: 0.9472 - precision: 0.9820 - recall: 0.9450 - val_loss: 0.1357 - val_accuracy: 0.9443 - val_precision: 0.9922 - val_recall: 0.9315
# Epoch 8/50
# 13/13 [==============================] - 3s 235ms/step - loss: 0.0754 - accuracy: 0.9540 - precision: 0.9820 - recall: 0.9544 - val_loss: 0.1770 - val_accuracy: 0.9224 - val_precision: 0.9926 - val_recall: 0.9002
# Epoch 9/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0795 - accuracy: 0.9474 - precision: 0.9810 - recall: 0.9456 - val_loss: 0.1264 - val_accuracy: 0.9463 - val_precision: 0.9866 - val_recall: 0.9389
# Epoch 10/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0767 - accuracy: 0.9510 - precision: 0.9815 - recall: 0.9508 - val_loss: 0.1120 - val_accuracy: 0.9531 - val_precision: 0.9888 - val_recall: 0.9464
# Epoch 11/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0690 - accuracy: 0.9566 - precision: 0.9872 - recall: 0.9530 - val_loss: 0.0967 - val_accuracy: 0.9634 - val_precision: 0.9837 - val_recall: 0.9659
# Epoch 12/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0638 - accuracy: 0.9575 - precision: 0.9832 - recall: 0.9584 - val_loss: 0.0913 - val_accuracy: 0.9658 - val_precision: 0.9830 - val_recall: 0.9698
# Epoch 13/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0658 - accuracy: 0.9578 - precision: 0.9872 - recall: 0.9549 - val_loss: 0.1018 - val_accuracy: 0.9648 - val_precision: 0.9857 - val_recall: 0.9660
# Epoch 14/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0581 - accuracy: 0.9620 - precision: 0.9878 - recall: 0.9596 - val_loss: 0.0869 - val_accuracy: 0.9683 - val_precision: 0.9831 - val_recall: 0.9733
# Epoch 15/50
# 13/13 [==============================] - 3s 228ms/step - loss: 0.0577 - accuracy: 0.9632 - precision: 0.9868 - recall: 0.9626 - val_loss: 0.0969 - val_accuracy: 0.9624 - val_precision: 0.9823 - val_recall: 0.9659
# Epoch 16/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0585 - accuracy: 0.9619 - precision: 0.9890 - recall: 0.9585 - val_loss: 0.0829 - val_accuracy: 0.9697 - val_precision: 0.9819 - val_recall: 0.9766
# Epoch 17/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0665 - accuracy: 0.9599 - precision: 0.9822 - recall: 0.9620 - val_loss: 0.0915 - val_accuracy: 0.9663 - val_precision: 0.9830 - val_recall: 0.9705
# Epoch 18/50
# 13/13 [==============================] - 3s 228ms/step - loss: 0.0652 - accuracy: 0.9587 - precision: 0.9818 - recall: 0.9610 - val_loss: 0.0940 - val_accuracy: 0.9668 - val_precision: 0.9791 - val_recall: 0.9752
# Epoch 19/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0658 - accuracy: 0.9598 - precision: 0.9828 - recall: 0.9617 - val_loss: 0.0987 - val_accuracy: 0.9658 - val_precision: 0.9837 - val_recall: 0.9693
# Epoch 20/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0581 - accuracy: 0.9639 - precision: 0.9871 - recall: 0.9631 - val_loss: 0.0804 - val_accuracy: 0.9722 - val_precision: 0.9808 - val_recall: 0.9814
# Epoch 21/50
# 13/13 [==============================] - 3s 228ms/step - loss: 0.0568 - accuracy: 0.9662 - precision: 0.9882 - recall: 0.9653 - val_loss: 0.0930 - val_accuracy: 0.9707 - val_precision: 0.9838 - val_recall: 0.9758
# Epoch 22/50
# 13/13 [==============================] - 3s 229ms/step - loss: 0.0535 - accuracy: 0.9635 - precision: 0.9878 - recall: 0.9623 - val_loss: 0.0855 - val_accuracy: 0.9712 - val_precision: 0.9798 - val_recall: 0.9804
# Epoch 23/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0510 - accuracy: 0.9692 - precision: 0.9878 - recall: 0.9697 - val_loss: 0.0877 - val_accuracy: 0.9722 - val_precision: 0.9858 - val_recall: 0.9759
# Epoch 24/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0554 - accuracy: 0.9612 - precision: 0.9891 - recall: 0.9573 - val_loss: 0.0866 - val_accuracy: 0.9663 - val_precision: 0.9760 - val_recall: 0.9780
# Epoch 25/50
# 13/13 [==============================] - 3s 231ms/step - loss: 0.0543 - accuracy: 0.9660 - precision: 0.9867 - recall: 0.9666 - val_loss: 0.0849 - val_accuracy: 0.9688 - val_precision: 0.9799 - val_recall: 0.9773
# Epoch 26/50
# ...
# Epoch 32/50
# 6/6 [==============================] - 2s 305ms/step - loss: 0.0765 - accuracy: 0.9471 - precision: 0.9796 - recall: 0.9477 - val_loss: 0.1053 - val_accuracy: 0.9561 - val_precision: 0.9823 - val_recall: 0.9576
# Epoch 33/50
# 6/6 [==============================] - 2s 302ms/step - loss: 0.0677 - accuracy: 0.9571 - precision: 0.9867 - recall: 0.9544 - val_loss: 0.1071 - val_accuracy: 0.9570 - val_precision: 0.9821 - val_recall: 0.9583
# Epoch 34/50
# 6/6 [==============================] - 2s 303ms/step - loss: 0.0745 - accuracy: 0.9586 - precision: 0.9818 - recall: 0.9604 - val_loss: 0.1052 - val_accuracy: 0.9561 - val_precision: 0.9795 - val_recall: 0.9599
# Epoch 35/50
# 6/6 [==============================] - 2s 294ms/step - loss: 0.0625 - accuracy: 0.9581 - precision: 0.9876 - recall: 0.9550 - val_loss: 0.1011 - val_accuracy: 0.9609 - val_precision: 0.9811 - val_recall: 0.9654
# Epoch 36/50
# 6/6 [==============================] - 2s 308ms/step - loss: 0.0771 - accuracy: 0.9539 - precision: 0.9840 - recall: 0.9535 - val_loss: 0.1042 - val_accuracy: 0.9590 - val_precision: 0.9809 - val_recall: 0.9625
# Epoch 37/50
# 6/6 [==============================] - 2s 327ms/step - loss: 0.0643 - accuracy: 0.9570 - precision: 0.9891 - recall: 0.9523 - val_loss: 0.0977 - val_accuracy: 0.9619 - val_precision: 0.9825 - val_recall: 0.9657
# Epoch 38/50
# 6/6 [==============================] - 2s 318ms/step - loss: 0.0775 - accuracy: 0.9488 - precision: 0.9784 - recall: 0.9504 - val_loss: 0.1024 - val_accuracy: 0.9609 - val_precision: 0.9810 - val_recall: 0.9653
# Epoch 39/50
# 6/6 [==============================] - 2s 302ms/step - loss: 0.0694 - accuracy: 0.9625 - precision: 0.9866 - recall: 0.9615 - val_loss: 0.0954 - val_accuracy: 0.9648 - val_precision: 0.9837 - val_recall: 0.9679
# Epoch 40/50
# 6/6 [==============================] - 2s 323ms/step - loss: 0.0769 - accuracy: 0.9503 - precision: 0.9794 - recall: 0.9518 - val_loss: 0.0945 - val_accuracy: 0.9658 - val_precision: 0.9810 - val_recall: 0.9717
# Epoch 41/50
# 6/6 [==============================] - 2s 319ms/step - loss: 0.0767 - accuracy: 0.9535 - precision: 0.9837 - recall: 0.9525 - val_loss: 0.0961 - val_accuracy: 0.9648 - val_precision: 0.9809 - val_recall: 0.9704
# Epoch 42/50
# 6/6 [==============================] - 2s 313ms/step - loss: 0.0660 - accuracy: 0.9538 - precision: 0.9860 - recall: 0.9516 - val_loss: 0.0972 - val_accuracy: 0.9658 - val_precision: 0.9839 - val_recall: 0.9695
# Epoch 43/50
# 6/6 [==============================] - 2s 301ms/step - loss: 0.0676 - accuracy: 0.9576 - precision: 0.9817 - recall: 0.9593 - val_loss: 0.1040 - val_accuracy: 0.9629 - val_precision: 0.9811 - val_recall: 0.9680
# Epoch 44/50
# 6/6 [==============================] - 2s 305ms/step - loss: 0.0676 - accuracy: 0.9568 - precision: 0.9858 - recall: 0.9557 - val_loss: 0.0959 - val_accuracy: 0.9658 - val_precision: 0.9851 - val_recall: 0.9681
# Epoch 45/50
# 6/6 [==============================] - 2s 314ms/step - loss: 0.0603 - accuracy: 0.9633 - precision: 0.9892 - recall: 0.9601 - val_loss: 0.1030 - val_accuracy: 0.9600 - val_precision: 0.9796 - val_recall: 0.9651
# Epoch 46/50
# 6/6 [==============================] - 2s 298ms/step - loss: 0.0713 - accuracy: 0.9606 - precision: 0.9886 - recall: 0.9569 - val_loss: 0.0995 - val_accuracy: 0.9629 - val_precision: 0.9824 - val_recall: 0.9666
# Epoch 47/50
# 6/6 [==============================] - 2s 315ms/step - loss: 0.0713 - accuracy: 0.9604 - precision: 0.9844 - recall: 0.9612 - val_loss: 0.0988 - val_accuracy: 0.9619 - val_precision: 0.9809 - val_recall: 0.9664
# Epoch 48/50
# 6/6 [==============================] - 2s 304ms/step - loss: 0.0773 - accuracy: 0.9520 - precision: 0.9789 - recall: 0.9543 - val_loss: 0.1021 - val_accuracy: 0.9639 - val_precision: 0.9812 - val_recall: 0.9695
# Epoch 49/50
# 6/6 [==============================] - 2s 310ms/step - loss: 0.0779 - accuracy: 0.9552 - precision: 0.9816 - recall: 0.9565 - val_loss: 0.0955 - val_accuracy: 0.9668 - val_precision: 0.9838 - val_recall: 0.9707
# Epoch 50/50
# 6/6 [==============================] - 2s 299ms/step - loss: 0.0721 - accuracy: 0.9543 - precision: 0.9845 - recall: 0.9528 - val_loss: 0.1018 - val_accuracy: 0.9648 - val_precision: 0.9822 - val_recall: 0.9690
# 3/3 [==============================] - 56s 23s/step
# Learning Rate: 0.010395
# Hidden Units: 256
# Mini Batch:64
# AUC score: 0.9895889172109238
# Test Recall: 0.9552414605418139
# Test Precision: 0.9724220623501199
# Test F1 Scores: 0.9637551990493167
#
#
#
#
# Batch Size: 1024
# Hidden Units: 256
# Learning Rate: 0.010395
# Epoch 1/50
# 3/3 [==============================] - 55s 10s/step - loss: 0.5023 - accuracy: 0.6380 - precision: 0.8484 - recall: 0.6000 - val_loss: 1.3706 - val_accuracy: 0.8418 - val_precision: 0.9761 - val_recall: 0.7944
# Epoch 2/50
# 3/3 [==============================] - 1s 562ms/step - loss: 0.2423 - accuracy: 0.8472 - precision: 0.9717 - recall: 0.8227 - val_loss: 0.3921 - val_accuracy: 0.9219 - val_precision: 0.9059 - val_recall: 0.9946
# Epoch 3/50
# 3/3 [==============================] - 1s 541ms/step - loss: 0.1584 - accuracy: 0.9061 - precision: 0.9459 - recall: 0.9240 - val_loss: 0.3214 - val_accuracy: 0.9180 - val_precision: 0.9095 - val_recall: 0.9837
# Epoch 4/50
# 3/3 [==============================] - 1s 518ms/step - loss: 0.1439 - accuracy: 0.9128 - precision: 0.9625 - recall: 0.9159 - val_loss: 0.4351 - val_accuracy: 0.8789 - val_precision: 0.9906 - val_recall: 0.8422
# Epoch 5/50
# 3/3 [==============================] - 1s 517ms/step - loss: 0.1173 - accuracy: 0.9305 - precision: 0.9829 - recall: 0.9212 - val_loss: 0.8757 - val_accuracy: 0.8125 - val_precision: 0.9929 - val_recall: 0.7473
# Epoch 6/50
# 3/3 [==============================] - 1s 532ms/step - loss: 0.1056 - accuracy: 0.9305 - precision: 0.9825 - recall: 0.9211 - val_loss: 1.2931 - val_accuracy: 0.7520 - val_precision: 1.0000 - val_recall: 0.6604
# Epoch 7/50
# 3/3 [==============================] - 1s 507ms/step - loss: 0.1152 - accuracy: 0.9217 - precision: 0.9817 - recall: 0.9117 - val_loss: 0.9743 - val_accuracy: 0.8047 - val_precision: 0.9965 - val_recall: 0.7395
# Epoch 8/50
# 3/3 [==============================] - 1s 515ms/step - loss: 0.1098 - accuracy: 0.9275 - precision: 0.9708 - recall: 0.9274 - val_loss: 0.6446 - val_accuracy: 0.8457 - val_precision: 0.9966 - val_recall: 0.7898
# Epoch 9/50
# 3/3 [==============================] - 1s 512ms/step - loss: 0.1115 - accuracy: 0.9266 - precision: 0.9712 - recall: 0.9267 - val_loss: 0.3151 - val_accuracy: 0.9082 - val_precision: 0.9970 - val_recall: 0.8767
# Epoch 10/50
# 3/3 [==============================] - 1s 527ms/step - loss: 0.1052 - accuracy: 0.9338 - precision: 0.9791 - recall: 0.9305 - val_loss: 0.2276 - val_accuracy: 0.9160 - val_precision: 0.9909 - val_recall: 0.8907
# Epoch 11/50
# 3/3 [==============================] - 1s 557ms/step - loss: 0.1021 - accuracy: 0.9375 - precision: 0.9689 - recall: 0.9434 - val_loss: 0.2405 - val_accuracy: 0.9102 - val_precision: 0.9854 - val_recall: 0.8915
# Epoch 12/50
# 3/3 [==============================] - 1s 519ms/step - loss: 0.0959 - accuracy: 0.9434 - precision: 0.9843 - recall: 0.9386 - val_loss: 0.2579 - val_accuracy: 0.9023 - val_precision: 0.9880 - val_recall: 0.8770
# Epoch 13/50
# 3/3 [==============================] - 1s 526ms/step - loss: 0.1083 - accuracy: 0.9351 - precision: 0.9686 - recall: 0.9400 - val_loss: 0.2720 - val_accuracy: 0.9023 - val_precision: 0.9912 - val_recall: 0.8776
# Epoch 14/50
# 3/3 [==============================] - 1s 498ms/step - loss: 0.0902 - accuracy: 0.9386 - precision: 0.9829 - recall: 0.9341 - val_loss: 0.2350 - val_accuracy: 0.9160 - val_precision: 0.9823 - val_recall: 0.9000
# Epoch 15/50
# 3/3 [==============================] - 1s 505ms/step - loss: 0.1013 - accuracy: 0.9395 - precision: 0.9778 - recall: 0.9380 - val_loss: 0.2307 - val_accuracy: 0.9141 - val_precision: 0.9910 - val_recall: 0.8901
# Epoch 16/50
# 3/3 [==============================] - 1s 554ms/step - loss: 0.1038 - accuracy: 0.9330 - precision: 0.9831 - recall: 0.9250 - val_loss: 0.2252 - val_accuracy: 0.9160 - val_precision: 0.9881 - val_recall: 0.8952
# Epoch 17/50
# 3/3 [==============================] - 1s 513ms/step - loss: 0.0934 - accuracy: 0.9377 - precision: 0.9834 - recall: 0.9313 - val_loss: 0.2169 - val_accuracy: 0.9082 - val_precision: 0.9910 - val_recall: 0.8830
# Epoch 18/50
# 3/3 [==============================] - 1s 530ms/step - loss: 0.0934 - accuracy: 0.9447 - precision: 0.9774 - recall: 0.9460 - val_loss: 0.1832 - val_accuracy: 0.9277 - val_precision: 0.9860 - val_recall: 0.9164
# Epoch 19/50
# 3/3 [==============================] - 1s 567ms/step - loss: 0.1050 - accuracy: 0.9456 - precision: 0.9745 - recall: 0.9488 - val_loss: 0.1916 - val_accuracy: 0.9160 - val_precision: 0.9941 - val_recall: 0.8918
# Epoch 20/50
# 3/3 [==============================] - 1s 560ms/step - loss: 0.0865 - accuracy: 0.9451 - precision: 0.9773 - recall: 0.9464 - val_loss: 0.1807 - val_accuracy: 0.9199 - val_precision: 0.9854 - val_recall: 0.9035
# Epoch 21/50
# 3/3 [==============================] - 1s 521ms/step - loss: 0.1055 - accuracy: 0.9329 - precision: 0.9837 - recall: 0.9265 - val_loss: 0.2167 - val_accuracy: 0.9082 - val_precision: 0.9850 - val_recall: 0.8865
# Epoch 22/50
# 3/3 [==============================] - 1s 531ms/step - loss: 0.1107 - accuracy: 0.9348 - precision: 0.9655 - recall: 0.9431 - val_loss: 0.1739 - val_accuracy: 0.9238 - val_precision: 0.9912 - val_recall: 0.9040
# Epoch 23/50
# 3/3 [==============================] - 1s 590ms/step - loss: 0.0884 - accuracy: 0.9468 - precision: 0.9817 - recall: 0.9452 - val_loss: 0.1744 - val_accuracy: 0.9258 - val_precision: 0.9941 - val_recall: 0.9035
# Epoch 24/50
# 3/3 [==============================] - 1s 510ms/step - loss: 0.0915 - accuracy: 0.9449 - precision: 0.9772 - recall: 0.9458 - val_loss: 0.1618 - val_accuracy: 0.9297 - val_precision: 0.9884 - val_recall: 0.9144
# Epoch 25/50
# 3/3 [==============================] - 1s 520ms/step - loss: 0.0965 - accuracy: 0.9354 - precision: 0.9816 - recall: 0.9287 - val_loss: 0.1573 - val_accuracy: 0.9336 - val_precision: 0.9828 - val_recall: 0.9243
# Epoch 26/50
# 3/3 [==============================] - 1s 531ms/step - loss: 0.0895 - accuracy: 0.9383 - precision: 0.9776 - recall: 0.9384 - val_loss: 0.1461 - val_accuracy: 0.9297 - val_precision: 0.9882 - val_recall: 0.9126
# Epoch 27/50
# 3/3 [==============================] - 1s 561ms/step - loss: 0.0857 - accuracy: 0.9384 - precision: 0.9830 - recall: 0.9319 - val_loss: 0.1832 - val_accuracy: 0.9141 - val_precision: 0.9883 - val_recall: 0.8942
# Epoch 28/50
# 3/3 [==============================] - 1s 550ms/step - loss: 0.0702 - accuracy: 0.9513 - precision: 0.9874 - recall: 0.9464 - val_loss: 0.1577 - val_accuracy: 0.9258 - val_precision: 0.9909 - val_recall: 0.9030
# Epoch 29/50
# 3/3 [==============================] - 1s 488ms/step - loss: 0.0940 - accuracy: 0.9449 - precision: 0.9716 - recall: 0.9498 - val_loss: 0.1784 - val_accuracy: 0.9199 - val_precision: 0.9831 - val_recall: 0.9091
# Epoch 30/50
# 3/3 [==============================] - 1s 498ms/step - loss: 0.0867 - accuracy: 0.9473 - precision: 0.9819 - recall: 0.9451 - val_loss: 0.1835 - val_accuracy: 0.9141 - val_precision: 0.9912 - val_recall: 0.8912
# Epoch 31/50
# 3/3 [==============================] - 1s 492ms/step - loss: 0.0968 - accuracy: 0.9486 - precision: 0.9836 - recall: 0.9457 - val_loss: 0.1797 - val_accuracy: 0.9160 - val_precision: 0.9912 - val_recall: 0.8942
# Epoch 32/50
# 3/3 [==============================] - 1s 530ms/step - loss: 0.0835 - accuracy: 0.9506 - precision: 0.9790 - recall: 0.9533 - val_loss: 0.1747 - val_accuracy: 0.9219 - val_precision: 0.9914 - val_recall: 0.9029
# Epoch 33/50
# 3/3 [==============================] - 1s 500ms/step - loss: 0.0922 - accuracy: 0.9478 - precision: 0.9714 - recall: 0.9551 - val_loss: 0.1593 - val_accuracy: 0.9297 - val_precision: 0.9855 - val_recall: 0.9167
# Epoch 34/50
# 3/3 [==============================] - 1s 498ms/step - loss: 0.0882 - accuracy: 0.9390 - precision: 0.9844 - recall: 0.9331 - val_loss: 0.1657 - val_accuracy: 0.9160 - val_precision: 0.9887 - val_recall: 0.9000
# Epoch 35/50
# 3/3 [==============================] - 1s 504ms/step - loss: 0.0910 - accuracy: 0.9449 - precision: 0.9817 - recall: 0.9420 - val_loss: 0.1396 - val_accuracy: 0.9277 - val_precision: 0.9888 - val_recall: 0.9145
# Epoch 36/50
# 3/3 [==============================] - 1s 513ms/step - loss: 0.0930 - accuracy: 0.9416 - precision: 0.9794 - recall: 0.9395 - val_loss: 0.1696 - val_accuracy: 0.9238 - val_precision: 0.9854 - val_recall: 0.9084
# Epoch 37/50
# 3/3 [==============================] - 1s 511ms/step - loss: 0.0861 - accuracy: 0.9479 - precision: 0.9800 - recall: 0.9485 - val_loss: 0.1680 - val_accuracy: 0.9238 - val_precision: 0.9911 - val_recall: 0.9027
# Epoch 38/50
# 3/3 [==============================] - 1s 505ms/step - loss: 0.0791 - accuracy: 0.9466 - precision: 0.9814 - recall: 0.9440 - val_loss: 0.1725 - val_accuracy: 0.9258 - val_precision: 0.9888 - val_recall: 0.9119
# Epoch 39/50
# 3/3 [==============================] - 1s 556ms/step - loss: 0.0890 - accuracy: 0.9325 - precision: 0.9798 - recall: 0.9289 - val_loss: 0.1497 - val_accuracy: 0.9355 - val_precision: 0.9915 - val_recall: 0.9206
# Epoch 40/50
# 3/3 [==============================] - 1s 512ms/step - loss: 0.0880 - accuracy: 0.9490 - precision: 0.9805 - recall: 0.9484 - val_loss: 0.1371 - val_accuracy: 0.9375 - val_precision: 0.9797 - val_recall: 0.9309
# Epoch 41/50
# 3/3 [==============================] - 1s 539ms/step - loss: 0.0955 - accuracy: 0.9417 - precision: 0.9780 - recall: 0.9413 - val_loss: 0.1515 - val_accuracy: 0.9297 - val_precision: 0.9885 - val_recall: 0.9147
# Epoch 42/50
# 3/3 [==============================] - 1s 501ms/step - loss: 0.1019 - accuracy: 0.9351 - precision: 0.9797 - recall: 0.9318 - val_loss: 0.1500 - val_accuracy: 0.9199 - val_precision: 0.9910 - val_recall: 0.8970
# Epoch 43/50
# 3/3 [==============================] - 1s 499ms/step - loss: 0.0993 - accuracy: 0.9339 - precision: 0.9721 - recall: 0.9347 - val_loss: 0.1442 - val_accuracy: 0.9336 - val_precision: 0.9942 - val_recall: 0.9142
# Epoch 44/50
# 3/3 [==============================] - 1s 515ms/step - loss: 0.0936 - accuracy: 0.9376 - precision: 0.9817 - recall: 0.9326 - val_loss: 0.1401 - val_accuracy: 0.9258 - val_precision: 0.9912 - val_recall: 0.9057
# Epoch 45/50
# 3/3 [==============================] - 1s 544ms/step - loss: 0.0973 - accuracy: 0.9360 - precision: 0.9810 - recall: 0.9312 - val_loss: 0.1564 - val_accuracy: 0.9219 - val_precision: 0.9855 - val_recall: 0.9067
# Epoch 46/50
# 3/3 [==============================] - 1s 513ms/step - loss: 0.0835 - accuracy: 0.9482 - precision: 0.9864 - recall: 0.9434 - val_loss: 0.1370 - val_accuracy: 0.9316 - val_precision: 0.9914 - val_recall: 0.9156
# Epoch 47/50
# 3/3 [==============================] - 1s 531ms/step - loss: 0.0982 - accuracy: 0.9448 - precision: 0.9753 - recall: 0.9470 - val_loss: 0.1759 - val_accuracy: 0.9238 - val_precision: 0.9822 - val_recall: 0.9096
# Epoch 48/50
# 3/3 [==============================] - 1s 519ms/step - loss: 0.0856 - accuracy: 0.9520 - precision: 0.9849 - recall: 0.9494 - val_loss: 0.1289 - val_accuracy: 0.9336 - val_precision: 0.9884 - val_recall: 0.9191
# Epoch 49/50
# 3/3 [==============================] - 1s 521ms/step - loss: 0.0996 - accuracy: 0.9395 - precision: 0.9696 - recall: 0.9456 - val_loss: 0.1383 - val_accuracy: 0.9336 - val_precision: 0.9808 - val_recall: 0.9299
# Epoch 50/50
# 3/3 [==============================] - 1s 559ms/step - loss: 0.0900 - accuracy: 0.9412 - precision: 0.9882 - recall: 0.9325 - val_loss: 0.1280 - val_accuracy: 0.9336 - val_precision: 0.9886 - val_recall: 0.9206
# 2/2 [==============================] - 65s 60s/step
# Learning Rate: 0.010395
# Hidden Units: 256
# Mini Batch:128
# AUC score: 0.9886991434103862
# Test Recall: 0.9269729093050648
# Test Precision: 0.9812967581047382
# Test F1 Scores: 0.9533615990308903

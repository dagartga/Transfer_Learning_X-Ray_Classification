# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import tensorflow as tf
from kaggle_datasets import KaggleDatasets
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import re
import glob
import random
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import auc, roc_curve

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# 2023-01-22 23:47:49.481297: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib
# 2023-01-22 23:47:49.481433: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Device:', tpu.master())
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
except:
    strategy = tf.distribute.get_strategy()
print('Number of replicas:', strategy.num_replicas_in_sync)

print(tf.__version__)
# Out:
# Device: grpc://10.0.0.2:8470
# 2023-01-22 23:47:56.111744: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-01-22 23:47:56.114861: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib
# 2023-01-22 23:47:56.114903: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-01-22 23:47:56.114933: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (ea6904650748): /proc/driver/nvidia/version does not exist
# 2023-01-22 23:47:56.118423: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-22 23:47:56.120665: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-01-22 23:47:56.128510: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-01-22 23:47:56.161822: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job worker -> {0 -> 10.0.0.2:8470}
# 2023-01-22 23:47:56.161883: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job localhost -> {0 -> localhost:30020}
# 2023-01-22 23:47:56.180843: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job worker -> {0 -> 10.0.0.2:8470}
# 2023-01-22 23:47:56.180901: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job localhost -> {0 -> localhost:30020}
# 2023-01-22 23:47:56.182557: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:411] Started server with target: grpc://localhost:30020
# Number of replicas: 8
# 2.4.1

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
GCS_PATH = KaggleDatasets().get_gcs_path('chest-xray-pneumonia')
BATCH_SIZE = 64*strategy.num_replicas_in_sync
#BATCH_SIZE = 64 # for non-TPU use
IMAGE_SIZE = [180, 180]
EPOCHS = 50

# %%
filenames = tf.io.gfile.glob(str(GCS_PATH + '/chest_xray/train/*/*'))
filenames.extend(tf.io.gfile.glob(str(GCS_PATH + '/chest_xray/val/*/*')))
filenames.extend(tf.io.gfile.glob(str(GCS_PATH + '/chest_xray/test/*/*')))

print(f'The total number of files is {len(filenames)}')
# Out:
# 2023-01-22 23:48:01.327003: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-22 23:48:01.499640: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-22 23:48:01.641988: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-22 23:48:01.745065: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-22 23:48:01.870111: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-22 23:48:01.966881: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-22 23:48:02.059680: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# The total number of files is 5856
# 2023-01-22 23:48:02.128459: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.

# %%
# split the data into 60:40 for train:test+val
train_files, val_test_files = train_test_split(filenames, test_size=0.4,random_state=18)

# %%
# split the val_test_files to 50:50 to have a final split of 60:20:20 of train:val:test
val_files, test_files = train_test_split(val_test_files, test_size=0.5, random_state=18)

# %%
pct_df = pd.DataFrame(columns = ['data_set', 'label', 'pct'], index = range(6))

totals = {'train':len(train_files), 'val':len(val_files), 'test':len(test_files)}

val_pneum_count = 0
val_norm_count = 0

re_pattern = '.*/(NORMAL|PNEUMONIA)/.*'

for file in val_files:
    re_match = re.match(re_pattern, file)
    if re_match[1] == 'NORMAL':
        val_norm_count += 1
    else:
        val_pneum_count += 1

pct_df.iloc[0, :] = ['val', 'NORMAL', round(100* val_norm_count / totals['val'], 1)]
pct_df.iloc[1, :] = ['val', 'PNEUMONIA', round(100* val_pneum_count / totals['val'], 1)]


test_pneum_count = 0
test_norm_count = 0
for file in test_files:
    re_match = re.match(re_pattern, file)
    if re_match[1] == 'NORMAL':
        test_norm_count += 1
    else:
        test_pneum_count += 1

pct_df.iloc[2, :] = ['test', 'NORMAL', round(100* test_norm_count / totals['test'], 1)]
pct_df.iloc[3, :] = ['test', 'PNEUMONIA', round(100* test_pneum_count / totals['test'], 1)]

train_pneum_count = 0
train_norm_count = 0
for file in train_files:
    re_match = re.match(re_pattern, file)
    if re_match[1] == 'NORMAL':
        train_norm_count += 1
    else:
        train_pneum_count += 1

pct_df.iloc[4, :] = ['train', 'NORMAL', round(100* train_norm_count / totals['train'], 1)]
pct_df.iloc[5, :] = ['train', 'PNEUMONIA', round(100* train_pneum_count / totals['train'], 1)]

# %%
PNEUM_COUNT = val_pneum_count + train_pneum_count + test_pneum_count
NORMAL_COUNT = val_norm_count + train_norm_count + test_norm_count
print(f'Normal: {NORMAL_COUNT}\nPneumonia: {PNEUM_COUNT}')

pct_df
# Out:
# Normal: 1583
# Pneumonia: 4273
#   data_set      label   pct
# 0      val     NORMAL  26.9
# 1      val  PNEUMONIA  73.1
# 2     test     NORMAL  27.6
# 3     test  PNEUMONIA  72.4
# 4    train     NORMAL  26.9
# 5    train  PNEUMONIA  73.1

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_files)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_files)
test_list_ds = tf.data.Dataset.from_tensor_slices(test_files)

#view the file paths for training
print('----Training Files----')
for f in train_list_ds.take(5):
    print(f.numpy())
# Out:
# ----Training Files----
# b'gs://kds-f4cd5298952c835b370b10b65341d209198e57d812057e8ad9550752/chest_xray/train/PNEUMONIA/person509_virus_1025.jpeg'
# b'gs://kds-f4cd5298952c835b370b10b65341d209198e57d812057e8ad9550752/chest_xray/train/PNEUMONIA/person671_bacteria_2564.jpeg'
# b'gs://kds-f4cd5298952c835b370b10b65341d209198e57d812057e8ad9550752/chest_xray/train/PNEUMONIA/person957_virus_1629.jpeg'
# b'gs://kds-f4cd5298952c835b370b10b65341d209198e57d812057e8ad9550752/chest_xray/test/PNEUMONIA/person81_bacteria_397.jpeg'
# b'gs://kds-f4cd5298952c835b370b10b65341d209198e57d812057e8ad9550752/chest_xray/train/NORMAL/IM-0500-0001.jpeg'

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
TEST_IMG_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()

print(f'Train Image Count: {TRAIN_IMG_COUNT}\nVal Image Count: {VAL_IMG_COUNT}\nTest Image Count: {TEST_IMG_COUNT}')
# Out:
# Train Image Count: 3513
# Val Image Count: 1171
# Test Image Count: 1172
# 2023-01-22 23:48:02.365984: W ./tensorflow/core/distributed_runtime/eager/destroy_tensor_handle_node.h:57] Ignoring an error encountered when deleting remote tensors handles: Invalid argument: Unable to find the relevant tensor remote_handle: Op ID: 28, Output num: 0
# Additional GRPC error information from remote target /job:worker/replica:0/task:0:
# :{"created":"@1674431282.362325318","description":"Error received from peer ipv4:10.0.0.2:8470","file":"external/com_github_grpc_grpc/src/core/lib/surface/call.cc","file_line":1056,"grpc_message":"Unable to find the relevant tensor remote_handle: Op ID: 28, Output num: 0","grpc_status":3}

# %%
# will label as 1 if pneumonia otherwise 0
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == 'PNEUMONIA'

def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    return tf.image.resize(img, IMAGE_SIZE)

def process_path(file_path):
    label = get_label(file_path)
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
y_train = []
for image, label in train_ds.take(TRAIN_IMG_COUNT):
    y_train.append(label)
    
print('Training Counts')
print(f'Pneumonia count: {np.sum(y_train)}\nNormal count: {TRAIN_IMG_COUNT - np.sum(y_train)}')
# Out:
# Training Counts
# 2023-01-22 23:50:04.064198: W ./tensorflow/core/distributed_runtime/eager/destroy_tensor_handle_node.h:57] Ignoring an error encountered when deleting remote tensors handles: Invalid argument: Unable to find the relevant tensor remote_handle: Op ID: 3562, Output num: 0
# Additional GRPC error information from remote target /job:worker/replica:0/task:0:
# :{"created":"@1674431404.064121403","description":"Error received from peer ipv4:10.0.0.2:8470","file":"external/com_github_grpc_grpc/src/core/lib/surface/call.cc","file_line":1056,"grpc_message":"Unable to find the relevant tensor remote_handle: Op ID: 3562, Output num: 0","grpc_status":3}
# Pneumonia count: 2568
# Normal count: 945

# %%
y_val = []
for image, label in val_ds.take(VAL_IMG_COUNT):
    y_val.append(label)
    
print('Validation Counts')
print(f'Pneumonia count: {np.sum(y_val)}\nNormal count: {VAL_IMG_COUNT - np.sum(y_val)}')
# Out:
# Validation Counts
# 2023-01-22 23:51:07.939833: W ./tensorflow/core/distributed_runtime/eager/destroy_tensor_handle_node.h:57] Ignoring an error encountered when deleting remote tensors handles: Invalid argument: Unable to find the relevant tensor remote_handle: Op ID: 18796, Output num: 0
# Additional GRPC error information from remote target /job:worker/replica:0/task:0:
# :{"created":"@1674431467.939718556","description":"Error received from peer ipv4:10.0.0.2:8470","file":"external/com_github_grpc_grpc/src/core/lib/surface/call.cc","file_line":1056,"grpc_message":"Unable to find the relevant tensor remote_handle: Op ID: 18796, Output num: 0","grpc_status":3}
# Pneumonia count: 856
# Normal count: 315

# %%
y_test = []
for image, label in test_ds.take(TEST_IMG_COUNT):
    y_test.append(label)
    
print('Test Counts')
print(f'Pneumonia count: {np.sum(y_test)}\nNormal count: {TEST_IMG_COUNT - np.sum(y_test)}')
# Out:
# Test Counts
# Pneumonia count: 849
# Normal count: 323

# %%
def prepare_for_training(ds, cache=True, shuffle_buffer_size=1000):
    
    if cache:
        if isinstance(cache, str):
            ds = ds.cache(cache)
        else:
            ds = ds.cache()
            
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    
    ds = ds.repeat()
    
    ds = ds.batch(BATCH_SIZE)
    
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    
    return ds

# %%
train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %%
weight_for_0 = (1 / NORMAL_COUNT)*(TRAIN_IMG_COUNT)/2.0
weight_for_1 = (1 / PNEUM_COUNT)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}
print(f'Weight for class 0: {weight_for_0:.2f}')
print(f'Weight for class 1: {weight_for_1:.2f}')
# Out:
# Weight for class 0: 1.11
# Weight for class 1: 0.41

# %%
# create some metrics for comparing on test results

def precision(y_test, y_pred):
    tp, fp = 0, 0
    
    for i in range(len(y_test)):
        if y_test[i] >= 0.5 and y_pred[i] >= 0.5:
            tp += 1
        elif y_test[i] < 0.5 and y_pred[i] >= 0.5:
            fp += 1
            
    return tp / (tp + fp)

def recall(y_test, y_pred):
    tp, fn = 0, 0
    
    for i in range(len(y_test)):
        if y_test[i] >= 0.5 and y_pred[i] >= 0.5:
            tp += 1
        elif y_test[i] >= 0.5 and y_pred[i] < 0.5:
            fn += 1
            
    return tp / (tp + fn)

def f1_score(y_test, y_pred):
    numerator = precision(y_test, y_pred) * recall(y_test, y_pred)
    denominator = precision(y_test, y_pred) + recall(y_test, y_pred)
    
    return 2 * (numerator / denominator)

# %%
# add exponential decay to try to improve fine tuning
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 ** (epoch / s)
    return exponential_decay_fn

# %% [markdown]
# ## Search Momentum, Learning Rate, Exponential Decay parameters in combinations
# #### Using Model Architecture 1 Dense Trainable layer of 4096 and batch size of 32*8

# %%
# use learning rate that gave best results in the learning rate hyperparameter tuning
lr = 0.010395
# use hidden_units that gave best results in the hidden units hyperparameter tuning
hidden_units = 4096
# use mini batch size that gave best results in the mini batch hyperparameter tuning
mini_batch = 32
# use the s value for the learning rate decay that was best
s = 34
# momentum that was best before
momentum = 0.82



# try 16 different combinations of hyperparameters
for _ in range(16):
    
    # learning rate random range from 0.01 to 0.1
    r = random.randint(10, 20)
    lr = 10 ** (- r / 10 )
    
    # choose from one of five different momentums
    momentum_list = [ 0.76, 0.78, 0.80, 0.82, 0.84]
    mom_ind = random.randint(0, 4)
    momentum = momentum_list[mom_ind]
    
    # choose a learning rate decay s value between 25 and 40
    s = random.randint(25, 40)
    
    BATCH_SIZE = mini_batch*strategy.num_replicas_in_sync
    print(f'\n\nBatch Size: {BATCH_SIZE}')    
    print(f'Hidden Units: {hidden_units}')
    print(f'Learning Rate: {lr}')
    print(f'1 Hidden Layer, {hidden_units} units')
    print(f'S value: {s}')
    print(f'Momentum: {momentum}')
    
    with strategy.scope():
        
        base_model = tf.keras.applications.densenet.DenseNet201(
                        input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3),
                        include_top=False,
                        weights='imagenet'
                        )
        base_model.trainable = False
        
        
        
        x=base_model.output
        inputs = tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))
        x = base_model(inputs, training=False)
        x = tf.keras.layers.GlobalAveragePooling2D()(x)
        x = tf.keras.layers.Dropout(0.3)(x)
        x = tf.keras.layers.Dense(hidden_units, activation='relu')(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.Dropout(0.3)(x)
            
        outputs = tf.keras.layers.Dense(1, activation='sigmoid')(x)
        model = tf.keras.Model(inputs, outputs)
        
        METRICS = [
                'accuracy',
                tf.keras.metrics.Precision(name='precision'),
                tf.keras.metrics.Recall(name='recall')
                ]
        
        opt = tf.keras.optimizers.Adam(learning_rate=lr, beta_1=momentum)
        
        model.compile(
                    optimizer=opt,
                    loss='binary_crossentropy',
                    metrics=METRICS
                     )
    
       
        checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(f"densenet_{lr}_{hidden_units}_{BATCH_SIZE}_1layer_{s}_{momentum}_xray_model.h5", save_best_only=True)
        early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=20, restore_best_weights=True)
        exponential_decay_fn = exponential_decay(lr, s)
        lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)
    
        history = model.fit(
                            train_ds,
                            steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
                            epochs=EPOCHS,
                            validation_data=val_ds,
                            validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
                            class_weight=class_weight,
                            callbacks=[checkpoint_cb, early_stopping_cb, lr_scheduler]
                            )
        
        
        
        test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
        test_ds = test_ds.batch(BATCH_SIZE)
                    
        y_preds = model.predict(test_ds, batch_size = BATCH_SIZE, verbose = True)
        y_preds = y_preds.reshape(-1)
        y_actual = [1 if x == True else 0 for x in y_test]
        
        print(f'\n\nBatch Size: {BATCH_SIZE}')    
        print(f'Hidden Units: {hidden_units}')
        print(f'Learning Rate: {lr}')
        print(f'1 Hidden Layer, {hidden_units} units')
        print(f'S value: {s}')
        print(f'Momentum: {momentum}')
        
        fpr, tpr, thresholds = roc_curve(y_actual, y_preds, pos_label=1)
        print(f'AUC score: {auc(fpr, tpr)}')
               
        print(f'Test Recall: {recall(y_actual, y_preds)}')
        print(f'Test Precision: {precision(y_actual, y_preds)}')
        print(f'Test F1 Scores: {f1_score(y_actual, y_preds)}\n\n')

        
        # print the visualization of the different training metrics
        fig, ax = plt.subplots(1, 4, figsize=(20, 3))
        ax = ax.ravel()
        
        print(f"densenet_{lr}_{hidden_units}_{BATCH_SIZE}_1layer_{s}_{momentum}_xray_model")
        for i, metric in enumerate(['precision', 'recall', 'accuracy', 'loss']):
            ax[i].plot(history.history[metric])
            ax[i].plot(history.history['val_'+metric])
            ax[i].set_title(f'Model {metric}')
            ax[i].set_xlabel('epochs')
            ax[i].set_ylabel(metric)
            ax[i].legend(['train', 'val'])
# Out:
# Batch Size: 256
# Hidden Units: 4096
# Learning Rate: 0.05011872336272722
# 1 Hidden Layer, 4096 units
# S value: 34
# Momentum: 0.78
# Epoch 1/50
# 13/13 [==============================] - 53s 2s/step - loss: 3.7873 - accuracy: 0.7387 - precision: 0.8911 - recall: 0.7285 - val_loss: 11.1381 - val_accuracy: 0.8677 - val_precision: 0.9927 - val_recall: 0.8243
# Epoch 2/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.7726 - accuracy: 0.9183 - precision: 0.9691 - recall: 0.9174 - val_loss: 1.5053 - val_accuracy: 0.9087 - val_precision: 0.9933 - val_recall: 0.8821
# Epoch 3/50
# 13/13 [==============================] - 3s 231ms/step - loss: 0.3288 - accuracy: 0.9201 - precision: 0.9773 - recall: 0.9134 - val_loss: 0.9538 - val_accuracy: 0.8901 - val_precision: 0.8696 - val_recall: 1.0000
# Epoch 4/50
# 13/13 [==============================] - 3s 230ms/step - loss: 0.1595 - accuracy: 0.9255 - precision: 0.9714 - recall: 0.9250 - val_loss: 0.4115 - val_accuracy: 0.9395 - val_precision: 0.9859 - val_recall: 0.9309
# Epoch 5/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.4214 - accuracy: 0.9098 - precision: 0.9707 - recall: 0.9042 - val_loss: 1.8081 - val_accuracy: 0.8911 - val_precision: 0.9969 - val_recall: 0.8541
# Epoch 6/50
# 13/13 [==============================] - 3s 227ms/step - loss: 0.3250 - accuracy: 0.9263 - precision: 0.9772 - recall: 0.9198 - val_loss: 0.3349 - val_accuracy: 0.9131 - val_precision: 0.9918 - val_recall: 0.8890
# Epoch 7/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.1305 - accuracy: 0.9336 - precision: 0.9800 - recall: 0.9279 - val_loss: 0.3810 - val_accuracy: 0.9248 - val_precision: 0.9107 - val_recall: 0.9947
# Epoch 8/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.1634 - accuracy: 0.9281 - precision: 0.9686 - recall: 0.9319 - val_loss: 0.7065 - val_accuracy: 0.8823 - val_precision: 0.9922 - val_recall: 0.8459
# Epoch 9/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.1471 - accuracy: 0.9319 - precision: 0.9779 - recall: 0.9272 - val_loss: 0.2299 - val_accuracy: 0.9302 - val_precision: 0.9927 - val_recall: 0.9111
# Epoch 10/50
# 13/13 [==============================] - 3s 227ms/step - loss: 0.1037 - accuracy: 0.9469 - precision: 0.9795 - recall: 0.9470 - val_loss: 0.3326 - val_accuracy: 0.9004 - val_precision: 0.9939 - val_recall: 0.8689
# Epoch 11/50
# 13/13 [==============================] - 3s 228ms/step - loss: 0.0858 - accuracy: 0.9435 - precision: 0.9824 - recall: 0.9395 - val_loss: 0.1131 - val_accuracy: 0.9668 - val_precision: 0.9690 - val_recall: 0.9859
# Epoch 12/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.1143 - accuracy: 0.9437 - precision: 0.9780 - recall: 0.9437 - val_loss: 0.1045 - val_accuracy: 0.9658 - val_precision: 0.9851 - val_recall: 0.9680
# Epoch 13/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0833 - accuracy: 0.9435 - precision: 0.9851 - recall: 0.9375 - val_loss: 0.1068 - val_accuracy: 0.9644 - val_precision: 0.9793 - val_recall: 0.9721
# Epoch 14/50
# 13/13 [==============================] - 3s 229ms/step - loss: 0.0684 - accuracy: 0.9533 - precision: 0.9885 - recall: 0.9474 - val_loss: 0.0902 - val_accuracy: 0.9644 - val_precision: 0.9666 - val_recall: 0.9853
# Epoch 15/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0748 - accuracy: 0.9488 - precision: 0.9834 - recall: 0.9465 - val_loss: 0.1014 - val_accuracy: 0.9595 - val_precision: 0.9567 - val_recall: 0.9893
# Epoch 16/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0655 - accuracy: 0.9594 - precision: 0.9869 - recall: 0.9578 - val_loss: 0.0910 - val_accuracy: 0.9688 - val_precision: 0.9755 - val_recall: 0.9820
# Epoch 17/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0643 - accuracy: 0.9556 - precision: 0.9863 - recall: 0.9528 - val_loss: 0.1113 - val_accuracy: 0.9580 - val_precision: 0.9604 - val_recall: 0.9834
# Epoch 18/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0681 - accuracy: 0.9581 - precision: 0.9851 - recall: 0.9569 - val_loss: 0.0951 - val_accuracy: 0.9619 - val_precision: 0.9652 - val_recall: 0.9833
# Epoch 19/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0667 - accuracy: 0.9572 - precision: 0.9824 - recall: 0.9585 - val_loss: 0.1375 - val_accuracy: 0.9487 - val_precision: 0.9936 - val_recall: 0.9360
# Epoch 20/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0640 - accuracy: 0.9592 - precision: 0.9868 - recall: 0.9569 - val_loss: 0.1236 - val_accuracy: 0.9551 - val_precision: 0.9840 - val_recall: 0.9536
# Epoch 21/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0705 - accuracy: 0.9548 - precision: 0.9846 - recall: 0.9532 - val_loss: 0.0967 - val_accuracy: 0.9629 - val_precision: 0.9837 - val_recall: 0.9653
# Epoch 22/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0626 - accuracy: 0.9574 - precision: 0.9858 - recall: 0.9559 - val_loss: 0.0872 - val_accuracy: 0.9678 - val_precision: 0.9798 - val_recall: 0.9759
# Epoch 23/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0557 - accuracy: 0.9639 - precision: 0.9885 - recall: 0.9622 - val_loss: 0.0808 - val_accuracy: 0.9692 - val_precision: 0.9722 - val_recall: 0.9859
# Epoch 24/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0591 - accuracy: 0.9639 - precision: 0.9868 - recall: 0.9636 - val_loss: 0.0864 - val_accuracy: 0.9658 - val_precision: 0.9753 - val_recall: 0.9780
# Epoch 25/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0564 - accuracy: 0.9622 - precision: 0.9889 - recall: 0.9591 - val_loss: 0.0847 - val_accuracy: 0.9692 - val_precision: 0.9754 - val_recall: 0.9826
# Epoch 26/50
# 13/13 [==============================] - 3s 214ms/step - loss: 0.0640 - accuracy: 0.9570 - precision: 0.9843 - recall: 0.9566 - val_loss: 0.0900 - val_accuracy: 0.9683 - val_precision: 0.9760 - val_recall: 0.9806
# Epoch 27/50
# 13/13 [==============================] - 3s 215ms/step - loss: 0.0586 - accuracy: 0.9611 - precision: 0.9856 - recall: 0.9604 - val_loss: 0.0884 - val_accuracy: 0.9678 - val_precision: 0.9774 - val_recall: 0.9787
# Epoch 28/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0628 - accuracy: 0.9623 - precision: 0.9896 - recall: 0.9588 - val_loss: 0.0807 - val_accuracy: 0.9692 - val_precision: 0.9792 - val_recall: 0.9786
# Epoch 29/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0555 - accuracy: 0.9655 - precision: 0.9867 - recall: 0.9655 - val_loss: 0.0863 - val_accuracy: 0.9702 - val_precision: 0.9826 - val_recall: 0.9767
# Epoch 30/50
# 13/13 [==============================] - 3s 234ms/step - loss: 0.0563 - accuracy: 0.9634 - precision: 0.9918 - recall: 0.9580 - val_loss: 0.0916 - val_accuracy: 0.9673 - val_precision: 0.9697 - val_recall: 0.9859
# Epoch 31/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0532 - accuracy: 0.9697 - precision: 0.9888 - recall: 0.9697 - val_loss: 0.0959 - val_accuracy: 0.9673 - val_precision: 0.9755 - val_recall: 0.9800
# Epoch 32/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0488 - accuracy: 0.9685 - precision: 0.9891 - recall: 0.9677 - val_loss: 0.0878 - val_accuracy: 0.9673 - val_precision: 0.9735 - val_recall: 0.9820
# Epoch 33/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0505 - accuracy: 0.9676 - precision: 0.9893 - recall: 0.9664 - val_loss: 0.0951 - val_accuracy: 0.9692 - val_precision: 0.9819 - val_recall: 0.9760
# Epoch 34/50
# 13/13 [==============================] - 3s 214ms/step - loss: 0.0507 - accuracy: 0.9658 - precision: 0.9906 - recall: 0.9623 - val_loss: 0.0907 - val_accuracy: 0.9634 - val_precision: 0.9656 - val_recall: 0.9854
# Epoch 35/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0518 - accuracy: 0.9681 - precision: 0.9889 - recall: 0.9673 - val_loss: 0.0865 - val_accuracy: 0.9663 - val_precision: 0.9652 - val_recall: 0.9892
# Epoch 36/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0519 - accuracy: 0.9702 - precision: 0.9869 - recall: 0.9715 - val_loss: 0.0864 - val_accuracy: 0.9648 - val_precision: 0.9779 - val_recall: 0.9740
# Epoch 37/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0476 - accuracy: 0.9653 - precision: 0.9920 - recall: 0.9602 - val_loss: 0.0820 - val_accuracy: 0.9673 - val_precision: 0.9704 - val_recall: 0.9853
# Epoch 38/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0504 - accuracy: 0.9696 - precision: 0.9888 - recall: 0.9693 - val_loss: 0.0794 - val_accuracy: 0.9702 - val_precision: 0.9761 - val_recall: 0.9833
# Epoch 39/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0545 - accuracy: 0.9660 - precision: 0.9883 - recall: 0.9648 - val_loss: 0.0833 - val_accuracy: 0.9668 - val_precision: 0.9691 - val_recall: 0.9860
# Epoch 40/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0521 - accuracy: 0.9638 - precision: 0.9883 - recall: 0.9622 - val_loss: 0.0799 - val_accuracy: 0.9692 - val_precision: 0.9712 - val_recall: 0.9873
# Epoch 41/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0528 - accuracy: 0.9665 - precision: 0.9864 - recall: 0.9675 - val_loss: 0.0779 - val_accuracy: 0.9731 - val_precision: 0.9808 - val_recall: 0.9828
# Epoch 42/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0437 - accuracy: 0.9721 - precision: 0.9935 - recall: 0.9683 - val_loss: 0.0834 - val_accuracy: 0.9722 - val_precision: 0.9794 - val_recall: 0.9827
# Epoch 43/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0432 - accuracy: 0.9712 - precision: 0.9912 - recall: 0.9693 - val_loss: 0.0800 - val_accuracy: 0.9707 - val_precision: 0.9747 - val_recall: 0.9852
# Epoch 44/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0470 - accuracy: 0.9718 - precision: 0.9910 - recall: 0.9699 - val_loss: 0.0777 - val_accuracy: 0.9746 - val_precision: 0.9775 - val_recall: 0.9880
# Epoch 45/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0416 - accuracy: 0.9710 - precision: 0.9902 - recall: 0.9700 - val_loss: 0.0814 - val_accuracy: 0.9712 - val_precision: 0.9772 - val_recall: 0.9831
# Epoch 46/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0474 - accuracy: 0.9723 - precision: 0.9873 - recall: 0.9745 - val_loss: 0.0785 - val_accuracy: 0.9712 - val_precision: 0.9800 - val_recall: 0.9807
# Epoch 47/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0467 - accuracy: 0.9691 - precision: 0.9887 - recall: 0.9685 - val_loss: 0.0785 - val_accuracy: 0.9717 - val_precision: 0.9768 - val_recall: 0.9847
# Epoch 48/50
# 13/13 [==============================] - 3s 229ms/step - loss: 0.0446 - accuracy: 0.9738 - precision: 0.9909 - recall: 0.9731 - val_loss: 0.0824 - val_accuracy: 0.9688 - val_precision: 0.9754 - val_recall: 0.9819
# Epoch 49/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0414 - accuracy: 0.9733 - precision: 0.9924 - recall: 0.9710 - val_loss: 0.0735 - val_accuracy: 0.9741 - val_precision: 0.9799 - val_recall: 0.9846
# Epoch 50/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0405 - accuracy: 0.9718 - precision: 0.9917 - recall: 0.9693 - val_loss: 0.0810 - val_accuracy: 0.9712 - val_precision: 0.9792 - val_recall: 0.9812
# 5/5 [==============================] - 49s 11s/step
#
#
# Batch Size: 256
# Hidden Units: 4096
# Learning Rate: 0.05011872336272722
# 1 Hidden Layer, 4096 units
# S value: 34
# Momentum: 0.78
# AUC score: 0.9891422070036868
# Test Recall: 0.9705535924617197
# Test Precision: 0.9682726204465335
# Test F1 Scores: 0.9694117647058824
#
#
# densenet_0.05011872336272722_4096_256_1layer_34_0.78_xray_model
#
#
# Batch Size: 256
# Hidden Units: 4096
# Learning Rate: 0.07943282347242814
# 1 Hidden Layer, 4096 units
# S value: 29
# Momentum: 0.78
# Epoch 1/50
# 13/13 [==============================] - 54s 2s/step - loss: 7.9605 - accuracy: 0.7292 - precision: 0.8752 - recall: 0.7295 - val_loss: 180.4491 - val_accuracy: 0.5264 - val_precision: 1.0000 - val_recall: 0.3507
# Epoch 2/50
# 13/13 [==============================] - 3s 230ms/step - loss: 2.6062 - accuracy: 0.9198 - precision: 0.9606 - recall: 0.9290 - val_loss: 14.6982 - val_accuracy: 0.7944 - val_precision: 1.0000 - val_recall: 0.7182
# Epoch 3/50
# 13/13 [==============================] - 3s 234ms/step - loss: 0.8220 - accuracy: 0.9238 - precision: 0.9745 - recall: 0.9212 - val_loss: 1.9409 - val_accuracy: 0.8848 - val_precision: 0.9984 - val_recall: 0.8437
# Epoch 4/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.4054 - accuracy: 0.9264 - precision: 0.9759 - recall: 0.9235 - val_loss: 3.5276 - val_accuracy: 0.8232 - val_precision: 0.8053 - val_recall: 1.0000
# Epoch 5/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.3659 - accuracy: 0.9291 - precision: 0.9701 - recall: 0.9324 - val_loss: 1.6128 - val_accuracy: 0.8530 - val_precision: 0.8345 - val_recall: 0.9973
# Epoch 6/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.2225 - accuracy: 0.9333 - precision: 0.9768 - recall: 0.9320 - val_loss: 0.3124 - val_accuracy: 0.9326 - val_precision: 0.9920 - val_recall: 0.9151
# Epoch 7/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.1325 - accuracy: 0.9436 - precision: 0.9785 - recall: 0.9435 - val_loss: 0.1988 - val_accuracy: 0.9604 - val_precision: 0.9622 - val_recall: 0.9847
# Epoch 8/50
# 13/13 [==============================] - 3s 228ms/step - loss: 0.1325 - accuracy: 0.9365 - precision: 0.9782 - recall: 0.9334 - val_loss: 0.2441 - val_accuracy: 0.9482 - val_precision: 0.9425 - val_recall: 0.9893
# Epoch 9/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.1271 - accuracy: 0.9352 - precision: 0.9745 - recall: 0.9350 - val_loss: 1.1425 - val_accuracy: 0.8403 - val_precision: 0.8203 - val_recall: 1.0000
# Epoch 10/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.1209 - accuracy: 0.9444 - precision: 0.9760 - recall: 0.9467 - val_loss: 0.1831 - val_accuracy: 0.9556 - val_precision: 0.9561 - val_recall: 0.9838
# Epoch 11/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.1761 - accuracy: 0.9322 - precision: 0.9741 - recall: 0.9319 - val_loss: 0.2687 - val_accuracy: 0.9380 - val_precision: 0.9224 - val_recall: 0.9987
# Epoch 12/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.1272 - accuracy: 0.9438 - precision: 0.9749 - recall: 0.9487 - val_loss: 0.7481 - val_accuracy: 0.8428 - val_precision: 0.8233 - val_recall: 0.9987
# Epoch 13/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.1050 - accuracy: 0.9461 - precision: 0.9745 - recall: 0.9512 - val_loss: 0.1665 - val_accuracy: 0.9482 - val_precision: 0.9399 - val_recall: 0.9934
# Epoch 14/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0917 - accuracy: 0.9438 - precision: 0.9821 - recall: 0.9403 - val_loss: 0.2531 - val_accuracy: 0.9355 - val_precision: 0.9192 - val_recall: 0.9993
# Epoch 15/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0847 - accuracy: 0.9510 - precision: 0.9826 - recall: 0.9494 - val_loss: 0.1396 - val_accuracy: 0.9565 - val_precision: 0.9496 - val_recall: 0.9933
# Epoch 16/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0925 - accuracy: 0.9405 - precision: 0.9873 - recall: 0.9318 - val_loss: 0.2496 - val_accuracy: 0.9487 - val_precision: 0.9441 - val_recall: 0.9887
# Epoch 17/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0859 - accuracy: 0.9541 - precision: 0.9824 - recall: 0.9540 - val_loss: 0.1912 - val_accuracy: 0.9448 - val_precision: 0.9298 - val_recall: 1.0000
# Epoch 18/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0745 - accuracy: 0.9558 - precision: 0.9838 - recall: 0.9550 - val_loss: 0.3249 - val_accuracy: 0.9014 - val_precision: 0.8817 - val_recall: 1.0000
# Epoch 19/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0716 - accuracy: 0.9566 - precision: 0.9816 - recall: 0.9583 - val_loss: 0.2890 - val_accuracy: 0.9087 - val_precision: 0.8892 - val_recall: 1.0000
# Epoch 20/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0838 - accuracy: 0.9537 - precision: 0.9785 - recall: 0.9572 - val_loss: 0.2029 - val_accuracy: 0.9316 - val_precision: 0.9149 - val_recall: 1.0000
# Epoch 21/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0645 - accuracy: 0.9611 - precision: 0.9839 - recall: 0.9621 - val_loss: 0.1199 - val_accuracy: 0.9546 - val_precision: 0.9471 - val_recall: 0.9933
# Epoch 22/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0673 - accuracy: 0.9600 - precision: 0.9900 - recall: 0.9551 - val_loss: 0.1288 - val_accuracy: 0.9536 - val_precision: 0.9449 - val_recall: 0.9947
# Epoch 23/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0654 - accuracy: 0.9549 - precision: 0.9870 - recall: 0.9516 - val_loss: 0.1160 - val_accuracy: 0.9561 - val_precision: 0.9485 - val_recall: 0.9940
# Epoch 24/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0719 - accuracy: 0.9561 - precision: 0.9837 - recall: 0.9553 - val_loss: 0.1381 - val_accuracy: 0.9473 - val_precision: 0.9355 - val_recall: 0.9967
# Epoch 25/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0591 - accuracy: 0.9653 - precision: 0.9885 - recall: 0.9639 - val_loss: 0.1331 - val_accuracy: 0.9531 - val_precision: 0.9446 - val_recall: 0.9940
# Epoch 26/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0553 - accuracy: 0.9617 - precision: 0.9872 - recall: 0.9600 - val_loss: 0.1553 - val_accuracy: 0.9424 - val_precision: 0.9289 - val_recall: 0.9980
# Epoch 27/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0616 - accuracy: 0.9633 - precision: 0.9828 - recall: 0.9666 - val_loss: 0.1264 - val_accuracy: 0.9546 - val_precision: 0.9434 - val_recall: 0.9973
# Epoch 28/50
# 13/13 [==============================] - 3s 232ms/step - loss: 0.0534 - accuracy: 0.9640 - precision: 0.9875 - recall: 0.9628 - val_loss: 0.0966 - val_accuracy: 0.9614 - val_precision: 0.9640 - val_recall: 0.9840
# Epoch 29/50
# 13/13 [==============================] - 3s 235ms/step - loss: 0.0628 - accuracy: 0.9602 - precision: 0.9853 - recall: 0.9597 - val_loss: 0.0928 - val_accuracy: 0.9614 - val_precision: 0.9643 - val_recall: 0.9841
# Epoch 30/50
# 13/13 [==============================] - 3s 237ms/step - loss: 0.0581 - accuracy: 0.9627 - precision: 0.9856 - recall: 0.9630 - val_loss: 0.0934 - val_accuracy: 0.9653 - val_precision: 0.9677 - val_recall: 0.9853
# Epoch 31/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0495 - accuracy: 0.9705 - precision: 0.9912 - recall: 0.9680 - val_loss: 0.0985 - val_accuracy: 0.9585 - val_precision: 0.9560 - val_recall: 0.9886
# Epoch 32/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0612 - accuracy: 0.9607 - precision: 0.9862 - recall: 0.9596 - val_loss: 0.0932 - val_accuracy: 0.9644 - val_precision: 0.9690 - val_recall: 0.9826
# Epoch 33/50
# 13/13 [==============================] - 3s 229ms/step - loss: 0.0490 - accuracy: 0.9686 - precision: 0.9892 - recall: 0.9676 - val_loss: 0.0917 - val_accuracy: 0.9624 - val_precision: 0.9665 - val_recall: 0.9826
# Epoch 34/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0533 - accuracy: 0.9656 - precision: 0.9883 - recall: 0.9644 - val_loss: 0.0915 - val_accuracy: 0.9609 - val_precision: 0.9630 - val_recall: 0.9847
# Epoch 35/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0532 - accuracy: 0.9673 - precision: 0.9884 - recall: 0.9668 - val_loss: 0.0836 - val_accuracy: 0.9653 - val_precision: 0.9686 - val_recall: 0.9847
# Epoch 36/50
# 13/13 [==============================] - 3s 238ms/step - loss: 0.0513 - accuracy: 0.9665 - precision: 0.9888 - recall: 0.9648 - val_loss: 0.0838 - val_accuracy: 0.9717 - val_precision: 0.9788 - val_recall: 0.9827
# Epoch 37/50
# 13/13 [==============================] - 3s 229ms/step - loss: 0.0487 - accuracy: 0.9665 - precision: 0.9915 - recall: 0.9626 - val_loss: 0.0924 - val_accuracy: 0.9673 - val_precision: 0.9724 - val_recall: 0.9834
# Epoch 38/50
# 13/13 [==============================] - 3s 227ms/step - loss: 0.0536 - accuracy: 0.9674 - precision: 0.9875 - recall: 0.9674 - val_loss: 0.0781 - val_accuracy: 0.9702 - val_precision: 0.9736 - val_recall: 0.9860
# Epoch 39/50
# 13/13 [==============================] - 4s 352ms/step - loss: 0.0515 - accuracy: 0.9673 - precision: 0.9882 - recall: 0.9668 - val_loss: 0.0821 - val_accuracy: 0.9673 - val_precision: 0.9742 - val_recall: 0.9813
# Epoch 40/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0475 - accuracy: 0.9696 - precision: 0.9904 - recall: 0.9680 - val_loss: 0.0814 - val_accuracy: 0.9692 - val_precision: 0.9709 - val_recall: 0.9872
# Epoch 41/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0493 - accuracy: 0.9698 - precision: 0.9895 - recall: 0.9689 - val_loss: 0.0835 - val_accuracy: 0.9712 - val_precision: 0.9766 - val_recall: 0.9838
# Epoch 42/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0445 - accuracy: 0.9684 - precision: 0.9927 - recall: 0.9640 - val_loss: 0.0873 - val_accuracy: 0.9673 - val_precision: 0.9728 - val_recall: 0.9826
# Epoch 43/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0456 - accuracy: 0.9722 - precision: 0.9920 - recall: 0.9698 - val_loss: 0.0838 - val_accuracy: 0.9697 - val_precision: 0.9746 - val_recall: 0.9838
# Epoch 44/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0516 - accuracy: 0.9660 - precision: 0.9875 - recall: 0.9658 - val_loss: 0.0900 - val_accuracy: 0.9653 - val_precision: 0.9709 - val_recall: 0.9819
# Epoch 45/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0472 - accuracy: 0.9709 - precision: 0.9891 - recall: 0.9708 - val_loss: 0.0799 - val_accuracy: 0.9722 - val_precision: 0.9795 - val_recall: 0.9828
# Epoch 46/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0491 - accuracy: 0.9714 - precision: 0.9918 - recall: 0.9687 - val_loss: 0.0892 - val_accuracy: 0.9688 - val_precision: 0.9767 - val_recall: 0.9807
# Epoch 47/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0483 - accuracy: 0.9686 - precision: 0.9893 - recall: 0.9676 - val_loss: 0.0861 - val_accuracy: 0.9697 - val_precision: 0.9766 - val_recall: 0.9819
# Epoch 48/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0505 - accuracy: 0.9685 - precision: 0.9887 - recall: 0.9678 - val_loss: 0.0822 - val_accuracy: 0.9717 - val_precision: 0.9799 - val_recall: 0.9812
# Epoch 49/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0458 - accuracy: 0.9713 - precision: 0.9918 - recall: 0.9686 - val_loss: 0.0887 - val_accuracy: 0.9702 - val_precision: 0.9775 - val_recall: 0.9820
# Epoch 50/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0501 - accuracy: 0.9655 - precision: 0.9873 - recall: 0.9650 - val_loss: 0.0816 - val_accuracy: 0.9707 - val_precision: 0.9793 - val_recall: 0.9806
# 5/5 [==============================] - 48s 11s/step
#
#
# Batch Size: 256
# Hidden Units: 4096
# Learning Rate: 0.07943282347242814
# 1 Hidden Layer, 4096 units
# S value: 29
# Momentum: 0.78
# AUC score: 0.9895232781600645
# Test Recall: 0.9705535924617197
# Test Precision: 0.9728453364817001
# Test F1 Scores: 0.9716981132075472
#
#
# densenet_0.07943282347242814_4096_256_1layer_29_0.78_xray_model
#
#
# Batch Size: 256
# Hidden Units: 4096
# Learning Rate: 0.012589254117941675
# 1 Hidden Layer, 4096 units
# S value: 39
# Momentum: 0.76
# Epoch 1/50
# 13/13 [==============================] - 56s 2s/step - loss: 0.8300 - accuracy: 0.7829 - precision: 0.9293 - recall: 0.7581 - val_loss: 6.0529 - val_accuracy: 0.6279 - val_precision: 1.0000 - val_recall: 0.4960
# Epoch 2/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.1816 - accuracy: 0.9174 - precision: 0.9684 - recall: 0.9168 - val_loss: 1.8127 - val_accuracy: 0.7773 - val_precision: 0.9990 - val_recall: 0.6940
# Epoch 3/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.1247 - accuracy: 0.9269 - precision: 0.9759 - recall: 0.9235 - val_loss: 0.5764 - val_accuracy: 0.8828 - val_precision: 0.8624 - val_recall: 1.0000
# Epoch 4/50
# 13/13 [==============================] - 3s 227ms/step - loss: 0.1276 - accuracy: 0.9302 - precision: 0.9723 - recall: 0.9314 - val_loss: 0.2730 - val_accuracy: 0.9141 - val_precision: 0.9005 - val_recall: 0.9920
# Epoch 5/50
# 13/13 [==============================] - 3s 231ms/step - loss: 0.0952 - accuracy: 0.9486 - precision: 0.9774 - recall: 0.9521 - val_loss: 0.4422 - val_accuracy: 0.9077 - val_precision: 0.9940 - val_recall: 0.8793
# Epoch 6/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0971 - accuracy: 0.9398 - precision: 0.9815 - recall: 0.9360 - val_loss: 0.2437 - val_accuracy: 0.9214 - val_precision: 0.9919 - val_recall: 0.8995
# Epoch 7/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0825 - accuracy: 0.9474 - precision: 0.9785 - recall: 0.9488 - val_loss: 0.2923 - val_accuracy: 0.9238 - val_precision: 0.9847 - val_recall: 0.9091
# Epoch 8/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0933 - accuracy: 0.9417 - precision: 0.9788 - recall: 0.9404 - val_loss: 0.1015 - val_accuracy: 0.9653 - val_precision: 0.9838 - val_recall: 0.9687
# Epoch 9/50
# 13/13 [==============================] - 3s 230ms/step - loss: 0.0813 - accuracy: 0.9483 - precision: 0.9801 - recall: 0.9480 - val_loss: 0.0970 - val_accuracy: 0.9585 - val_precision: 0.9636 - val_recall: 0.9798
# Epoch 10/50
# 13/13 [==============================] - 3s 228ms/step - loss: 0.0711 - accuracy: 0.9528 - precision: 0.9829 - recall: 0.9521 - val_loss: 0.0997 - val_accuracy: 0.9595 - val_precision: 0.9870 - val_recall: 0.9574
# Epoch 11/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0692 - accuracy: 0.9518 - precision: 0.9848 - recall: 0.9489 - val_loss: 0.0806 - val_accuracy: 0.9712 - val_precision: 0.9793 - val_recall: 0.9813
# Epoch 12/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0625 - accuracy: 0.9588 - precision: 0.9819 - recall: 0.9611 - val_loss: 0.2047 - val_accuracy: 0.9248 - val_precision: 0.9934 - val_recall: 0.9031
# Epoch 13/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0739 - accuracy: 0.9549 - precision: 0.9846 - recall: 0.9535 - val_loss: 0.0928 - val_accuracy: 0.9653 - val_precision: 0.9691 - val_recall: 0.9840
# Epoch 14/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0730 - accuracy: 0.9533 - precision: 0.9857 - recall: 0.9502 - val_loss: 0.0811 - val_accuracy: 0.9678 - val_precision: 0.9735 - val_recall: 0.9826
# Epoch 15/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0604 - accuracy: 0.9609 - precision: 0.9865 - recall: 0.9599 - val_loss: 0.1077 - val_accuracy: 0.9644 - val_precision: 0.9719 - val_recall: 0.9791
# Epoch 16/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0650 - accuracy: 0.9596 - precision: 0.9885 - recall: 0.9559 - val_loss: 0.0834 - val_accuracy: 0.9639 - val_precision: 0.9667 - val_recall: 0.9847
# Epoch 17/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0622 - accuracy: 0.9609 - precision: 0.9873 - recall: 0.9589 - val_loss: 0.0897 - val_accuracy: 0.9639 - val_precision: 0.9657 - val_recall: 0.9852
# Epoch 18/50
# 13/13 [==============================] - 3s 229ms/step - loss: 0.0582 - accuracy: 0.9596 - precision: 0.9888 - recall: 0.9559 - val_loss: 0.0816 - val_accuracy: 0.9707 - val_precision: 0.9813 - val_recall: 0.9787
# Epoch 19/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0583 - accuracy: 0.9629 - precision: 0.9885 - recall: 0.9605 - val_loss: 0.0889 - val_accuracy: 0.9658 - val_precision: 0.9811 - val_recall: 0.9719
# Epoch 20/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0613 - accuracy: 0.9622 - precision: 0.9859 - recall: 0.9619 - val_loss: 0.0801 - val_accuracy: 0.9692 - val_precision: 0.9754 - val_recall: 0.9826
# Epoch 21/50
# 13/13 [==============================] - 3s 230ms/step - loss: 0.0525 - accuracy: 0.9683 - precision: 0.9886 - recall: 0.9680 - val_loss: 0.0770 - val_accuracy: 0.9688 - val_precision: 0.9754 - val_recall: 0.9819
# Epoch 22/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0611 - accuracy: 0.9611 - precision: 0.9852 - recall: 0.9613 - val_loss: 0.0810 - val_accuracy: 0.9722 - val_precision: 0.9839 - val_recall: 0.9780
# Epoch 23/50
# 13/13 [==============================] - 3s 228ms/step - loss: 0.0577 - accuracy: 0.9638 - precision: 0.9886 - recall: 0.9615 - val_loss: 0.0975 - val_accuracy: 0.9629 - val_precision: 0.9714 - val_recall: 0.9779
# Epoch 24/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0603 - accuracy: 0.9611 - precision: 0.9839 - recall: 0.9626 - val_loss: 0.0836 - val_accuracy: 0.9668 - val_precision: 0.9734 - val_recall: 0.9812
# Epoch 25/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0606 - accuracy: 0.9613 - precision: 0.9846 - recall: 0.9615 - val_loss: 0.0843 - val_accuracy: 0.9644 - val_precision: 0.9665 - val_recall: 0.9853
# Epoch 26/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0475 - accuracy: 0.9707 - precision: 0.9894 - recall: 0.9701 - val_loss: 0.0935 - val_accuracy: 0.9639 - val_precision: 0.9703 - val_recall: 0.9807
# Epoch 27/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0578 - accuracy: 0.9621 - precision: 0.9830 - recall: 0.9646 - val_loss: 0.0782 - val_accuracy: 0.9727 - val_precision: 0.9774 - val_recall: 0.9852
# Epoch 28/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0540 - accuracy: 0.9666 - precision: 0.9869 - recall: 0.9674 - val_loss: 0.0802 - val_accuracy: 0.9731 - val_precision: 0.9813 - val_recall: 0.9820
# Epoch 29/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0480 - accuracy: 0.9704 - precision: 0.9901 - recall: 0.9692 - val_loss: 0.0786 - val_accuracy: 0.9712 - val_precision: 0.9782 - val_recall: 0.9827
# Epoch 30/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0445 - accuracy: 0.9734 - precision: 0.9921 - recall: 0.9714 - val_loss: 0.0796 - val_accuracy: 0.9692 - val_precision: 0.9744 - val_recall: 0.9841
# Epoch 31/50
# 13/13 [==============================] - 3s 213ms/step - loss: 0.0455 - accuracy: 0.9669 - precision: 0.9893 - recall: 0.9654 - val_loss: 0.0731 - val_accuracy: 0.9731 - val_precision: 0.9808 - val_recall: 0.9828
# Epoch 32/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0468 - accuracy: 0.9716 - precision: 0.9910 - recall: 0.9701 - val_loss: 0.0837 - val_accuracy: 0.9692 - val_precision: 0.9721 - val_recall: 0.9858
# Epoch 33/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0434 - accuracy: 0.9715 - precision: 0.9902 - recall: 0.9706 - val_loss: 0.0788 - val_accuracy: 0.9707 - val_precision: 0.9787 - val_recall: 0.9813
# Epoch 34/50
# 13/13 [==============================] - 3s 212ms/step - loss: 0.0433 - accuracy: 0.9694 - precision: 0.9941 - recall: 0.9643 - val_loss: 0.0821 - val_accuracy: 0.9707 - val_precision: 0.9840 - val_recall: 0.9761
# Epoch 35/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0395 - accuracy: 0.9704 - precision: 0.9920 - recall: 0.9675 - val_loss: 0.0758 - val_accuracy: 0.9707 - val_precision: 0.9750 - val_recall: 0.9854
# Epoch 36/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0483 - accuracy: 0.9686 - precision: 0.9892 - recall: 0.9677 - val_loss: 0.0780 - val_accuracy: 0.9727 - val_precision: 0.9818 - val_recall: 0.9805
# Epoch 37/50
# 13/13 [==============================] - 3s 215ms/step - loss: 0.0461 - accuracy: 0.9702 - precision: 0.9917 - recall: 0.9675 - val_loss: 0.0757 - val_accuracy: 0.9727 - val_precision: 0.9781 - val_recall: 0.9847
# Epoch 38/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0458 - accuracy: 0.9714 - precision: 0.9920 - recall: 0.9689 - val_loss: 0.0799 - val_accuracy: 0.9717 - val_precision: 0.9832 - val_recall: 0.9780
# Epoch 39/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0407 - accuracy: 0.9737 - precision: 0.9896 - recall: 0.9741 - val_loss: 0.0801 - val_accuracy: 0.9722 - val_precision: 0.9787 - val_recall: 0.9833
# Epoch 40/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0386 - accuracy: 0.9744 - precision: 0.9918 - recall: 0.9732 - val_loss: 0.0786 - val_accuracy: 0.9678 - val_precision: 0.9712 - val_recall: 0.9854
# Epoch 41/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0394 - accuracy: 0.9768 - precision: 0.9925 - recall: 0.9757 - val_loss: 0.0754 - val_accuracy: 0.9712 - val_precision: 0.9775 - val_recall: 0.9834
# Epoch 42/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0343 - accuracy: 0.9786 - precision: 0.9948 - recall: 0.9758 - val_loss: 0.0746 - val_accuracy: 0.9741 - val_precision: 0.9807 - val_recall: 0.9840
# Epoch 43/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0370 - accuracy: 0.9724 - precision: 0.9918 - recall: 0.9709 - val_loss: 0.0822 - val_accuracy: 0.9712 - val_precision: 0.9811 - val_recall: 0.9792
# Epoch 44/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0377 - accuracy: 0.9743 - precision: 0.9929 - recall: 0.9718 - val_loss: 0.0796 - val_accuracy: 0.9722 - val_precision: 0.9780 - val_recall: 0.9839
# Epoch 45/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0354 - accuracy: 0.9784 - precision: 0.9935 - recall: 0.9768 - val_loss: 0.0786 - val_accuracy: 0.9717 - val_precision: 0.9788 - val_recall: 0.9827
# Epoch 46/50
# 13/13 [==============================] - 3s 213ms/step - loss: 0.0397 - accuracy: 0.9762 - precision: 0.9909 - recall: 0.9760 - val_loss: 0.0716 - val_accuracy: 0.9736 - val_precision: 0.9807 - val_recall: 0.9833
# Epoch 47/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0370 - accuracy: 0.9764 - precision: 0.9922 - recall: 0.9754 - val_loss: 0.0846 - val_accuracy: 0.9731 - val_precision: 0.9858 - val_recall: 0.9772
# Epoch 48/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0351 - accuracy: 0.9783 - precision: 0.9943 - recall: 0.9759 - val_loss: 0.0846 - val_accuracy: 0.9712 - val_precision: 0.9832 - val_recall: 0.9773
# Epoch 49/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0406 - accuracy: 0.9754 - precision: 0.9914 - recall: 0.9749 - val_loss: 0.0868 - val_accuracy: 0.9736 - val_precision: 0.9839 - val_recall: 0.9799
# Epoch 50/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0346 - accuracy: 0.9785 - precision: 0.9932 - recall: 0.9772 - val_loss: 0.0819 - val_accuracy: 0.9722 - val_precision: 0.9806 - val_recall: 0.9813
# 5/5 [==============================] - 49s 11s/step
#
#
# Batch Size: 256
# Hidden Units: 4096
# Learning Rate: 0.012589254117941675
# 1 Hidden Layer, 4096 units
# S value: 39
# Momentum: 0.76
# AUC score: 0.9889070004047741
# Test Recall: 0.9658421672555948
# Test Precision: 0.9738717339667459
# Test F1 Scores: 0.9698403311649911
#
#
# densenet_0.012589254117941675_4096_256_1layer_39_0.76_xray_model
#
#
# Batch Size: 256
# Hidden Units: 4096
# Learning Rate: 0.0199526231496888
# 1 Hidden Layer, 4096 units
# S value: 35
# Momentum: 0.8
# Epoch 1/50
# 13/13 [==============================] - 56s 2s/step - loss: 0.8849 - accuracy: 0.7852 - precision: 0.9174 - recall: 0.7734 - val_loss: 0.8796 - val_accuracy: 0.9321 - val_precision: 0.9717 - val_recall: 0.9349
# Epoch 2/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.2644 - accuracy: 0.9216 - precision: 0.9604 - recall: 0.9303 - val_loss: 2.3067 - val_accuracy: 0.7588 - val_precision: 1.0000 - val_recall: 0.6696
# Epoch 3/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.1352 - accuracy: 0.9267 - precision: 0.9745 - recall: 0.9255 - val_loss: 0.5456 - val_accuracy: 0.9248 - val_precision: 0.9848 - val_recall: 0.9110
# Epoch 4/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.1476 - accuracy: 0.9277 - precision: 0.9759 - recall: 0.9241 - val_loss: 0.1236 - val_accuracy: 0.9648 - val_precision: 0.9708 - val_recall: 0.9812
# Epoch 5/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.1891 - accuracy: 0.9142 - precision: 0.9626 - recall: 0.9186 - val_loss: 0.5523 - val_accuracy: 0.8984 - val_precision: 0.9923 - val_recall: 0.8675
# Epoch 6/50
# 13/13 [==============================] - 4s 279ms/step - loss: 0.1072 - accuracy: 0.9484 - precision: 0.9810 - recall: 0.9475 - val_loss: 0.1320 - val_accuracy: 0.9541 - val_precision: 0.9895 - val_recall: 0.9473
# Epoch 7/50
# 13/13 [==============================] - 3s 230ms/step - loss: 0.0930 - accuracy: 0.9440 - precision: 0.9771 - recall: 0.9456 - val_loss: 0.1207 - val_accuracy: 0.9570 - val_precision: 0.9513 - val_recall: 0.9920
# Epoch 8/50
# 13/13 [==============================] - 3s 228ms/step - loss: 0.0871 - accuracy: 0.9487 - precision: 0.9726 - recall: 0.9557 - val_loss: 0.1803 - val_accuracy: 0.9409 - val_precision: 0.9845 - val_recall: 0.9338
# Epoch 9/50
# 13/13 [==============================] - 3s 228ms/step - loss: 0.0768 - accuracy: 0.9541 - precision: 0.9856 - recall: 0.9509 - val_loss: 0.1201 - val_accuracy: 0.9521 - val_precision: 0.9827 - val_recall: 0.9511
# Epoch 10/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0801 - accuracy: 0.9526 - precision: 0.9825 - recall: 0.9520 - val_loss: 0.1180 - val_accuracy: 0.9565 - val_precision: 0.9599 - val_recall: 0.9812
# Epoch 11/50
# 13/13 [==============================] - 3s 231ms/step - loss: 0.0969 - accuracy: 0.9463 - precision: 0.9723 - recall: 0.9532 - val_loss: 0.2395 - val_accuracy: 0.9185 - val_precision: 0.9897 - val_recall: 0.8975
# Epoch 12/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0751 - accuracy: 0.9514 - precision: 0.9848 - recall: 0.9483 - val_loss: 0.4630 - val_accuracy: 0.8921 - val_precision: 0.9930 - val_recall: 0.8577
# Epoch 13/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0789 - accuracy: 0.9527 - precision: 0.9854 - recall: 0.9494 - val_loss: 0.0856 - val_accuracy: 0.9658 - val_precision: 0.9793 - val_recall: 0.9741
# Epoch 14/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0613 - accuracy: 0.9616 - precision: 0.9859 - recall: 0.9617 - val_loss: 0.0968 - val_accuracy: 0.9580 - val_precision: 0.9530 - val_recall: 0.9913
# Epoch 15/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0692 - accuracy: 0.9628 - precision: 0.9838 - recall: 0.9649 - val_loss: 0.0825 - val_accuracy: 0.9702 - val_precision: 0.9769 - val_recall: 0.9827
# Epoch 16/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0688 - accuracy: 0.9555 - precision: 0.9819 - recall: 0.9569 - val_loss: 0.1321 - val_accuracy: 0.9502 - val_precision: 0.9923 - val_recall: 0.9393
# Epoch 17/50
# 13/13 [==============================] - 3s 228ms/step - loss: 0.0585 - accuracy: 0.9624 - precision: 0.9888 - recall: 0.9594 - val_loss: 0.0880 - val_accuracy: 0.9658 - val_precision: 0.9883 - val_recall: 0.9644
# Epoch 18/50
# 13/13 [==============================] - 3s 228ms/step - loss: 0.0592 - accuracy: 0.9623 - precision: 0.9866 - recall: 0.9609 - val_loss: 0.0837 - val_accuracy: 0.9697 - val_precision: 0.9775 - val_recall: 0.9814
# Epoch 19/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0601 - accuracy: 0.9627 - precision: 0.9871 - recall: 0.9614 - val_loss: 0.1018 - val_accuracy: 0.9570 - val_precision: 0.9538 - val_recall: 0.9893
# Epoch 20/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0601 - accuracy: 0.9648 - precision: 0.9844 - recall: 0.9671 - val_loss: 0.0853 - val_accuracy: 0.9673 - val_precision: 0.9765 - val_recall: 0.9785
# Epoch 21/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0573 - accuracy: 0.9644 - precision: 0.9849 - recall: 0.9663 - val_loss: 0.0838 - val_accuracy: 0.9653 - val_precision: 0.9752 - val_recall: 0.9772
# Epoch 22/50
# 13/13 [==============================] - 3s 213ms/step - loss: 0.0548 - accuracy: 0.9658 - precision: 0.9868 - recall: 0.9665 - val_loss: 0.0848 - val_accuracy: 0.9653 - val_precision: 0.9742 - val_recall: 0.9787
# Epoch 23/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0488 - accuracy: 0.9679 - precision: 0.9884 - recall: 0.9677 - val_loss: 0.0759 - val_accuracy: 0.9683 - val_precision: 0.9685 - val_recall: 0.9895
# Epoch 24/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0453 - accuracy: 0.9705 - precision: 0.9911 - recall: 0.9686 - val_loss: 0.1210 - val_accuracy: 0.9507 - val_precision: 0.9419 - val_recall: 0.9940
# Epoch 25/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0475 - accuracy: 0.9701 - precision: 0.9892 - recall: 0.9699 - val_loss: 0.0824 - val_accuracy: 0.9692 - val_precision: 0.9730 - val_recall: 0.9853
# Epoch 26/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0490 - accuracy: 0.9649 - precision: 0.9885 - recall: 0.9629 - val_loss: 0.0770 - val_accuracy: 0.9678 - val_precision: 0.9793 - val_recall: 0.9767
# Epoch 27/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0513 - accuracy: 0.9654 - precision: 0.9856 - recall: 0.9668 - val_loss: 0.1026 - val_accuracy: 0.9624 - val_precision: 0.9850 - val_recall: 0.9634
# Epoch 28/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0494 - accuracy: 0.9670 - precision: 0.9904 - recall: 0.9640 - val_loss: 0.0778 - val_accuracy: 0.9658 - val_precision: 0.9747 - val_recall: 0.9786
# Epoch 29/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0456 - accuracy: 0.9707 - precision: 0.9897 - recall: 0.9696 - val_loss: 0.0855 - val_accuracy: 0.9697 - val_precision: 0.9780 - val_recall: 0.9807
# Epoch 30/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0441 - accuracy: 0.9758 - precision: 0.9925 - recall: 0.9744 - val_loss: 0.0822 - val_accuracy: 0.9663 - val_precision: 0.9699 - val_recall: 0.9847
# Epoch 31/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0408 - accuracy: 0.9759 - precision: 0.9910 - recall: 0.9760 - val_loss: 0.0780 - val_accuracy: 0.9697 - val_precision: 0.9743 - val_recall: 0.9847
# Epoch 32/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0404 - accuracy: 0.9749 - precision: 0.9916 - recall: 0.9742 - val_loss: 0.0787 - val_accuracy: 0.9717 - val_precision: 0.9774 - val_recall: 0.9839
# Epoch 33/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0401 - accuracy: 0.9746 - precision: 0.9918 - recall: 0.9736 - val_loss: 0.0833 - val_accuracy: 0.9663 - val_precision: 0.9722 - val_recall: 0.9819
# Epoch 34/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0371 - accuracy: 0.9769 - precision: 0.9912 - recall: 0.9773 - val_loss: 0.0814 - val_accuracy: 0.9668 - val_precision: 0.9804 - val_recall: 0.9739
# Epoch 35/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0410 - accuracy: 0.9744 - precision: 0.9933 - recall: 0.9716 - val_loss: 0.0790 - val_accuracy: 0.9697 - val_precision: 0.9723 - val_recall: 0.9866
# Epoch 36/50
# 13/13 [==============================] - 3s 213ms/step - loss: 0.0401 - accuracy: 0.9754 - precision: 0.9887 - recall: 0.9774 - val_loss: 0.0809 - val_accuracy: 0.9707 - val_precision: 0.9812 - val_recall: 0.9786
# Epoch 37/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0384 - accuracy: 0.9765 - precision: 0.9912 - recall: 0.9765 - val_loss: 0.0772 - val_accuracy: 0.9688 - val_precision: 0.9780 - val_recall: 0.9793
# Epoch 38/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0361 - accuracy: 0.9770 - precision: 0.9922 - recall: 0.9762 - val_loss: 0.0803 - val_accuracy: 0.9678 - val_precision: 0.9758 - val_recall: 0.9798
# Epoch 39/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0333 - accuracy: 0.9807 - precision: 0.9933 - recall: 0.9800 - val_loss: 0.0718 - val_accuracy: 0.9707 - val_precision: 0.9754 - val_recall: 0.9845
# Epoch 40/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0369 - accuracy: 0.9776 - precision: 0.9905 - recall: 0.9787 - val_loss: 0.0772 - val_accuracy: 0.9717 - val_precision: 0.9787 - val_recall: 0.9826
# Epoch 41/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0338 - accuracy: 0.9796 - precision: 0.9927 - recall: 0.9793 - val_loss: 0.0751 - val_accuracy: 0.9688 - val_precision: 0.9741 - val_recall: 0.9833
# Epoch 42/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0314 - accuracy: 0.9816 - precision: 0.9937 - recall: 0.9810 - val_loss: 0.0757 - val_accuracy: 0.9692 - val_precision: 0.9801 - val_recall: 0.9782
# Epoch 43/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0348 - accuracy: 0.9772 - precision: 0.9927 - recall: 0.9759 - val_loss: 0.0738 - val_accuracy: 0.9707 - val_precision: 0.9749 - val_recall: 0.9853
# Epoch 44/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0322 - accuracy: 0.9805 - precision: 0.9942 - recall: 0.9793 - val_loss: 0.0737 - val_accuracy: 0.9697 - val_precision: 0.9799 - val_recall: 0.9786
# Epoch 45/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0339 - accuracy: 0.9765 - precision: 0.9958 - recall: 0.9720 - val_loss: 0.0746 - val_accuracy: 0.9707 - val_precision: 0.9775 - val_recall: 0.9827
# Epoch 46/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0363 - accuracy: 0.9815 - precision: 0.9917 - recall: 0.9827 - val_loss: 0.0750 - val_accuracy: 0.9678 - val_precision: 0.9767 - val_recall: 0.9793
# Epoch 47/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0315 - accuracy: 0.9824 - precision: 0.9933 - recall: 0.9825 - val_loss: 0.0792 - val_accuracy: 0.9727 - val_precision: 0.9819 - val_recall: 0.9806
# Epoch 48/50
# 13/13 [==============================] - 3s 229ms/step - loss: 0.0334 - accuracy: 0.9808 - precision: 0.9928 - recall: 0.9807 - val_loss: 0.0830 - val_accuracy: 0.9702 - val_precision: 0.9839 - val_recall: 0.9753
# Epoch 49/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0366 - accuracy: 0.9766 - precision: 0.9923 - recall: 0.9757 - val_loss: 0.0856 - val_accuracy: 0.9692 - val_precision: 0.9820 - val_recall: 0.9761
# Epoch 50/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0306 - accuracy: 0.9827 - precision: 0.9957 - recall: 0.9805 - val_loss: 0.0798 - val_accuracy: 0.9702 - val_precision: 0.9800 - val_recall: 0.9794
# 5/5 [==============================] - 49s 11s/step
#
#
# Batch Size: 256
# Hidden Units: 4096
# Learning Rate: 0.0199526231496888
# 1 Hidden Layer, 4096 units
# S value: 35
# Momentum: 0.8
# AUC score: 0.988465760118442
# Test Recall: 0.9646643109540636
# Test Precision: 0.9738406658739596
# Test F1 Scores: 0.9692307692307692
#
#
# densenet_0.0199526231496888_4096_256_1layer_35_0.8_xray_model
#
#
# Batch Size: 256
# Hidden Units: 4096
# Learning Rate: 0.07943282347242814
# 1 Hidden Layer, 4096 units
# S value: 37
# Momentum: 0.78
# Epoch 1/50
# 13/13 [==============================] - 53s 2s/step - loss: 8.0825 - accuracy: 0.7033 - precision: 0.8555 - recall: 0.7081 - val_loss: 46.6231 - val_accuracy: 0.8096 - val_precision: 0.9937 - val_recall: 0.7431
# Epoch 2/50
# 13/13 [==============================] - 3s 224ms/step - loss: 2.1312 - accuracy: 0.9240 - precision: 0.9649 - recall: 0.9299 - val_loss: 40.5729 - val_accuracy: 0.3662 - val_precision: 1.0000 - val_recall: 0.1335
# Epoch 3/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.4743 - accuracy: 0.9221 - precision: 0.9734 - recall: 0.9195 - val_loss: 10.2087 - val_accuracy: 0.7446 - val_precision: 0.7433 - val_recall: 0.9987
# Epoch 4/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.8146 - accuracy: 0.9052 - precision: 0.9502 - recall: 0.9192 - val_loss: 1.5016 - val_accuracy: 0.8726 - val_precision: 0.8524 - val_recall: 0.9987
# Epoch 5/50
# ...
# Epoch 34/50
# 13/13 [==============================] - 3s 237ms/step - loss: 0.0401 - accuracy: 0.9735 - precision: 0.9902 - recall: 0.9735 - val_loss: 0.0779 - val_accuracy: 0.9697 - val_precision: 0.9774 - val_recall: 0.9813
# Epoch 35/50
# 13/13 [==============================] - 3s 229ms/step - loss: 0.0444 - accuracy: 0.9695 - precision: 0.9888 - recall: 0.9693 - val_loss: 0.0844 - val_accuracy: 0.9663 - val_precision: 0.9732 - val_recall: 0.9815
# Epoch 36/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0384 - accuracy: 0.9766 - precision: 0.9915 - recall: 0.9762 - val_loss: 0.0767 - val_accuracy: 0.9697 - val_precision: 0.9743 - val_recall: 0.9847
# Epoch 37/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0440 - accuracy: 0.9747 - precision: 0.9916 - recall: 0.9733 - val_loss: 0.0770 - val_accuracy: 0.9683 - val_precision: 0.9736 - val_recall: 0.9834
# Epoch 38/50
# 13/13 [==============================] - 3s 228ms/step - loss: 0.0402 - accuracy: 0.9736 - precision: 0.9907 - recall: 0.9730 - val_loss: 0.0794 - val_accuracy: 0.9683 - val_precision: 0.9722 - val_recall: 0.9846
# Epoch 39/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0370 - accuracy: 0.9772 - precision: 0.9920 - recall: 0.9766 - val_loss: 0.0798 - val_accuracy: 0.9688 - val_precision: 0.9794 - val_recall: 0.9781
# Epoch 40/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0379 - accuracy: 0.9761 - precision: 0.9944 - recall: 0.9728 - val_loss: 0.0854 - val_accuracy: 0.9707 - val_precision: 0.9749 - val_recall: 0.9853
# Epoch 41/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0353 - accuracy: 0.9775 - precision: 0.9908 - recall: 0.9782 - val_loss: 0.0874 - val_accuracy: 0.9668 - val_precision: 0.9799 - val_recall: 0.9747
# Epoch 42/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0384 - accuracy: 0.9737 - precision: 0.9924 - recall: 0.9717 - val_loss: 0.0863 - val_accuracy: 0.9688 - val_precision: 0.9747 - val_recall: 0.9825
# Epoch 43/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0356 - accuracy: 0.9769 - precision: 0.9924 - recall: 0.9762 - val_loss: 0.0823 - val_accuracy: 0.9678 - val_precision: 0.9791 - val_recall: 0.9765
# Epoch 44/50
# 13/13 [==============================] - 3s 227ms/step - loss: 0.0369 - accuracy: 0.9780 - precision: 0.9925 - recall: 0.9771 - val_loss: 0.0855 - val_accuracy: 0.9683 - val_precision: 0.9787 - val_recall: 0.9780
# Epoch 45/50
# 13/13 [==============================] - 3s 228ms/step - loss: 0.0375 - accuracy: 0.9775 - precision: 0.9935 - recall: 0.9756 - val_loss: 0.0800 - val_accuracy: 0.9707 - val_precision: 0.9747 - val_recall: 0.9852
# Epoch 46/50
# 13/13 [==============================] - 3s 229ms/step - loss: 0.0376 - accuracy: 0.9780 - precision: 0.9917 - recall: 0.9780 - val_loss: 0.0803 - val_accuracy: 0.9727 - val_precision: 0.9801 - val_recall: 0.9827
# Epoch 47/50
# 13/13 [==============================] - 3s 228ms/step - loss: 0.0439 - accuracy: 0.9726 - precision: 0.9890 - recall: 0.9730 - val_loss: 0.0835 - val_accuracy: 0.9673 - val_precision: 0.9805 - val_recall: 0.9747
# Epoch 48/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0380 - accuracy: 0.9783 - precision: 0.9928 - recall: 0.9773 - val_loss: 0.0852 - val_accuracy: 0.9673 - val_precision: 0.9787 - val_recall: 0.9768
# Epoch 49/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0359 - accuracy: 0.9750 - precision: 0.9938 - recall: 0.9720 - val_loss: 0.0832 - val_accuracy: 0.9683 - val_precision: 0.9793 - val_recall: 0.9774
# Epoch 50/50
# 13/13 [==============================] - 3s 228ms/step - loss: 0.0324 - accuracy: 0.9789 - precision: 0.9930 - recall: 0.9779 - val_loss: 0.0798 - val_accuracy: 0.9673 - val_precision: 0.9805 - val_recall: 0.9745
# 5/5 [==============================] - 51s 11s/step
#
#
# Batch Size: 256
# Hidden Units: 4096
# Learning Rate: 0.012589254117941675
# 1 Hidden Layer, 4096 units
# S value: 34
# Momentum: 0.82
# AUC score: 0.9900848567063054
# Test Recall: 0.9646643109540636
# Test Precision: 0.9715302491103203
# Test F1 Scores: 0.9680851063829787
#
#
# densenet_0.012589254117941675_4096_256_1layer_34_0.82_xray_model
#
#
# Batch Size: 256
# Hidden Units: 4096
# Learning Rate: 0.05011872336272722
# 1 Hidden Layer, 4096 units
# S value: 35
# Momentum: 0.78
# Epoch 1/50
# 13/13 [==============================] - 55s 2s/step - loss: 3.7496 - accuracy: 0.7181 - precision: 0.8786 - recall: 0.7075 - val_loss: 8.5487 - val_accuracy: 0.8799 - val_precision: 0.9905 - val_recall: 0.8430
# Epoch 2/50
# 13/13 [==============================] - 3s 229ms/step - loss: 0.8368 - accuracy: 0.9204 - precision: 0.9685 - recall: 0.9217 - val_loss: 5.2446 - val_accuracy: 0.7505 - val_precision: 1.0000 - val_recall: 0.6568
# Epoch 3/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.2486 - accuracy: 0.9227 - precision: 0.9764 - recall: 0.9163 - val_loss: 0.2448 - val_accuracy: 0.9414 - val_precision: 0.9534 - val_recall: 0.9674
# Epoch 4/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.2212 - accuracy: 0.9271 - precision: 0.9685 - recall: 0.9305 - val_loss: 0.6586 - val_accuracy: 0.8711 - val_precision: 0.8519 - val_recall: 0.9967
# Epoch 5/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.2563 - accuracy: 0.9183 - precision: 0.9594 - recall: 0.9278 - val_loss: 1.2702 - val_accuracy: 0.7607 - val_precision: 1.0000 - val_recall: 0.6709
# Epoch 6/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.2054 - accuracy: 0.9173 - precision: 0.9697 - recall: 0.9155 - val_loss: 0.9002 - val_accuracy: 0.8892 - val_precision: 0.9878 - val_recall: 0.8598
# Epoch 7/50
# 13/13 [==============================] - 4s 350ms/step - loss: 0.1926 - accuracy: 0.9320 - precision: 0.9754 - recall: 0.9302 - val_loss: 0.3810 - val_accuracy: 0.9268 - val_precision: 0.9871 - val_recall: 0.9126
# Epoch 8/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.1702 - accuracy: 0.9316 - precision: 0.9757 - recall: 0.9285 - val_loss: 0.5965 - val_accuracy: 0.8735 - val_precision: 0.8521 - val_recall: 0.9987
# Epoch 9/50
# 13/13 [==============================] - 3s 231ms/step - loss: 0.1214 - accuracy: 0.9418 - precision: 0.9746 - recall: 0.9447 - val_loss: 1.4842 - val_accuracy: 0.8706 - val_precision: 0.9857 - val_recall: 0.8345
# Epoch 10/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.2106 - accuracy: 0.9317 - precision: 0.9757 - recall: 0.9293 - val_loss: 0.1292 - val_accuracy: 0.9565 - val_precision: 0.9501 - val_recall: 0.9927
# Epoch 11/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0873 - accuracy: 0.9513 - precision: 0.9780 - recall: 0.9550 - val_loss: 0.3128 - val_accuracy: 0.9067 - val_precision: 0.9888 - val_recall: 0.8827
# Epoch 12/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0969 - accuracy: 0.9432 - precision: 0.9816 - recall: 0.9393 - val_loss: 0.0942 - val_accuracy: 0.9624 - val_precision: 0.9680 - val_recall: 0.9815
# Epoch 13/50
# 13/13 [==============================] - 3s 229ms/step - loss: 0.0753 - accuracy: 0.9529 - precision: 0.9854 - recall: 0.9501 - val_loss: 0.0946 - val_accuracy: 0.9614 - val_precision: 0.9624 - val_recall: 0.9860
# Epoch 14/50
# 13/13 [==============================] - 3s 227ms/step - loss: 0.0795 - accuracy: 0.9425 - precision: 0.9812 - recall: 0.9400 - val_loss: 0.1217 - val_accuracy: 0.9609 - val_precision: 0.9759 - val_recall: 0.9707
# Epoch 15/50
# 13/13 [==============================] - 3s 230ms/step - loss: 0.0771 - accuracy: 0.9543 - precision: 0.9904 - recall: 0.9468 - val_loss: 0.0984 - val_accuracy: 0.9604 - val_precision: 0.9734 - val_recall: 0.9727
# Epoch 16/50
# 13/13 [==============================] - 3s 229ms/step - loss: 0.1192 - accuracy: 0.9393 - precision: 0.9738 - recall: 0.9425 - val_loss: 0.1073 - val_accuracy: 0.9624 - val_precision: 0.9624 - val_recall: 0.9874
# Epoch 17/50
# 13/13 [==============================] - 3s 231ms/step - loss: 0.0770 - accuracy: 0.9545 - precision: 0.9840 - recall: 0.9532 - val_loss: 0.1181 - val_accuracy: 0.9585 - val_precision: 0.9842 - val_recall: 0.9585
# Epoch 18/50
# 13/13 [==============================] - 3s 230ms/step - loss: 0.0766 - accuracy: 0.9537 - precision: 0.9814 - recall: 0.9542 - val_loss: 0.1231 - val_accuracy: 0.9600 - val_precision: 0.9829 - val_recall: 0.9618
# Epoch 19/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0613 - accuracy: 0.9591 - precision: 0.9880 - recall: 0.9557 - val_loss: 0.0980 - val_accuracy: 0.9678 - val_precision: 0.9858 - val_recall: 0.9700
# Epoch 20/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0701 - accuracy: 0.9562 - precision: 0.9860 - recall: 0.9533 - val_loss: 0.0796 - val_accuracy: 0.9692 - val_precision: 0.9788 - val_recall: 0.9794
# Epoch 21/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0561 - accuracy: 0.9613 - precision: 0.9883 - recall: 0.9583 - val_loss: 0.0834 - val_accuracy: 0.9712 - val_precision: 0.9807 - val_recall: 0.9801
# Epoch 22/50
# 13/13 [==============================] - 3s 227ms/step - loss: 0.0616 - accuracy: 0.9588 - precision: 0.9865 - recall: 0.9576 - val_loss: 0.0843 - val_accuracy: 0.9663 - val_precision: 0.9686 - val_recall: 0.9860
# Epoch 23/50
# 13/13 [==============================] - 3s 231ms/step - loss: 0.0562 - accuracy: 0.9663 - precision: 0.9886 - recall: 0.9648 - val_loss: 0.1046 - val_accuracy: 0.9590 - val_precision: 0.9525 - val_recall: 0.9933
# Epoch 24/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0589 - accuracy: 0.9626 - precision: 0.9846 - recall: 0.9635 - val_loss: 0.0821 - val_accuracy: 0.9702 - val_precision: 0.9775 - val_recall: 0.9820
# Epoch 25/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0556 - accuracy: 0.9628 - precision: 0.9886 - recall: 0.9601 - val_loss: 0.0845 - val_accuracy: 0.9692 - val_precision: 0.9760 - val_recall: 0.9819
# Epoch 26/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0629 - accuracy: 0.9648 - precision: 0.9858 - recall: 0.9657 - val_loss: 0.0995 - val_accuracy: 0.9570 - val_precision: 0.9503 - val_recall: 0.9933
# Epoch 27/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0568 - accuracy: 0.9653 - precision: 0.9832 - recall: 0.9688 - val_loss: 0.0835 - val_accuracy: 0.9663 - val_precision: 0.9698 - val_recall: 0.9847
# Epoch 28/50
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0623 - accuracy: 0.9591 - precision: 0.9824 - recall: 0.9610 - val_loss: 0.0989 - val_accuracy: 0.9644 - val_precision: 0.9707 - val_recall: 0.9805
# Epoch 29/50
# 13/13 [==============================] - 3s 227ms/step - loss: 0.0571 - accuracy: 0.9659 - precision: 0.9877 - recall: 0.9650 - val_loss: 0.0838 - val_accuracy: 0.9663 - val_precision: 0.9736 - val_recall: 0.9807
# Epoch 30/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0528 - accuracy: 0.9665 - precision: 0.9882 - recall: 0.9653 - val_loss: 0.0934 - val_accuracy: 0.9712 - val_precision: 0.9800 - val_recall: 0.9806
# Epoch 31/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0553 - accuracy: 0.9638 - precision: 0.9868 - recall: 0.9631 - val_loss: 0.0840 - val_accuracy: 0.9639 - val_precision: 0.9678 - val_recall: 0.9833
# Epoch 32/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0474 - accuracy: 0.9713 - precision: 0.9913 - recall: 0.9694 - val_loss: 0.0784 - val_accuracy: 0.9673 - val_precision: 0.9711 - val_recall: 0.9847
# Epoch 33/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0530 - accuracy: 0.9684 - precision: 0.9877 - recall: 0.9688 - val_loss: 0.0869 - val_accuracy: 0.9727 - val_precision: 0.9799 - val_recall: 0.9826
# Epoch 34/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0540 - accuracy: 0.9647 - precision: 0.9900 - recall: 0.9619 - val_loss: 0.0805 - val_accuracy: 0.9697 - val_precision: 0.9738 - val_recall: 0.9854
# Epoch 35/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0450 - accuracy: 0.9726 - precision: 0.9932 - recall: 0.9690 - val_loss: 0.0910 - val_accuracy: 0.9673 - val_precision: 0.9740 - val_recall: 0.9812
# Epoch 36/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0462 - accuracy: 0.9708 - precision: 0.9908 - recall: 0.9690 - val_loss: 0.0915 - val_accuracy: 0.9629 - val_precision: 0.9635 - val_recall: 0.9867
# Epoch 37/50
# 13/13 [==============================] - 3s 227ms/step - loss: 0.0578 - accuracy: 0.9630 - precision: 0.9836 - recall: 0.9651 - val_loss: 0.0857 - val_accuracy: 0.9658 - val_precision: 0.9697 - val_recall: 0.9840
# Epoch 38/50
# 13/13 [==============================] - 3s 217ms/step - loss: 0.0412 - accuracy: 0.9765 - precision: 0.9906 - recall: 0.9768 - val_loss: 0.0845 - val_accuracy: 0.9653 - val_precision: 0.9689 - val_recall: 0.9839
# Epoch 39/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0474 - accuracy: 0.9716 - precision: 0.9899 - recall: 0.9708 - val_loss: 0.0810 - val_accuracy: 0.9717 - val_precision: 0.9800 - val_recall: 0.9813
# Epoch 40/50
# 13/13 [==============================] - 3s 221ms/step - loss: 0.0420 - accuracy: 0.9727 - precision: 0.9911 - recall: 0.9712 - val_loss: 0.0802 - val_accuracy: 0.9668 - val_precision: 0.9696 - val_recall: 0.9852
# Epoch 41/50
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0422 - accuracy: 0.9735 - precision: 0.9917 - recall: 0.9717 - val_loss: 0.0897 - val_accuracy: 0.9678 - val_precision: 0.9749 - val_recall: 0.9814
# Epoch 42/50
# 13/13 [==============================] - 3s 224ms/step - loss: 0.0445 - accuracy: 0.9709 - precision: 0.9926 - recall: 0.9676 - val_loss: 0.0815 - val_accuracy: 0.9678 - val_precision: 0.9718 - val_recall: 0.9847
# Epoch 43/50
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0409 - accuracy: 0.9759 - precision: 0.9918 - recall: 0.9751 - val_loss: 0.0761 - val_accuracy: 0.9697 - val_precision: 0.9799 - val_recall: 0.9785
# Epoch 44/50
# 13/13 [==============================] - 3s 225ms/step - loss: 0.0420 - accuracy: 0.9748 - precision: 0.9900 - recall: 0.9752 - val_loss: 0.0815 - val_accuracy: 0.9722 - val_precision: 0.9806 - val_recall: 0.9813
# Epoch 45/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0422 - accuracy: 0.9728 - precision: 0.9929 - recall: 0.9700 - val_loss: 0.0821 - val_accuracy: 0.9707 - val_precision: 0.9773 - val_recall: 0.9825
# Epoch 46/50
# 13/13 [==============================] - 3s 214ms/step - loss: 0.0511 - accuracy: 0.9685 - precision: 0.9881 - recall: 0.9688 - val_loss: 0.0859 - val_accuracy: 0.9692 - val_precision: 0.9754 - val_recall: 0.9826
# Epoch 47/50
# 13/13 [==============================] - 3s 220ms/step - loss: 0.0450 - accuracy: 0.9706 - precision: 0.9897 - recall: 0.9699 - val_loss: 0.0841 - val_accuracy: 0.9673 - val_precision: 0.9755 - val_recall: 0.9800
# Epoch 48/50
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0494 - accuracy: 0.9697 - precision: 0.9870 - recall: 0.9710 - val_loss: 0.0824 - val_accuracy: 0.9707 - val_precision: 0.9788 - val_recall: 0.9814
# Epoch 49/50
# 13/13 [==============================] - 3s 219ms/step - loss: 0.0398 - accuracy: 0.9761 - precision: 0.9940 - recall: 0.9733 - val_loss: 0.0869 - val_accuracy: 0.9673 - val_precision: 0.9774 - val_recall: 0.9781
# Epoch 50/50
# 13/13 [==============================] - 3s 223ms/step - loss: 0.0426 - accuracy: 0.9699 - precision: 0.9903 - recall: 0.9682 - val_loss: 0.0848 - val_accuracy: 0.9702 - val_precision: 0.9761 - val_recall: 0.9833
# 5/5 [==============================] - 51s 12s/step
#
#
# Batch Size: 256
# Hidden Units: 4096
# Learning Rate: 0.05011872336272722
# 1 Hidden Layer, 4096 units
# S value: 35
# Momentum: 0.78
# AUC score: 0.9892534287287539
# Test Recall: 0.9681978798586572
# Test Precision: 0.9625292740046838
# Test F1 Scores: 0.9653552554315913
#
#
# densenet_0.05011872336272722_4096_256_1layer_35_0.78_xray_model

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import tensorflow as tf
from kaggle_datasets import KaggleDatasets
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import re
import glob
import random
import seaborn as sns
import matplotlib.pyplot as plt

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# 2023-01-02 03:56:22.938372: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib
# 2023-01-02 03:56:22.938527: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Device:', tpu.master())
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
except:
    strategy = tf.distribute.get_strategy()
print('Number of replicas:', strategy.num_replicas_in_sync)

print(tf.__version__)
# Out:
# Device: grpc://10.0.0.2:8470
# 2023-01-02 03:56:29.585751: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-01-02 03:56:29.588978: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib
# 2023-01-02 03:56:29.589020: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-01-02 03:56:29.589049: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (5db2ff89004f): /proc/driver/nvidia/version does not exist
# 2023-01-02 03:56:29.592837: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-02 03:56:29.594234: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-01-02 03:56:29.629993: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job worker -> {0 -> 10.0.0.2:8470}
# 2023-01-02 03:56:29.630068: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job localhost -> {0 -> localhost:30019}
# 2023-01-02 03:56:29.655414: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job worker -> {0 -> 10.0.0.2:8470}
# 2023-01-02 03:56:29.655476: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job localhost -> {0 -> localhost:30019}
# 2023-01-02 03:56:29.657238: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:411] Started server with target: grpc://localhost:30019
# Number of replicas: 8
# 2.4.1

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
GCS_PATH = KaggleDatasets().get_gcs_path()
BATCH_SIZE = 64*strategy.num_replicas_in_sync
#BATCH_SIZE = 64 # for non-TPU use
IMAGE_SIZE = [180, 180]
EPOCHS = 50

# %%
filenames = tf.io.gfile.glob(str(GCS_PATH + '/chest_xray/train/*/*'))
filenames.extend(tf.io.gfile.glob(str(GCS_PATH + '/chest_xray/val/*/*')))
filenames.extend(tf.io.gfile.glob(str(GCS_PATH + '/chest_xray/test/*/*')))

print(f'The total number of files is {len(filenames)}')
# Out:
# 2023-01-02 03:56:35.951383: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-02 03:56:36.061509: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-02 03:56:36.152239: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-02 03:56:36.273230: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-02 03:56:36.386941: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-02 03:56:36.487678: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-02 03:56:36.574345: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-02 03:56:36.638018: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# The total number of files is 5856

# %%
# split the data into 60:40 for train:test+val
train_files, val_test_files = train_test_split(filenames, test_size=0.4,random_state=18)

# %%
# split the val_test_files to 50:50 to have a final split of 60:20:20 of train:val:test
val_files, test_files = train_test_split(val_test_files, test_size=0.5, random_state=18)

# %%
pct_df = pd.DataFrame(columns = ['data_set', 'label', 'pct'], index = range(6))

totals = {'train':len(train_files), 'val':len(val_files), 'test':len(test_files)}

val_pneum_count = 0
val_norm_count = 0

re_pattern = '.*/(NORMAL|PNEUMONIA)/.*'

for file in val_files:
    re_match = re.match(re_pattern, file)
    if re_match[1] == 'NORMAL':
        val_norm_count += 1
    else:
        val_pneum_count += 1

pct_df.iloc[0, :] = ['val', 'NORMAL', round(100* val_norm_count / totals['val'], 1)]
pct_df.iloc[1, :] = ['val', 'PNEUMONIA', round(100* val_pneum_count / totals['val'], 1)]


test_pneum_count = 0
test_norm_count = 0
for file in test_files:
    re_match = re.match(re_pattern, file)
    if re_match[1] == 'NORMAL':
        test_norm_count += 1
    else:
        test_pneum_count += 1

pct_df.iloc[2, :] = ['test', 'NORMAL', round(100* test_norm_count / totals['test'], 1)]
pct_df.iloc[3, :] = ['test', 'PNEUMONIA', round(100* test_pneum_count / totals['test'], 1)]

train_pneum_count = 0
train_norm_count = 0
for file in train_files:
    re_match = re.match(re_pattern, file)
    if re_match[1] == 'NORMAL':
        train_norm_count += 1
    else:
        train_pneum_count += 1

pct_df.iloc[4, :] = ['train', 'NORMAL', round(100* train_norm_count / totals['train'], 1)]
pct_df.iloc[5, :] = ['train', 'PNEUMONIA', round(100* train_pneum_count / totals['train'], 1)]

# %%
PNEUM_COUNT = val_pneum_count + train_pneum_count + test_pneum_count
NORMAL_COUNT = val_norm_count + train_norm_count + test_norm_count
print(f'Normal: {NORMAL_COUNT}\nPneumonia: {PNEUM_COUNT}')

pct_df
# Out:
# Normal: 1583
# Pneumonia: 4273
#   data_set      label   pct
# 0      val     NORMAL  26.9
# 1      val  PNEUMONIA  73.1
# 2     test     NORMAL  27.6
# 3     test  PNEUMONIA  72.4
# 4    train     NORMAL  26.9
# 5    train  PNEUMONIA  73.1

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_files)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_files)
test_list_ds = tf.data.Dataset.from_tensor_slices(test_files)

#view the file paths for training
print('----Training Files----')
for f in train_list_ds.take(5):
    print(f.numpy())
# Out:
# ----Training Files----
# b'gs://kds-2620457a4e9f9b50269b131bc7e626ac570c179e3a006cd1452d73ba/chest_xray/train/PNEUMONIA/person509_virus_1025.jpeg'
# b'gs://kds-2620457a4e9f9b50269b131bc7e626ac570c179e3a006cd1452d73ba/chest_xray/train/PNEUMONIA/person671_bacteria_2564.jpeg'
# b'gs://kds-2620457a4e9f9b50269b131bc7e626ac570c179e3a006cd1452d73ba/chest_xray/train/PNEUMONIA/person957_virus_1629.jpeg'
# b'gs://kds-2620457a4e9f9b50269b131bc7e626ac570c179e3a006cd1452d73ba/chest_xray/test/PNEUMONIA/person81_bacteria_397.jpeg'
# b'gs://kds-2620457a4e9f9b50269b131bc7e626ac570c179e3a006cd1452d73ba/chest_xray/train/NORMAL/IM-0500-0001.jpeg'

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
TEST_IMG_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()

print(f'Train Image Count: {TRAIN_IMG_COUNT}\nVal Image Count: {VAL_IMG_COUNT}\nTest Image Count: {TEST_IMG_COUNT}')
# Out:
# Train Image Count: 3513
# Val Image Count: 1171
# Test Image Count: 1172
# 2023-01-02 03:56:37.112660: W ./tensorflow/core/distributed_runtime/eager/destroy_tensor_handle_node.h:57] Ignoring an error encountered when deleting remote tensors handles: Invalid argument: Unable to find the relevant tensor remote_handle: Op ID: 28, Output num: 0
# Additional GRPC error information from remote target /job:worker/replica:0/task:0:
# :{"created":"@1672631797.109374659","description":"Error received from peer ipv4:10.0.0.2:8470","file":"external/com_github_grpc_grpc/src/core/lib/surface/call.cc","file_line":1056,"grpc_message":"Unable to find the relevant tensor remote_handle: Op ID: 28, Output num: 0","grpc_status":3}

# %%
# will label as 1 if pneumonia otherwise 0
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == 'PNEUMONIA'

# %%
def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    return tf.image.resize(img, IMAGE_SIZE)

# %%
def process_path(file_path):
    label = get_label(file_path)
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
y_train = []
for image, label in train_ds.take(TRAIN_IMG_COUNT):
    y_train.append(label)
    
print('Training Counts')
print(f'Pneumonia count: {np.sum(y_train)}\nNormal count: {TRAIN_IMG_COUNT - np.sum(y_train)}')
# Out:
# 2023-01-02 03:58:32.488157: W ./tensorflow/core/distributed_runtime/eager/destroy_tensor_handle_node.h:57] Ignoring an error encountered when deleting remote tensors handles: Invalid argument: Unable to find the relevant tensor remote_handle: Op ID: 3562, Output num: 1
# Additional GRPC error information from remote target /job:worker/replica:0/task:0:
# :{"created":"@1672631912.488052773","description":"Error received from peer ipv4:10.0.0.2:8470","file":"external/com_github_grpc_grpc/src/core/lib/surface/call.cc","file_line":1056,"grpc_message":"Unable to find the relevant tensor remote_handle: Op ID: 3562, Output num: 1","grpc_status":3}
# Training Counts
# Pneumonia count: 2568
# Normal count: 945

# %%
y_val = []
for image, label in val_ds.take(VAL_IMG_COUNT):
    y_val.append(label)
    
print('Validation Counts')
print(f'Pneumonia count: {np.sum(y_val)}\nNormal count: {VAL_IMG_COUNT - np.sum(y_val)}')
# Out:
# 2023-01-02 03:59:34.678937: W ./tensorflow/core/distributed_runtime/eager/destroy_tensor_handle_node.h:57] Ignoring an error encountered when deleting remote tensors handles: Invalid argument: Unable to find the relevant tensor remote_handle: Op ID: 18796, Output num: 1
# Additional GRPC error information from remote target /job:worker/replica:0/task:0:
# :{"created":"@1672631974.678849988","description":"Error received from peer ipv4:10.0.0.2:8470","file":"external/com_github_grpc_grpc/src/core/lib/surface/call.cc","file_line":1056,"grpc_message":"Unable to find the relevant tensor remote_handle: Op ID: 18796, Output num: 1","grpc_status":3}
# Validation Counts
# Pneumonia count: 856
# Normal count: 315

# %%
y_test = []
for image, label in test_ds.take(TEST_IMG_COUNT):
    y_test.append(label)
    
print('Test Counts')
print(f'Pneumonia count: {np.sum(y_test)}\nNormal count: {TEST_IMG_COUNT - np.sum(y_test)}')
# Out:
# Test Counts
# Pneumonia count: 849
# Normal count: 323

# %%
def prepare_for_training(ds, cache=True, shuffle_buffer_size=1000):
    
    if cache:
        if isinstance(cache, str):
            ds = ds.cache(cache)
        else:
            ds = ds.cache()
            
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    
    ds = ds.repeat()
    
    ds = ds.batch(BATCH_SIZE)
    
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    
    return ds

# %%
train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)


image_batch, label_batch = next(iter(train_ds))

# %%
weight_for_0 = (1 / NORMAL_COUNT)*(TRAIN_IMG_COUNT)/2.0
weight_for_1 = (1 / PNEUM_COUNT)*(TRAIN_IMG_COUNT)/2.0

# %%
class_weight = {0: weight_for_0, 1: weight_for_1}
print(f'Weight for class 0: {weight_for_0:.2f}')
print(f'Weight for class 1: {weight_for_1:.2f}')
# Out:
# Weight for class 0: 1.11
# Weight for class 1: 0.41

# %%
# create some metrics for comparing on test results

def precision(y_test, y_pred):
    tp, fp = 0, 0
    
    for i in range(len(y_test)):
        if y_test[i] >= 0.5 and y_pred[i] >= 0.5:
            tp += 1
        elif y_test[i] < 0.5 and y_pred[i] >= 0.5:
            fp += 1
            
    return tp / (tp + fp)

def recall(y_test, y_pred):
    tp, fn = 0, 0
    
    for i in range(len(y_test)):
        if y_test[i] >= 0.5 and y_pred[i] >= 0.5:
            tp += 1
        elif y_test[i] >= 0.5 and y_pred[i] < 0.5:
            fn += 1
            
    return tp / (tp + fn)

def f1_score(y_test, y_pred):
    numerator = precision(y_test, y_pred) * recall(y_test, y_pred)
    denominator = precision(y_test, y_pred) + recall(y_test, y_pred)
    
    return 2 * (numerator / denominator)

# %% [markdown]
# ## Fine Tune the Model
#
# ## Explore Learning Rate values

# %%
# add exponential decay to try to improve fine tuning
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 ** (epoch / s)
    return exponential_decay_fn

# %%
# try 10 different learning rates randomly selected between 1.0 to 0.0001
for _ in range(10):
    
    # randomly sample a number in the half-open interval [0.0, 1.0)
    r = random.random()
    learning_rate = 10 ** (-4 * r)
    print(f'Learning Rate: {learning_rate}')

    with strategy.scope():
    
        base_model = tf.keras.applications.densenet.DenseNet201(
                    input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3),
                    include_top=False,
                    weights='imagenet'
                    )
        base_model.trainable = False
    
        x=base_model.output
        inputs = tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))
        x = base_model(inputs, training=False)
        x = tf.keras.layers.GlobalAveragePooling2D()(x)
        x = tf.keras.layers.Dropout(0.3)(x)
        outputs = tf.keras.layers.Dense(1, activation='sigmoid')(x)
        model = tf.keras.Model(inputs, outputs)

    
    
        METRICS = [
            'accuracy',
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')
            ]
    
        model.compile(
                optimizer='adam',
                loss='binary_crossentropy',
                metrics=METRICS
                 )
        
        checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(f"densenet_{learning_rate}_xray_model.h5", save_best_only=True)
        early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
        exponential_decay_fn = exponential_decay(learning_rate, 20)
        lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)

        history = model.fit(
                            train_ds,
                            steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
                            epochs=EPOCHS,
                            validation_data=val_ds,
                            validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
                            class_weight=class_weight,
                            callbacks=[checkpoint_cb, early_stopping_cb, lr_scheduler]
                            )
# Out:
# Learning Rate: 0.2619195164960712
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74842112/74836368 [==============================] - 0s 0us/step
# Epoch 1/50
# 6/6 [==============================] - 146s 16s/step - loss: 16.3523 - accuracy: 0.5263 - precision: 0.7666 - recall: 0.5173 - val_loss: 8.6319 - val_accuracy: 0.7490 - val_precision: 0.7445 - val_recall: 1.0000
# Epoch 2/50
# 6/6 [==============================] - 2s 299ms/step - loss: 6.2343 - accuracy: 0.7489 - precision: 0.8593 - recall: 0.7991 - val_loss: 11.9316 - val_accuracy: 0.7324 - val_precision: 0.9897 - val_recall: 0.6409
# Epoch 3/50
# 6/6 [==============================] - 2s 293ms/step - loss: 3.8030 - accuracy: 0.8074 - precision: 0.9671 - recall: 0.7666 - val_loss: 3.8664 - val_accuracy: 0.8975 - val_precision: 0.8892 - val_recall: 0.9827
# Epoch 4/50
# 6/6 [==============================] - 2s 310ms/step - loss: 3.1091 - accuracy: 0.9046 - precision: 0.9107 - recall: 0.9669 - val_loss: 4.5170 - val_accuracy: 0.8828 - val_precision: 0.9744 - val_recall: 0.8628
# Epoch 5/50
# 6/6 [==============================] - 2s 313ms/step - loss: 2.2539 - accuracy: 0.8685 - precision: 0.9796 - recall: 0.8395 - val_loss: 4.7239 - val_accuracy: 0.8809 - val_precision: 0.9770 - val_recall: 0.8560
# Epoch 6/50
# 6/6 [==============================] - 2s 294ms/step - loss: 1.9425 - accuracy: 0.8989 - precision: 0.9714 - recall: 0.8875 - val_loss: 2.3807 - val_accuracy: 0.9111 - val_precision: 0.9395 - val_recall: 0.9383
# Epoch 7/50
# 6/6 [==============================] - 2s 325ms/step - loss: 1.7647 - accuracy: 0.9296 - precision: 0.9498 - recall: 0.9546 - val_loss: 2.1864 - val_accuracy: 0.9189 - val_precision: 0.9614 - val_recall: 0.9270
# Epoch 8/50
# 6/6 [==============================] - 2s 332ms/step - loss: 1.4806 - accuracy: 0.9135 - precision: 0.9597 - recall: 0.9182 - val_loss: 2.8348 - val_accuracy: 0.8994 - val_precision: 0.9711 - val_recall: 0.8899
# Epoch 9/50
# 6/6 [==============================] - 2s 326ms/step - loss: 1.3359 - accuracy: 0.9152 - precision: 0.9809 - recall: 0.9013 - val_loss: 1.9176 - val_accuracy: 0.9199 - val_precision: 0.9690 - val_recall: 0.9198
# Epoch 10/50
# 6/6 [==============================] - 2s 330ms/step - loss: 1.1197 - accuracy: 0.9301 - precision: 0.9675 - recall: 0.9366 - val_loss: 1.5598 - val_accuracy: 0.9287 - val_precision: 0.9683 - val_recall: 0.9335
# Epoch 11/50
# 6/6 [==============================] - 2s 308ms/step - loss: 1.0529 - accuracy: 0.9320 - precision: 0.9707 - recall: 0.9366 - val_loss: 1.7084 - val_accuracy: 0.9209 - val_precision: 0.9730 - val_recall: 0.9171
# Epoch 12/50
# 6/6 [==============================] - 2s 307ms/step - loss: 0.9276 - accuracy: 0.9292 - precision: 0.9784 - recall: 0.9245 - val_loss: 1.4621 - val_accuracy: 0.9238 - val_precision: 0.9688 - val_recall: 0.9242
# Epoch 13/50
# 6/6 [==============================] - 2s 322ms/step - loss: 1.0170 - accuracy: 0.9342 - precision: 0.9709 - recall: 0.9375 - val_loss: 1.0823 - val_accuracy: 0.9375 - val_precision: 0.9739 - val_recall: 0.9402
# Epoch 14/50
# 6/6 [==============================] - 2s 297ms/step - loss: 0.8851 - accuracy: 0.9392 - precision: 0.9774 - recall: 0.9390 - val_loss: 1.0773 - val_accuracy: 0.9316 - val_precision: 0.9711 - val_recall: 0.9351
# Epoch 15/50
# 6/6 [==============================] - 2s 312ms/step - loss: 0.9314 - accuracy: 0.9334 - precision: 0.9699 - recall: 0.9369 - val_loss: 1.2779 - val_accuracy: 0.9258 - val_precision: 0.9707 - val_recall: 0.9268
# Epoch 16/50
# 6/6 [==============================] - 2s 316ms/step - loss: 0.7468 - accuracy: 0.9354 - precision: 0.9761 - recall: 0.9358 - val_loss: 1.1029 - val_accuracy: 0.9287 - val_precision: 0.9721 - val_recall: 0.9294
# Epoch 17/50
# 6/6 [==============================] - 2s 306ms/step - loss: 0.8095 - accuracy: 0.9292 - precision: 0.9743 - recall: 0.9278 - val_loss: 1.1455 - val_accuracy: 0.9307 - val_precision: 0.9681 - val_recall: 0.9356
# Epoch 18/50
# 6/6 [==============================] - 2s 295ms/step - loss: 0.6711 - accuracy: 0.9481 - precision: 0.9743 - recall: 0.9541 - val_loss: 1.0511 - val_accuracy: 0.9307 - val_precision: 0.9733 - val_recall: 0.9302
# Epoch 19/50
# 6/6 [==============================] - 2s 409ms/step - loss: 0.6637 - accuracy: 0.9401 - precision: 0.9831 - recall: 0.9352 - val_loss: 1.0417 - val_accuracy: 0.9316 - val_precision: 0.9709 - val_recall: 0.9347
# Epoch 20/50
# 6/6 [==============================] - 2s 322ms/step - loss: 0.5729 - accuracy: 0.9442 - precision: 0.9736 - recall: 0.9500 - val_loss: 0.8603 - val_accuracy: 0.9404 - val_precision: 0.9738 - val_recall: 0.9438
# Epoch 21/50
# 6/6 [==============================] - 2s 317ms/step - loss: 0.6567 - accuracy: 0.9378 - precision: 0.9727 - recall: 0.9414 - val_loss: 0.9768 - val_accuracy: 0.9316 - val_precision: 0.9721 - val_recall: 0.9330
# Epoch 22/50
# 6/6 [==============================] - 2s 304ms/step - loss: 0.6235 - accuracy: 0.9382 - precision: 0.9748 - recall: 0.9388 - val_loss: 0.8654 - val_accuracy: 0.9346 - val_precision: 0.9760 - val_recall: 0.9325
# Epoch 23/50
# 6/6 [==============================] - 2s 306ms/step - loss: 0.5921 - accuracy: 0.9391 - precision: 0.9810 - recall: 0.9336 - val_loss: 0.8379 - val_accuracy: 0.9336 - val_precision: 0.9735 - val_recall: 0.9344
# Epoch 24/50
# 6/6 [==============================] - 2s 312ms/step - loss: 0.6565 - accuracy: 0.9293 - precision: 0.9738 - recall: 0.9291 - val_loss: 0.7822 - val_accuracy: 0.9385 - val_precision: 0.9726 - val_recall: 0.9428
# Epoch 25/50
# 6/6 [==============================] - 2s 327ms/step - loss: 0.5620 - accuracy: 0.9394 - precision: 0.9744 - recall: 0.9413 - val_loss: 0.8056 - val_accuracy: 0.9346 - val_precision: 0.9669 - val_recall: 0.9422
# Epoch 26/50
# 6/6 [==============================] - 2s 297ms/step - loss: 0.5009 - accuracy: 0.9460 - precision: 0.9763 - recall: 0.9494 - val_loss: 0.7845 - val_accuracy: 0.9375 - val_precision: 0.9686 - val_recall: 0.9454
# Epoch 27/50
# 6/6 [==============================] - 2s 312ms/step - loss: 0.6248 - accuracy: 0.9417 - precision: 0.9734 - recall: 0.9468 - val_loss: 0.8143 - val_accuracy: 0.9355 - val_precision: 0.9698 - val_recall: 0.9413
# Epoch 28/50
# 6/6 [==============================] - 2s 309ms/step - loss: 0.5260 - accuracy: 0.9429 - precision: 0.9769 - recall: 0.9455 - val_loss: 0.7104 - val_accuracy: 0.9404 - val_precision: 0.9751 - val_recall: 0.9424
# Epoch 29/50
# 6/6 [==============================] - 2s 304ms/step - loss: 0.4838 - accuracy: 0.9456 - precision: 0.9840 - recall: 0.9413 - val_loss: 0.7806 - val_accuracy: 0.9375 - val_precision: 0.9710 - val_recall: 0.9424
# Epoch 30/50
# 6/6 [==============================] - 2s 320ms/step - loss: 0.5711 - accuracy: 0.9394 - precision: 0.9747 - recall: 0.9406 - val_loss: 0.7352 - val_accuracy: 0.9375 - val_precision: 0.9735 - val_recall: 0.9394
# Epoch 31/50
# 6/6 [==============================] - 2s 310ms/step - loss: 0.6997 - accuracy: 0.9300 - precision: 0.9731 - recall: 0.9298 - val_loss: 0.6852 - val_accuracy: 0.9365 - val_precision: 0.9681 - val_recall: 0.9432
# Epoch 32/50
# 6/6 [==============================] - 2s 330ms/step - loss: 0.6017 - accuracy: 0.9432 - precision: 0.9765 - recall: 0.9439 - val_loss: 0.6782 - val_accuracy: 0.9404 - val_precision: 0.9752 - val_recall: 0.9427
# Epoch 33/50
# 6/6 [==============================] - 2s 308ms/step - loss: 0.5787 - accuracy: 0.9406 - precision: 0.9774 - recall: 0.9398 - val_loss: 0.7387 - val_accuracy: 0.9355 - val_precision: 0.9723 - val_recall: 0.9385
# Epoch 34/50
# 6/6 [==============================] - 2s 318ms/step - loss: 0.4070 - accuracy: 0.9453 - precision: 0.9807 - recall: 0.9429 - val_loss: 0.7816 - val_accuracy: 0.9336 - val_precision: 0.9696 - val_recall: 0.9384
# Epoch 35/50
# 6/6 [==============================] - 2s 295ms/step - loss: 0.4884 - accuracy: 0.9425 - precision: 0.9772 - recall: 0.9440 - val_loss: 0.6971 - val_accuracy: 0.9375 - val_precision: 0.9711 - val_recall: 0.9426
# Epoch 36/50
# 6/6 [==============================] - 2s 305ms/step - loss: 0.6218 - accuracy: 0.9375 - precision: 0.9739 - recall: 0.9392 - val_loss: 0.7326 - val_accuracy: 0.9326 - val_precision: 0.9708 - val_recall: 0.9357
# Epoch 37/50
# 6/6 [==============================] - 2s 318ms/step - loss: 0.4133 - accuracy: 0.9497 - precision: 0.9828 - recall: 0.9482 - val_loss: 0.5988 - val_accuracy: 0.9434 - val_precision: 0.9766 - val_recall: 0.9453
# Epoch 38/50
# 6/6 [==============================] - 2s 315ms/step - loss: 0.5163 - accuracy: 0.9418 - precision: 0.9777 - recall: 0.9420 - val_loss: 0.6366 - val_accuracy: 0.9434 - val_precision: 0.9752 - val_recall: 0.9466
# Epoch 39/50
# 6/6 [==============================] - 2s 312ms/step - loss: 0.5382 - accuracy: 0.9354 - precision: 0.9746 - recall: 0.9363 - val_loss: 0.6326 - val_accuracy: 0.9404 - val_precision: 0.9766 - val_recall: 0.9415
# Epoch 40/50
# 6/6 [==============================] - 2s 313ms/step - loss: 0.4933 - accuracy: 0.9432 - precision: 0.9790 - recall: 0.9417 - val_loss: 0.6857 - val_accuracy: 0.9414 - val_precision: 0.9715 - val_recall: 0.9484
# Epoch 41/50
# 6/6 [==============================] - 2s 297ms/step - loss: 0.5309 - accuracy: 0.9413 - precision: 0.9752 - recall: 0.9436 - val_loss: 0.6174 - val_accuracy: 0.9414 - val_precision: 0.9699 - val_recall: 0.9491
# Epoch 42/50
# 6/6 [==============================] - 2s 292ms/step - loss: 0.5402 - accuracy: 0.9401 - precision: 0.9735 - recall: 0.9428 - val_loss: 0.6591 - val_accuracy: 0.9424 - val_precision: 0.9728 - val_recall: 0.9482
# Epoch 43/50
# 6/6 [==============================] - 2s 306ms/step - loss: 0.4561 - accuracy: 0.9459 - precision: 0.9846 - recall: 0.9418 - val_loss: 0.6682 - val_accuracy: 0.9404 - val_precision: 0.9735 - val_recall: 0.9433
# Epoch 44/50
# 6/6 [==============================] - 2s 302ms/step - loss: 0.4005 - accuracy: 0.9490 - precision: 0.9781 - recall: 0.9516 - val_loss: 0.6565 - val_accuracy: 0.9424 - val_precision: 0.9726 - val_recall: 0.9479
# Epoch 45/50
# 6/6 [==============================] - 2s 312ms/step - loss: 0.5054 - accuracy: 0.9411 - precision: 0.9722 - recall: 0.9467 - val_loss: 0.7085 - val_accuracy: 0.9365 - val_precision: 0.9711 - val_recall: 0.9413
# Epoch 46/50
# 6/6 [==============================] - 2s 305ms/step - loss: 0.4118 - accuracy: 0.9487 - precision: 0.9771 - recall: 0.9525 - val_loss: 0.6625 - val_accuracy: 0.9404 - val_precision: 0.9694 - val_recall: 0.9470
# Epoch 47/50
# 6/6 [==============================] - 2s 422ms/step - loss: 0.4946 - accuracy: 0.9410 - precision: 0.9779 - recall: 0.9400 - val_loss: 0.7043 - val_accuracy: 0.9365 - val_precision: 0.9698 - val_recall: 0.9427
# Learning Rate: 0.0005602857196485778
# Epoch 1/50
# 6/6 [==============================] - 51s 4s/step - loss: 0.5706 - accuracy: 0.6849 - precision: 0.7349 - recall: 0.8876 - val_loss: 0.6877 - val_accuracy: 0.5498 - val_precision: 0.8356 - val_recall: 0.4807
# Epoch 2/50
# 6/6 [==============================] - 2s 312ms/step - loss: 0.4160 - accuracy: 0.4972 - precision: 0.8249 - recall: 0.4107 - val_loss: 0.7662 - val_accuracy: 0.4434 - val_precision: 0.9515 - val_recall: 0.2593
# Epoch 3/50
# 6/6 [==============================] - 2s 298ms/step - loss: 0.4024 - accuracy: 0.4955 - precision: 0.8640 - recall: 0.3706 - val_loss: 0.6191 - val_accuracy: 0.6641 - val_precision: 0.9512 - val_recall: 0.5712
# Epoch 4/50
# 6/6 [==============================] - 2s 312ms/step - loss: 0.3521 - accuracy: 0.6220 - precision: 0.8855 - recall: 0.5594 - val_loss: 0.5124 - val_accuracy: 0.8037 - val_precision: 0.9160 - val_recall: 0.8043
# Epoch 5/50
# 6/6 [==============================] - 2s 309ms/step - loss: 0.3248 - accuracy: 0.7350 - precision: 0.8817 - recall: 0.7371 - val_loss: 0.4545 - val_accuracy: 0.8389 - val_precision: 0.9155 - val_recall: 0.8609
# Epoch 6/50
# 6/6 [==============================] - 2s 319ms/step - loss: 0.3278 - accuracy: 0.7421 - precision: 0.8598 - recall: 0.7748 - val_loss: 0.4414 - val_accuracy: 0.8457 - val_precision: 0.9356 - val_recall: 0.8486
# Epoch 7/50
# 6/6 [==============================] - 2s 320ms/step - loss: 0.2952 - accuracy: 0.7695 - precision: 0.8964 - recall: 0.7712 - val_loss: 0.4476 - val_accuracy: 0.8271 - val_precision: 0.9480 - val_recall: 0.8070
# Epoch 8/50
# 6/6 [==============================] - 2s 308ms/step - loss: 0.2838 - accuracy: 0.7814 - precision: 0.9171 - recall: 0.7678 - val_loss: 0.4390 - val_accuracy: 0.8252 - val_precision: 0.9553 - val_recall: 0.7987
# Epoch 9/50
# 6/6 [==============================] - 2s 314ms/step - loss: 0.2631 - accuracy: 0.7923 - precision: 0.9404 - recall: 0.7633 - val_loss: 0.4238 - val_accuracy: 0.8369 - val_precision: 0.9490 - val_recall: 0.8209
# Epoch 10/50
# 6/6 [==============================] - 2s 299ms/step - loss: 0.2687 - accuracy: 0.7860 - precision: 0.9233 - recall: 0.7698 - val_loss: 0.4013 - val_accuracy: 0.8555 - val_precision: 0.9561 - val_recall: 0.8413
# Epoch 11/50
# 6/6 [==============================] - 2s 308ms/step - loss: 0.2581 - accuracy: 0.8023 - precision: 0.9274 - recall: 0.7930 - val_loss: 0.3915 - val_accuracy: 0.8564 - val_precision: 0.9498 - val_recall: 0.8505
# Epoch 12/50
# 6/6 [==============================] - 2s 304ms/step - loss: 0.2427 - accuracy: 0.8183 - precision: 0.9358 - recall: 0.8079 - val_loss: 0.3806 - val_accuracy: 0.8594 - val_precision: 0.9496 - val_recall: 0.8535
# Epoch 13/50
# 6/6 [==============================] - 2s 312ms/step - loss: 0.2467 - accuracy: 0.8227 - precision: 0.9297 - recall: 0.8172 - val_loss: 0.3693 - val_accuracy: 0.8682 - val_precision: 0.9527 - val_recall: 0.8623
# Epoch 14/50
# 6/6 [==============================] - 2s 300ms/step - loss: 0.2432 - accuracy: 0.8274 - precision: 0.9389 - recall: 0.8180 - val_loss: 0.3730 - val_accuracy: 0.8564 - val_precision: 0.9478 - val_recall: 0.8503
# Epoch 15/50
# 6/6 [==============================] - 2s 297ms/step - loss: 0.2513 - accuracy: 0.8248 - precision: 0.9172 - recall: 0.8266 - val_loss: 0.3628 - val_accuracy: 0.8691 - val_precision: 0.9568 - val_recall: 0.8596
# Epoch 16/50
# 6/6 [==============================] - 2s 302ms/step - loss: 0.2363 - accuracy: 0.8366 - precision: 0.9402 - recall: 0.8257 - val_loss: 0.3612 - val_accuracy: 0.8662 - val_precision: 0.9531 - val_recall: 0.8609
# Epoch 17/50
# 6/6 [==============================] - 2s 308ms/step - loss: 0.2335 - accuracy: 0.8275 - precision: 0.9473 - recall: 0.8096 - val_loss: 0.3644 - val_accuracy: 0.8623 - val_precision: 0.9521 - val_recall: 0.8537
# Epoch 18/50
# 6/6 [==============================] - 2s 302ms/step - loss: 0.2355 - accuracy: 0.8358 - precision: 0.9317 - recall: 0.8371 - val_loss: 0.3639 - val_accuracy: 0.8584 - val_precision: 0.9522 - val_recall: 0.8493
# Epoch 19/50
# 6/6 [==============================] - 2s 306ms/step - loss: 0.2306 - accuracy: 0.8325 - precision: 0.9342 - recall: 0.8275 - val_loss: 0.3628 - val_accuracy: 0.8564 - val_precision: 0.9566 - val_recall: 0.8441
# Epoch 20/50
# 6/6 [==============================] - 2s 294ms/step - loss: 0.2249 - accuracy: 0.8396 - precision: 0.9498 - recall: 0.8240 - val_loss: 0.3583 - val_accuracy: 0.8604 - val_precision: 0.9507 - val_recall: 0.8525
# Epoch 21/50
# 6/6 [==============================] - 2s 297ms/step - loss: 0.2270 - accuracy: 0.8378 - precision: 0.9393 - recall: 0.8322 - val_loss: 0.3576 - val_accuracy: 0.8623 - val_precision: 0.9545 - val_recall: 0.8500
# Epoch 22/50
# 6/6 [==============================] - 2s 307ms/step - loss: 0.2364 - accuracy: 0.8225 - precision: 0.9376 - recall: 0.8131 - val_loss: 0.3513 - val_accuracy: 0.8672 - val_precision: 0.9558 - val_recall: 0.8596
# Epoch 23/50
# 6/6 [==============================] - 2s 302ms/step - loss: 0.2326 - accuracy: 0.8310 - precision: 0.9308 - recall: 0.8314 - val_loss: 0.3495 - val_accuracy: 0.8711 - val_precision: 0.9581 - val_recall: 0.8604
# Epoch 24/50
# 6/6 [==============================] - 2s 308ms/step - loss: 0.2226 - accuracy: 0.8440 - precision: 0.9482 - recall: 0.8334 - val_loss: 0.3487 - val_accuracy: 0.8652 - val_precision: 0.9583 - val_recall: 0.8539
# Epoch 25/50
# 6/6 [==============================] - 2s 330ms/step - loss: 0.2179 - accuracy: 0.8519 - precision: 0.9468 - recall: 0.8471 - val_loss: 0.3481 - val_accuracy: 0.8672 - val_precision: 0.9539 - val_recall: 0.8592
# Epoch 26/50
# 6/6 [==============================] - 2s 303ms/step - loss: 0.2293 - accuracy: 0.8297 - precision: 0.9333 - recall: 0.8228 - val_loss: 0.3437 - val_accuracy: 0.8721 - val_precision: 0.9666 - val_recall: 0.8537
# Epoch 27/50
# 6/6 [==============================] - 2s 311ms/step - loss: 0.2324 - accuracy: 0.8280 - precision: 0.9317 - recall: 0.8215 - val_loss: 0.3418 - val_accuracy: 0.8721 - val_precision: 0.9615 - val_recall: 0.8609
# Epoch 28/50
# 6/6 [==============================] - 2s 304ms/step - loss: 0.2180 - accuracy: 0.8458 - precision: 0.9457 - recall: 0.8395 - val_loss: 0.3414 - val_accuracy: 0.8691 - val_precision: 0.9569 - val_recall: 0.8598
# Epoch 29/50
# 6/6 [==============================] - 2s 313ms/step - loss: 0.2228 - accuracy: 0.8463 - precision: 0.9438 - recall: 0.8402 - val_loss: 0.3464 - val_accuracy: 0.8711 - val_precision: 0.9588 - val_recall: 0.8624
# Epoch 30/50
# 6/6 [==============================] - 2s 309ms/step - loss: 0.2164 - accuracy: 0.8475 - precision: 0.9429 - recall: 0.8417 - val_loss: 0.3416 - val_accuracy: 0.8701 - val_precision: 0.9593 - val_recall: 0.8571
# Epoch 31/50
# 6/6 [==============================] - 2s 288ms/step - loss: 0.2284 - accuracy: 0.8379 - precision: 0.9340 - recall: 0.8363 - val_loss: 0.3452 - val_accuracy: 0.8652 - val_precision: 0.9584 - val_recall: 0.8543
# Epoch 32/50
# 6/6 [==============================] - 2s 296ms/step - loss: 0.2292 - accuracy: 0.8347 - precision: 0.9300 - recall: 0.8354 - val_loss: 0.3361 - val_accuracy: 0.8750 - val_precision: 0.9602 - val_recall: 0.8657
# Epoch 33/50
# 6/6 [==============================] - 2s 307ms/step - loss: 0.2128 - accuracy: 0.8432 - precision: 0.9512 - recall: 0.8274 - val_loss: 0.3357 - val_accuracy: 0.8779 - val_precision: 0.9644 - val_recall: 0.8655
# Epoch 34/50
# 6/6 [==============================] - 2s 302ms/step - loss: 0.2164 - accuracy: 0.8435 - precision: 0.9471 - recall: 0.8343 - val_loss: 0.3439 - val_accuracy: 0.8691 - val_precision: 0.9597 - val_recall: 0.8573
# Epoch 35/50
# 6/6 [==============================] - 2s 305ms/step - loss: 0.2141 - accuracy: 0.8546 - precision: 0.9439 - recall: 0.8528 - val_loss: 0.3421 - val_accuracy: 0.8721 - val_precision: 0.9611 - val_recall: 0.8596
# Epoch 36/50
# 6/6 [==============================] - 2s 296ms/step - loss: 0.2232 - accuracy: 0.8354 - precision: 0.9438 - recall: 0.8268 - val_loss: 0.3386 - val_accuracy: 0.8760 - val_precision: 0.9572 - val_recall: 0.8688
# Epoch 37/50
# 6/6 [==============================] - 2s 300ms/step - loss: 0.2211 - accuracy: 0.8498 - precision: 0.9410 - recall: 0.8479 - val_loss: 0.3367 - val_accuracy: 0.8740 - val_precision: 0.9602 - val_recall: 0.8647
# Epoch 38/50
# 6/6 [==============================] - 2s 294ms/step - loss: 0.2190 - accuracy: 0.8454 - precision: 0.9432 - recall: 0.8373 - val_loss: 0.3385 - val_accuracy: 0.8730 - val_precision: 0.9598 - val_recall: 0.8623
# Epoch 39/50
# 6/6 [==============================] - 2s 297ms/step - loss: 0.2103 - accuracy: 0.8491 - precision: 0.9455 - recall: 0.8408 - val_loss: 0.3296 - val_accuracy: 0.8809 - val_precision: 0.9647 - val_recall: 0.8700
# Epoch 40/50
# 6/6 [==============================] - 2s 302ms/step - loss: 0.2186 - accuracy: 0.8483 - precision: 0.9459 - recall: 0.8434 - val_loss: 0.3368 - val_accuracy: 0.8740 - val_precision: 0.9625 - val_recall: 0.8604
# Epoch 41/50
# 6/6 [==============================] - 2s 299ms/step - loss: 0.2191 - accuracy: 0.8414 - precision: 0.9405 - recall: 0.8338 - val_loss: 0.3323 - val_accuracy: 0.8789 - val_precision: 0.9603 - val_recall: 0.8707
# Epoch 42/50
# 6/6 [==============================] - 2s 294ms/step - loss: 0.2198 - accuracy: 0.8470 - precision: 0.9437 - recall: 0.8418 - val_loss: 0.3432 - val_accuracy: 0.8672 - val_precision: 0.9591 - val_recall: 0.8588
# Epoch 43/50
# 6/6 [==============================] - 2s 304ms/step - loss: 0.2198 - accuracy: 0.8421 - precision: 0.9423 - recall: 0.8375 - val_loss: 0.3335 - val_accuracy: 0.8799 - val_precision: 0.9632 - val_recall: 0.8697
# Epoch 44/50
# 6/6 [==============================] - 2s 304ms/step - loss: 0.2083 - accuracy: 0.8506 - precision: 0.9496 - recall: 0.8427 - val_loss: 0.3334 - val_accuracy: 0.8809 - val_precision: 0.9649 - val_recall: 0.8707
# Epoch 45/50
# 6/6 [==============================] - 2s 291ms/step - loss: 0.2192 - accuracy: 0.8489 - precision: 0.9501 - recall: 0.8363 - val_loss: 0.3372 - val_accuracy: 0.8760 - val_precision: 0.9612 - val_recall: 0.8644
# Epoch 46/50
# 6/6 [==============================] - 2s 294ms/step - loss: 0.2171 - accuracy: 0.8524 - precision: 0.9424 - recall: 0.8509 - val_loss: 0.3323 - val_accuracy: 0.8789 - val_precision: 0.9658 - val_recall: 0.8655
# Epoch 47/50
# 6/6 [==============================] - 2s 295ms/step - loss: 0.2176 - accuracy: 0.8386 - precision: 0.9384 - recall: 0.8327 - val_loss: 0.3380 - val_accuracy: 0.8770 - val_precision: 0.9644 - val_recall: 0.8644
# Epoch 48/50
# 6/6 [==============================] - 2s 290ms/step - loss: 0.2243 - accuracy: 0.8384 - precision: 0.9380 - recall: 0.8354 - val_loss: 0.3353 - val_accuracy: 0.8760 - val_precision: 0.9627 - val_recall: 0.8635
# Epoch 49/50
# 6/6 [==============================] - 2s 307ms/step - loss: 0.2102 - accuracy: 0.8522 - precision: 0.9465 - recall: 0.8421 - val_loss: 0.3357 - val_accuracy: 0.8740 - val_precision: 0.9609 - val_recall: 0.8612
# Learning Rate: 0.00017067671642955384
# Epoch 1/50
# 6/6 [==============================] - 50s 4s/step - loss: 0.5304 - accuracy: 0.6740 - precision: 0.7392 - recall: 0.8461 - val_loss: 0.6014 - val_accuracy: 0.6963 - val_precision: 0.7582 - val_recall: 0.8602
# Epoch 2/50
# 6/6 [==============================] - 2s 303ms/step - loss: 0.4612 - accuracy: 0.6260 - precision: 0.7668 - recall: 0.7077 - val_loss: 0.6382 - val_accuracy: 0.6338 - val_precision: 0.7959 - val_recall: 0.6689
# Epoch 3/50
# 6/6 [==============================] - 2s 296ms/step - loss: 0.4332 - accuracy: 0.5806 - precision: 0.7888 - recall: 0.5892 - val_loss: 0.6598 - val_accuracy: 0.5986 - val_precision: 0.8458 - val_recall: 0.5545
# Epoch 4/50
# 6/6 [==============================] - 2s 316ms/step - loss: 0.4007 - accuracy: 0.5667 - precision: 0.8142 - recall: 0.5393 - val_loss: 0.6598 - val_accuracy: 0.6094 - val_precision: 0.8807 - val_recall: 0.5406
# Epoch 5/50
# 6/6 [==============================] - 2s 287ms/step - loss: 0.3936 - accuracy: 0.5740 - precision: 0.8454 - recall: 0.5283 - val_loss: 0.6325 - val_accuracy: 0.6416 - val_precision: 0.9036 - val_recall: 0.5672
# Epoch 6/50
# 6/6 [==============================] - 2s 290ms/step - loss: 0.3999 - accuracy: 0.6006 - precision: 0.8418 - recall: 0.5632 - val_loss: 0.6112 - val_accuracy: 0.6592 - val_precision: 0.9121 - val_recall: 0.5931
# Epoch 7/50
# 6/6 [==============================] - 2s 294ms/step - loss: 0.3876 - accuracy: 0.6203 - precision: 0.8438 - recall: 0.5814 - val_loss: 0.5964 - val_accuracy: 0.6914 - val_precision: 0.9072 - val_recall: 0.6364
# Epoch 8/50
# 6/6 [==============================] - 2s 297ms/step - loss: 0.3730 - accuracy: 0.6289 - precision: 0.8503 - recall: 0.6002 - val_loss: 0.5737 - val_accuracy: 0.7129 - val_precision: 0.9079 - val_recall: 0.6743
# Epoch 9/50
# 6/6 [==============================] - 2s 305ms/step - loss: 0.3832 - accuracy: 0.6339 - precision: 0.8335 - recall: 0.6218 - val_loss: 0.5650 - val_accuracy: 0.7197 - val_precision: 0.9102 - val_recall: 0.6866
# Epoch 10/50
# 6/6 [==============================] - 2s 309ms/step - loss: 0.3608 - accuracy: 0.6655 - precision: 0.8576 - recall: 0.6537 - val_loss: 0.5544 - val_accuracy: 0.7432 - val_precision: 0.9085 - val_recall: 0.7195
# Epoch 11/50
# 6/6 [==============================] - 2s 303ms/step - loss: 0.3561 - accuracy: 0.6757 - precision: 0.8543 - recall: 0.6709 - val_loss: 0.5468 - val_accuracy: 0.7549 - val_precision: 0.9121 - val_recall: 0.7353
# Epoch 12/50
# 6/6 [==============================] - 2s 305ms/step - loss: 0.3514 - accuracy: 0.6738 - precision: 0.8650 - recall: 0.6603 - val_loss: 0.5437 - val_accuracy: 0.7598 - val_precision: 0.9272 - val_recall: 0.7297
# Epoch 13/50
# 6/6 [==============================] - 2s 317ms/step - loss: 0.3506 - accuracy: 0.6838 - precision: 0.8703 - recall: 0.6704 - val_loss: 0.5407 - val_accuracy: 0.7598 - val_precision: 0.9153 - val_recall: 0.7386
# Epoch 14/50
# 6/6 [==============================] - 2s 304ms/step - loss: 0.3540 - accuracy: 0.6765 - precision: 0.8671 - recall: 0.6589 - val_loss: 0.5341 - val_accuracy: 0.7676 - val_precision: 0.9238 - val_recall: 0.7440
# Epoch 15/50
# 6/6 [==============================] - 2s 308ms/step - loss: 0.3456 - accuracy: 0.6849 - precision: 0.8571 - recall: 0.6834 - val_loss: 0.5299 - val_accuracy: 0.7686 - val_precision: 0.9259 - val_recall: 0.7402
# Epoch 16/50
# 6/6 [==============================] - 2s 304ms/step - loss: 0.3379 - accuracy: 0.7002 - precision: 0.8719 - recall: 0.6905 - val_loss: 0.5173 - val_accuracy: 0.7861 - val_precision: 0.9331 - val_recall: 0.7627
# Epoch 17/50
# 6/6 [==============================] - 2s 309ms/step - loss: 0.3420 - accuracy: 0.6890 - precision: 0.8583 - recall: 0.6840 - val_loss: 0.5213 - val_accuracy: 0.7773 - val_precision: 0.9320 - val_recall: 0.7503
# Epoch 18/50
# 6/6 [==============================] - 2s 303ms/step - loss: 0.3396 - accuracy: 0.6903 - precision: 0.8711 - recall: 0.6780 - val_loss: 0.5121 - val_accuracy: 0.7881 - val_precision: 0.9386 - val_recall: 0.7645
# Epoch 19/50
# 6/6 [==============================] - 2s 302ms/step - loss: 0.3329 - accuracy: 0.7110 - precision: 0.8851 - recall: 0.7025 - val_loss: 0.5094 - val_accuracy: 0.7881 - val_precision: 0.9327 - val_recall: 0.7634
# Epoch 20/50
# 6/6 [==============================] - 2s 308ms/step - loss: 0.3328 - accuracy: 0.7095 - precision: 0.8753 - recall: 0.7036 - val_loss: 0.5130 - val_accuracy: 0.7852 - val_precision: 0.9286 - val_recall: 0.7647
# Epoch 21/50
# 6/6 [==============================] - 2s 303ms/step - loss: 0.3320 - accuracy: 0.7010 - precision: 0.8658 - recall: 0.6948 - val_loss: 0.5079 - val_accuracy: 0.7891 - val_precision: 0.9283 - val_recall: 0.7682
# Epoch 22/50
# 6/6 [==============================] - 2s 313ms/step - loss: 0.3299 - accuracy: 0.6936 - precision: 0.8717 - recall: 0.6848 - val_loss: 0.5077 - val_accuracy: 0.7881 - val_precision: 0.9365 - val_recall: 0.7636
# Epoch 23/50
# 6/6 [==============================] - 2s 305ms/step - loss: 0.3342 - accuracy: 0.6874 - precision: 0.8794 - recall: 0.6632 - val_loss: 0.5049 - val_accuracy: 0.7920 - val_precision: 0.9311 - val_recall: 0.7686
# Epoch 24/50
# 6/6 [==============================] - 2s 300ms/step - loss: 0.3282 - accuracy: 0.7151 - precision: 0.8862 - recall: 0.7015 - val_loss: 0.5064 - val_accuracy: 0.7949 - val_precision: 0.9281 - val_recall: 0.7788
# Epoch 25/50
# 6/6 [==============================] - 2s 309ms/step - loss: 0.3377 - accuracy: 0.7043 - precision: 0.8800 - recall: 0.6910 - val_loss: 0.5049 - val_accuracy: 0.7969 - val_precision: 0.9370 - val_recall: 0.7744
# Epoch 26/50
# 6/6 [==============================] - 2s 308ms/step - loss: 0.3340 - accuracy: 0.7059 - precision: 0.8758 - recall: 0.6985 - val_loss: 0.5027 - val_accuracy: 0.7920 - val_precision: 0.9311 - val_recall: 0.7736
# Epoch 27/50
# 6/6 [==============================] - 2s 310ms/step - loss: 0.3340 - accuracy: 0.7076 - precision: 0.8771 - recall: 0.6994 - val_loss: 0.4993 - val_accuracy: 0.8096 - val_precision: 0.9451 - val_recall: 0.7842
# Epoch 28/50
# 6/6 [==============================] - 2s 304ms/step - loss: 0.3277 - accuracy: 0.7111 - precision: 0.8925 - recall: 0.6928 - val_loss: 0.4984 - val_accuracy: 0.8037 - val_precision: 0.9406 - val_recall: 0.7813
# Epoch 29/50
# 6/6 [==============================] - 2s 307ms/step - loss: 0.3248 - accuracy: 0.7232 - precision: 0.8868 - recall: 0.7136 - val_loss: 0.5020 - val_accuracy: 0.7979 - val_precision: 0.9348 - val_recall: 0.7798
# Epoch 30/50
# 6/6 [==============================] - 2s 301ms/step - loss: 0.3222 - accuracy: 0.7259 - precision: 0.8838 - recall: 0.7178 - val_loss: 0.4997 - val_accuracy: 0.7949 - val_precision: 0.9324 - val_recall: 0.7751
# Epoch 31/50
# 6/6 [==============================] - 2s 303ms/step - loss: 0.3221 - accuracy: 0.7124 - precision: 0.8853 - recall: 0.6942 - val_loss: 0.4978 - val_accuracy: 0.7988 - val_precision: 0.9364 - val_recall: 0.7746
# Epoch 32/50
# 6/6 [==============================] - 2s 301ms/step - loss: 0.3254 - accuracy: 0.7140 - precision: 0.8810 - recall: 0.7032 - val_loss: 0.5041 - val_accuracy: 0.7920 - val_precision: 0.9294 - val_recall: 0.7741
# Epoch 33/50
# 6/6 [==============================] - 2s 300ms/step - loss: 0.3409 - accuracy: 0.6953 - precision: 0.8625 - recall: 0.6908 - val_loss: 0.5058 - val_accuracy: 0.7910 - val_precision: 0.9363 - val_recall: 0.7660
# Epoch 34/50
# 6/6 [==============================] - 2s 303ms/step - loss: 0.3119 - accuracy: 0.7327 - precision: 0.8969 - recall: 0.7207 - val_loss: 0.4939 - val_accuracy: 0.8047 - val_precision: 0.9390 - val_recall: 0.7831
# Epoch 35/50
# 6/6 [==============================] - 2s 303ms/step - loss: 0.3137 - accuracy: 0.7367 - precision: 0.8967 - recall: 0.7209 - val_loss: 0.4976 - val_accuracy: 0.7998 - val_precision: 0.9388 - val_recall: 0.7773
# Epoch 36/50
# 6/6 [==============================] - 2s 304ms/step - loss: 0.3274 - accuracy: 0.7077 - precision: 0.8876 - recall: 0.6960 - val_loss: 0.4970 - val_accuracy: 0.7979 - val_precision: 0.9372 - val_recall: 0.7760
# Epoch 37/50
# 6/6 [==============================] - 2s 299ms/step - loss: 0.3214 - accuracy: 0.7283 - precision: 0.8839 - recall: 0.7189 - val_loss: 0.5068 - val_accuracy: 0.7822 - val_precision: 0.9301 - val_recall: 0.7606
# Epoch 38/50
# 6/6 [==============================] - 2s 299ms/step - loss: 0.3188 - accuracy: 0.7257 - precision: 0.8853 - recall: 0.7227 - val_loss: 0.4960 - val_accuracy: 0.7998 - val_precision: 0.9410 - val_recall: 0.7784
# Epoch 39/50
# 6/6 [==============================] - 2s 304ms/step - loss: 0.3323 - accuracy: 0.7034 - precision: 0.8795 - recall: 0.6909 - val_loss: 0.4925 - val_accuracy: 0.8018 - val_precision: 0.9452 - val_recall: 0.7765
# Epoch 40/50
# 6/6 [==============================] - 2s 302ms/step - loss: 0.3269 - accuracy: 0.7291 - precision: 0.8856 - recall: 0.7191 - val_loss: 0.4940 - val_accuracy: 0.8057 - val_precision: 0.9469 - val_recall: 0.7798
# Epoch 41/50
# 6/6 [==============================] - 2s 290ms/step - loss: 0.3217 - accuracy: 0.7129 - precision: 0.8900 - recall: 0.6945 - val_loss: 0.4966 - val_accuracy: 0.7939 - val_precision: 0.9343 - val_recall: 0.7689
# Epoch 42/50
# 6/6 [==============================] - 2s 293ms/step - loss: 0.3240 - accuracy: 0.7183 - precision: 0.8777 - recall: 0.7135 - val_loss: 0.4935 - val_accuracy: 0.8008 - val_precision: 0.9418 - val_recall: 0.7763
# Epoch 43/50
# 6/6 [==============================] - 2s 297ms/step - loss: 0.3147 - accuracy: 0.7197 - precision: 0.8942 - recall: 0.7007 - val_loss: 0.4958 - val_accuracy: 0.8057 - val_precision: 0.9411 - val_recall: 0.7849
# Epoch 44/50
# 6/6 [==============================] - 2s 297ms/step - loss: 0.3203 - accuracy: 0.7227 - precision: 0.8896 - recall: 0.7093 - val_loss: 0.4983 - val_accuracy: 0.7949 - val_precision: 0.9285 - val_recall: 0.7748
# Epoch 45/50
# 6/6 [==============================] - 2s 285ms/step - loss: 0.3179 - accuracy: 0.7270 - precision: 0.8875 - recall: 0.7264 - val_loss: 0.4924 - val_accuracy: 0.8047 - val_precision: 0.9351 - val_recall: 0.7880
# Epoch 46/50
# 6/6 [==============================] - 2s 302ms/step - loss: 0.3174 - accuracy: 0.7274 - precision: 0.9001 - recall: 0.7047 - val_loss: 0.5000 - val_accuracy: 0.7881 - val_precision: 0.9365 - val_recall: 0.7636
# Epoch 47/50
# 6/6 [==============================] - 2s 297ms/step - loss: 0.3187 - accuracy: 0.7268 - precision: 0.8927 - recall: 0.7135 - val_loss: 0.4947 - val_accuracy: 0.8018 - val_precision: 0.9371 - val_recall: 0.7799
# Epoch 48/50
# 6/6 [==============================] - 2s 293ms/step - loss: 0.3229 - accuracy: 0.7202 - precision: 0.8842 - recall: 0.7074 - val_loss: 0.5033 - val_accuracy: 0.7930 - val_precision: 0.9373 - val_recall: 0.7712
# Epoch 49/50
# 6/6 [==============================] - 2s 296ms/step - loss: 0.3261 - accuracy: 0.7214 - precision: 0.8836 - recall: 0.7131 - val_loss: 0.4935 - val_accuracy: 0.8027 - val_precision: 0.9357 - val_recall: 0.7823
# Epoch 50/50
# 6/6 [==============================] - 2s 296ms/step - loss: 0.3161 - accuracy: 0.7226 - precision: 0.8937 - recall: 0.6975 - val_loss: 0.4964 - val_accuracy: 0.7930 - val_precision: 0.9332 - val_recall: 0.7702
# Learning Rate: 0.0014165614055817728
# Epoch 1/50
# 6/6 [==============================] - 50s 4s/step - loss: 0.5045 - accuracy: 0.4367 - precision: 0.7150 - recall: 0.3648 - val_loss: 0.6104 - val_accuracy: 0.6855 - val_precision: 0.9371 - val_recall: 0.6135
# Epoch 2/50
# 6/6 [==============================] - 2s 307ms/step - loss: 0.3482 - accuracy: 0.6606 - precision: 0.8749 - recall: 0.6255 - val_loss: 0.4123 - val_accuracy: 0.8594 - val_precision: 0.9532 - val_recall: 0.8481
# Epoch 3/50
# 6/6 [==============================] - 2s 304ms/step - loss: 0.2607 - accuracy: 0.8026 - precision: 0.9286 - recall: 0.7941 - val_loss: 0.3583 - val_accuracy: 0.8574 - val_precision: 0.9574 - val_recall: 0.8420
# Epoch 4/50
# 6/6 [==============================] - 2s 311ms/step - loss: 0.2081 - accuracy: 0.8451 - precision: 0.9668 - recall: 0.8202 - val_loss: 0.3009 - val_accuracy: 0.8818 - val_precision: 0.9496 - val_recall: 0.8847
# Epoch 5/50
# 6/6 [==============================] - 2s 318ms/step - loss: 0.2063 - accuracy: 0.8584 - precision: 0.9368 - recall: 0.8654 - val_loss: 0.2750 - val_accuracy: 0.8955 - val_precision: 0.9604 - val_recall: 0.8958
# Epoch 6/50
# 6/6 [==============================] - 2s 326ms/step - loss: 0.1752 - accuracy: 0.8825 - precision: 0.9538 - recall: 0.8784 - val_loss: 0.2704 - val_accuracy: 0.8857 - val_precision: 0.9536 - val_recall: 0.8854
# Epoch 7/50
# 6/6 [==============================] - 2s 316ms/step - loss: 0.1749 - accuracy: 0.8863 - precision: 0.9594 - recall: 0.8814 - val_loss: 0.2626 - val_accuracy: 0.8945 - val_precision: 0.9573 - val_recall: 0.8960
# Epoch 8/50
# 6/6 [==============================] - 2s 316ms/step - loss: 0.1702 - accuracy: 0.8843 - precision: 0.9520 - recall: 0.8860 - val_loss: 0.2547 - val_accuracy: 0.8994 - val_precision: 0.9585 - val_recall: 0.9004
# Epoch 9/50
# 6/6 [==============================] - 2s 321ms/step - loss: 0.1579 - accuracy: 0.8961 - precision: 0.9577 - recall: 0.8970 - val_loss: 0.2450 - val_accuracy: 0.9072 - val_precision: 0.9699 - val_recall: 0.9013
# Epoch 10/50
# 6/6 [==============================] - 2s 317ms/step - loss: 0.1535 - accuracy: 0.8989 - precision: 0.9653 - recall: 0.8921 - val_loss: 0.2404 - val_accuracy: 0.9111 - val_precision: 0.9685 - val_recall: 0.9075
# Epoch 11/50
# 6/6 [==============================] - 2s 319ms/step - loss: 0.1533 - accuracy: 0.8919 - precision: 0.9577 - recall: 0.8919 - val_loss: 0.2452 - val_accuracy: 0.9014 - val_precision: 0.9644 - val_recall: 0.8992
# Epoch 12/50
# 6/6 [==============================] - 2s 319ms/step - loss: 0.1402 - accuracy: 0.9018 - precision: 0.9634 - recall: 0.9010 - val_loss: 0.2345 - val_accuracy: 0.9082 - val_precision: 0.9666 - val_recall: 0.9037
# Epoch 13/50
# 6/6 [==============================] - 2s 303ms/step - loss: 0.1441 - accuracy: 0.9031 - precision: 0.9713 - recall: 0.8949 - val_loss: 0.2300 - val_accuracy: 0.9111 - val_precision: 0.9703 - val_recall: 0.9075
# Epoch 14/50
# 6/6 [==============================] - 2s 332ms/step - loss: 0.1521 - accuracy: 0.8987 - precision: 0.9605 - recall: 0.8999 - val_loss: 0.2319 - val_accuracy: 0.9033 - val_precision: 0.9642 - val_recall: 0.9011
# Epoch 15/50
# 6/6 [==============================] - 2s 311ms/step - loss: 0.1445 - accuracy: 0.9006 - precision: 0.9670 - recall: 0.8960 - val_loss: 0.2338 - val_accuracy: 0.9082 - val_precision: 0.9728 - val_recall: 0.9005
# Epoch 16/50
# 6/6 [==============================] - 2s 296ms/step - loss: 0.1519 - accuracy: 0.9011 - precision: 0.9605 - recall: 0.9005 - val_loss: 0.2205 - val_accuracy: 0.9121 - val_precision: 0.9713 - val_recall: 0.9064
# Epoch 17/50
# 6/6 [==============================] - 2s 307ms/step - loss: 0.1445 - accuracy: 0.9069 - precision: 0.9657 - recall: 0.9056 - val_loss: 0.2261 - val_accuracy: 0.9092 - val_precision: 0.9688 - val_recall: 0.9057
# Epoch 18/50
# 6/6 [==============================] - 2s 302ms/step - loss: 0.1429 - accuracy: 0.8957 - precision: 0.9668 - recall: 0.8847 - val_loss: 0.2203 - val_accuracy: 0.9092 - val_precision: 0.9688 - val_recall: 0.9058
# Epoch 19/50
# 6/6 [==============================] - 2s 306ms/step - loss: 0.1402 - accuracy: 0.9081 - precision: 0.9652 - recall: 0.9085 - val_loss: 0.2163 - val_accuracy: 0.9121 - val_precision: 0.9642 - val_recall: 0.9119
# Epoch 20/50
# 6/6 [==============================] - 2s 326ms/step - loss: 0.1484 - accuracy: 0.9041 - precision: 0.9596 - recall: 0.9081 - val_loss: 0.2166 - val_accuracy: 0.9111 - val_precision: 0.9700 - val_recall: 0.9065
# Epoch 21/50
# 6/6 [==============================] - 2s 315ms/step - loss: 0.1331 - accuracy: 0.9145 - precision: 0.9722 - recall: 0.9101 - val_loss: 0.2210 - val_accuracy: 0.9072 - val_precision: 0.9672 - val_recall: 0.9040
# Epoch 22/50
# 6/6 [==============================] - 2s 292ms/step - loss: 0.1378 - accuracy: 0.8995 - precision: 0.9724 - recall: 0.8886 - val_loss: 0.2234 - val_accuracy: 0.9111 - val_precision: 0.9672 - val_recall: 0.9088
# Epoch 23/50
# 6/6 [==============================] - 2s 284ms/step - loss: 0.1389 - accuracy: 0.9070 - precision: 0.9686 - recall: 0.9018 - val_loss: 0.2226 - val_accuracy: 0.9131 - val_precision: 0.9690 - val_recall: 0.9113
# Epoch 24/50
# 6/6 [==============================] - 2s 291ms/step - loss: 0.1412 - accuracy: 0.9080 - precision: 0.9649 - recall: 0.9047 - val_loss: 0.2138 - val_accuracy: 0.9131 - val_precision: 0.9686 - val_recall: 0.9102
# Epoch 25/50
# 6/6 [==============================] - 2s 311ms/step - loss: 0.1344 - accuracy: 0.9104 - precision: 0.9701 - recall: 0.9067 - val_loss: 0.2138 - val_accuracy: 0.9062 - val_precision: 0.9655 - val_recall: 0.9032
# Epoch 26/50
# 6/6 [==============================] - 2s 302ms/step - loss: 0.1496 - accuracy: 0.8975 - precision: 0.9538 - recall: 0.9033 - val_loss: 0.2167 - val_accuracy: 0.9121 - val_precision: 0.9702 - val_recall: 0.9082
# Epoch 27/50
# 6/6 [==============================] - 2s 301ms/step - loss: 0.1405 - accuracy: 0.9131 - precision: 0.9675 - recall: 0.9107 - val_loss: 0.2231 - val_accuracy: 0.9062 - val_precision: 0.9674 - val_recall: 0.9033
# Epoch 28/50
# 6/6 [==============================] - 2s 298ms/step - loss: 0.1347 - accuracy: 0.9116 - precision: 0.9673 - recall: 0.9126 - val_loss: 0.2233 - val_accuracy: 0.9092 - val_precision: 0.9660 - val_recall: 0.9081
# Epoch 29/50
# 6/6 [==============================] - 2s 293ms/step - loss: 0.1393 - accuracy: 0.9077 - precision: 0.9624 - recall: 0.9087 - val_loss: 0.2179 - val_accuracy: 0.9111 - val_precision: 0.9715 - val_recall: 0.9056
# Epoch 30/50
# 6/6 [==============================] - 2s 306ms/step - loss: 0.1416 - accuracy: 0.9067 - precision: 0.9674 - recall: 0.9007 - val_loss: 0.2192 - val_accuracy: 0.9092 - val_precision: 0.9690 - val_recall: 0.9063
# Epoch 31/50
# 6/6 [==============================] - 2s 302ms/step - loss: 0.1336 - accuracy: 0.9152 - precision: 0.9691 - recall: 0.9115 - val_loss: 0.2171 - val_accuracy: 0.9053 - val_precision: 0.9656 - val_recall: 0.9023
# Epoch 32/50
# 6/6 [==============================] - 2s 293ms/step - loss: 0.1410 - accuracy: 0.9076 - precision: 0.9709 - recall: 0.9009 - val_loss: 0.2160 - val_accuracy: 0.9121 - val_precision: 0.9662 - val_recall: 0.9124
# Epoch 33/50
# 6/6 [==============================] - 2s 303ms/step - loss: 0.1394 - accuracy: 0.9096 - precision: 0.9668 - recall: 0.9069 - val_loss: 0.2138 - val_accuracy: 0.9141 - val_precision: 0.9690 - val_recall: 0.9124
# Epoch 34/50
# 6/6 [==============================] - 2s 307ms/step - loss: 0.1357 - accuracy: 0.9173 - precision: 0.9712 - recall: 0.9149 - val_loss: 0.2181 - val_accuracy: 0.9111 - val_precision: 0.9674 - val_recall: 0.9095
# Learning Rate: 0.00010046476543373706
# Epoch 1/50
# 6/6 [==============================] - 51s 4s/step - loss: 0.6782 - accuracy: 0.2680 - precision: 0.4594 - recall: 0.0410 - val_loss: 1.3317 - val_accuracy: 0.2520 - val_precision: 0.1622 - val_recall: 0.0081
# Epoch 2/50
# 6/6 [==============================] - 2s 311ms/step - loss: 0.6325 - accuracy: 0.2690 - precision: 0.5100 - recall: 0.0777 - val_loss: 1.2172 - val_accuracy: 0.2305 - val_precision: 0.2436 - val_recall: 0.0254
# Epoch 3/50
# 6/6 [==============================] - 2s 302ms/step - loss: 0.6196 - accuracy: 0.2557 - precision: 0.4363 - recall: 0.0954 - val_loss: 1.1132 - val_accuracy: 0.2393 - val_precision: 0.3565 - val_recall: 0.0550
# Epoch 4/50
# 6/6 [==============================] - 2s 313ms/step - loss: 0.6018 - accuracy: 0.2805 - precision: 0.5214 - recall: 0.1467 - val_loss: 1.0604 - val_accuracy: 0.2451 - val_precision: 0.4218 - val_recall: 0.0827
# Epoch 5/50
# 6/6 [==============================] - 2s 304ms/step - loss: 0.5798 - accuracy: 0.3102 - precision: 0.5857 - recall: 0.1939 - val_loss: 1.0153 - val_accuracy: 0.2578 - val_precision: 0.4767 - val_recall: 0.1090
# Epoch 6/50
# 6/6 [==============================] - 2s 365ms/step - loss: 0.5734 - accuracy: 0.3027 - precision: 0.5669 - recall: 0.2097 - val_loss: 0.9829 - val_accuracy: 0.2695 - val_precision: 0.4949 - val_recall: 0.1300
# Epoch 7/50
# 6/6 [==============================] - 2s 315ms/step - loss: 0.5668 - accuracy: 0.3265 - precision: 0.5971 - recall: 0.2351 - val_loss: 0.9595 - val_accuracy: 0.2695 - val_precision: 0.5024 - val_recall: 0.1375
# Epoch 8/50
# 6/6 [==============================] - 2s 311ms/step - loss: 0.5463 - accuracy: 0.3507 - precision: 0.6190 - recall: 0.2606 - val_loss: 0.9377 - val_accuracy: 0.2881 - val_precision: 0.5189 - val_recall: 0.1493
# Epoch 9/50
# 6/6 [==============================] - 2s 321ms/step - loss: 0.5434 - accuracy: 0.3595 - precision: 0.6284 - recall: 0.2764 - val_loss: 0.9288 - val_accuracy: 0.2949 - val_precision: 0.5676 - val_recall: 0.1676
# Epoch 10/50
# 6/6 [==============================] - 2s 334ms/step - loss: 0.5383 - accuracy: 0.3456 - precision: 0.6385 - recall: 0.2640 - val_loss: 0.9169 - val_accuracy: 0.3018 - val_precision: 0.5792 - val_recall: 0.1707
# Epoch 11/50
# 6/6 [==============================] - 2s 308ms/step - loss: 0.5343 - accuracy: 0.3684 - precision: 0.6529 - recall: 0.2898 - val_loss: 0.9104 - val_accuracy: 0.3027 - val_precision: 0.5796 - val_recall: 0.1747
# Epoch 12/50
# 6/6 [==============================] - 2s 328ms/step - loss: 0.5177 - accuracy: 0.3602 - precision: 0.6584 - recall: 0.2753 - val_loss: 0.9027 - val_accuracy: 0.3135 - val_precision: 0.6059 - val_recall: 0.1899
# Epoch 13/50
# 6/6 [==============================] - 2s 335ms/step - loss: 0.5220 - accuracy: 0.3810 - precision: 0.6859 - recall: 0.2946 - val_loss: 0.8904 - val_accuracy: 0.3242 - val_precision: 0.6311 - val_recall: 0.2037
# Epoch 14/50
# 6/6 [==============================] - 2s 309ms/step - loss: 0.5149 - accuracy: 0.3924 - precision: 0.6774 - recall: 0.3146 - val_loss: 0.8815 - val_accuracy: 0.3301 - val_precision: 0.6230 - val_recall: 0.2038
# Epoch 15/50
# 6/6 [==============================] - 2s 315ms/step - loss: 0.5045 - accuracy: 0.3984 - precision: 0.6843 - recall: 0.3236 - val_loss: 0.8775 - val_accuracy: 0.3281 - val_precision: 0.6295 - val_recall: 0.2098
# Epoch 16/50
# 6/6 [==============================] - 2s 323ms/step - loss: 0.5031 - accuracy: 0.3804 - precision: 0.6687 - recall: 0.2899 - val_loss: 0.8666 - val_accuracy: 0.3311 - val_precision: 0.6364 - val_recall: 0.2135
# Epoch 17/50
# 6/6 [==============================] - 2s 323ms/step - loss: 0.5034 - accuracy: 0.4055 - precision: 0.6849 - recall: 0.3381 - val_loss: 0.8675 - val_accuracy: 0.3340 - val_precision: 0.6231 - val_recall: 0.2172
# Epoch 18/50
# 6/6 [==============================] - 2s 326ms/step - loss: 0.5188 - accuracy: 0.3659 - precision: 0.6491 - recall: 0.2934 - val_loss: 0.8589 - val_accuracy: 0.3418 - val_precision: 0.6357 - val_recall: 0.2204
# Epoch 19/50
# 6/6 [==============================] - 2s 304ms/step - loss: 0.4996 - accuracy: 0.3863 - precision: 0.6915 - recall: 0.3205 - val_loss: 0.8600 - val_accuracy: 0.3389 - val_precision: 0.6367 - val_recall: 0.2182
# Epoch 20/50
# 6/6 [==============================] - 2s 305ms/step - loss: 0.4924 - accuracy: 0.3996 - precision: 0.7077 - recall: 0.3292 - val_loss: 0.8484 - val_accuracy: 0.3486 - val_precision: 0.6367 - val_recall: 0.2297
# Epoch 21/50
# 6/6 [==============================] - 2s 310ms/step - loss: 0.4897 - accuracy: 0.4102 - precision: 0.7158 - recall: 0.3374 - val_loss: 0.8497 - val_accuracy: 0.3496 - val_precision: 0.6567 - val_recall: 0.2347
# Epoch 22/50
# 6/6 [==============================] - 2s 312ms/step - loss: 0.4964 - accuracy: 0.4034 - precision: 0.6945 - recall: 0.3323 - val_loss: 0.8437 - val_accuracy: 0.3516 - val_precision: 0.6581 - val_recall: 0.2387
# Epoch 23/50
# 6/6 [==============================] - 2s 309ms/step - loss: 0.4980 - accuracy: 0.4076 - precision: 0.6880 - recall: 0.3335 - val_loss: 0.8442 - val_accuracy: 0.3555 - val_precision: 0.6753 - val_recall: 0.2424
# Epoch 24/50
# 6/6 [==============================] - 2s 316ms/step - loss: 0.4986 - accuracy: 0.4236 - precision: 0.6923 - recall: 0.3715 - val_loss: 0.8398 - val_accuracy: 0.3604 - val_precision: 0.6631 - val_recall: 0.2480
# Epoch 25/50
# 6/6 [==============================] - 2s 312ms/step - loss: 0.4918 - accuracy: 0.4231 - precision: 0.7149 - recall: 0.3466 - val_loss: 0.8422 - val_accuracy: 0.3516 - val_precision: 0.6520 - val_recall: 0.2383
# Epoch 26/50
# 6/6 [==============================] - 2s 306ms/step - loss: 0.4997 - accuracy: 0.4020 - precision: 0.6918 - recall: 0.3498 - val_loss: 0.8410 - val_accuracy: 0.3486 - val_precision: 0.6603 - val_recall: 0.2304
# Epoch 27/50
# 6/6 [==============================] - 2s 297ms/step - loss: 0.4822 - accuracy: 0.4259 - precision: 0.7395 - recall: 0.3496 - val_loss: 0.8322 - val_accuracy: 0.3643 - val_precision: 0.6643 - val_recall: 0.2480
# Epoch 28/50
# 6/6 [==============================] - 2s 324ms/step - loss: 0.4942 - accuracy: 0.4101 - precision: 0.7022 - recall: 0.3326 - val_loss: 0.8369 - val_accuracy: 0.3623 - val_precision: 0.6740 - val_recall: 0.2460
# Epoch 29/50
# 6/6 [==============================] - 2s 314ms/step - loss: 0.4842 - accuracy: 0.4146 - precision: 0.7202 - recall: 0.3325 - val_loss: 0.8326 - val_accuracy: 0.3594 - val_precision: 0.6703 - val_recall: 0.2467
# Epoch 30/50
# 6/6 [==============================] - 2s 310ms/step - loss: 0.5077 - accuracy: 0.3903 - precision: 0.6786 - recall: 0.3236 - val_loss: 0.8337 - val_accuracy: 0.3564 - val_precision: 0.6716 - val_recall: 0.2397
# Epoch 31/50
# 6/6 [==============================] - 2s 307ms/step - loss: 0.4898 - accuracy: 0.4361 - precision: 0.7109 - recall: 0.3691 - val_loss: 0.8319 - val_accuracy: 0.3652 - val_precision: 0.6619 - val_recall: 0.2486
# Epoch 32/50
# 6/6 [==============================] - 2s 315ms/step - loss: 0.4816 - accuracy: 0.4235 - precision: 0.7244 - recall: 0.3406 - val_loss: 0.8285 - val_accuracy: 0.3711 - val_precision: 0.6855 - val_recall: 0.2590
# Epoch 33/50
# 6/6 [==============================] - 2s 314ms/step - loss: 0.4953 - accuracy: 0.4105 - precision: 0.7021 - recall: 0.3456 - val_loss: 0.8239 - val_accuracy: 0.3740 - val_precision: 0.6996 - val_recall: 0.2626
# Epoch 34/50
# ...
# Epoch 22/50
# 6/6 [==============================] - 2s 319ms/step - loss: 0.0839 - accuracy: 0.9504 - precision: 0.9834 - recall: 0.9487 - val_loss: 0.1283 - val_accuracy: 0.9531 - val_precision: 0.9834 - val_recall: 0.9519
# Epoch 23/50
# 6/6 [==============================] - 2s 303ms/step - loss: 0.0938 - accuracy: 0.9419 - precision: 0.9845 - recall: 0.9349 - val_loss: 0.1140 - val_accuracy: 0.9619 - val_precision: 0.9850 - val_recall: 0.9628
# Epoch 24/50
# 6/6 [==============================] - 3s 503ms/step - loss: 0.1104 - accuracy: 0.9469 - precision: 0.9744 - recall: 0.9519 - val_loss: 0.1036 - val_accuracy: 0.9639 - val_precision: 0.9862 - val_recall: 0.9637
# Epoch 25/50
# 6/6 [==============================] - 2s 306ms/step - loss: 0.0948 - accuracy: 0.9467 - precision: 0.9796 - recall: 0.9462 - val_loss: 0.1202 - val_accuracy: 0.9561 - val_precision: 0.9822 - val_recall: 0.9572
# Epoch 26/50
# 6/6 [==============================] - 2s 300ms/step - loss: 0.0801 - accuracy: 0.9515 - precision: 0.9836 - recall: 0.9494 - val_loss: 0.1195 - val_accuracy: 0.9541 - val_precision: 0.9847 - val_recall: 0.9516
# Epoch 27/50
# 6/6 [==============================] - 2s 291ms/step - loss: 0.1027 - accuracy: 0.9392 - precision: 0.9780 - recall: 0.9385 - val_loss: 0.1135 - val_accuracy: 0.9561 - val_precision: 0.9849 - val_recall: 0.9548
# Epoch 28/50
# 6/6 [==============================] - 2s 295ms/step - loss: 0.0947 - accuracy: 0.9451 - precision: 0.9807 - recall: 0.9437 - val_loss: 0.1150 - val_accuracy: 0.9570 - val_precision: 0.9836 - val_recall: 0.9574
# Epoch 29/50
# 6/6 [==============================] - 2s 303ms/step - loss: 0.0900 - accuracy: 0.9473 - precision: 0.9798 - recall: 0.9480 - val_loss: 0.1035 - val_accuracy: 0.9619 - val_precision: 0.9837 - val_recall: 0.9641
# Epoch 30/50
# 6/6 [==============================] - 2s 304ms/step - loss: 0.0796 - accuracy: 0.9532 - precision: 0.9834 - recall: 0.9522 - val_loss: 0.1121 - val_accuracy: 0.9570 - val_precision: 0.9821 - val_recall: 0.9583
# Epoch 31/50
# 6/6 [==============================] - 2s 323ms/step - loss: 0.0835 - accuracy: 0.9499 - precision: 0.9857 - recall: 0.9449 - val_loss: 0.1120 - val_accuracy: 0.9590 - val_precision: 0.9850 - val_recall: 0.9588
# Epoch 32/50
# 6/6 [==============================] - 2s 299ms/step - loss: 0.0913 - accuracy: 0.9489 - precision: 0.9811 - recall: 0.9482 - val_loss: 0.1009 - val_accuracy: 0.9629 - val_precision: 0.9863 - val_recall: 0.9627
# Epoch 33/50
# 6/6 [==============================] - 2s 303ms/step - loss: 0.0796 - accuracy: 0.9526 - precision: 0.9782 - recall: 0.9563 - val_loss: 0.1140 - val_accuracy: 0.9570 - val_precision: 0.9835 - val_recall: 0.9572
# Epoch 34/50
# 6/6 [==============================] - 2s 298ms/step - loss: 0.0743 - accuracy: 0.9504 - precision: 0.9830 - recall: 0.9475 - val_loss: 0.1145 - val_accuracy: 0.9561 - val_precision: 0.9848 - val_recall: 0.9546
# Epoch 35/50
# 6/6 [==============================] - 2s 290ms/step - loss: 0.0832 - accuracy: 0.9532 - precision: 0.9807 - recall: 0.9553 - val_loss: 0.1088 - val_accuracy: 0.9580 - val_precision: 0.9847 - val_recall: 0.9567
# Epoch 36/50
# 6/6 [==============================] - 2s 294ms/step - loss: 0.0852 - accuracy: 0.9461 - precision: 0.9823 - recall: 0.9440 - val_loss: 0.1118 - val_accuracy: 0.9570 - val_precision: 0.9834 - val_recall: 0.9570
# Epoch 37/50
# 6/6 [==============================] - 2s 313ms/step - loss: 0.0874 - accuracy: 0.9477 - precision: 0.9833 - recall: 0.9450 - val_loss: 0.1167 - val_accuracy: 0.9570 - val_precision: 0.9823 - val_recall: 0.9589
# Epoch 38/50
# 6/6 [==============================] - 2s 309ms/step - loss: 0.0907 - accuracy: 0.9491 - precision: 0.9751 - recall: 0.9542 - val_loss: 0.1049 - val_accuracy: 0.9600 - val_precision: 0.9861 - val_recall: 0.9583
# Epoch 39/50
# 6/6 [==============================] - 2s 301ms/step - loss: 0.0850 - accuracy: 0.9536 - precision: 0.9798 - recall: 0.9558 - val_loss: 0.1086 - val_accuracy: 0.9580 - val_precision: 0.9834 - val_recall: 0.9582
# Epoch 40/50
# 6/6 [==============================] - 2s 314ms/step - loss: 0.0928 - accuracy: 0.9460 - precision: 0.9808 - recall: 0.9448 - val_loss: 0.1093 - val_accuracy: 0.9570 - val_precision: 0.9835 - val_recall: 0.9572
# Epoch 41/50
# 6/6 [==============================] - 2s 302ms/step - loss: 0.0753 - accuracy: 0.9535 - precision: 0.9838 - recall: 0.9521 - val_loss: 0.1068 - val_accuracy: 0.9609 - val_precision: 0.9836 - val_recall: 0.9626
# Epoch 42/50
# 6/6 [==============================] - 2s 301ms/step - loss: 0.0955 - accuracy: 0.9518 - precision: 0.9757 - recall: 0.9565 - val_loss: 0.1165 - val_accuracy: 0.9561 - val_precision: 0.9863 - val_recall: 0.9535
# Learning Rate: 0.3608510106588103
# Epoch 1/50
# 6/6 [==============================] - 51s 4s/step - loss: 23.5151 - accuracy: 0.4991 - precision: 0.7401 - recall: 0.4840 - val_loss: 22.1787 - val_accuracy: 0.7354 - val_precision: 0.7351 - val_recall: 1.0000
# Epoch 2/50
# 6/6 [==============================] - 2s 315ms/step - loss: 14.7603 - accuracy: 0.7319 - precision: 0.8115 - recall: 0.8376 - val_loss: 27.8720 - val_accuracy: 0.6084 - val_precision: 1.0000 - val_recall: 0.4668
# Epoch 3/50
# 6/6 [==============================] - 2s 299ms/step - loss: 7.9995 - accuracy: 0.7175 - precision: 0.9809 - recall: 0.6342 - val_loss: 6.5991 - val_accuracy: 0.8926 - val_precision: 0.8832 - val_recall: 0.9841
# Epoch 4/50
# 6/6 [==============================] - 2s 305ms/step - loss: 6.6049 - accuracy: 0.8932 - precision: 0.8867 - recall: 0.9791 - val_loss: 5.2224 - val_accuracy: 0.8945 - val_precision: 0.9516 - val_recall: 0.9003
# Epoch 5/50
# 6/6 [==============================] - 2s 301ms/step - loss: 3.3557 - accuracy: 0.8843 - precision: 0.9736 - recall: 0.8642 - val_loss: 9.9097 - val_accuracy: 0.8438 - val_precision: 0.9835 - val_recall: 0.7989
# Epoch 6/50
# 6/6 [==============================] - 2s 296ms/step - loss: 3.4842 - accuracy: 0.8701 - precision: 0.9813 - recall: 0.8417 - val_loss: 3.6256 - val_accuracy: 0.9180 - val_precision: 0.9550 - val_recall: 0.9322
# Epoch 7/50
# 6/6 [==============================] - 2s 304ms/step - loss: 2.5957 - accuracy: 0.9184 - precision: 0.9461 - recall: 0.9418 - val_loss: 3.3689 - val_accuracy: 0.9180 - val_precision: 0.9456 - val_recall: 0.9405
# Epoch 8/50
# 6/6 [==============================] - 2s 308ms/step - loss: 2.1383 - accuracy: 0.9229 - precision: 0.9600 - recall: 0.9324 - val_loss: 4.4338 - val_accuracy: 0.8945 - val_precision: 0.9689 - val_recall: 0.8826
# Epoch 9/50
# 6/6 [==============================] - 2s 306ms/step - loss: 2.2575 - accuracy: 0.9112 - precision: 0.9784 - recall: 0.8970 - val_loss: 3.8209 - val_accuracy: 0.9072 - val_precision: 0.9725 - val_recall: 0.8985
# Epoch 10/50
# 6/6 [==============================] - 2s 307ms/step - loss: 2.2779 - accuracy: 0.9093 - precision: 0.9679 - recall: 0.9073 - val_loss: 2.7039 - val_accuracy: 0.9229 - val_precision: 0.9586 - val_recall: 0.9341
# Epoch 11/50
# 6/6 [==============================] - 2s 307ms/step - loss: 1.6089 - accuracy: 0.9346 - precision: 0.9666 - recall: 0.9445 - val_loss: 2.4764 - val_accuracy: 0.9258 - val_precision: 0.9658 - val_recall: 0.9327
# Epoch 12/50
# 6/6 [==============================] - 2s 309ms/step - loss: 1.6025 - accuracy: 0.9262 - precision: 0.9698 - recall: 0.9293 - val_loss: 2.7261 - val_accuracy: 0.9199 - val_precision: 0.9742 - val_recall: 0.9140
# Epoch 13/50
# 6/6 [==============================] - 2s 314ms/step - loss: 1.5008 - accuracy: 0.9298 - precision: 0.9785 - recall: 0.9247 - val_loss: 2.2915 - val_accuracy: 0.9268 - val_precision: 0.9719 - val_recall: 0.9265
# Epoch 14/50
# 6/6 [==============================] - 2s 306ms/step - loss: 1.5431 - accuracy: 0.9277 - precision: 0.9702 - recall: 0.9295 - val_loss: 2.0960 - val_accuracy: 0.9248 - val_precision: 0.9646 - val_recall: 0.9329
# Epoch 15/50
# 6/6 [==============================] - 2s 304ms/step - loss: 1.3484 - accuracy: 0.9357 - precision: 0.9712 - recall: 0.9392 - val_loss: 1.9551 - val_accuracy: 0.9297 - val_precision: 0.9656 - val_recall: 0.9372
# Epoch 16/50
# 6/6 [==============================] - 2s 306ms/step - loss: 1.3865 - accuracy: 0.9296 - precision: 0.9686 - recall: 0.9334 - val_loss: 2.2356 - val_accuracy: 0.9170 - val_precision: 0.9703 - val_recall: 0.9147
# Epoch 17/50
# 6/6 [==============================] - 2s 322ms/step - loss: 1.3864 - accuracy: 0.9265 - precision: 0.9788 - recall: 0.9197 - val_loss: 1.8672 - val_accuracy: 0.9248 - val_precision: 0.9680 - val_recall: 0.9279
# Epoch 18/50
# 6/6 [==============================] - 2s 309ms/step - loss: 1.2274 - accuracy: 0.9361 - precision: 0.9716 - recall: 0.9394 - val_loss: 1.6697 - val_accuracy: 0.9307 - val_precision: 0.9695 - val_recall: 0.9346
# Epoch 19/50
# 6/6 [==============================] - 2s 308ms/step - loss: 1.1950 - accuracy: 0.9344 - precision: 0.9684 - recall: 0.9407 - val_loss: 1.6765 - val_accuracy: 0.9248 - val_precision: 0.9655 - val_recall: 0.9309
# Epoch 20/50
# 6/6 [==============================] - 3s 491ms/step - loss: 1.1318 - accuracy: 0.9353 - precision: 0.9762 - recall: 0.9349 - val_loss: 1.7257 - val_accuracy: 0.9248 - val_precision: 0.9683 - val_recall: 0.9286
# Epoch 21/50
# 6/6 [==============================] - 2s 310ms/step - loss: 1.0749 - accuracy: 0.9379 - precision: 0.9828 - recall: 0.9308 - val_loss: 1.4621 - val_accuracy: 0.9307 - val_precision: 0.9711 - val_recall: 0.9339
# Epoch 22/50
# 6/6 [==============================] - 2s 318ms/step - loss: 0.9729 - accuracy: 0.9382 - precision: 0.9752 - recall: 0.9390 - val_loss: 1.5040 - val_accuracy: 0.9355 - val_precision: 0.9699 - val_recall: 0.9416
# Epoch 23/50
# 6/6 [==============================] - 2s 318ms/step - loss: 1.1445 - accuracy: 0.9380 - precision: 0.9788 - recall: 0.9353 - val_loss: 1.4003 - val_accuracy: 0.9385 - val_precision: 0.9698 - val_recall: 0.9451
# Epoch 24/50
# 6/6 [==============================] - 2s 304ms/step - loss: 1.0147 - accuracy: 0.9442 - precision: 0.9752 - recall: 0.9466 - val_loss: 1.3723 - val_accuracy: 0.9375 - val_precision: 0.9658 - val_recall: 0.9476
# Epoch 25/50
# 6/6 [==============================] - 2s 313ms/step - loss: 0.9496 - accuracy: 0.9386 - precision: 0.9749 - recall: 0.9401 - val_loss: 1.4249 - val_accuracy: 0.9326 - val_precision: 0.9671 - val_recall: 0.9401
# Epoch 26/50
# 6/6 [==============================] - 2s 307ms/step - loss: 0.9628 - accuracy: 0.9416 - precision: 0.9738 - recall: 0.9452 - val_loss: 1.5726 - val_accuracy: 0.9248 - val_precision: 0.9709 - val_recall: 0.9259
# Epoch 27/50
# 6/6 [==============================] - 2s 294ms/step - loss: 0.8094 - accuracy: 0.9362 - precision: 0.9819 - recall: 0.9315 - val_loss: 1.5314 - val_accuracy: 0.9268 - val_precision: 0.9677 - val_recall: 0.9297
# Epoch 28/50
# 6/6 [==============================] - 2s 300ms/step - loss: 1.0519 - accuracy: 0.9366 - precision: 0.9768 - recall: 0.9368 - val_loss: 1.3263 - val_accuracy: 0.9297 - val_precision: 0.9695 - val_recall: 0.9333
# Epoch 29/50
# 6/6 [==============================] - 2s 306ms/step - loss: 0.9229 - accuracy: 0.9329 - precision: 0.9784 - recall: 0.9281 - val_loss: 1.4002 - val_accuracy: 0.9287 - val_precision: 0.9654 - val_recall: 0.9357
# Epoch 30/50
# 6/6 [==============================] - 2s 307ms/step - loss: 0.9709 - accuracy: 0.9388 - precision: 0.9714 - recall: 0.9426 - val_loss: 1.2402 - val_accuracy: 0.9365 - val_precision: 0.9687 - val_recall: 0.9443
# Epoch 31/50
# 6/6 [==============================] - 2s 317ms/step - loss: 0.8661 - accuracy: 0.9317 - precision: 0.9721 - recall: 0.9330 - val_loss: 1.1715 - val_accuracy: 0.9346 - val_precision: 0.9708 - val_recall: 0.9382
# Epoch 32/50
# 6/6 [==============================] - 2s 309ms/step - loss: 1.0767 - accuracy: 0.9377 - precision: 0.9752 - recall: 0.9382 - val_loss: 1.2442 - val_accuracy: 0.9326 - val_precision: 0.9653 - val_recall: 0.9405
# Epoch 33/50
# 6/6 [==============================] - 2s 308ms/step - loss: 0.8335 - accuracy: 0.9442 - precision: 0.9781 - recall: 0.9457 - val_loss: 1.2346 - val_accuracy: 0.9336 - val_precision: 0.9696 - val_recall: 0.9385
# Epoch 34/50
# 6/6 [==============================] - 2s 300ms/step - loss: 0.8217 - accuracy: 0.9429 - precision: 0.9759 - recall: 0.9434 - val_loss: 1.2773 - val_accuracy: 0.9355 - val_precision: 0.9710 - val_recall: 0.9399
# Epoch 35/50
# 6/6 [==============================] - 2s 299ms/step - loss: 0.9041 - accuracy: 0.9396 - precision: 0.9800 - recall: 0.9378 - val_loss: 1.1736 - val_accuracy: 0.9355 - val_precision: 0.9657 - val_recall: 0.9450
# Epoch 36/50
# 6/6 [==============================] - 2s 294ms/step - loss: 0.6957 - accuracy: 0.9486 - precision: 0.9832 - recall: 0.9455 - val_loss: 1.0481 - val_accuracy: 0.9434 - val_precision: 0.9712 - val_recall: 0.9504
# Epoch 37/50
# 6/6 [==============================] - 2s 311ms/step - loss: 0.9049 - accuracy: 0.9352 - precision: 0.9741 - recall: 0.9378 - val_loss: 1.0815 - val_accuracy: 0.9414 - val_precision: 0.9737 - val_recall: 0.9449
# Epoch 38/50
# 6/6 [==============================] - 2s 307ms/step - loss: 1.0126 - accuracy: 0.9408 - precision: 0.9708 - recall: 0.9478 - val_loss: 1.2039 - val_accuracy: 0.9336 - val_precision: 0.9686 - val_recall: 0.9403
# Epoch 39/50
# 6/6 [==============================] - 2s 307ms/step - loss: 0.9544 - accuracy: 0.9380 - precision: 0.9720 - recall: 0.9427 - val_loss: 1.1838 - val_accuracy: 0.9365 - val_precision: 0.9749 - val_recall: 0.9369
# Epoch 40/50
# 6/6 [==============================] - 2s 299ms/step - loss: 0.7781 - accuracy: 0.9392 - precision: 0.9736 - recall: 0.9419 - val_loss: 0.9718 - val_accuracy: 0.9365 - val_precision: 0.9709 - val_recall: 0.9409
# Epoch 41/50
# 6/6 [==============================] - 2s 309ms/step - loss: 0.8049 - accuracy: 0.9409 - precision: 0.9751 - recall: 0.9429 - val_loss: 1.1896 - val_accuracy: 0.9346 - val_precision: 0.9711 - val_recall: 0.9388
# Epoch 42/50
# 6/6 [==============================] - 2s 308ms/step - loss: 0.8585 - accuracy: 0.9410 - precision: 0.9775 - recall: 0.9423 - val_loss: 1.1810 - val_accuracy: 0.9346 - val_precision: 0.9680 - val_recall: 0.9405
# Epoch 43/50
# 6/6 [==============================] - 2s 306ms/step - loss: 0.7481 - accuracy: 0.9384 - precision: 0.9742 - recall: 0.9404 - val_loss: 1.3242 - val_accuracy: 0.9287 - val_precision: 0.9697 - val_recall: 0.9325
# Epoch 44/50
# 6/6 [==============================] - 2s 297ms/step - loss: 0.8653 - accuracy: 0.9374 - precision: 0.9772 - recall: 0.9366 - val_loss: 1.1618 - val_accuracy: 0.9365 - val_precision: 0.9725 - val_recall: 0.9402
# Epoch 45/50
# 6/6 [==============================] - 2s 299ms/step - loss: 0.9793 - accuracy: 0.9333 - precision: 0.9740 - recall: 0.9338 - val_loss: 1.1348 - val_accuracy: 0.9355 - val_precision: 0.9710 - val_recall: 0.9398
# Epoch 46/50
# 6/6 [==============================] - 2s 308ms/step - loss: 0.8256 - accuracy: 0.9356 - precision: 0.9776 - recall: 0.9322 - val_loss: 1.1378 - val_accuracy: 0.9355 - val_precision: 0.9685 - val_recall: 0.9427
# Epoch 47/50
# 6/6 [==============================] - 2s 303ms/step - loss: 0.8773 - accuracy: 0.9352 - precision: 0.9756 - recall: 0.9344 - val_loss: 1.1537 - val_accuracy: 0.9346 - val_precision: 0.9689 - val_recall: 0.9422
# Epoch 48/50
# 6/6 [==============================] - 2s 300ms/step - loss: 0.7849 - accuracy: 0.9478 - precision: 0.9776 - recall: 0.9509 - val_loss: 1.2296 - val_accuracy: 0.9346 - val_precision: 0.9710 - val_recall: 0.9387
# Epoch 49/50
# 6/6 [==============================] - 2s 300ms/step - loss: 0.7381 - accuracy: 0.9463 - precision: 0.9768 - recall: 0.9488 - val_loss: 1.1197 - val_accuracy: 0.9365 - val_precision: 0.9697 - val_recall: 0.9425
# Epoch 50/50
# 6/6 [==============================] - 2s 297ms/step - loss: 0.7832 - accuracy: 0.9462 - precision: 0.9778 - recall: 0.9479 - val_loss: 1.0479 - val_accuracy: 0.9365 - val_precision: 0.9698 - val_recall: 0.9427

# %%
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMG_COUNT)
# Out:
# 1172

# %%
y_preds = model.predict(test_ds, batch_size = BATCH_SIZE, verbose = True)
y_preds = y_preds.reshape(-1)
y_actual = [1 if x == True else 0 for x in y_test]
print(f'Test Recall: {recall(y_actual, y_preds)}')
print(f'Test Precision: {precision(y_actual, y_preds)}')
print(f'Test F1 Scores: {f1_score(y_actual, y_preds)}')
# Out:
# 3/3 [==============================] - 47s 21s/step
# Test Recall: 0.9493521790341578
# Test Precision: 0.9664268585131894
# Test F1 Scores: 0.9578134284016637

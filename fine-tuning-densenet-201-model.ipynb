# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import tensorflow as tf
from kaggle_datasets import KaggleDatasets
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import re
import glob
import random
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# 2023-01-21 02:58:48.647502: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib
# 2023-01-21 02:58:48.647639: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Device:', tpu.master())
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
except:
    strategy = tf.distribute.get_strategy()
print('Number of replicas:', strategy.num_replicas_in_sync)

print(tf.__version__)
# Out:
# Device: grpc://10.0.0.2:8470
# 2023-01-21 02:58:54.708362: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-01-21 02:58:54.711290: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib
# 2023-01-21 02:58:54.711326: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-01-21 02:58:54.711355: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (aa8f7d661311): /proc/driver/nvidia/version does not exist
# 2023-01-21 02:58:54.714727: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-21 02:58:54.716424: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2023-01-21 02:58:54.747280: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job worker -> {0 -> 10.0.0.2:8470}
# 2023-01-21 02:58:54.747358: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job localhost -> {0 -> localhost:30019}
# 2023-01-21 02:58:54.773362: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job worker -> {0 -> 10.0.0.2:8470}
# 2023-01-21 02:58:54.773419: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job localhost -> {0 -> localhost:30019}
# 2023-01-21 02:58:54.774840: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:411] Started server with target: grpc://localhost:30019
# Number of replicas: 8
# 2.4.1

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
GCS_PATH = KaggleDatasets().get_gcs_path()
BATCH_SIZE = 64*strategy.num_replicas_in_sync
#BATCH_SIZE = 64 # for non-TPU use
IMAGE_SIZE = [180, 180]
EPOCHS = 50

# %%
filenames = tf.io.gfile.glob(str(GCS_PATH + '/chest_xray/train/*/*'))
filenames.extend(tf.io.gfile.glob(str(GCS_PATH + '/chest_xray/val/*/*')))
filenames.extend(tf.io.gfile.glob(str(GCS_PATH + '/chest_xray/test/*/*')))

print(f'The total number of files is {len(filenames)}')
# Out:
# 2023-01-21 02:59:00.201588: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-21 02:59:00.309823: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-21 02:59:00.408679: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-21 02:59:00.509067: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-21 02:59:00.601495: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-21 02:59:00.702217: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-21 02:59:00.784985: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# 2023-01-21 02:59:00.849855: I tensorflow/core/platform/cloud/google_auth_provider.cc:180] Attempting an empty bearer token since no token was retrieved from files, and GCE metadata check was skipped.
# The total number of files is 5856

# %%
# split the data into 60:40 for train:test+val
train_files, val_test_files = train_test_split(filenames, test_size=0.4,random_state=18)

# %%
# split the val_test_files to 50:50 to have a final split of 60:20:20 of train:val:test
val_files, test_files = train_test_split(val_test_files, test_size=0.5, random_state=18)

# %%
pct_df = pd.DataFrame(columns = ['data_set', 'label', 'pct'], index = range(6))

totals = {'train':len(train_files), 'val':len(val_files), 'test':len(test_files)}

val_pneum_count = 0
val_norm_count = 0

re_pattern = '.*/(NORMAL|PNEUMONIA)/.*'

for file in val_files:
    re_match = re.match(re_pattern, file)
    if re_match[1] == 'NORMAL':
        val_norm_count += 1
    else:
        val_pneum_count += 1

pct_df.iloc[0, :] = ['val', 'NORMAL', round(100* val_norm_count / totals['val'], 1)]
pct_df.iloc[1, :] = ['val', 'PNEUMONIA', round(100* val_pneum_count / totals['val'], 1)]


test_pneum_count = 0
test_norm_count = 0
for file in test_files:
    re_match = re.match(re_pattern, file)
    if re_match[1] == 'NORMAL':
        test_norm_count += 1
    else:
        test_pneum_count += 1

pct_df.iloc[2, :] = ['test', 'NORMAL', round(100* test_norm_count / totals['test'], 1)]
pct_df.iloc[3, :] = ['test', 'PNEUMONIA', round(100* test_pneum_count / totals['test'], 1)]

train_pneum_count = 0
train_norm_count = 0
for file in train_files:
    re_match = re.match(re_pattern, file)
    if re_match[1] == 'NORMAL':
        train_norm_count += 1
    else:
        train_pneum_count += 1

pct_df.iloc[4, :] = ['train', 'NORMAL', round(100* train_norm_count / totals['train'], 1)]
pct_df.iloc[5, :] = ['train', 'PNEUMONIA', round(100* train_pneum_count / totals['train'], 1)]

# %%
PNEUM_COUNT = val_pneum_count + train_pneum_count + test_pneum_count
NORMAL_COUNT = val_norm_count + train_norm_count + test_norm_count
print(f'Normal: {NORMAL_COUNT}\nPneumonia: {PNEUM_COUNT}')

pct_df
# Out:
# Normal: 1583
# Pneumonia: 4273
#   data_set      label   pct
# 0      val     NORMAL  26.9
# 1      val  PNEUMONIA  73.1
# 2     test     NORMAL  27.6
# 3     test  PNEUMONIA  72.4
# 4    train     NORMAL  26.9
# 5    train  PNEUMONIA  73.1

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_files)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_files)
test_list_ds = tf.data.Dataset.from_tensor_slices(test_files)

#view the file paths for training
print('----Training Files----')
for f in train_list_ds.take(5):
    print(f.numpy())
# Out:
# ----Training Files----
# b'gs://kds-f4cd5298952c835b370b10b65341d209198e57d812057e8ad9550752/chest_xray/train/PNEUMONIA/person509_virus_1025.jpeg'
# b'gs://kds-f4cd5298952c835b370b10b65341d209198e57d812057e8ad9550752/chest_xray/train/PNEUMONIA/person671_bacteria_2564.jpeg'
# b'gs://kds-f4cd5298952c835b370b10b65341d209198e57d812057e8ad9550752/chest_xray/train/PNEUMONIA/person957_virus_1629.jpeg'
# b'gs://kds-f4cd5298952c835b370b10b65341d209198e57d812057e8ad9550752/chest_xray/test/PNEUMONIA/person81_bacteria_397.jpeg'
# b'gs://kds-f4cd5298952c835b370b10b65341d209198e57d812057e8ad9550752/chest_xray/train/NORMAL/IM-0500-0001.jpeg'

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
TEST_IMG_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()

print(f'Train Image Count: {TRAIN_IMG_COUNT}\nVal Image Count: {VAL_IMG_COUNT}\nTest Image Count: {TEST_IMG_COUNT}')
# Out:
# Train Image Count: 3513
# Val Image Count: 1171
# Test Image Count: 1172
# 2023-01-21 02:59:01.306192: W ./tensorflow/core/distributed_runtime/eager/destroy_tensor_handle_node.h:57] Ignoring an error encountered when deleting remote tensors handles: Invalid argument: Unable to find the relevant tensor remote_handle: Op ID: 28, Output num: 0
# Additional GRPC error information from remote target /job:worker/replica:0/task:0:
# :{"created":"@1674269941.302835477","description":"Error received from peer ipv4:10.0.0.2:8470","file":"external/com_github_grpc_grpc/src/core/lib/surface/call.cc","file_line":1056,"grpc_message":"Unable to find the relevant tensor remote_handle: Op ID: 28, Output num: 0","grpc_status":3}

# %%
# will label as 1 if pneumonia otherwise 0
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == 'PNEUMONIA'

# %%
def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    return tf.image.resize(img, IMAGE_SIZE)

# %%
def process_path(file_path):
    label = get_label(file_path)
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
y_train = []
for image, label in train_ds.take(TRAIN_IMG_COUNT):
    y_train.append(label)
    
print('Training Counts')
print(f'Pneumonia count: {np.sum(y_train)}\nNormal count: {TRAIN_IMG_COUNT - np.sum(y_train)}')
# Out:
# Training Counts
# 2023-01-21 03:01:07.678817: W ./tensorflow/core/distributed_runtime/eager/destroy_tensor_handle_node.h:57] Ignoring an error encountered when deleting remote tensors handles: Invalid argument: Unable to find the relevant tensor remote_handle: Op ID: 3562, Output num: 0
# Additional GRPC error information from remote target /job:worker/replica:0/task:0:
# :{"created":"@1674270067.678740113","description":"Error received from peer ipv4:10.0.0.2:8470","file":"external/com_github_grpc_grpc/src/core/lib/surface/call.cc","file_line":1056,"grpc_message":"Unable to find the relevant tensor remote_handle: Op ID: 3562, Output num: 0","grpc_status":3}
# Pneumonia count: 2568
# Normal count: 945

# %%
y_val = []
for image, label in val_ds.take(VAL_IMG_COUNT):
    y_val.append(label)
    
print('Validation Counts')
print(f'Pneumonia count: {np.sum(y_val)}\nNormal count: {VAL_IMG_COUNT - np.sum(y_val)}')
# Out:
# Validation Counts
# 2023-01-21 03:02:11.408209: W ./tensorflow/core/distributed_runtime/eager/destroy_tensor_handle_node.h:57] Ignoring an error encountered when deleting remote tensors handles: Invalid argument: Unable to find the relevant tensor remote_handle: Op ID: 18796, Output num: 1
# Additional GRPC error information from remote target /job:worker/replica:0/task:0:
# :{"created":"@1674270131.408085727","description":"Error received from peer ipv4:10.0.0.2:8470","file":"external/com_github_grpc_grpc/src/core/lib/surface/call.cc","file_line":1056,"grpc_message":"Unable to find the relevant tensor remote_handle: Op ID: 18796, Output num: 1","grpc_status":3}
# Pneumonia count: 856
# Normal count: 315

# %%
y_test = []
for image, label in test_ds.take(TEST_IMG_COUNT):
    y_test.append(label)
    
print('Test Counts')
print(f'Pneumonia count: {np.sum(y_test)}\nNormal count: {TEST_IMG_COUNT - np.sum(y_test)}')
# Out:
# Test Counts
# Pneumonia count: 849
# Normal count: 323

# %%
def prepare_for_training(ds, cache=True, shuffle_buffer_size=1000):
    
    if cache:
        if isinstance(cache, str):
            ds = ds.cache(cache)
        else:
            ds = ds.cache()
            
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    
    ds = ds.repeat()
    
    ds = ds.batch(BATCH_SIZE)
    
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    
    return ds

# %%
train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)


image_batch, label_batch = next(iter(train_ds))

# %%
weight_for_0 = (1 / NORMAL_COUNT)*(TRAIN_IMG_COUNT)/2.0
weight_for_1 = (1 / PNEUM_COUNT)*(TRAIN_IMG_COUNT)/2.0

# %%
class_weight = {0: weight_for_0, 1: weight_for_1}
print(f'Weight for class 0: {weight_for_0:.2f}')
print(f'Weight for class 1: {weight_for_1:.2f}')
# Out:
# Weight for class 0: 1.11
# Weight for class 1: 0.41

# %%
# create some metrics for comparing on test results

def precision(y_test, y_pred):
    tp, fp = 0, 0
    
    for i in range(len(y_test)):
        if y_test[i] >= 0.5 and y_pred[i] >= 0.5:
            tp += 1
        elif y_test[i] < 0.5 and y_pred[i] >= 0.5:
            fp += 1
            
    return tp / (tp + fp)

def recall(y_test, y_pred):
    tp, fn = 0, 0
    
    for i in range(len(y_test)):
        if y_test[i] >= 0.5 and y_pred[i] >= 0.5:
            tp += 1
        elif y_test[i] >= 0.5 and y_pred[i] < 0.5:
            fn += 1
            
    return tp / (tp + fn)

def f1_score(y_test, y_pred):
    numerator = precision(y_test, y_pred) * recall(y_test, y_pred)
    denominator = precision(y_test, y_pred) + recall(y_test, y_pred)
    
    return 2 * (numerator / denominator)

# %% [markdown]
# ## Fine Tune the Model
#
# ## Explore Learning Rate values

# %%
# add exponential decay to try to improve fine tuning
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 ** (epoch / s)
    return exponential_decay_fn

# %%
# try 10 different learning rates randomly selected between 1.0 to 0.0001
for _ in range(10):
    
    # randomly sample a number in the half-open interval [0.0, 1.0)
    r = random.random()
    learning_rate = 10 ** (-4 * r)
    print(f'Learning Rate: {learning_rate}')

    with strategy.scope():
    
        base_model = tf.keras.applications.densenet.DenseNet201(
                    input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3),
                    include_top=False,
                    weights='imagenet'
                    )
        base_model.trainable = False
    
        x=base_model.output
        inputs = tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))
        x = base_model(inputs, training=False)
        x = tf.keras.layers.GlobalAveragePooling2D()(x)
        x = tf.keras.layers.Dropout(0.3)(x)
        outputs = tf.keras.layers.Dense(1, activation='sigmoid')(x)
        model = tf.keras.Model(inputs, outputs)

    
    
        METRICS = [
            'accuracy',
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')
            ]
    
        model.compile(
                optimizer='adam',
                loss='binary_crossentropy',
                metrics=METRICS
                 )
        
        checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(f"densenet_{learning_rate}_xray_model.h5", save_best_only=True)
        early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)
        exponential_decay_fn = exponential_decay(learning_rate, 20)
        lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)

        history = model.fit(
                            train_ds,
                            steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
                            epochs=EPOCHS,
                            validation_data=val_ds,
                            validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
                            class_weight=class_weight,
                            callbacks=[checkpoint_cb, early_stopping_cb, lr_scheduler]
                            )
        
        test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
        test_ds = test_ds.batch(BATCH_SIZE)
            
        y_preds = model.predict(test_ds, batch_size = BATCH_SIZE, verbose = True)
        y_preds = y_preds.reshape(-1)
        y_actual = [1 if x == True else 0 for x in y_test]

        fpr, tpr, thresholds = roc_curve(y_actual, y_preds, pos_label=1)
        print(f'Learning Rate: {learning_rate}')
        print(f'AUC score: {auc(fpr, tpr)}')
       
        print(f'Test Recall: {recall(y_actual, y_preds)}')
        print(f'Test Precision: {precision(y_actual, y_preds)}')
        print(f'Test F1 Scores: {f1_score(y_actual, y_preds)}\n\n')
# Out:
# Learning Rate: 0.010475274980286293
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74842112/74836368 [==============================] - 0s 0us/step
# Epoch 1/50
# 6/6 [==============================] - 157s 17s/step - loss: 0.4365 - accuracy: 0.5857 - precision: 0.7993 - recall: 0.5542 - val_loss: 0.4799 - val_accuracy: 0.8037 - val_precision: 0.9859 - val_recall: 0.7437
# Epoch 2/50
# 6/6 [==============================] - 2s 313ms/step - loss: 0.1966 - accuracy: 0.8433 - precision: 0.9709 - recall: 0.8158 - val_loss: 0.2205 - val_accuracy: 0.8994 - val_precision: 0.9434 - val_recall: 0.9168
# Epoch 3/50
# 6/6 [==============================] - 2s 299ms/step - loss: 0.1619 - accuracy: 0.8900 - precision: 0.9541 - recall: 0.8933 - val_loss: 0.2476 - val_accuracy: 0.8906 - val_precision: 0.9704 - val_recall: 0.8770
# Epoch 4/50
# 6/6 [==============================] - 2s 293ms/step - loss: 0.1303 - accuracy: 0.9086 - precision: 0.9706 - recall: 0.9049 - val_loss: 0.1974 - val_accuracy: 0.9111 - val_precision: 0.9619 - val_recall: 0.9142
# Epoch 5/50
# 6/6 [==============================] - 2s 308ms/step - loss: 0.1299 - accuracy: 0.9148 - precision: 0.9715 - recall: 0.9096 - val_loss: 0.1992 - val_accuracy: 0.9111 - val_precision: 0.9674 - val_recall: 0.9095
# Epoch 6/50
# 6/6 [==============================] - 2s 302ms/step - loss: 0.1233 - accuracy: 0.9177 - precision: 0.9649 - recall: 0.9217 - val_loss: 0.1813 - val_accuracy: 0.9180 - val_precision: 0.9688 - val_recall: 0.9168
# Epoch 7/50
# 6/6 [==============================] - 2s 304ms/step - loss: 0.1275 - accuracy: 0.9221 - precision: 0.9703 - recall: 0.9202 - val_loss: 0.1713 - val_accuracy: 0.9180 - val_precision: 0.9647 - val_recall: 0.9205
# Epoch 8/50
# 6/6 [==============================] - 2s 300ms/step - loss: 0.1076 - accuracy: 0.9389 - precision: 0.9807 - recall: 0.9338 - val_loss: 0.1736 - val_accuracy: 0.9189 - val_precision: 0.9662 - val_recall: 0.9209
# Epoch 9/50
# 6/6 [==============================] - 2s 303ms/step - loss: 0.1178 - accuracy: 0.9209 - precision: 0.9734 - recall: 0.9161 - val_loss: 0.1782 - val_accuracy: 0.9160 - val_precision: 0.9700 - val_recall: 0.9125
# Epoch 10/50
# 6/6 [==============================] - 2s 294ms/step - loss: 0.1036 - accuracy: 0.9329 - precision: 0.9772 - recall: 0.9298 - val_loss: 0.1693 - val_accuracy: 0.9160 - val_precision: 0.9676 - val_recall: 0.9160
# Epoch 11/50
# 6/6 [==============================] - 2s 310ms/step - loss: 0.1018 - accuracy: 0.9325 - precision: 0.9787 - recall: 0.9283 - val_loss: 0.1601 - val_accuracy: 0.9238 - val_precision: 0.9681 - val_recall: 0.9269
# Epoch 12/50
# 6/6 [==============================] - 2s 297ms/step - loss: 0.1078 - accuracy: 0.9345 - precision: 0.9730 - recall: 0.9358 - val_loss: 0.1600 - val_accuracy: 0.9297 - val_precision: 0.9732 - val_recall: 0.9286
# Epoch 13/50
# 6/6 [==============================] - 2s 300ms/step - loss: 0.0987 - accuracy: 0.9337 - precision: 0.9811 - recall: 0.9280 - val_loss: 0.1569 - val_accuracy: 0.9258 - val_precision: 0.9760 - val_recall: 0.9212
# Epoch 14/50
# 6/6 [==============================] - 2s 306ms/step - loss: 0.0995 - accuracy: 0.9319 - precision: 0.9789 - recall: 0.9272 - val_loss: 0.1469 - val_accuracy: 0.9346 - val_precision: 0.9709 - val_recall: 0.9383
# Epoch 15/50
# 6/6 [==============================] - 2s 299ms/step - loss: 0.1035 - accuracy: 0.9313 - precision: 0.9745 - recall: 0.9301 - val_loss: 0.1613 - val_accuracy: 0.9248 - val_precision: 0.9784 - val_recall: 0.9164
# Epoch 16/50
# 6/6 [==============================] - 2s 289ms/step - loss: 0.0978 - accuracy: 0.9361 - precision: 0.9816 - recall: 0.9292 - val_loss: 0.1501 - val_accuracy: 0.9316 - val_precision: 0.9711 - val_recall: 0.9351
# Epoch 17/50
# 6/6 [==============================] - 2s 283ms/step - loss: 0.0968 - accuracy: 0.9369 - precision: 0.9761 - recall: 0.9365 - val_loss: 0.1412 - val_accuracy: 0.9346 - val_precision: 0.9710 - val_recall: 0.9387
# Epoch 18/50
# 6/6 [==============================] - 2s 305ms/step - loss: 0.1004 - accuracy: 0.9357 - precision: 0.9786 - recall: 0.9325 - val_loss: 0.1562 - val_accuracy: 0.9297 - val_precision: 0.9800 - val_recall: 0.9220
# Epoch 19/50
# 6/6 [==============================] - 2s 304ms/step - loss: 0.1047 - accuracy: 0.9298 - precision: 0.9810 - recall: 0.9232 - val_loss: 0.1480 - val_accuracy: 0.9307 - val_precision: 0.9707 - val_recall: 0.9329
# Epoch 20/50
# 6/6 [==============================] - 2s 296ms/step - loss: 0.1066 - accuracy: 0.9269 - precision: 0.9747 - recall: 0.9250 - val_loss: 0.1431 - val_accuracy: 0.9355 - val_precision: 0.9708 - val_recall: 0.9394
# Epoch 21/50
# 6/6 [==============================] - 2s 291ms/step - loss: 0.0955 - accuracy: 0.9399 - precision: 0.9770 - recall: 0.9407 - val_loss: 0.1450 - val_accuracy: 0.9395 - val_precision: 0.9818 - val_recall: 0.9346
# Epoch 22/50
# 6/6 [==============================] - 2s 284ms/step - loss: 0.0928 - accuracy: 0.9348 - precision: 0.9814 - recall: 0.9285 - val_loss: 0.1528 - val_accuracy: 0.9336 - val_precision: 0.9803 - val_recall: 0.9281
# Epoch 23/50
# 6/6 [==============================] - 2s 309ms/step - loss: 0.0941 - accuracy: 0.9434 - precision: 0.9804 - recall: 0.9400 - val_loss: 0.1357 - val_accuracy: 0.9434 - val_precision: 0.9777 - val_recall: 0.9434
# Epoch 24/50
# 6/6 [==============================] - 2s 299ms/step - loss: 0.0926 - accuracy: 0.9458 - precision: 0.9799 - recall: 0.9449 - val_loss: 0.1466 - val_accuracy: 0.9365 - val_precision: 0.9831 - val_recall: 0.9293
# Epoch 25/50
# 6/6 [==============================] - 2s 297ms/step - loss: 0.0913 - accuracy: 0.9440 - precision: 0.9790 - recall: 0.9434 - val_loss: 0.1455 - val_accuracy: 0.9365 - val_precision: 0.9818 - val_recall: 0.9310
# Epoch 26/50
# 6/6 [==============================] - 2s 312ms/step - loss: 0.0947 - accuracy: 0.9325 - precision: 0.9814 - recall: 0.9248 - val_loss: 0.1482 - val_accuracy: 0.9346 - val_precision: 0.9803 - val_recall: 0.9293
# Epoch 27/50
# 6/6 [==============================] - 2s 296ms/step - loss: 0.0880 - accuracy: 0.9385 - precision: 0.9805 - recall: 0.9363 - val_loss: 0.1457 - val_accuracy: 0.9346 - val_precision: 0.9815 - val_recall: 0.9273
# Epoch 28/50
# 6/6 [==============================] - 2s 292ms/step - loss: 0.0953 - accuracy: 0.9322 - precision: 0.9776 - recall: 0.9294 - val_loss: 0.1448 - val_accuracy: 0.9395 - val_precision: 0.9802 - val_recall: 0.9351
# Epoch 29/50
# 6/6 [==============================] - 2s 296ms/step - loss: 0.0971 - accuracy: 0.9352 - precision: 0.9786 - recall: 0.9318 - val_loss: 0.1394 - val_accuracy: 0.9424 - val_precision: 0.9830 - val_recall: 0.9367
# Epoch 30/50
# 6/6 [==============================] - 2s 305ms/step - loss: 0.0922 - accuracy: 0.9396 - precision: 0.9798 - recall: 0.9373 - val_loss: 0.1337 - val_accuracy: 0.9443 - val_precision: 0.9834 - val_recall: 0.9404
# Epoch 31/50
# 6/6 [==============================] - 2s 303ms/step - loss: 0.1039 - accuracy: 0.9385 - precision: 0.9772 - recall: 0.9361 - val_loss: 0.1423 - val_accuracy: 0.9395 - val_precision: 0.9831 - val_recall: 0.9332
# Epoch 32/50
# 6/6 [==============================] - 2s 298ms/step - loss: 0.0936 - accuracy: 0.9419 - precision: 0.9773 - recall: 0.9423 - val_loss: 0.1465 - val_accuracy: 0.9375 - val_precision: 0.9804 - val_recall: 0.9335
# Epoch 33/50
# 6/6 [==============================] - 2s 296ms/step - loss: 0.0888 - accuracy: 0.9410 - precision: 0.9820 - recall: 0.9366 - val_loss: 0.1353 - val_accuracy: 0.9453 - val_precision: 0.9847 - val_recall: 0.9402
# Epoch 34/50
# 6/6 [==============================] - 2s 286ms/step - loss: 0.0983 - accuracy: 0.9377 - precision: 0.9765 - recall: 0.9375 - val_loss: 0.1441 - val_accuracy: 0.9414 - val_precision: 0.9792 - val_recall: 0.9400
# Epoch 35/50
# 6/6 [==============================] - 2s 292ms/step - loss: 0.0871 - accuracy: 0.9450 - precision: 0.9822 - recall: 0.9417 - val_loss: 0.1408 - val_accuracy: 0.9424 - val_precision: 0.9816 - val_recall: 0.9377
# Epoch 36/50
# 6/6 [==============================] - 2s 287ms/step - loss: 0.0945 - accuracy: 0.9388 - precision: 0.9829 - recall: 0.9339 - val_loss: 0.1389 - val_accuracy: 0.9443 - val_precision: 0.9818 - val_recall: 0.9409
# Epoch 37/50
# 6/6 [==============================] - 2s 291ms/step - loss: 0.0877 - accuracy: 0.9412 - precision: 0.9814 - recall: 0.9354 - val_loss: 0.1332 - val_accuracy: 0.9453 - val_precision: 0.9833 - val_recall: 0.9413
# Epoch 38/50
# 6/6 [==============================] - 2s 315ms/step - loss: 0.0885 - accuracy: 0.9439 - precision: 0.9800 - recall: 0.9420 - val_loss: 0.1378 - val_accuracy: 0.9434 - val_precision: 0.9848 - val_recall: 0.9382
# Epoch 39/50
# 6/6 [==============================] - 2s 311ms/step - loss: 0.0966 - accuracy: 0.9384 - precision: 0.9819 - recall: 0.9337 - val_loss: 0.1430 - val_accuracy: 0.9404 - val_precision: 0.9805 - val_recall: 0.9374
# Epoch 40/50
# 6/6 [==============================] - 2s 296ms/step - loss: 0.0928 - accuracy: 0.9422 - precision: 0.9806 - recall: 0.9390 - val_loss: 0.1363 - val_accuracy: 0.9424 - val_precision: 0.9847 - val_recall: 0.9363
# Epoch 41/50
# 6/6 [==============================] - 2s 298ms/step - loss: 0.0910 - accuracy: 0.9423 - precision: 0.9763 - recall: 0.9431 - val_loss: 0.1408 - val_accuracy: 0.9355 - val_precision: 0.9802 - val_recall: 0.9301
# Epoch 42/50
# 6/6 [==============================] - 2s 296ms/step - loss: 0.0945 - accuracy: 0.9427 - precision: 0.9788 - recall: 0.9429 - val_loss: 0.1439 - val_accuracy: 0.9375 - val_precision: 0.9805 - val_recall: 0.9336
# Epoch 43/50
# 6/6 [==============================] - 2s 292ms/step - loss: 0.0871 - accuracy: 0.9444 - precision: 0.9846 - recall: 0.9393 - val_loss: 0.1390 - val_accuracy: 0.9443 - val_precision: 0.9803 - val_recall: 0.9419
# Epoch 44/50
# 6/6 [==============================] - 2s 297ms/step - loss: 0.0951 - accuracy: 0.9381 - precision: 0.9791 - recall: 0.9358 - val_loss: 0.1441 - val_accuracy: 0.9395 - val_precision: 0.9803 - val_recall: 0.9355
# Epoch 45/50
# 6/6 [==============================] - 2s 293ms/step - loss: 0.0853 - accuracy: 0.9474 - precision: 0.9821 - recall: 0.9445 - val_loss: 0.1405 - val_accuracy: 0.9395 - val_precision: 0.9819 - val_recall: 0.9352
# Epoch 46/50
# 6/6 [==============================] - 2s 288ms/step - loss: 0.0904 - accuracy: 0.9407 - precision: 0.9784 - recall: 0.9384 - val_loss: 0.1339 - val_accuracy: 0.9453 - val_precision: 0.9819 - val_recall: 0.9425
# Epoch 47/50
# 6/6 [==============================] - 2s 301ms/step - loss: 0.0913 - accuracy: 0.9440 - precision: 0.9829 - recall: 0.9389 - val_loss: 0.1402 - val_accuracy: 0.9404 - val_precision: 0.9804 - val_recall: 0.9372
# 3/3 [==============================] - 49s 22s/step
# Learning Rate: 0.010475274980286293
# AUC score: 0.9865768140992681
# Test Recall: 0.9458186101295641
# Test Precision: 0.9733333333333334
# Test F1 Scores: 0.959378733572282
#
#
# Learning Rate: 0.002735398741113085
# Epoch 1/50
# 6/6 [==============================] - 51s 4s/step - loss: 0.4037 - accuracy: 0.5877 - precision: 0.8177 - recall: 0.5560 - val_loss: 0.3270 - val_accuracy: 0.8799 - val_precision: 0.9488 - val_recall: 0.8846
# Epoch 2/50
# 6/6 [==============================] - 2s 306ms/step - loss: 0.2292 - accuracy: 0.8393 - precision: 0.9314 - recall: 0.8441 - val_loss: 0.2713 - val_accuracy: 0.8887 - val_precision: 0.9627 - val_recall: 0.8841
# Epoch 3/50
# 6/6 [==============================] - 2s 309ms/step - loss: 0.1757 - accuracy: 0.8824 - precision: 0.9456 - recall: 0.8902 - val_loss: 0.2680 - val_accuracy: 0.8857 - val_precision: 0.9672 - val_recall: 0.8723
# Epoch 4/50
# 6/6 [==============================] - 2s 304ms/step - loss: 0.1554 - accuracy: 0.8870 - precision: 0.9597 - recall: 0.8832 - val_loss: 0.2253 - val_accuracy: 0.9053 - val_precision: 0.9604 - val_recall: 0.9078
# Epoch 5/50
# 6/6 [==============================] - 2s 320ms/step - loss: 0.1517 - accuracy: 0.8944 - precision: 0.9596 - recall: 0.8922 - val_loss: 0.2400 - val_accuracy: 0.9004 - val_precision: 0.9767 - val_recall: 0.8865
# Epoch 6/50
# 6/6 [==============================] - 2s 300ms/step - loss: 0.1337 - accuracy: 0.8977 - precision: 0.9691 - recall: 0.8885 - val_loss: 0.1949 - val_accuracy: 0.9219 - val_precision: 0.9630 - val_recall: 0.9298
# Epoch 7/50
# 6/6 [==============================] - 2s 305ms/step - loss: 0.1423 - accuracy: 0.9017 - precision: 0.9544 - recall: 0.9067 - val_loss: 0.2236 - val_accuracy: 0.9072 - val_precision: 0.9753 - val_recall: 0.8960
# Epoch 8/50
# 6/6 [==============================] - 2s 298ms/step - loss: 0.1360 - accuracy: 0.9026 - precision: 0.9636 - recall: 0.8998 - val_loss: 0.1984 - val_accuracy: 0.9189 - val_precision: 0.9730 - val_recall: 0.9144
# Epoch 9/50
# 6/6 [==============================] - 2s 297ms/step - loss: 0.1275 - accuracy: 0.9163 - precision: 0.9699 - recall: 0.9145 - val_loss: 0.1880 - val_accuracy: 0.9170 - val_precision: 0.9706 - val_recall: 0.9156
# Epoch 10/50
# 6/6 [==============================] - 2s 303ms/step - loss: 0.1322 - accuracy: 0.9167 - precision: 0.9658 - recall: 0.9172 - val_loss: 0.2034 - val_accuracy: 0.9131 - val_precision: 0.9756 - val_recall: 0.9041
# Epoch 11/50
# 6/6 [==============================] - 2s 304ms/step - loss: 0.1303 - accuracy: 0.9110 - precision: 0.9722 - recall: 0.9057 - val_loss: 0.1797 - val_accuracy: 0.9268 - val_precision: 0.9748 - val_recall: 0.9242
# Epoch 12/50
# 6/6 [==============================] - 2s 316ms/step - loss: 0.1158 - accuracy: 0.9238 - precision: 0.9715 - recall: 0.9242 - val_loss: 0.1834 - val_accuracy: 0.9258 - val_precision: 0.9761 - val_recall: 0.9218
# Epoch 13/50
# 6/6 [==============================] - 2s 297ms/step - loss: 0.1265 - accuracy: 0.9128 - precision: 0.9721 - recall: 0.9078 - val_loss: 0.1765 - val_accuracy: 0.9287 - val_precision: 0.9762 - val_recall: 0.9255
# Epoch 14/50
# 6/6 [==============================] - 2s 319ms/step - loss: 0.1146 - accuracy: 0.9244 - precision: 0.9758 - recall: 0.9195 - val_loss: 0.1875 - val_accuracy: 0.9238 - val_precision: 0.9718 - val_recall: 0.9223
# Epoch 15/50
# 6/6 [==============================] - 2s 298ms/step - loss: 0.1239 - accuracy: 0.9168 - precision: 0.9755 - recall: 0.9067 - val_loss: 0.1760 - val_accuracy: 0.9287 - val_precision: 0.9785 - val_recall: 0.9218
# Epoch 16/50
# 6/6 [==============================] - 2s 321ms/step - loss: 0.1211 - accuracy: 0.9173 - precision: 0.9632 - recall: 0.9213 - val_loss: 0.1852 - val_accuracy: 0.9268 - val_precision: 0.9773 - val_recall: 0.9212
# Epoch 17/50
# 6/6 [==============================] - 2s 295ms/step - loss: 0.1205 - accuracy: 0.9180 - precision: 0.9711 - recall: 0.9139 - val_loss: 0.1832 - val_accuracy: 0.9277 - val_precision: 0.9759 - val_recall: 0.9234
# Epoch 18/50
# 6/6 [==============================] - 2s 302ms/step - loss: 0.1145 - accuracy: 0.9241 - precision: 0.9751 - recall: 0.9198 - val_loss: 0.1822 - val_accuracy: 0.9297 - val_precision: 0.9723 - val_recall: 0.9310
# Epoch 19/50
# 6/6 [==============================] - 2s 284ms/step - loss: 0.1101 - accuracy: 0.9254 - precision: 0.9740 - recall: 0.9241 - val_loss: 0.1749 - val_accuracy: 0.9326 - val_precision: 0.9779 - val_recall: 0.9303
# Epoch 20/50
# 6/6 [==============================] - 2s 304ms/step - loss: 0.1112 - accuracy: 0.9289 - precision: 0.9803 - recall: 0.9225 - val_loss: 0.1746 - val_accuracy: 0.9326 - val_precision: 0.9719 - val_recall: 0.9339
# Epoch 21/50
# 6/6 [==============================] - 2s 312ms/step - loss: 0.1148 - accuracy: 0.9257 - precision: 0.9750 - recall: 0.9226 - val_loss: 0.1641 - val_accuracy: 0.9395 - val_precision: 0.9748 - val_recall: 0.9406
# Epoch 22/50
# 6/6 [==============================] - 2s 313ms/step - loss: 0.1140 - accuracy: 0.9173 - precision: 0.9725 - recall: 0.9149 - val_loss: 0.1761 - val_accuracy: 0.9297 - val_precision: 0.9761 - val_recall: 0.9266
# Epoch 23/50
# 6/6 [==============================] - 2s 301ms/step - loss: 0.1108 - accuracy: 0.9316 - precision: 0.9778 - recall: 0.9276 - val_loss: 0.1683 - val_accuracy: 0.9375 - val_precision: 0.9803 - val_recall: 0.9332
# Epoch 24/50
# 6/6 [==============================] - 2s 306ms/step - loss: 0.1187 - accuracy: 0.9217 - precision: 0.9724 - recall: 0.9183 - val_loss: 0.1821 - val_accuracy: 0.9229 - val_precision: 0.9757 - val_recall: 0.9167
# Epoch 25/50
# 6/6 [==============================] - 2s 283ms/step - loss: 0.1092 - accuracy: 0.9302 - precision: 0.9761 - recall: 0.9273 - val_loss: 0.1754 - val_accuracy: 0.9307 - val_precision: 0.9774 - val_recall: 0.9265
# Epoch 26/50
# 6/6 [==============================] - 2s 297ms/step - loss: 0.1138 - accuracy: 0.9260 - precision: 0.9774 - recall: 0.9192 - val_loss: 0.1664 - val_accuracy: 0.9336 - val_precision: 0.9788 - val_recall: 0.9290
# Epoch 27/50
# 6/6 [==============================] - 2s 292ms/step - loss: 0.1193 - accuracy: 0.9231 - precision: 0.9702 - recall: 0.9239 - val_loss: 0.1690 - val_accuracy: 0.9336 - val_precision: 0.9775 - val_recall: 0.9305
# Epoch 28/50
# 6/6 [==============================] - 2s 291ms/step - loss: 0.1068 - accuracy: 0.9295 - precision: 0.9782 - recall: 0.9238 - val_loss: 0.1761 - val_accuracy: 0.9287 - val_precision: 0.9761 - val_recall: 0.9254
# Epoch 29/50
# 6/6 [==============================] - 2s 291ms/step - loss: 0.1131 - accuracy: 0.9297 - precision: 0.9763 - recall: 0.9270 - val_loss: 0.1697 - val_accuracy: 0.9326 - val_precision: 0.9786 - val_recall: 0.9271
# Epoch 30/50
# 6/6 [==============================] - 2s 293ms/step - loss: 0.1127 - accuracy: 0.9287 - precision: 0.9754 - recall: 0.9260 - val_loss: 0.1670 - val_accuracy: 0.9336 - val_precision: 0.9761 - val_recall: 0.9315
# Epoch 31/50
# 6/6 [==============================] - 2s 285ms/step - loss: 0.1189 - accuracy: 0.9272 - precision: 0.9740 - recall: 0.9243 - val_loss: 0.1695 - val_accuracy: 0.9326 - val_precision: 0.9799 - val_recall: 0.9255
# 3/3 [==============================] - 52s 22s/step
# Learning Rate: 0.002735398741113085
# AUC score: 0.9828682077257163
# Test Recall: 0.9363957597173145
# Test Precision: 0.9742647058823529
# Test F1 Scores: 0.954954954954955
#
#
# Learning Rate: 0.000569208412659075
# Epoch 1/50
# 6/6 [==============================] - 50s 4s/step - loss: 0.4520 - accuracy: 0.4659 - precision: 0.8101 - recall: 0.3406 - val_loss: 0.5805 - val_accuracy: 0.7197 - val_precision: 0.8459 - val_recall: 0.7517
# Epoch 2/50
# 6/6 [==============================] - 2s 305ms/step - loss: 0.3772 - accuracy: 0.6653 - precision: 0.8323 - recall: 0.6775 - val_loss: 0.5406 - val_accuracy: 0.7656 - val_precision: 0.9356 - val_recall: 0.7321
# Epoch 3/50
# 6/6 [==============================] - 2s 309ms/step - loss: 0.3362 - accuracy: 0.7010 - precision: 0.8915 - recall: 0.6742 - val_loss: 0.5023 - val_accuracy: 0.7959 - val_precision: 0.9672 - val_recall: 0.7470
# Epoch 4/50
# 6/6 [==============================] - 2s 310ms/step - loss: 0.3048 - accuracy: 0.7380 - precision: 0.9133 - recall: 0.7076 - val_loss: 0.4538 - val_accuracy: 0.8203 - val_precision: 0.9625 - val_recall: 0.7859
# Epoch 5/50
# 6/6 [==============================] - 2s 305ms/step - loss: 0.2746 - accuracy: 0.7725 - precision: 0.9214 - recall: 0.7553 - val_loss: 0.3933 - val_accuracy: 0.8477 - val_precision: 0.9462 - val_recall: 0.8406
# Epoch 6/50
# 6/6 [==============================] - 2s 305ms/step - loss: 0.2590 - accuracy: 0.8149 - precision: 0.9236 - recall: 0.8090 - val_loss: 0.3773 - val_accuracy: 0.8564 - val_precision: 0.9510 - val_recall: 0.8490
# Epoch 7/50
# 6/6 [==============================] - 2s 317ms/step - loss: 0.2535 - accuracy: 0.8214 - precision: 0.9247 - recall: 0.8201 - val_loss: 0.3792 - val_accuracy: 0.8525 - val_precision: 0.9583 - val_recall: 0.8336
# Epoch 8/50
# 6/6 [==============================] - 2s 294ms/step - loss: 0.2439 - accuracy: 0.8045 - precision: 0.9300 - recall: 0.7910 - val_loss: 0.3663 - val_accuracy: 0.8623 - val_precision: 0.9671 - val_recall: 0.8444
# Epoch 9/50
# 6/6 [==============================] - 2s 303ms/step - loss: 0.2265 - accuracy: 0.8344 - precision: 0.9424 - recall: 0.8230 - val_loss: 0.3505 - val_accuracy: 0.8623 - val_precision: 0.9537 - val_recall: 0.8531
# Epoch 10/50
# 6/6 [==============================] - 2s 301ms/step - loss: 0.2227 - accuracy: 0.8355 - precision: 0.9403 - recall: 0.8269 - val_loss: 0.3424 - val_accuracy: 0.8750 - val_precision: 0.9631 - val_recall: 0.8636
# Epoch 11/50
# 6/6 [==============================] - 2s 305ms/step - loss: 0.2123 - accuracy: 0.8464 - precision: 0.9514 - recall: 0.8345 - val_loss: 0.3314 - val_accuracy: 0.8740 - val_precision: 0.9565 - val_recall: 0.8694
# Epoch 12/50
# 6/6 [==============================] - 2s 298ms/step - loss: 0.2054 - accuracy: 0.8611 - precision: 0.9500 - recall: 0.8560 - val_loss: 0.3244 - val_accuracy: 0.8789 - val_precision: 0.9550 - val_recall: 0.8762
# Epoch 13/50
# 6/6 [==============================] - 2s 305ms/step - loss: 0.2113 - accuracy: 0.8590 - precision: 0.9406 - recall: 0.8600 - val_loss: 0.3274 - val_accuracy: 0.8770 - val_precision: 0.9602 - val_recall: 0.8682
# Epoch 14/50
# 6/6 [==============================] - 2s 298ms/step - loss: 0.2057 - accuracy: 0.8601 - precision: 0.9550 - recall: 0.8481 - val_loss: 0.3256 - val_accuracy: 0.8760 - val_precision: 0.9613 - val_recall: 0.8648
# Epoch 15/50
# 6/6 [==============================] - 2s 290ms/step - loss: 0.2038 - accuracy: 0.8467 - precision: 0.9456 - recall: 0.8403 - val_loss: 0.3217 - val_accuracy: 0.8828 - val_precision: 0.9614 - val_recall: 0.8733
# Epoch 16/50
# 6/6 [==============================] - 2s 305ms/step - loss: 0.1984 - accuracy: 0.8582 - precision: 0.9478 - recall: 0.8481 - val_loss: 0.3110 - val_accuracy: 0.8867 - val_precision: 0.9646 - val_recall: 0.8767
# Epoch 17/50
# 6/6 [==============================] - 2s 299ms/step - loss: 0.1951 - accuracy: 0.8713 - precision: 0.9552 - recall: 0.8664 - val_loss: 0.3077 - val_accuracy: 0.8857 - val_precision: 0.9631 - val_recall: 0.8765
# Epoch 18/50
# 6/6 [==============================] - 2s 304ms/step - loss: 0.1971 - accuracy: 0.8660 - precision: 0.9488 - recall: 0.8602 - val_loss: 0.3071 - val_accuracy: 0.8857 - val_precision: 0.9619 - val_recall: 0.8782
# Epoch 19/50
# 6/6 [==============================] - 2s 311ms/step - loss: 0.1891 - accuracy: 0.8678 - precision: 0.9598 - recall: 0.8576 - val_loss: 0.3106 - val_accuracy: 0.8818 - val_precision: 0.9600 - val_recall: 0.8733
# Epoch 20/50
# 6/6 [==============================] - 2s 299ms/step - loss: 0.1892 - accuracy: 0.8704 - precision: 0.9510 - recall: 0.8685 - val_loss: 0.3014 - val_accuracy: 0.8857 - val_precision: 0.9610 - val_recall: 0.8808
# Epoch 21/50
# 6/6 [==============================] - 2s 309ms/step - loss: 0.1851 - accuracy: 0.8760 - precision: 0.9596 - recall: 0.8696 - val_loss: 0.3048 - val_accuracy: 0.8838 - val_precision: 0.9629 - val_recall: 0.8735
# Epoch 22/50
# 6/6 [==============================] - 2s 301ms/step - loss: 0.1880 - accuracy: 0.8735 - precision: 0.9532 - recall: 0.8693 - val_loss: 0.2966 - val_accuracy: 0.8906 - val_precision: 0.9645 - val_recall: 0.8811
# Epoch 23/50
# 6/6 [==============================] - 2s 306ms/step - loss: 0.1895 - accuracy: 0.8699 - precision: 0.9553 - recall: 0.8613 - val_loss: 0.3060 - val_accuracy: 0.8809 - val_precision: 0.9599 - val_recall: 0.8720
# Epoch 24/50
# 6/6 [==============================] - 2s 297ms/step - loss: 0.1857 - accuracy: 0.8719 - precision: 0.9584 - recall: 0.8629 - val_loss: 0.2957 - val_accuracy: 0.8887 - val_precision: 0.9605 - val_recall: 0.8829
# Epoch 25/50
# 6/6 [==============================] - 2s 305ms/step - loss: 0.2009 - accuracy: 0.8656 - precision: 0.9469 - recall: 0.8627 - val_loss: 0.2997 - val_accuracy: 0.8848 - val_precision: 0.9588 - val_recall: 0.8787
# Epoch 26/50
# 6/6 [==============================] - 2s 305ms/step - loss: 0.1918 - accuracy: 0.8596 - precision: 0.9470 - recall: 0.8545 - val_loss: 0.2871 - val_accuracy: 0.8926 - val_precision: 0.9677 - val_recall: 0.8824
# Epoch 27/50
# 6/6 [==============================] - 2s 306ms/step - loss: 0.1837 - accuracy: 0.8790 - precision: 0.9515 - recall: 0.8804 - val_loss: 0.2955 - val_accuracy: 0.8867 - val_precision: 0.9590 - val_recall: 0.8816
# Epoch 28/50
# 6/6 [==============================] - 2s 297ms/step - loss: 0.1935 - accuracy: 0.8631 - precision: 0.9521 - recall: 0.8577 - val_loss: 0.3053 - val_accuracy: 0.8779 - val_precision: 0.9599 - val_recall: 0.8683
# Epoch 29/50
# 6/6 [==============================] - 2s 290ms/step - loss: 0.1886 - accuracy: 0.8680 - precision: 0.9540 - recall: 0.8629 - val_loss: 0.2958 - val_accuracy: 0.8857 - val_precision: 0.9674 - val_recall: 0.8730
# Epoch 30/50
# 6/6 [==============================] - 2s 309ms/step - loss: 0.1838 - accuracy: 0.8797 - precision: 0.9579 - recall: 0.8742 - val_loss: 0.2951 - val_accuracy: 0.8877 - val_precision: 0.9649 - val_recall: 0.8787
# Epoch 31/50
# 6/6 [==============================] - 2s 297ms/step - loss: 0.1919 - accuracy: 0.8682 - precision: 0.9548 - recall: 0.8579 - val_loss: 0.2958 - val_accuracy: 0.8828 - val_precision: 0.9631 - val_recall: 0.8728
# Epoch 32/50
# 6/6 [==============================] - 2s 290ms/step - loss: 0.1830 - accuracy: 0.8854 - precision: 0.9575 - recall: 0.8812 - val_loss: 0.2922 - val_accuracy: 0.8906 - val_precision: 0.9662 - val_recall: 0.8809
# Epoch 33/50
# 6/6 [==============================] - 2s 302ms/step - loss: 0.1829 - accuracy: 0.8712 - precision: 0.9508 - recall: 0.8677 - val_loss: 0.2987 - val_accuracy: 0.8848 - val_precision: 0.9617 - val_recall: 0.8763
# Epoch 34/50
# 6/6 [==============================] - 2s 294ms/step - loss: 0.1906 - accuracy: 0.8688 - precision: 0.9549 - recall: 0.8609 - val_loss: 0.2955 - val_accuracy: 0.8857 - val_precision: 0.9650 - val_recall: 0.8767
# Epoch 35/50
# 6/6 [==============================] - 2s 297ms/step - loss: 0.1806 - accuracy: 0.8759 - precision: 0.9583 - recall: 0.8681 - val_loss: 0.2958 - val_accuracy: 0.8848 - val_precision: 0.9617 - val_recall: 0.8765
# Epoch 36/50
# 6/6 [==============================] - 2s 289ms/step - loss: 0.1935 - accuracy: 0.8708 - precision: 0.9486 - recall: 0.8704 - val_loss: 0.2945 - val_accuracy: 0.8857 - val_precision: 0.9689 - val_recall: 0.8720
# 3/3 [==============================] - 49s 22s/step
# Learning Rate: 0.000569208412659075
# AUC score: 0.9632020187654753
# Test Recall: 0.8822143698468787
# Test Precision: 0.963963963963964
# Test F1 Scores: 0.921279212792128
#
#
# Learning Rate: 0.002092680561942426
# Epoch 1/50
# 6/6 [==============================] - 51s 4s/step - loss: 0.5695 - accuracy: 0.3961 - precision: 0.6646 - recall: 0.3275 - val_loss: 0.6026 - val_accuracy: 0.6826 - val_precision: 0.9370 - val_recall: 0.6106
# Epoch 2/50
# 6/6 [==============================] - 2s 303ms/step - loss: 0.3493 - accuracy: 0.6669 - precision: 0.8855 - recall: 0.6157 - val_loss: 0.3678 - val_accuracy: 0.8730 - val_precision: 0.9513 - val_recall: 0.8691
# Epoch 3/50
# 6/6 [==============================] - 2s 318ms/step - loss: 0.2368 - accuracy: 0.8404 - precision: 0.9336 - recall: 0.8404 - val_loss: 0.3048 - val_accuracy: 0.8779 - val_precision: 0.9508 - val_recall: 0.8783
# Epoch 4/50
# 6/6 [==============================] - 2s 295ms/step - loss: 0.2045 - accuracy: 0.8527 - precision: 0.9404 - recall: 0.8531 - val_loss: 0.2925 - val_accuracy: 0.8701 - val_precision: 0.9554 - val_recall: 0.8619
# Epoch 5/50
# 6/6 [==============================] - 2s 302ms/step - loss: 0.1906 - accuracy: 0.8538 - precision: 0.9503 - recall: 0.8439 - val_loss: 0.2514 - val_accuracy: 0.8916 - val_precision: 0.9564 - val_recall: 0.8947
# Epoch 6/50
# 6/6 [==============================] - 2s 298ms/step - loss: 0.1593 - accuracy: 0.8906 - precision: 0.9620 - recall: 0.8865 - val_loss: 0.2404 - val_accuracy: 0.8965 - val_precision: 0.9653 - val_recall: 0.8905
# Epoch 7/50
# 6/6 [==============================] - 2s 312ms/step - loss: 0.1597 - accuracy: 0.8889 - precision: 0.9637 - recall: 0.8807 - val_loss: 0.2425 - val_accuracy: 0.8984 - val_precision: 0.9681 - val_recall: 0.8907
# Epoch 8/50
# 6/6 [==============================] - 2s 298ms/step - loss: 0.1472 - accuracy: 0.9038 - precision: 0.9653 - recall: 0.9013 - val_loss: 0.2403 - val_accuracy: 0.8965 - val_precision: 0.9653 - val_recall: 0.8907
# Epoch 9/50
# 6/6 [==============================] - 2s 307ms/step - loss: 0.1661 - accuracy: 0.8799 - precision: 0.9531 - recall: 0.8762 - val_loss: 0.2356 - val_accuracy: 0.9023 - val_precision: 0.9686 - val_recall: 0.8970
# Epoch 10/50
# 6/6 [==============================] - 2s 314ms/step - loss: 0.1560 - accuracy: 0.8965 - precision: 0.9598 - recall: 0.8962 - val_loss: 0.2301 - val_accuracy: 0.9023 - val_precision: 0.9680 - val_recall: 0.8950
# Epoch 11/50
# 6/6 [==============================] - 2s 312ms/step - loss: 0.1318 - accuracy: 0.9116 - precision: 0.9748 - recall: 0.9046 - val_loss: 0.2259 - val_accuracy: 0.9033 - val_precision: 0.9680 - val_recall: 0.8964
# Epoch 12/50
# 6/6 [==============================] - 2s 300ms/step - loss: 0.1446 - accuracy: 0.9015 - precision: 0.9661 - recall: 0.8977 - val_loss: 0.2109 - val_accuracy: 0.9131 - val_precision: 0.9713 - val_recall: 0.9076
# Epoch 13/50
# 6/6 [==============================] - 2s 299ms/step - loss: 0.1385 - accuracy: 0.9132 - precision: 0.9713 - recall: 0.9098 - val_loss: 0.2128 - val_accuracy: 0.9092 - val_precision: 0.9684 - val_recall: 0.9048
# Epoch 14/50
# 6/6 [==============================] - 2s 296ms/step - loss: 0.1393 - accuracy: 0.9055 - precision: 0.9669 - recall: 0.9003 - val_loss: 0.2236 - val_accuracy: 0.9043 - val_precision: 0.9724 - val_recall: 0.8945
# Epoch 15/50
# 6/6 [==============================] - 2s 292ms/step - loss: 0.1398 - accuracy: 0.9006 - precision: 0.9704 - recall: 0.8902 - val_loss: 0.2203 - val_accuracy: 0.9062 - val_precision: 0.9722 - val_recall: 0.8962
# Epoch 16/50
# 6/6 [==============================] - 2s 301ms/step - loss: 0.1396 - accuracy: 0.9072 - precision: 0.9609 - recall: 0.9105 - val_loss: 0.2218 - val_accuracy: 0.9062 - val_precision: 0.9713 - val_recall: 0.8989
# Epoch 17/50
# 6/6 [==============================] - 2s 295ms/step - loss: 0.1390 - accuracy: 0.9054 - precision: 0.9658 - recall: 0.9015 - val_loss: 0.2049 - val_accuracy: 0.9131 - val_precision: 0.9702 - val_recall: 0.9096
# Epoch 18/50
# 6/6 [==============================] - 2s 304ms/step - loss: 0.1305 - accuracy: 0.9100 - precision: 0.9652 - recall: 0.9087 - val_loss: 0.2069 - val_accuracy: 0.9121 - val_precision: 0.9714 - val_recall: 0.9065
# Epoch 19/50
# 6/6 [==============================] - 2s 302ms/step - loss: 0.1325 - accuracy: 0.9079 - precision: 0.9653 - recall: 0.9079 - val_loss: 0.2083 - val_accuracy: 0.9131 - val_precision: 0.9701 - val_recall: 0.9092
# Epoch 20/50
# 6/6 [==============================] - 2s 299ms/step - loss: 0.1331 - accuracy: 0.9141 - precision: 0.9693 - recall: 0.9110 - val_loss: 0.2080 - val_accuracy: 0.9111 - val_precision: 0.9727 - val_recall: 0.9040
# Epoch 21/50
# 6/6 [==============================] - 2s 289ms/step - loss: 0.1331 - accuracy: 0.9102 - precision: 0.9631 - recall: 0.9124 - val_loss: 0.2045 - val_accuracy: 0.9160 - val_precision: 0.9798 - val_recall: 0.9041
# Epoch 22/50
# 6/6 [==============================] - 2s 302ms/step - loss: 0.1324 - accuracy: 0.9063 - precision: 0.9657 - recall: 0.9029 - val_loss: 0.2044 - val_accuracy: 0.9121 - val_precision: 0.9716 - val_recall: 0.9072
# Epoch 23/50
# 6/6 [==============================] - 2s 316ms/step - loss: 0.1373 - accuracy: 0.9089 - precision: 0.9692 - recall: 0.9038 - val_loss: 0.1978 - val_accuracy: 0.9189 - val_precision: 0.9714 - val_recall: 0.9152
# Epoch 24/50
# 6/6 [==============================] - 2s 308ms/step - loss: 0.1280 - accuracy: 0.9111 - precision: 0.9683 - recall: 0.9078 - val_loss: 0.2005 - val_accuracy: 0.9189 - val_precision: 0.9701 - val_recall: 0.9166
# Epoch 25/50
# 6/6 [==============================] - 2s 300ms/step - loss: 0.1335 - accuracy: 0.9113 - precision: 0.9676 - recall: 0.9080 - val_loss: 0.1971 - val_accuracy: 0.9189 - val_precision: 0.9755 - val_recall: 0.9111
# Epoch 26/50
# 6/6 [==============================] - 2s 308ms/step - loss: 0.1324 - accuracy: 0.9104 - precision: 0.9673 - recall: 0.9075 - val_loss: 0.2057 - val_accuracy: 0.9150 - val_precision: 0.9716 - val_recall: 0.9108
# Epoch 27/50
# 6/6 [==============================] - 2s 306ms/step - loss: 0.1246 - accuracy: 0.9120 - precision: 0.9732 - recall: 0.9061 - val_loss: 0.1932 - val_accuracy: 0.9229 - val_precision: 0.9732 - val_recall: 0.9199
# Epoch 28/50
# 6/6 [==============================] - 2s 322ms/step - loss: 0.1278 - accuracy: 0.9146 - precision: 0.9649 - recall: 0.9164 - val_loss: 0.1985 - val_accuracy: 0.9160 - val_precision: 0.9740 - val_recall: 0.9085
# Epoch 29/50
# 6/6 [==============================] - 2s 304ms/step - loss: 0.1222 - accuracy: 0.9237 - precision: 0.9787 - recall: 0.9170 - val_loss: 0.1998 - val_accuracy: 0.9189 - val_precision: 0.9758 - val_recall: 0.9121
# Epoch 30/50
# 6/6 [==============================] - 2s 303ms/step - loss: 0.1355 - accuracy: 0.9121 - precision: 0.9681 - recall: 0.9092 - val_loss: 0.1978 - val_accuracy: 0.9189 - val_precision: 0.9759 - val_recall: 0.9124
# Epoch 31/50
# 6/6 [==============================] - 2s 295ms/step - loss: 0.1304 - accuracy: 0.9120 - precision: 0.9648 - recall: 0.9134 - val_loss: 0.2032 - val_accuracy: 0.9160 - val_precision: 0.9743 - val_recall: 0.9095
# Epoch 32/50
# 6/6 [==============================] - 2s 293ms/step - loss: 0.1306 - accuracy: 0.9120 - precision: 0.9714 - recall: 0.9058 - val_loss: 0.2078 - val_accuracy: 0.9141 - val_precision: 0.9730 - val_recall: 0.9085
# Epoch 33/50
# 6/6 [==============================] - 2s 299ms/step - loss: 0.1291 - accuracy: 0.9166 - precision: 0.9722 - recall: 0.9104 - val_loss: 0.1903 - val_accuracy: 0.9238 - val_precision: 0.9756 - val_recall: 0.9177
# Epoch 34/50
# 6/6 [==============================] - 2s 309ms/step - loss: 0.1277 - accuracy: 0.9142 - precision: 0.9684 - recall: 0.9127 - val_loss: 0.2042 - val_accuracy: 0.9150 - val_precision: 0.9730 - val_recall: 0.9097
# Epoch 35/50
# 6/6 [==============================] - 2s 309ms/step - loss: 0.1285 - accuracy: 0.9139 - precision: 0.9711 - recall: 0.9105 - val_loss: 0.2023 - val_accuracy: 0.9170 - val_precision: 0.9689 - val_recall: 0.9158
# Epoch 36/50
# 6/6 [==============================] - 2s 305ms/step - loss: 0.1226 - accuracy: 0.9207 - precision: 0.9743 - recall: 0.9156 - val_loss: 0.2014 - val_accuracy: 0.9189 - val_precision: 0.9759 - val_recall: 0.9126
# Epoch 37/50
# 6/6 [==============================] - 2s 296ms/step - loss: 0.1250 - accuracy: 0.9221 - precision: 0.9771 - recall: 0.9142 - val_loss: 0.1989 - val_accuracy: 0.9199 - val_precision: 0.9716 - val_recall: 0.9169
# Epoch 38/50
# 6/6 [==============================] - 2s 301ms/step - loss: 0.1302 - accuracy: 0.9141 - precision: 0.9674 - recall: 0.9133 - val_loss: 0.2032 - val_accuracy: 0.9150 - val_precision: 0.9715 - val_recall: 0.9105
# Epoch 39/50
# 6/6 [==============================] - 2s 295ms/step - loss: 0.1288 - accuracy: 0.9152 - precision: 0.9702 - recall: 0.9121 - val_loss: 0.1978 - val_accuracy: 0.9229 - val_precision: 0.9745 - val_recall: 0.9187
# Epoch 40/50
# 6/6 [==============================] - 2s 304ms/step - loss: 0.1226 - accuracy: 0.9224 - precision: 0.9765 - recall: 0.9146 - val_loss: 0.1908 - val_accuracy: 0.9219 - val_precision: 0.9719 - val_recall: 0.9203
# Epoch 41/50
# 6/6 [==============================] - 2s 296ms/step - loss: 0.1311 - accuracy: 0.9139 - precision: 0.9755 - recall: 0.9056 - val_loss: 0.1963 - val_accuracy: 0.9219 - val_precision: 0.9784 - val_recall: 0.9128
# Epoch 42/50
# 6/6 [==============================] - 2s 289ms/step - loss: 0.1323 - accuracy: 0.9137 - precision: 0.9705 - recall: 0.9105 - val_loss: 0.1985 - val_accuracy: 0.9199 - val_precision: 0.9742 - val_recall: 0.9141
# Epoch 43/50
# 6/6 [==============================] - 2s 293ms/step - loss: 0.1267 - accuracy: 0.9119 - precision: 0.9734 - recall: 0.9064 - val_loss: 0.1987 - val_accuracy: 0.9189 - val_precision: 0.9692 - val_recall: 0.9190
# 3/3 [==============================] - 54s 23s/step
# Learning Rate: 0.002092680561942426
# AUC score: 0.9792580599284535
# Test Recall: 0.9187279151943463
# Test Precision: 0.9713574097135741
# Test F1 Scores: 0.9443099273607748
#
#
# Learning Rate: 0.0022019069759384234
# Epoch 1/50
# 6/6 [==============================] - 51s 4s/step - loss: 0.5261 - accuracy: 0.4184 - precision: 0.6821 - recall: 0.3742 - val_loss: 0.5934 - val_accuracy: 0.7070 - val_precision: 0.9576 - val_recall: 0.6295
# Epoch 2/50
# 6/6 [==============================] - 2s 308ms/step - loss: 0.3187 - accuracy: 0.6944 - precision: 0.9078 - recall: 0.6428 - val_loss: 0.3443 - val_accuracy: 0.8730 - val_precision: 0.9387 - val_recall: 0.8832
# Epoch 3/50
# 6/6 [==============================] - 2s 308ms/step - loss: 0.2282 - accuracy: 0.8499 - precision: 0.9330 - recall: 0.8549 - val_loss: 0.3459 - val_accuracy: 0.8604 - val_precision: 0.9648 - val_recall: 0.8400
# Epoch 4/50
# 6/6 [==============================] - 2s 306ms/step - loss: 0.1988 - accuracy: 0.8436 - precision: 0.9572 - recall: 0.8275 - val_loss: 0.2643 - val_accuracy: 0.9004 - val_precision: 0.9631 - val_recall: 0.8992
# Epoch 5/50
# 6/6 [==============================] - 2s 302ms/step - loss: 0.1711 - accuracy: 0.8875 - precision: 0.9546 - recall: 0.8918 - val_loss: 0.2545 - val_accuracy: 0.9043 - val_precision: 0.9686 - val_recall: 0.8992
# Epoch 6/50
# 6/6 [==============================] - 2s 309ms/step - loss: 0.1608 - accuracy: 0.8868 - precision: 0.9603 - recall: 0.8820 - val_loss: 0.2696 - val_accuracy: 0.8926 - val_precision: 0.9637 - val_recall: 0.8864
# Epoch 7/50
# 6/6 [==============================] - 2s 296ms/step - loss: 0.1501 - accuracy: 0.8962 - precision: 0.9691 - recall: 0.8862 - val_loss: 0.2413 - val_accuracy: 0.9023 - val_precision: 0.9711 - val_recall: 0.8938
# Epoch 8/50
# 6/6 [==============================] - 2s 306ms/step - loss: 0.1564 - accuracy: 0.8921 - precision: 0.9559 - recall: 0.8915 - val_loss: 0.2318 - val_accuracy: 0.9023 - val_precision: 0.9647 - val_recall: 0.9011
# Epoch 9/50
# 6/6 [==============================] - 2s 302ms/step - loss: 0.1457 - accuracy: 0.8956 - precision: 0.9634 - recall: 0.8901 - val_loss: 0.2280 - val_accuracy: 0.9033 - val_precision: 0.9708 - val_recall: 0.8938
# Epoch 10/50
# 6/6 [==============================] - 2s 318ms/step - loss: 0.1549 - accuracy: 0.8978 - precision: 0.9544 - recall: 0.9022 - val_loss: 0.2503 - val_accuracy: 0.8975 - val_precision: 0.9753 - val_recall: 0.8842
# Epoch 11/50
# 6/6 [==============================] - 2s 305ms/step - loss: 0.1454 - accuracy: 0.8983 - precision: 0.9710 - recall: 0.8895 - val_loss: 0.2354 - val_accuracy: 0.9033 - val_precision: 0.9711 - val_recall: 0.8947
# Epoch 12/50
# 6/6 [==============================] - 2s 291ms/step - loss: 0.1335 - accuracy: 0.9154 - precision: 0.9731 - recall: 0.9113 - val_loss: 0.2172 - val_accuracy: 0.9092 - val_precision: 0.9731 - val_recall: 0.9029
# Epoch 13/50
# 6/6 [==============================] - 2s 317ms/step - loss: 0.1393 - accuracy: 0.9051 - precision: 0.9618 - recall: 0.9071 - val_loss: 0.2225 - val_accuracy: 0.9033 - val_precision: 0.9683 - val_recall: 0.8973
# Epoch 14/50
# 6/6 [==============================] - 2s 321ms/step - loss: 0.1341 - accuracy: 0.9139 - precision: 0.9706 - recall: 0.9089 - val_loss: 0.2255 - val_accuracy: 0.9023 - val_precision: 0.9738 - val_recall: 0.8908
# Epoch 15/50
# 6/6 [==============================] - 2s 289ms/step - loss: 0.1474 - accuracy: 0.9001 - precision: 0.9604 - recall: 0.8982 - val_loss: 0.2219 - val_accuracy: 0.9062 - val_precision: 0.9767 - val_recall: 0.8936
# Epoch 16/50
# 6/6 [==============================] - 2s 289ms/step - loss: 0.1270 - accuracy: 0.9162 - precision: 0.9730 - recall: 0.9105 - val_loss: 0.2227 - val_accuracy: 0.9102 - val_precision: 0.9740 - val_recall: 0.9009
# Epoch 17/50
# 6/6 [==============================] - 2s 289ms/step - loss: 0.1410 - accuracy: 0.9023 - precision: 0.9695 - recall: 0.8955 - val_loss: 0.2127 - val_accuracy: 0.9121 - val_precision: 0.9698 - val_recall: 0.9071
# Epoch 18/50
# 6/6 [==============================] - 2s 302ms/step - loss: 0.1298 - accuracy: 0.9164 - precision: 0.9668 - recall: 0.9161 - val_loss: 0.2214 - val_accuracy: 0.9062 - val_precision: 0.9725 - val_recall: 0.8972
# Epoch 19/50
# 6/6 [==============================] - 2s 308ms/step - loss: 0.1261 - accuracy: 0.9159 - precision: 0.9700 - recall: 0.9119 - val_loss: 0.2215 - val_accuracy: 0.9062 - val_precision: 0.9711 - val_recall: 0.8984
# Epoch 20/50
# 6/6 [==============================] - 2s 287ms/step - loss: 0.1303 - accuracy: 0.9176 - precision: 0.9674 - recall: 0.9184 - val_loss: 0.2196 - val_accuracy: 0.9062 - val_precision: 0.9753 - val_recall: 0.8948
# Epoch 21/50
# 6/6 [==============================] - 2s 284ms/step - loss: 0.1272 - accuracy: 0.9123 - precision: 0.9719 - recall: 0.9072 - val_loss: 0.2149 - val_accuracy: 0.9121 - val_precision: 0.9726 - val_recall: 0.9047
# Epoch 22/50
# 6/6 [==============================] - 2s 284ms/step - loss: 0.1233 - accuracy: 0.9226 - precision: 0.9722 - recall: 0.9206 - val_loss: 0.2072 - val_accuracy: 0.9131 - val_precision: 0.9713 - val_recall: 0.9074
# Epoch 23/50
# 6/6 [==============================] - 2s 298ms/step - loss: 0.1326 - accuracy: 0.9136 - precision: 0.9664 - recall: 0.9114 - val_loss: 0.2175 - val_accuracy: 0.9082 - val_precision: 0.9698 - val_recall: 0.9024
# Epoch 24/50
# 6/6 [==============================] - 2s 293ms/step - loss: 0.1371 - accuracy: 0.9072 - precision: 0.9658 - recall: 0.9050 - val_loss: 0.1976 - val_accuracy: 0.9219 - val_precision: 0.9731 - val_recall: 0.9184
# Epoch 25/50
# 6/6 [==============================] - 2s 304ms/step - loss: 0.1339 - accuracy: 0.9115 - precision: 0.9666 - recall: 0.9096 - val_loss: 0.1996 - val_accuracy: 0.9131 - val_precision: 0.9741 - val_recall: 0.9051
# Epoch 26/50
# 6/6 [==============================] - 2s 295ms/step - loss: 0.1325 - accuracy: 0.9116 - precision: 0.9699 - recall: 0.9064 - val_loss: 0.2154 - val_accuracy: 0.9121 - val_precision: 0.9727 - val_recall: 0.9052
# Epoch 27/50
# 6/6 [==============================] - 2s 287ms/step - loss: 0.1215 - accuracy: 0.9151 - precision: 0.9683 - recall: 0.9156 - val_loss: 0.2084 - val_accuracy: 0.9141 - val_precision: 0.9765 - val_recall: 0.9024
# Epoch 28/50
# 6/6 [==============================] - 2s 296ms/step - loss: 0.1376 - accuracy: 0.9120 - precision: 0.9679 - recall: 0.9100 - val_loss: 0.1979 - val_accuracy: 0.9131 - val_precision: 0.9766 - val_recall: 0.9016
# Epoch 29/50
# 6/6 [==============================] - 2s 286ms/step - loss: 0.1301 - accuracy: 0.9136 - precision: 0.9698 - recall: 0.9104 - val_loss: 0.1963 - val_accuracy: 0.9199 - val_precision: 0.9745 - val_recall: 0.9148
# Epoch 30/50
# 6/6 [==============================] - 2s 304ms/step - loss: 0.1333 - accuracy: 0.9155 - precision: 0.9689 - recall: 0.9113 - val_loss: 0.2094 - val_accuracy: 0.9121 - val_precision: 0.9752 - val_recall: 0.9015
# Epoch 31/50
# 6/6 [==============================] - 2s 298ms/step - loss: 0.1299 - accuracy: 0.9055 - precision: 0.9650 - recall: 0.9033 - val_loss: 0.2071 - val_accuracy: 0.9150 - val_precision: 0.9733 - val_recall: 0.9105
# Epoch 32/50
# 6/6 [==============================] - 2s 297ms/step - loss: 0.1269 - accuracy: 0.9168 - precision: 0.9673 - recall: 0.9160 - val_loss: 0.2118 - val_accuracy: 0.9141 - val_precision: 0.9742 - val_recall: 0.9065
# Epoch 33/50
# 6/6 [==============================] - 2s 295ms/step - loss: 0.1303 - accuracy: 0.9114 - precision: 0.9690 - recall: 0.9077 - val_loss: 0.2096 - val_accuracy: 0.9111 - val_precision: 0.9755 - val_recall: 0.9016
# Epoch 34/50
# 6/6 [==============================] - 2s 298ms/step - loss: 0.1167 - accuracy: 0.9280 - precision: 0.9762 - recall: 0.9256 - val_loss: 0.2003 - val_accuracy: 0.9170 - val_precision: 0.9728 - val_recall: 0.9115
# Epoch 35/50
# 6/6 [==============================] - 2s 308ms/step - loss: 0.1231 - accuracy: 0.9233 - precision: 0.9660 - recall: 0.9282 - val_loss: 0.2060 - val_accuracy: 0.9092 - val_precision: 0.9726 - val_recall: 0.9011
# Epoch 36/50
# 6/6 [==============================] - 2s 299ms/step - loss: 0.1251 - accuracy: 0.9153 - precision: 0.9711 - recall: 0.9107 - val_loss: 0.2032 - val_accuracy: 0.9170 - val_precision: 0.9743 - val_recall: 0.9105
# Epoch 37/50
# 6/6 [==============================] - 2s 300ms/step - loss: 0.1280 - accuracy: 0.9088 - precision: 0.9641 - recall: 0.9099 - val_loss: 0.2101 - val_accuracy: 0.9092 - val_precision: 0.9738 - val_recall: 0.8993
# Epoch 38/50
# 6/6 [==============================] - 2s 298ms/step - loss: 0.1220 - accuracy: 0.9187 - precision: 0.9755 - recall: 0.9122 - val_loss: 0.2049 - val_accuracy: 0.9141 - val_precision: 0.9742 - val_recall: 0.9067
# Epoch 39/50
# 6/6 [==============================] - 2s 295ms/step - loss: 0.1272 - accuracy: 0.9175 - precision: 0.9725 - recall: 0.9117 - val_loss: 0.2085 - val_accuracy: 0.9121 - val_precision: 0.9754 - val_recall: 0.9024
# 3/3 [==============================] - 49s 22s/step
# Learning Rate: 0.0022019069759384234
# AUC score: 0.9792653531563268
# Test Recall: 0.9187279151943463
# Test Precision: 0.9713574097135741
# Test F1 Scores: 0.9443099273607748
#
#
# Learning Rate: 0.0015055403605162138
# Epoch 1/50
# 6/6 [==============================] - 50s 4s/step - loss: 0.5786 - accuracy: 0.3717 - precision: 0.6270 - recall: 0.3395 - val_loss: 0.6848 - val_accuracy: 0.5537 - val_precision: 0.8425 - val_recall: 0.4745
# Epoch 2/50
# 6/6 [==============================] - 2s 303ms/step - loss: 0.3915 - accuracy: 0.6211 - precision: 0.8137 - recall: 0.6217 - val_loss: 0.4576 - val_accuracy: 0.8418 - val_precision: 0.9290 - val_recall: 0.8501
# Epoch 3/50
# 6/6 [==============================] - 2s 306ms/step - loss: 0.2809 - accuracy: 0.7791 - precision: 0.9106 - recall: 0.7762 - val_loss: 0.3966 - val_accuracy: 0.8525 - val_precision: 0.9559 - val_recall: 0.8373
# Epoch 4/50
# 6/6 [==============================] - 2s 298ms/step - loss: 0.2349 - accuracy: 0.8132 - precision: 0.9391 - recall: 0.7933 - val_loss: 0.3227 - val_accuracy: 0.8838 - val_precision: 0.9511 - val_recall: 0.8862
# Epoch 5/50
# 6/6 [==============================] - 2s 315ms/step - loss: 0.2008 - accuracy: 0.8752 - precision: 0.9500 - recall: 0.8762 - val_loss: 0.2961 - val_accuracy: 0.8916 - val_precision: 0.9517 - val_recall: 0.8969
# Epoch 6/50
# 6/6 [==============================] - 2s 304ms/step - loss: 0.1971 - accuracy: 0.8675 - precision: 0.9418 - recall: 0.8725 - val_loss: 0.2914 - val_accuracy: 0.8857 - val_precision: 0.9589 - val_recall: 0.8802
# Epoch 7/50
# 6/6 [==============================] - 2s 324ms/step - loss: 0.1943 - accuracy: 0.8660 - precision: 0.9522 - recall: 0.8582 - val_loss: 0.2722 - val_accuracy: 0.8984 - val_precision: 0.9603 - val_recall: 0.8992
# Epoch 8/50
# 6/6 [==============================] - 2s 308ms/step - loss: 0.1779 - accuracy: 0.8860 - precision: 0.9537 - recall: 0.8861 - val_loss: 0.2612 - val_accuracy: 0.9043 - val_precision: 0.9655 - val_recall: 0.9007
# Epoch 9/50
# 6/6 [==============================] - 2s 304ms/step - loss: 0.1829 - accuracy: 0.8776 - precision: 0.9488 - recall: 0.8786 - val_loss: 0.2632 - val_accuracy: 0.9043 - val_precision: 0.9680 - val_recall: 0.8976
# Epoch 10/50
# 6/6 [==============================] - 2s 299ms/step - loss: 0.1639 - accuracy: 0.8898 - precision: 0.9662 - recall: 0.8818 - val_loss: 0.2620 - val_accuracy: 0.9004 - val_precision: 0.9667 - val_recall: 0.8942
# Epoch 11/50
# 6/6 [==============================] - 2s 293ms/step - loss: 0.1647 - accuracy: 0.8836 - precision: 0.9610 - recall: 0.8766 - val_loss: 0.2407 - val_accuracy: 0.9121 - val_precision: 0.9644 - val_recall: 0.9124
# Epoch 12/50
# 6/6 [==============================] - 2s 301ms/step - loss: 0.1568 - accuracy: 0.8973 - precision: 0.9573 - recall: 0.9026 - val_loss: 0.2430 - val_accuracy: 0.9062 - val_precision: 0.9596 - val_recall: 0.9114
# Epoch 13/50
# ...
# Epoch 11/50
# 6/6 [==============================] - 2s 304ms/step - loss: 0.0994 - accuracy: 0.9322 - precision: 0.9757 - recall: 0.9323 - val_loss: 0.1506 - val_accuracy: 0.9326 - val_precision: 0.9775 - val_recall: 0.9290
# Epoch 12/50
# 6/6 [==============================] - 2s 305ms/step - loss: 0.0960 - accuracy: 0.9370 - precision: 0.9763 - recall: 0.9356 - val_loss: 0.1580 - val_accuracy: 0.9307 - val_precision: 0.9787 - val_recall: 0.9249
# Epoch 13/50
# 6/6 [==============================] - 2s 317ms/step - loss: 0.0998 - accuracy: 0.9340 - precision: 0.9809 - recall: 0.9296 - val_loss: 0.1376 - val_accuracy: 0.9463 - val_precision: 0.9808 - val_recall: 0.9459
# Epoch 14/50
# 6/6 [==============================] - 2s 304ms/step - loss: 0.0983 - accuracy: 0.9429 - precision: 0.9761 - recall: 0.9456 - val_loss: 0.1518 - val_accuracy: 0.9346 - val_precision: 0.9817 - val_recall: 0.9282
# Epoch 15/50
# 6/6 [==============================] - 2s 316ms/step - loss: 0.0940 - accuracy: 0.9391 - precision: 0.9787 - recall: 0.9374 - val_loss: 0.1389 - val_accuracy: 0.9385 - val_precision: 0.9846 - val_recall: 0.9310
# Epoch 16/50
# 6/6 [==============================] - 2s 292ms/step - loss: 0.1001 - accuracy: 0.9349 - precision: 0.9796 - recall: 0.9313 - val_loss: 0.1281 - val_accuracy: 0.9512 - val_precision: 0.9834 - val_recall: 0.9492
# Epoch 17/50
# 6/6 [==============================] - 2s 302ms/step - loss: 0.0913 - accuracy: 0.9472 - precision: 0.9834 - recall: 0.9430 - val_loss: 0.1423 - val_accuracy: 0.9375 - val_precision: 0.9830 - val_recall: 0.9304
# Epoch 18/50
# 6/6 [==============================] - 2s 299ms/step - loss: 0.0925 - accuracy: 0.9394 - precision: 0.9803 - recall: 0.9353 - val_loss: 0.1441 - val_accuracy: 0.9355 - val_precision: 0.9788 - val_recall: 0.9315
# Epoch 19/50
# 6/6 [==============================] - 2s 300ms/step - loss: 0.0892 - accuracy: 0.9443 - precision: 0.9828 - recall: 0.9404 - val_loss: 0.1371 - val_accuracy: 0.9434 - val_precision: 0.9817 - val_recall: 0.9395
# Epoch 20/50
# 6/6 [==============================] - 2s 292ms/step - loss: 0.0955 - accuracy: 0.9419 - precision: 0.9808 - recall: 0.9393 - val_loss: 0.1322 - val_accuracy: 0.9424 - val_precision: 0.9847 - val_recall: 0.9364
# Epoch 21/50
# 6/6 [==============================] - 2s 308ms/step - loss: 0.0926 - accuracy: 0.9404 - precision: 0.9783 - recall: 0.9398 - val_loss: 0.1375 - val_accuracy: 0.9395 - val_precision: 0.9834 - val_recall: 0.9344
# Epoch 22/50
# 6/6 [==============================] - 2s 302ms/step - loss: 0.0912 - accuracy: 0.9421 - precision: 0.9790 - recall: 0.9404 - val_loss: 0.1421 - val_accuracy: 0.9395 - val_precision: 0.9803 - val_recall: 0.9354
# Epoch 23/50
# 6/6 [==============================] - 2s 301ms/step - loss: 0.0877 - accuracy: 0.9465 - precision: 0.9843 - recall: 0.9411 - val_loss: 0.1366 - val_accuracy: 0.9395 - val_precision: 0.9788 - val_recall: 0.9366
# Epoch 24/50
# 6/6 [==============================] - 2s 307ms/step - loss: 0.0908 - accuracy: 0.9407 - precision: 0.9825 - recall: 0.9345 - val_loss: 0.1379 - val_accuracy: 0.9424 - val_precision: 0.9806 - val_recall: 0.9402
# Epoch 25/50
# 6/6 [==============================] - 2s 301ms/step - loss: 0.0945 - accuracy: 0.9396 - precision: 0.9768 - recall: 0.9391 - val_loss: 0.1337 - val_accuracy: 0.9414 - val_precision: 0.9832 - val_recall: 0.9359
# Epoch 26/50
# 6/6 [==============================] - 2s 290ms/step - loss: 0.0932 - accuracy: 0.9333 - precision: 0.9775 - recall: 0.9302 - val_loss: 0.1340 - val_accuracy: 0.9434 - val_precision: 0.9806 - val_recall: 0.9416
# 3/3 [==============================] - 52s 22s/step
# Learning Rate: 0.010395482487874017
# AUC score: 0.9862012128637954
# Test Recall: 0.9517078916372202
# Test Precision: 0.9688249400479616
# Test F1 Scores: 0.960190136660725
#
#
# Learning Rate: 0.0019613680133445405
# Epoch 1/50
# 6/6 [==============================] - 51s 4s/step - loss: 0.4936 - accuracy: 0.5809 - precision: 0.7694 - recall: 0.6110 - val_loss: 0.6176 - val_accuracy: 0.6729 - val_precision: 0.9619 - val_recall: 0.5743
# Epoch 2/50
# 6/6 [==============================] - 2s 313ms/step - loss: 0.3201 - accuracy: 0.6981 - precision: 0.8844 - recall: 0.6802 - val_loss: 0.3521 - val_accuracy: 0.8760 - val_precision: 0.9019 - val_recall: 0.9320
# Epoch 3/50
# 6/6 [==============================] - 2s 309ms/step - loss: 0.2584 - accuracy: 0.8403 - precision: 0.9022 - recall: 0.8748 - val_loss: 0.3905 - val_accuracy: 0.8564 - val_precision: 0.9733 - val_recall: 0.8264
# Epoch 4/50
# 6/6 [==============================] - 2s 297ms/step - loss: 0.2186 - accuracy: 0.8146 - precision: 0.9599 - recall: 0.7818 - val_loss: 0.3131 - val_accuracy: 0.8848 - val_precision: 0.9606 - val_recall: 0.8787
# Epoch 5/50
# 6/6 [==============================] - 2s 311ms/step - loss: 0.1932 - accuracy: 0.8686 - precision: 0.9493 - recall: 0.8686 - val_loss: 0.2601 - val_accuracy: 0.9053 - val_precision: 0.9530 - val_recall: 0.9163
# Epoch 6/50
# 6/6 [==============================] - 2s 303ms/step - loss: 0.1817 - accuracy: 0.8884 - precision: 0.9448 - recall: 0.8995 - val_loss: 0.2729 - val_accuracy: 0.8975 - val_precision: 0.9653 - val_recall: 0.8917
# Epoch 7/50
# 6/6 [==============================] - 2s 312ms/step - loss: 0.1778 - accuracy: 0.8773 - precision: 0.9555 - recall: 0.8710 - val_loss: 0.2768 - val_accuracy: 0.8955 - val_precision: 0.9717 - val_recall: 0.8812
# Epoch 8/50
# 6/6 [==============================] - 2s 312ms/step - loss: 0.1733 - accuracy: 0.8785 - precision: 0.9586 - recall: 0.8712 - val_loss: 0.2531 - val_accuracy: 0.9014 - val_precision: 0.9670 - val_recall: 0.8963
# Epoch 9/50
# 6/6 [==============================] - 2s 312ms/step - loss: 0.1625 - accuracy: 0.8898 - precision: 0.9558 - recall: 0.8898 - val_loss: 0.2433 - val_accuracy: 0.9053 - val_precision: 0.9671 - val_recall: 0.9015
# Epoch 10/50
# 6/6 [==============================] - 2s 312ms/step - loss: 0.1596 - accuracy: 0.8916 - precision: 0.9598 - recall: 0.8905 - val_loss: 0.2547 - val_accuracy: 0.8965 - val_precision: 0.9681 - val_recall: 0.8881
# Epoch 11/50
# 6/6 [==============================] - 2s 307ms/step - loss: 0.1513 - accuracy: 0.8920 - precision: 0.9612 - recall: 0.8902 - val_loss: 0.2443 - val_accuracy: 0.8994 - val_precision: 0.9711 - val_recall: 0.8902
# Epoch 12/50
# 6/6 [==============================] - 2s 305ms/step - loss: 0.1563 - accuracy: 0.8921 - precision: 0.9631 - recall: 0.8867 - val_loss: 0.2418 - val_accuracy: 0.9043 - val_precision: 0.9654 - val_recall: 0.9005
# Epoch 13/50
# 6/6 [==============================] - 2s 322ms/step - loss: 0.1506 - accuracy: 0.8992 - precision: 0.9619 - recall: 0.8971 - val_loss: 0.2367 - val_accuracy: 0.9092 - val_precision: 0.9660 - val_recall: 0.9080
# Epoch 14/50
# 6/6 [==============================] - 2s 310ms/step - loss: 0.1471 - accuracy: 0.8942 - precision: 0.9607 - recall: 0.8915 - val_loss: 0.2303 - val_accuracy: 0.9102 - val_precision: 0.9687 - val_recall: 0.9067
# Epoch 15/50
# 6/6 [==============================] - 2s 297ms/step - loss: 0.1488 - accuracy: 0.8963 - precision: 0.9624 - recall: 0.8921 - val_loss: 0.2248 - val_accuracy: 0.9141 - val_precision: 0.9714 - val_recall: 0.9091
# Epoch 16/50
# 6/6 [==============================] - 2s 306ms/step - loss: 0.1554 - accuracy: 0.8975 - precision: 0.9578 - recall: 0.8973 - val_loss: 0.2343 - val_accuracy: 0.9053 - val_precision: 0.9694 - val_recall: 0.8976
# Epoch 17/50
# 6/6 [==============================] - 2s 298ms/step - loss: 0.1460 - accuracy: 0.9098 - precision: 0.9697 - recall: 0.9043 - val_loss: 0.2321 - val_accuracy: 0.9072 - val_precision: 0.9712 - val_recall: 0.9000
# Epoch 18/50
# 6/6 [==============================] - 2s 303ms/step - loss: 0.1457 - accuracy: 0.9054 - precision: 0.9639 - recall: 0.9033 - val_loss: 0.2282 - val_accuracy: 0.9072 - val_precision: 0.9681 - val_recall: 0.9015
# Epoch 19/50
# 6/6 [==============================] - 2s 298ms/step - loss: 0.1372 - accuracy: 0.9019 - precision: 0.9670 - recall: 0.8974 - val_loss: 0.2262 - val_accuracy: 0.9131 - val_precision: 0.9755 - val_recall: 0.9040
# Epoch 20/50
# 6/6 [==============================] - 2s 294ms/step - loss: 0.1390 - accuracy: 0.9073 - precision: 0.9676 - recall: 0.9037 - val_loss: 0.2245 - val_accuracy: 0.9150 - val_precision: 0.9700 - val_recall: 0.9113
# Epoch 21/50
# 6/6 [==============================] - 2s 299ms/step - loss: 0.1402 - accuracy: 0.9033 - precision: 0.9634 - recall: 0.9029 - val_loss: 0.2254 - val_accuracy: 0.9150 - val_precision: 0.9730 - val_recall: 0.9096
# Epoch 22/50
# 6/6 [==============================] - 2s 297ms/step - loss: 0.1341 - accuracy: 0.9131 - precision: 0.9739 - recall: 0.9051 - val_loss: 0.2156 - val_accuracy: 0.9180 - val_precision: 0.9730 - val_recall: 0.9132
# Epoch 23/50
# 6/6 [==============================] - 2s 303ms/step - loss: 0.1377 - accuracy: 0.9084 - precision: 0.9675 - recall: 0.9056 - val_loss: 0.2126 - val_accuracy: 0.9199 - val_precision: 0.9730 - val_recall: 0.9157
# Epoch 24/50
# 6/6 [==============================] - 2s 313ms/step - loss: 0.1492 - accuracy: 0.9016 - precision: 0.9596 - recall: 0.9034 - val_loss: 0.2253 - val_accuracy: 0.9131 - val_precision: 0.9696 - val_recall: 0.9079
# Epoch 25/50
# 6/6 [==============================] - 2s 306ms/step - loss: 0.1470 - accuracy: 0.8990 - precision: 0.9616 - recall: 0.8969 - val_loss: 0.2201 - val_accuracy: 0.9131 - val_precision: 0.9725 - val_recall: 0.9057
# Epoch 26/50
# 6/6 [==============================] - 2s 305ms/step - loss: 0.1297 - accuracy: 0.9173 - precision: 0.9760 - recall: 0.9093 - val_loss: 0.2195 - val_accuracy: 0.9121 - val_precision: 0.9715 - val_recall: 0.9068
# Epoch 27/50
# 6/6 [==============================] - 2s 305ms/step - loss: 0.1437 - accuracy: 0.9004 - precision: 0.9642 - recall: 0.8973 - val_loss: 0.2229 - val_accuracy: 0.9131 - val_precision: 0.9738 - val_recall: 0.9042
# Epoch 28/50
# 6/6 [==============================] - 2s 296ms/step - loss: 0.1340 - accuracy: 0.9088 - precision: 0.9699 - recall: 0.9044 - val_loss: 0.2197 - val_accuracy: 0.9160 - val_precision: 0.9730 - val_recall: 0.9109
# Epoch 29/50
# 6/6 [==============================] - 2s 293ms/step - loss: 0.1352 - accuracy: 0.9113 - precision: 0.9677 - recall: 0.9081 - val_loss: 0.2136 - val_accuracy: 0.9180 - val_precision: 0.9743 - val_recall: 0.9118
# Epoch 30/50
# 6/6 [==============================] - 2s 305ms/step - loss: 0.1321 - accuracy: 0.9137 - precision: 0.9676 - recall: 0.9132 - val_loss: 0.2084 - val_accuracy: 0.9170 - val_precision: 0.9757 - val_recall: 0.9093
# Epoch 31/50
# 6/6 [==============================] - 2s 303ms/step - loss: 0.1353 - accuracy: 0.9182 - precision: 0.9693 - recall: 0.9159 - val_loss: 0.2068 - val_accuracy: 0.9180 - val_precision: 0.9725 - val_recall: 0.9119
# Epoch 32/50
# 6/6 [==============================] - 2s 305ms/step - loss: 0.1400 - accuracy: 0.9065 - precision: 0.9651 - recall: 0.9049 - val_loss: 0.2159 - val_accuracy: 0.9141 - val_precision: 0.9771 - val_recall: 0.9046
# Epoch 33/50
# 6/6 [==============================] - 2s 297ms/step - loss: 0.1329 - accuracy: 0.9056 - precision: 0.9677 - recall: 0.8995 - val_loss: 0.2087 - val_accuracy: 0.9199 - val_precision: 0.9759 - val_recall: 0.9136
# Epoch 34/50
# 6/6 [==============================] - 2s 298ms/step - loss: 0.1476 - accuracy: 0.8949 - precision: 0.9581 - recall: 0.8940 - val_loss: 0.2210 - val_accuracy: 0.9121 - val_precision: 0.9724 - val_recall: 0.9042
# Epoch 35/50
# 6/6 [==============================] - 2s 304ms/step - loss: 0.1370 - accuracy: 0.9086 - precision: 0.9655 - recall: 0.9082 - val_loss: 0.2170 - val_accuracy: 0.9170 - val_precision: 0.9788 - val_recall: 0.9083
# Epoch 36/50
# 6/6 [==============================] - 2s 311ms/step - loss: 0.1401 - accuracy: 0.9068 - precision: 0.9661 - recall: 0.9044 - val_loss: 0.2201 - val_accuracy: 0.9150 - val_precision: 0.9713 - val_recall: 0.9101
# Epoch 37/50
# 6/6 [==============================] - 2s 301ms/step - loss: 0.1319 - accuracy: 0.9106 - precision: 0.9683 - recall: 0.9088 - val_loss: 0.2226 - val_accuracy: 0.9111 - val_precision: 0.9740 - val_recall: 0.9021
# Epoch 38/50
# 6/6 [==============================] - 2s 307ms/step - loss: 0.1436 - accuracy: 0.9088 - precision: 0.9638 - recall: 0.9081 - val_loss: 0.2106 - val_accuracy: 0.9160 - val_precision: 0.9740 - val_recall: 0.9082
# Epoch 39/50
# 6/6 [==============================] - 2s 301ms/step - loss: 0.1362 - accuracy: 0.9150 - precision: 0.9671 - recall: 0.9130 - val_loss: 0.2157 - val_accuracy: 0.9180 - val_precision: 0.9756 - val_recall: 0.9104
# Epoch 40/50
# 6/6 [==============================] - 2s 316ms/step - loss: 0.1464 - accuracy: 0.8998 - precision: 0.9612 - recall: 0.8981 - val_loss: 0.2140 - val_accuracy: 0.9170 - val_precision: 0.9741 - val_recall: 0.9098
# Epoch 41/50
# 6/6 [==============================] - 2s 301ms/step - loss: 0.1315 - accuracy: 0.9204 - precision: 0.9739 - recall: 0.9152 - val_loss: 0.2136 - val_accuracy: 0.9180 - val_precision: 0.9758 - val_recall: 0.9110
# 3/3 [==============================] - 49s 22s/step
# Learning Rate: 0.0019613680133445405
# AUC score: 0.9762678365004175
# Test Recall: 0.9140164899882215
# Test Precision: 0.9712140175219024
# Test F1 Scores: 0.941747572815534
#
#
# Learning Rate: 0.0001353518339796301
# Epoch 1/50
# 6/6 [==============================] - 51s 4s/step - loss: 0.6906 - accuracy: 0.6611 - precision: 0.7067 - recall: 0.9036 - val_loss: 0.6785 - val_accuracy: 0.6787 - val_precision: 0.7159 - val_recall: 0.9277
# Epoch 2/50
# 6/6 [==============================] - 2s 311ms/step - loss: 0.5606 - accuracy: 0.6237 - precision: 0.7279 - recall: 0.7863 - val_loss: 0.6902 - val_accuracy: 0.6113 - val_precision: 0.7054 - val_recall: 0.8035
# Epoch 3/50
# 6/6 [==============================] - 2s 320ms/step - loss: 0.5314 - accuracy: 0.5771 - precision: 0.7165 - recall: 0.7005 - val_loss: 0.6996 - val_accuracy: 0.5615 - val_precision: 0.7139 - val_recall: 0.6751
# Epoch 4/50
# 6/6 [==============================] - 2s 311ms/step - loss: 0.4960 - accuracy: 0.5371 - precision: 0.7191 - recall: 0.6074 - val_loss: 0.7181 - val_accuracy: 0.5293 - val_precision: 0.7210 - val_recall: 0.5758
# Epoch 5/50
# 6/6 [==============================] - 2s 306ms/step - loss: 0.4901 - accuracy: 0.5020 - precision: 0.7165 - recall: 0.5292 - val_loss: 0.7298 - val_accuracy: 0.5186 - val_precision: 0.7548 - val_recall: 0.5165
# Epoch 6/50
# 6/6 [==============================] - 2s 294ms/step - loss: 0.4743 - accuracy: 0.4885 - precision: 0.7187 - recall: 0.4947 - val_loss: 0.7319 - val_accuracy: 0.5059 - val_precision: 0.7510 - val_recall: 0.4894
# Epoch 7/50
# 6/6 [==============================] - 2s 294ms/step - loss: 0.4816 - accuracy: 0.4954 - precision: 0.7219 - recall: 0.4891 - val_loss: 0.7283 - val_accuracy: 0.5146 - val_precision: 0.7558 - val_recall: 0.4851
# Epoch 8/50
# 6/6 [==============================] - 2s 303ms/step - loss: 0.4586 - accuracy: 0.5185 - precision: 0.7466 - recall: 0.5045 - val_loss: 0.7157 - val_accuracy: 0.5332 - val_precision: 0.7710 - val_recall: 0.5074
# Epoch 9/50
# 6/6 [==============================] - 2s 313ms/step - loss: 0.4631 - accuracy: 0.5132 - precision: 0.7516 - recall: 0.4979 - val_loss: 0.7046 - val_accuracy: 0.5537 - val_precision: 0.7938 - val_recall: 0.5189
# Epoch 10/50
# 6/6 [==============================] - 2s 301ms/step - loss: 0.4489 - accuracy: 0.5317 - precision: 0.7666 - recall: 0.5140 - val_loss: 0.7005 - val_accuracy: 0.5576 - val_precision: 0.8049 - val_recall: 0.5227
# Epoch 11/50
# 6/6 [==============================] - 2s 292ms/step - loss: 0.4397 - accuracy: 0.5502 - precision: 0.7811 - recall: 0.5363 - val_loss: 0.6893 - val_accuracy: 0.5742 - val_precision: 0.8196 - val_recall: 0.5417
# 3/3 [==============================] - 50s 22s/step
# Learning Rate: 0.0001353518339796301
# AUC score: 0.35442534834279626
# Test Recall: 0.9069493521790342
# Test Precision: 0.7090239410681399
# Test F1 Scores: 0.7958656330749355
